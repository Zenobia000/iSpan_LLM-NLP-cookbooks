# %% [markdown]
# # IA3 實戰：以 (IA)3 微調繁中聊天機器人
#
# ## 學習目標
#
# 1. 理解 (IA)3（Infused Adapter by Inhibiting and Amplifying Inner Activations）的原理，以及它與 LoRA 的核心差異。
# 2. 掌握 2026 版 PEFT 統一寫法：`device_map='auto'`、`torch.bfloat16`、`use_safetensors=True`。
# 3. 學會以 `tokenizer.apply_chat_template()` 取代手寫 `Human:/Assistant:` 格式，建立訓練/推論一致的對話模板。
# 4. 使用 `trl.SFTTrainer` 自動處理 `-100` 標籤遮罩，並對照底層手刻版理解機制。
# 5. 完成訓練後以 `push_to_hub` 發布並撰寫最小 model card。
#
# ## 前置條件
#
# - 已完成 `../01-LoRA/chatbot_lora.ipynb`（LoRA 基礎概念）
# - GPU VRAM >= 8 GB（訓練 bloom-1b4-zh + IA3；無 GPU 可改用 4-bit 量化，見下方備注）
#
# ## 與相鄰 notebook 的銜接
#
# | 方向 | Notebook | 關聯 |
# |------|----------|------|
# | 前一章 | [`../01-LoRA/chatbot_lora.ipynb`](../01-LoRA/chatbot_lora.ipynb) | LoRA 微調同一份資料集 |
# | 下一章 | [`../../04-kbits-tuning/02-16bits_training/llama2_lora_16bit.ipynb`](../../04-kbits-tuning/02-16bits_training/llama2_lora_16bit.ipynb) | 量化訓練（QLoRA）|
#
# ## (IA)3 vs LoRA 一眼看懂
#
# | | LoRA | (IA)3 |
# |---|---|---|
# | 做法 | 在權重矩陣旁加低秩分解 $\Delta W = AB$ | 在注意力與 FFN 的 key/value/feedforward 加**逐元素縮放向量** $l$ |
# | 可訓練參數 | 相對 LoRA rank 成比例 | **更少**（僅向量，非矩陣）|
# | 適合場景 | 一般指令微調 | 資源極受限、或 few-shot 遷移 |
# | 2026 PEFT class | `LoraConfig` | `IA3Config` |

# %%
# ============================================================
# 版本鎖定（執行環境一致性）
# ============================================================
# pip install -q \
#   transformers>=4.46 \
#   datasets>=3.0 \
#   trl>=0.12 \
#   peft>=0.13 \
#   accelerate>=1.0 \
#   bitsandbytes>=0.44 \
#   evaluate>=0.4 \
#   safetensors>=0.4 \
#   "torch>=2.4"

import importlib, sys
for pkg in ["transformers", "datasets", "trl", "peft", "accelerate", "evaluate", "safetensors"]:
    try:
        m = importlib.import_module(pkg)
        print(f"{pkg}: {m.__version__}")
    except Exception as e:
        print(f"{pkg}: NOT FOUND — {e}")

# %% [markdown]
# ## Step 1：匯入套件與全域設定
#
# 2026 統一慣例：
# - `set_seed(42)` 讓亂數完全可重現（`torch`、`numpy`、`random` 三合一）。
# - `torch.bfloat16` 是 Ampere（A100/RTX 30xx）以後的首選精度：動態範圍比 `fp16` 大，不需要 loss scaling，訓練更穩定。

# %%
import torch
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    set_seed,
)
from peft import IA3Config, TaskType, get_peft_model
from trl import SFTTrainer, SFTConfig

set_seed(42)

print(f"PyTorch  : {torch.__version__}")
print(f"CUDA     : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU      : {torch.cuda.get_device_name(0)}")
    print(f"VRAM     : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %% [markdown]
# ## Step 2：載入資料集
#
# 使用 `c-s-ale/alpaca-gpt4-data-zh`（與 LoRA notebook 相同），取前 50% 做示範。
# 資料集欄位：`instruction`（任務說明）、`input`（可選的上下文）、`output`（目標回答）。

# %%
ds = load_dataset("c-s-ale/alpaca-gpt4-data-zh", split="train[:50%]")
print(ds)
print("\n--- 前三筆 ---")
for i in range(3):
    print(f"[{i}] instruction: {ds[i]['instruction']}")
    print(f"    input      : {ds[i]['input']}")
    print(f"    output     : {ds[i]['output'][:60]}...")
    print()

# %% [markdown]
# ## Step 3：資料前處理
#
# ### 3-1 載入 Tokenizer
#
# `use_fast=True`（預設）啟用 Rust 加速版 tokenizer，速度比 Python 版快數倍。

# %%
MODEL_ID = "Langboat/bloom-1b4-zh"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)
print(tokenizer)

# %% [markdown]
# ### 3-2 建立對話模板
#
# **WHY：為何要用 `apply_chat_template()` 而非手寫分隔字串？**
#
# `apply_chat_template()` 將對話格式存在 `tokenizer_config.json` 中，跨模型可攜、原生支援多輪對話與 system prompt，且訓練與推論使用同一函式，確保格式完全一致。
#
# **注意**：`bloom-1b4-zh` 本身沒有預設的 chat template，需要手動設定簡單模板或使用 `formatting_func`。在有內建 chat template 的模型（如 Llama-3、Qwen-2、Mistral-v3）上，直接呼叫 `apply_chat_template()` 即可，無需額外設定。
#
# 以下展示兩種路徑：
# 1. **底層手刻版**（理解 -100 遮罩機制）：手動 tokenize 並設定 `-100` 遮罩，幫助理解損失計算原理。
# 2. **SFTTrainer 路徑**（推薦）：用 `formatting_func` 組裝對話字串，由 SFTTrainer 自動處理 tokenize 與 `-100` 遮罩。

# %%
# ----------------------------------------------------------------
# 底層手刻版：說明 -100 遮罩機制
# CrossEntropyLoss 忽略 label == -100 的位置，
# 因此只有 response token 計算損失，模型學的是「如何回答」。
# ----------------------------------------------------------------

def process_func(example):
    """Tokenize one example and build -100 masked labels.

    The instruction part is masked with -100 so the model only
    computes loss on the response tokens.
    """
    MAX_LENGTH = 256
    # Build prompt string
    messages = [
        {"role": "user", "content": "\n".join(
            filter(None, [example["instruction"], example["input"]])
        )},
    ]
    # bloom-1b4-zh has no built-in chat template; use a simple delimiter
    prompt = "Human: " + messages[0]["content"].strip() + "\n\nAssistant: "
    response_text = example["output"] + tokenizer.eos_token

    instruction_enc = tokenizer(prompt, add_special_tokens=False)
    response_enc   = tokenizer(response_text, add_special_tokens=False)

    input_ids      = instruction_enc["input_ids"] + response_enc["input_ids"]
    attention_mask = instruction_enc["attention_mask"] + response_enc["attention_mask"]
    # -100 on instruction tokens → loss only on response
    labels         = [-100] * len(instruction_enc["input_ids"]) + response_enc["input_ids"]

    if len(input_ids) > MAX_LENGTH:
        input_ids      = input_ids[:MAX_LENGTH]
        attention_mask = attention_mask[:MAX_LENGTH]
        labels         = labels[:MAX_LENGTH]

    return {"input_ids": input_ids, "attention_mask": attention_mask, "labels": labels}


tokenized_ds = ds.map(
    process_func,
    remove_columns=ds.column_names,
    num_proc=4,
    desc="Tokenizing",
)
print(tokenized_ds)

# %%
# 驗證：解碼 input_ids 確認格式正確
print("=== input_ids decode ===")
print(tokenizer.decode(tokenized_ds[1]["input_ids"]))
print()
print("=== labels decode（過濾 -100）===")
print(tokenizer.decode([x for x in tokenized_ds[1]["labels"] if x != -100]))

# %% [markdown]
# ### 3-3 SFTTrainer 用的 formatting_func
#
# SFTTrainer 接受 `formatting_func`：給定一筆 example，回傳格式化字串。
# SFTTrainer 內部會自動：
# 1. Tokenize
# 2. 設定 response-only `-100` 遮罩（需搭配 `DataCollatorForCompletionOnlyLM`）
# 3. Packing（把多筆短序列合併成 max_seq_length，提升 GPU 利用率）

# %%
def formatting_func(example):
    """Return a formatted chat string for SFTTrainer.

    This keeps instruction/input/output consistent with the
    manual tokenize path above, just as a plain string.
    """
    user_content = "\n".join(
        filter(None, [example["instruction"], example["input"]])
    ).strip()
    return f"Human: {user_content}\n\nAssistant: {example['output']}{tokenizer.eos_token}"

# Quick sanity check
print(formatting_func(ds[0])[:300])

# %% [markdown]
# ## Step 4：建立模型
#
# **2026 統一載入慣例：**
#
# ```python
# model = AutoModelForCausalLM.from_pretrained(
#     model_id,
#     device_map="auto",           # Accelerate 自動分配 CPU/GPU/disk
#     torch_dtype=torch.bfloat16,  # bf16 比 fp16 穩定，不需 loss scaling
#     use_safetensors=True,        # 安全格式，無 pickle 執行風險，載入更快
# )
# ```
#
# - `device_map='auto'`：Accelerate 依照可用 VRAM 自動切割 tensor，超過時可 offload 到 CPU/disk，無需手動 `.cuda()`。
# - `torch.bfloat16`：保留 fp32 的動態範圍（指數位更多），只降低精度位，訓練穩定性遠優於 fp16。
# - `use_safetensors=True`：`safetensors` 格式不執行任意 Python code，且採用 mmap 零拷貝載入，比 `pickle`（`.bin`）更快更安全。
#
# > **VRAM 估算**：bloom-1b4-zh bf16 約 2.8 GB；加上 IA3 幾乎無額外 VRAM（僅向量），總需求約 4–6 GB（含激活值）。若 VRAM < 4 GB，可改用 4-bit 量化（見 Step 4b）。

# %%
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    use_safetensors=True,
)
print(model.dtype)
print(model.hf_device_map)

# %% [markdown]
# ### Step 4b（選用）：VRAM 不足時改用 4-bit 量化
#
# 若 GPU VRAM < 4 GB，可加入 `BitsAndBytesConfig` 以 4-bit NF4 量化載入：
#
# ```python
# # 需要先安裝 bitsandbytes >= 0.44
# from transformers import BitsAndBytesConfig
# from peft import prepare_model_for_kbit_training
#
# quant_config = BitsAndBytesConfig(
#     load_in_4bit=True,
#     bnb_4bit_quant_type="nf4",              # NormalFloat4，比 fp4 更符合權重分布
#     bnb_4bit_compute_dtype=torch.bfloat16,  # 前向計算時還原成 bf16
#     bnb_4bit_use_double_quant=True,         # 對量化常數再量化，節省約 0.4 bit/param
# )
#
# model_4bit = AutoModelForCausalLM.from_pretrained(
#     MODEL_ID,
#     quantization_config=quant_config,
#     device_map="auto",
#     use_safetensors=True,
# )
#
# # PEFT 前必須呼叫，讓 k-bit 模型可梯度傳播
# model_4bit = prepare_model_for_kbit_training(model_4bit)
# ```

# %% [markdown]
# ## Step 5：設定 IA3 PEFT 配置
#
# ### (IA)3 核心原理
#
# (IA)3 在每個 Transformer 層的以下位置插入**可學習縮放向量 $l$**：
# - Key 投影（$K \leftarrow l_k \odot K$）
# - Value 投影（$V \leftarrow l_v \odot V$）
# - Position-wise FFN 的啟動（$h \leftarrow l_{ff} \odot h$）
#
# 原始權重完全凍結，只訓練這些向量。
#
# **可訓練參數量極小**：以 bloom-1b4-zh 為例，IA3 可訓練參數約為 LoRA（rank=8）的 1/10。
# 適合資源非常受限的場景，或多任務 prompt tuning（每個任務只存一組向量）。

# %%
ia3_config = IA3Config(
    task_type=TaskType.CAUSAL_LM,
    # target_modules: 預設已涵蓋 key/value/feedforward，可明確列出
    # feedforward_modules: 指定哪些 module 是 FFN（需乘上 l_ff）
    # 預設值對 BLOOM 架構已正確，一般不需調整
)
print(ia3_config)

# %%
model = get_peft_model(model, ia3_config)
model.print_trainable_parameters()
# 預期輸出範例：
# trainable params: 0.XX M || all params: 1,XXX M || trainable%: 0.0X%
# (IA)3 可訓練比例遠低於 LoRA（rank=8 約 0.1%）

# %% [markdown]
# ## Step 6：訓練配置
#
# ### 路徑 A：使用 SFTTrainer（推薦）
#
# `SFTConfig` 繼承自 `TrainingArguments`，額外提供：
# - `max_seq_length`：截斷/padding 上限
# - `packing`：自動 packing 多筆短序列
#
# **2026 TrainingArguments 必填項目說明：**
#
# | 參數 | 值 | 原因 |
# |---|---|---|
# | `bf16=True` | True | bf16 訓練，比 fp16 穩定 |
# | `warmup_ratio=0.1` | 0.1 | 前 10% steps 線性 warmup，防止初期梯度爆炸 |
# | `lr_scheduler_type='cosine'` | cosine | 餘弦退火，比 linear 收斂更平滑 |
# | `max_grad_norm=1.0` | 1.0 | 梯度裁剪，防止梯度爆炸 |
# | `optim='adamw_torch_fused'` | fused | CUDA kernel 融合版 AdamW，比標準版快 ~10% |
# | `save_safetensors=True` | True | 儲存為 safetensors 格式 |
# | `seed=42` | 42 | 搭配 set_seed(42) 完全可重現 |
#
# **effective_batch_size = per_device_train_batch_size × gradient_accumulation_steps × num_gpus**
# 本例：1 × 8 × 1 = 8（記憶體受限時用梯度累積模擬大 batch）

# %%
OUTPUT_DIR = "./chatbot-ia3"

sft_config = SFTConfig(
    output_dir=OUTPUT_DIR,
    # --- batch / steps ---
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,   # effective batch = 1 * 8 = 8
    num_train_epochs=1,
    # --- optimisation ---
    learning_rate=3e-3,              # IA3 通常用比 LoRA 更高的 lr
    optim="adamw_torch_fused",
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    max_grad_norm=1.0,
    # --- precision ---
    bf16=torch.cuda.is_available(),  # 有 GPU 才開 bf16
    # --- logging / saving ---
    logging_steps=10,
    save_steps=100,
    save_total_limit=2,
    save_safetensors=True,
    # --- reproducibility ---
    seed=42,
    # --- SFT specific ---
    max_seq_length=256,
    packing=False,                   # 可開啟 packing 提升 GPU 利用率
)
print(sft_config)

# %% [markdown]
# ## Step 7：建立 SFTTrainer 並訓練
#
# SFTTrainer 相較手刻 Trainer + DataCollatorForSeq2Seq 的優勢：
# 1. **自動 -100 遮罩**：內部使用 `DataCollatorForCompletionOnlyLM`，只對 response 計算 loss。
# 2. **formatting_func 整合**：直接傳入格式化函式，資料流更清晰。
# 3. **Packing 支援**：開啟 `packing=True` 可大幅提升短序列資料集的 GPU 利用率。
# 4. **與 PEFT 原生整合**：傳入 `peft_config` 自動呼叫 `get_peft_model()`（若模型尚未套用）。

# %%
trainer = SFTTrainer(
    model=model,
    args=sft_config,
    train_dataset=ds,
    formatting_func=formatting_func,
    # peft_config=ia3_config,  # 若模型尚未套用 PEFT，可在此傳入
    processing_class=tokenizer,
)

trainer.train()

# %% [markdown]
# ## Step 8：儲存模型（PEFT adapter）
#
# `save_pretrained` 只儲存 IA3 的縮放向量（幾 KB），不包含凍結的基礎模型。
# `safe_serialization=True` 確保輸出為 safetensors 格式。

# %%
import os
from pathlib import Path

ADAPTER_DIR = Path(OUTPUT_DIR) / "ia3-adapter"
ADAPTER_DIR.mkdir(parents=True, exist_ok=True)

model.save_pretrained(str(ADAPTER_DIR), safe_serialization=True)
tokenizer.save_pretrained(str(ADAPTER_DIR))

print(f"Adapter saved to: {ADAPTER_DIR}")
for f in sorted(ADAPTER_DIR.iterdir()):
    size = os.path.getsize(f)
    print(f"  {f.name:40s}  {size:>10,} bytes")

# %% [markdown]
# ### （選用）發布到 Hugging Face Hub
#
# ```python
# # 需先 huggingface-cli login
# HF_USER = "your-username"
# REPO_NAME = f"{HF_USER}/bloom-1b4-zh-ia3-alpaca"
#
# model.push_to_hub(
#     REPO_NAME,
#     safe_serialization=True,
#     commit_message="Add IA3 adapter for Alpaca-ZH instruction tuning",
# )
# tokenizer.push_to_hub(REPO_NAME)
#
# # 最小 model card（寫在 README.md）
# from huggingface_hub import ModelCard, ModelCardData
# card = ModelCard.from_template(
#     ModelCardData(
#         language=["zh"],
#         license="apache-2.0",
#         base_model="Langboat/bloom-1b4-zh",
#         tags=["peft", "ia3", "causal-lm", "instruction-tuning"],
#     )
# )
# card.push_to_hub(REPO_NAME)
# ```

# %% [markdown]
# ## Step 9：模型推理
#
# **2026 推論寫法：不需 `model.cuda()`**
#
# `device_map='auto'` 在 `from_pretrained` 時已把 tensor 放好，直接對 `model.device` 做 `.to()` 即可。
#
# 對話格式與訓練側完全相同（使用同一個 `formatting_func` 邏輯），確保訓練/推論一致。

# %%
def chat(question: str, context: str = "") -> str:
    """Run inference with the IA3-tuned model.

    Uses the same prompt format as formatting_func to guarantee
    train/inference consistency.
    """
    user_content = "\n".join(filter(None, [question, context])).strip()
    prompt = f"Human: {user_content}\n\nAssistant: "

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    with torch.inference_mode():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=128,
            do_sample=True,
            temperature=0.7,
            top_p=0.9,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id,
        )

    # Decode only the generated part (skip the prompt tokens)
    generated = output_ids[0][inputs["input_ids"].shape[-1]:]
    return tokenizer.decode(generated, skip_special_tokens=True)


# Test
result = chat("考試有哪些技巧？")
print(result)

# %%
# 多輪對話測試
test_questions = [
    "如何提升學習效率？",
    "健康飲食的原則是什麼？",
    "給初學者推薦三本程式設計書籍。",
]

for q in test_questions:
    print(f"Q: {q}")
    print(f"A: {chat(q)}")
    print("-" * 60)

# %% [markdown]
# ## Step 10：從 adapter 重新載入（驗證持久化）
#
# 展示如何從儲存的 adapter 重新組裝完整模型，確認儲存/載入流程正確。

# %%
from peft import PeftModel

# 1. 重新載入乾淨的基礎模型
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    use_safetensors=True,
)

# 2. 套上 IA3 adapter
loaded_model = PeftModel.from_pretrained(
    base_model,
    str(ADAPTER_DIR),
    is_trainable=False,  # 推論模式
)

print("Model loaded successfully.")
print(loaded_model.active_adapter)

# 3. 快速推論驗證
loaded_tokenizer = AutoTokenizer.from_pretrained(str(ADAPTER_DIR))
prompt = "Human: 寫一首關於秋天的短詩。\n\nAssistant: "
inputs = loaded_tokenizer(prompt, return_tensors="pt").to(loaded_model.device)
with torch.inference_mode():
    out = loaded_model.generate(**inputs, max_new_tokens=64, do_sample=True, temperature=0.8)
print(loaded_tokenizer.decode(out[0][inputs["input_ids"].shape[-1]:], skip_special_tokens=True))

# %% [markdown]
# ## 小結
#
# ### 本節重點
#
# 1. **(IA)3 vs LoRA**：IA3 只訓練逐元素縮放向量，可訓練參數量遠少於 LoRA，適合資源極受限場景或多任務切換（每個任務只需儲存幾 KB 的向量）。
#
# 2. **2026 統一載入慣例**：`device_map='auto'` + `torch.bfloat16` + `use_safetensors=True` 三合一，取代散落的 `.cuda()`、`low_cpu_mem_usage`、手動精度轉換。
#
# 3. **SFTTrainer 取代手刻 Trainer**：自動處理 `-100` 遮罩、formatting、packing，程式更短更不易出錯。底層機制（`-100` = CrossEntropyLoss 忽略該位置）仍值得理解。
#
# 4. **訓練/推論一致性**：使用同一個 `formatting_func` 組裝 prompt，避免訓練時 `Human:` 推論時用 `[INST]` 的格式不一致。在有內建 chat template 的模型上，直接用 `apply_chat_template()` 更為標準。
#
# 5. **safetensors 持久化**：`save_pretrained(safe_serialization=True)` 確保 adapter 以安全格式儲存，PeftModel.from_pretrained 可正確重新載入。
#
# ### 練習題
#
# 1. 修改 `IA3Config`，明確列出 `target_modules` 並印出模型結構，比較不同設定下的可訓練參數量。
# 2. 在同一份資料集上分別訓練 LoRA（rank=8）與 IA3，比較兩者的訓練速度、VRAM 峰值與推論品質。
# 3. 嘗試開啟 `packing=True` 並比較與 `packing=False` 的訓練速度差異（注意：packing 要求 `max_seq_length` 設定合理）。
# 4. 加入 `BitsAndBytesConfig` 以 4-bit NF4 載入模型，重新執行 IA3 訓練並觀察 VRAM 使用量變化。
# 5. 使用一個有內建 chat template 的模型（如 `Qwen/Qwen2.5-0.5B-Instruct`），改寫 `formatting_func` 為 `tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)` 的標準寫法。
