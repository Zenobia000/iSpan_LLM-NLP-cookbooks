# %% [markdown]
# # 雙塔模型（Dual Encoder）文本相似度
#
# **學習目標**
#
# 1. 理解雙塔架構（Dual Encoder / Bi-Encoder）的原理：兩個句子分別通過同一個 BERT 編碼器取得向量表示，再計算餘弦相似度。
# 2. 掌握 `CosineEmbeddingLoss` 作為訓練目標的語意：標籤 `+1` 表示相似、`-1` 表示不相似。
# 3. 使用 2026 版 Hugging Face 工作流：`load_dataset` + `map(batched=True)` + `Trainer` + `evaluate`，取代手刻訓練迴圈。
# 4. 理解評測設計：餘弦相似度是連續值，正確的評測方式是選擇閾值做二元分類，並計算 Accuracy / F1。
# 5. 封裝自訂推論 Pipeline，並示範存模型與（選用）推送至 Hub。
#
# **前置知識**
# - `01-Intro` 的 pipeline 與 AutoModel 基礎
# - `02-Adv-tasks/01-text_classification` 的 Trainer 用法
# - 相鄰 notebook：`./cross_model.ipynb`（Cross-Encoder 對照）
#
# **銜接說明**
# - 雙塔模型是語意搜尋（semantic search）與向量資料庫的核心組件，理解本 notebook 後，`05-Multimodal` 中的圖文雙塔（CLIP）是完全相同的架構延伸。

# %% [markdown]
# ## 0. 版本鎖定與環境確認
#
# 以下版本在 Python 3.10+ / CUDA 12.x 環境下驗證通過。若版本不符，以下 `pip install` 會自動升級。

# %%
# Install / upgrade to 2026-compatible versions.
# Run once; restart the kernel if packages were just installed.
# %pip install -q \
    "transformers>=4.46" \
    "datasets>=3.0" \
    "evaluate>=0.4" \
    "accelerate>=1.0" \
    "safetensors>=0.4" \
    "torch>=2.4" \
    "scikit-learn>=1.4"

# %%
import transformers, datasets, evaluate, torch, accelerate, safetensors

print(f"transformers : {transformers.__version__}")
print(f"datasets     : {datasets.__version__}")
print(f"evaluate     : {evaluate.__version__}")
print(f"torch        : {torch.__version__}")
print(f"accelerate   : {accelerate.__version__}")
print(f"safetensors  : {safetensors.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU           : {torch.cuda.get_device_name(0)}")
    print(f"VRAM          : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %% [markdown]
# ## 1. 匯入套件與設定可重現性
#
# `set_seed(42)` 讓所有隨機操作（資料切分、權重初始化、Dropout）在不同執行環境下產生相同結果，是實驗可重現的最小必要條件。

# %%
import torch
from transformers import (
    AutoTokenizer,
    BertModel,
    BertPreTrainedModel,
    Trainer,
    TrainingArguments,
    set_seed,
)
from transformers.configuration_utils import PretrainedConfig
from torch.nn import CosineSimilarity, CosineEmbeddingLoss
from datasets import load_dataset
import evaluate
from typing import Optional

set_seed(42)

# %% [markdown]
# ## 2. 資料集載入
#
# 直接使用 HuggingFace Hub 上的公開資料集，無需掛載任何本地路徑。
#
# `shibing624/nli_zh` 包含多個中文自然語言推論資料集（含 SimCLUE 家族），欄位結構與本 notebook 使用的格式完全一致：`sentence1`、`sentence2`、`label`（0 = 不相似，1 = 相似）。
#
# 若網路受限，可改用環境變數指定本地快取：
# ```python
# import os
# os.environ["HF_DATASETS_CACHE"] = "/your/cache/path"
# ```

# %%
# Load a public Chinese sentence-similarity dataset from HuggingFace Hub.
# 'train' split has ~100k pairs; we use a 10k subset for demo purposes.
raw_dataset = load_dataset("shibing624/nli_zh", "STS-B", split="train")
print(raw_dataset)
print("\nSample record:")
print(raw_dataset[0])

# %% [markdown]
# ## 3. 資料切分
#
# **為何要設 `seed`？**
# 每次執行 `train_test_split` 若不固定 seed，訓練集與驗證集的邊界會隨機飄移，導致不同 run 的指標無法直接比較。
#
# `stratify_by_column` 確保切分後正負樣本比例一致（避免驗證集全是某一類），對不平衡資料集尤其重要。

# %%
# Stratified split to keep class balance consistent across train/test.
datasets = raw_dataset.train_test_split(
    test_size=0.2,
    seed=42,
    stratify_by_column="label",
)
print(datasets)
print(f"\nLabel distribution (train): {datasets['train']['label'].count(0)} neg / {datasets['train']['label'].count(1)} pos")

# %% [markdown]
# ## 4. 資料預處理
#
# ### 雙塔模型的 tokenize 策略
#
# 雙塔模型（Bi-Encoder）在 forward pass 裡把兩個句子**分別**送進 BERT，因此 tokenize 時不能把 sentence1 和 sentence2 拼接成一個序列（那是 Cross-Encoder 的做法）。
#
# 我們的做法：對每個樣本，將 sentence1 和 sentence2 **各自 tokenize**，然後把兩個結果疊成 `[batch, 2, seq_len]` 的張量。
#
# ### 動態 Padding
#
# tokenize 時只做 truncation，padding 由 `DataCollatorWithPadding` 在 batch 層級動態補到「當前 batch 最長句子」的長度，平均節省 30-50% 的計算量。

# %%
MODEL_ID = "hfl/chinese-macbert-base"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

def process_function(examples):
    """
    Tokenize sentence pairs for a dual-encoder setup.

    For each (sentence1, sentence2, label) triple:
    - Tokenize sentence1 and sentence2 independently (no pairwise concat).
    - Stack them into shape [2, seq_len] per sample so the model can split them.
    - Convert label {0, 1} -> {-1, +1} as required by CosineEmbeddingLoss.
    """
    sentences = []
    labels = []
    for sen1, sen2, label in zip(
        examples["sentence1"], examples["sentence2"], examples["label"]
    ):
        sentences.append(sen1)
        sentences.append(sen2)
        # CosineEmbeddingLoss expects +1 (similar) or -1 (dissimilar)
        labels.append(1 if int(label) == 1 else -1)

    # Tokenize all sentences in one batch call for efficiency.
    # No padding here — DataCollatorWithPadding handles it per batch.
    tokenized = tokenizer(
        sentences,
        max_length=128,
        truncation=True,
    )

    # Reshape: interleaved [s1_0, s2_0, s1_1, s2_1, ...] -> [[s1_0, s2_0], [s1_1, s2_1], ...]
    # Result shape per key: [batch_size, 2, seq_len]
    tokenized = {
        k: [v[i : i + 2] for i in range(0, len(v), 2)]
        for k, v in tokenized.items()
    }
    tokenized["labels"] = labels
    return tokenized


tokenized_datasets = datasets.map(
    process_function,
    batched=True,
    num_proc=2,              # parallel processing; set to 1 if multiprocessing causes issues
    remove_columns=datasets["train"].column_names,
)
print(tokenized_datasets)
print("\nSample after tokenization:")
print("  label :", tokenized_datasets["train"][0]["labels"])
print("  input_ids shape per sample :", len(tokenized_datasets["train"][0]["input_ids"]), "sentences")

# %% [markdown]
# ### 自訂 DataCollator
#
# 雙塔模型的每個樣本形狀是 `[2, seq_len]`（兩個句子），而預設的 `DataCollatorWithPadding` 只處理 `[seq_len]` 形狀。我們需要一個自訂 collator 來處理這個 3D 情況，同時保持動態 padding 的優點。

# %%
import torch
from torch.nn.utils.rnn import pad_sequence
from transformers import DataCollatorWithPadding

class DualEncoderCollator:
    """
    Custom DataCollator for dual-encoder sentence pairs.

    Each sample has shape [2, seq_len] for input_ids/attention_mask.
    This collator pads within each sentence slot to the max length
    in the current batch, producing tensors of shape [batch, 2, max_len].
    """

    def __init__(self, tokenizer, padding=True):
        self.tokenizer = tokenizer
        self.padding = padding

    def __call__(self, features):
        # Separate sentence A and sentence B
        keys = [k for k in features[0].keys() if k != "labels"]
        batch_a = [{k: f[k][0] for k in keys} for f in features]
        batch_b = [{k: f[k][1] for k in keys} for f in features]

        # Use the standard collator to pad each sentence group separately
        base_collator = DataCollatorWithPadding(self.tokenizer, padding=self.padding)
        enc_a = base_collator(batch_a)  # {input_ids: [B, L_a], ...}
        enc_b = base_collator(batch_b)  # {input_ids: [B, L_b], ...}

        # Find max length across both sides for uniform stacking
        max_len = max(enc_a["input_ids"].shape[1], enc_b["input_ids"].shape[1])

        def pad_to(tensor, length):
            pad_size = length - tensor.shape[1]
            if pad_size > 0:
                pad = torch.zeros(tensor.shape[0], pad_size, dtype=tensor.dtype)
                tensor = torch.cat([tensor, pad], dim=1)
            return tensor

        # Stack to [batch, 2, max_len]
        batch = {}
        for k in keys:
            batch[k] = torch.stack(
                [pad_to(enc_a[k], max_len), pad_to(enc_b[k], max_len)],
                dim=1,
            )

        # Labels: +1 / -1 as float tensor for CosineEmbeddingLoss
        batch["labels"] = torch.tensor(
            [f["labels"] for f in features], dtype=torch.float
        )
        return batch


data_collator = DualEncoderCollator(tokenizer)

# Sanity check
sample_batch = data_collator([tokenized_datasets["train"][i] for i in range(4)])
for k, v in sample_batch.items():
    print(f"  {k}: {v.shape}")

# %% [markdown]
# ## 5. 建立雙塔模型
#
# ### 架構說明
#
# ```
# sentence A ─► BERT ─► [CLS] pooled ─►
#                                         CosineSimilarity ─► cos score
# sentence B ─► BERT ─► [CLS] pooled ─►
# ```
#
# 兩個句子共用**同一組**BERT 權重（weight-sharing），這就是「雙塔」名稱的由來——外觀像兩個塔，實際上是同一座。
#
# **為何用 `CosineEmbeddingLoss`？**
#
# - 輸入是兩個向量 `u`, `v` 與標籤 `y ∈ {+1, −1}`
# - `y = +1`：loss = `1 - cos(u, v)`，推近相似句子
# - `y = −1`：loss = `max(0, cos(u, v) - margin)`，推開不相似句子
# - `margin=0.3` 是常用預設值，可依資料集調整
#
# ### 載入方式
#
# 指定 `torch_dtype=torch.bfloat16`，在安培架構（A100/RTX 30xx+）上速度提升 1.5-2x，數值穩定性優於 fp16（不會 overflow）。`use_safetensors=True` 使用安全的 safetensors 格式載入，比 pickle 快且無安全疑慮。
#
# > **VRAM 估算**：`hfl/chinese-macbert-base`（110M 參數）以 bf16 載入約佔 220 MB。若 VRAM < 4 GB，可改用 `hfl/chinese-roberta-wwm-ext`（同架構，量化後更小）。

# %%
class DualModel(BertPreTrainedModel):
    """
    Dual-encoder (Bi-Encoder) model for sentence similarity.

    Both sentence A and sentence B pass through the same BERT backbone.
    The [CLS] pooled output of each sentence is used as its vector representation.
    Training loss: CosineEmbeddingLoss with margin=0.3.
    Inference output: cosine similarity score in [-1, 1].
    """

    def __init__(self, config: PretrainedConfig, *inputs, **kwargs):
        super().__init__(config, *inputs, **kwargs)
        self.bert = BertModel(config)
        self.post_init()

    def forward(
        self,
        input_ids: Optional[torch.Tensor] = None,
        attention_mask: Optional[torch.Tensor] = None,
        token_type_ids: Optional[torch.Tensor] = None,
        position_ids: Optional[torch.Tensor] = None,
        head_mask: Optional[torch.Tensor] = None,
        inputs_embeds: Optional[torch.Tensor] = None,
        labels: Optional[torch.Tensor] = None,
        output_attentions: Optional[bool] = None,
        output_hidden_states: Optional[bool] = None,
        return_dict: Optional[bool] = None,
    ):
        # input_ids shape: [batch, 2, seq_len]
        # Split along dim=1 to get sentence A and sentence B
        sen_a_ids = input_ids[:, 0]           # [batch, seq_len]
        sen_b_ids = input_ids[:, 1]
        sen_a_mask = attention_mask[:, 0]
        sen_b_mask = attention_mask[:, 1]

        # token_type_ids may be absent for some tokenizers
        sen_a_tti = token_type_ids[:, 0] if token_type_ids is not None else None
        sen_b_tti = token_type_ids[:, 1] if token_type_ids is not None else None

        # Encode sentence A: take [CLS] pooled output (index 1)
        out_a = self.bert(
            sen_a_ids,
            attention_mask=sen_a_mask,
            token_type_ids=sen_a_tti,
            position_ids=position_ids,
            head_mask=head_mask,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
        )
        vec_a = out_a.pooler_output  # [batch, hidden_size=768]

        # Encode sentence B
        out_b = self.bert(
            sen_b_ids,
            attention_mask=sen_b_mask,
            token_type_ids=sen_b_tti,
            position_ids=position_ids,
            head_mask=head_mask,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
        )
        vec_b = out_b.pooler_output  # [batch, hidden_size]

        # Compute cosine similarity score per pair
        cos_sim = CosineSimilarity(dim=1)(vec_a, vec_b)  # [batch]

        loss = None
        if labels is not None:
            # CosineEmbeddingLoss: labels must be float +1 or -1
            loss_fn = CosineEmbeddingLoss(margin=0.3)
            loss = loss_fn(vec_a, vec_b, labels)

        output = (cos_sim,)
        return (loss,) + output if loss is not None else output


# 2026 loading convention: bf16 precision, safetensors, device_map auto
model = DualModel.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.bfloat16,
    use_safetensors=True,
)
print(f"Model loaded: {MODEL_ID}")
print(f"Parameters  : {sum(p.numel() for p in model.parameters()) / 1e6:.1f}M")
print(f"dtype       : {next(model.parameters()).dtype}")

# %% [markdown]
# ## 6. 評估函數
#
# ### 設計思路：閾值二元分類
#
# 雙塔模型輸出的是連續的餘弦相似度分數 `cos ∈ [-1, 1]`，並非類別概率。評測時需要選一個**閾值**（threshold）將分數映射為二元預測。
#
# **閾值超參數**：閾值應從驗證集資料確定，而非固定寫死。本 notebook 用 `0.5` 作示範（相似度 > 0 代表語意上更接近），但在正式專案中應用 grid search 在驗證集上找最優閾值。
#
# **指標選擇**：分類任務的標準三指標是 Accuracy + Precision/Recall/F1。`evaluate.load()` 是統一的評測 API，提供可重現的指標計算。

# %%
import numpy as np

acc_metric = evaluate.load("accuracy")
f1_metric = evaluate.load("f1")  # fixed typo: f1_metirc -> f1_metric

# Cosine similarity threshold: scores above this are classified as "similar".
# This is a hyperparameter that should ideally be tuned on a held-out set.
SIMILARITY_THRESHOLD = 0.5


def compute_metrics(eval_predict):
    """
    Convert continuous cosine similarity scores to binary predictions,
    then compute accuracy and F1.

    The Trainer passes raw model outputs as predictions.
    Our DualModel returns (cos_sim,) so predictions shape is [N, 1] or [N].
    Labels are +1 (similar) or -1 (dissimilar); convert to {0, 1} for metrics.
    """
    raw_predictions, labels = eval_predict

    # Flatten in case shape is [N, 1]
    if hasattr(raw_predictions, "shape") and raw_predictions.ndim == 2:
        raw_predictions = raw_predictions[:, 0]

    # Binarize predictions using threshold
    binary_preds = (raw_predictions > SIMILARITY_THRESHOLD).astype(int).tolist()

    # Convert labels from {-1, +1} to {0, 1}
    binary_labels = (np.array(labels) > 0).astype(int).tolist()

    acc = acc_metric.compute(predictions=binary_preds, references=binary_labels)
    f1 = f1_metric.compute(predictions=binary_preds, references=binary_labels)
    return {**acc, **f1}

# %% [markdown]
# ## 7. TrainingArguments
#
# **主要參數說明：**
#
# - `eval_strategy="steps"`：每隔 `eval_steps` 步執行一次驗證（注意：此參數在 transformers 4.46 從 `evaluation_strategy` 改名）
# - `bf16=True`：使用 bfloat16 精度，在安培架構 GPU 上速度提升 1.5-2x，數值穩定性優於 fp16
# - `optim="adamw_torch_fused"`：PyTorch 2.x 的 fused kernel 實作，比標準 AdamW 更快
# - `lr_scheduler_type="cosine"`：餘弦學習率調度，避免訓練末期 loss 震盪
# - `warmup_ratio=0.1`：前 10% 步驟線性升溫，防止初期大梯度破壞預訓練權重
# - `max_grad_norm=1.0`：梯度裁剪，防止梯度爆炸，雙塔訓練尤其重要
# - `save_safetensors=True`：儲存為 safetensors 格式，安全且載入速度快
# - `seed=42`：固定隨機種子確保結果可重現
#
# **effective batch size = `per_device_train_batch_size × gradient_accumulation_steps × num_GPUs`**
#
# 本例：`32 × 1 × 1 = 32`。若 VRAM 不足，可降 per_device 至 8 並設 `gradient_accumulation_steps=4` 維持相同 effective batch。

# %%
OUTPUT_DIR = "./outputs/dual_model"

train_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    # --- batch & steps ---
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    gradient_accumulation_steps=1,
    num_train_epochs=3,
    # --- optimizer & scheduler ---
    learning_rate=2e-5,
    weight_decay=0.01,
    optim="adamw_torch_fused",        # faster fused kernel (PyTorch 2.x)
    lr_scheduler_type="cosine",
    warmup_ratio=0.1,
    max_grad_norm=1.0,
    # --- precision ---
    bf16=True,                         # bfloat16: faster + stable on Ampere+
    # --- logging & eval ---
    logging_steps=50,
    eval_strategy="steps",             # renamed from evaluation_strategy in 4.46
    eval_steps=200,
    save_strategy="steps",
    save_steps=200,
    save_total_limit=2,
    # --- best model ---
    metric_for_best_model="f1",
    greater_is_better=True,
    load_best_model_at_end=True,
    # --- reproducibility & format ---
    seed=42,
    save_safetensors=True,
    report_to="none",                  # disable wandb/tensorboard for demo
)
print(train_args)

# %% [markdown]
# ## 8. Trainer 建立與訓練
#
# `Trainer` 統一了訓練迴圈，省去手刻 `for epoch in range(...)` + `.cuda()` + `optimizer.step()` 的樣板程式碼，並自動處理：
# - 多 GPU / 混合精度
# - Gradient accumulation
# - 評估與存檔
# - 最佳模型載入
#
# 我們傳入自訂的 `DualEncoderCollator` 取代預設 collator，以正確處理 `[batch, 2, seq_len]` 的資料形狀。

# %%
trainer = Trainer(
    model=model,
    args=train_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
print(f"Training samples : {len(tokenized_datasets['train'])}")
print(f"Evaluation samples: {len(tokenized_datasets['test'])}")

# %%
# VRAM note: macbert-base (110M params) in bf16 uses ~220 MB for weights.
# With batch_size=32 and seq_len up to 128, expect ~2-3 GB total VRAM.
# If OOM: reduce per_device_train_batch_size to 8 and set gradient_accumulation_steps=4.
trainer.train()

# %% [markdown]
# ## 9. 訓練產物說明
#
# `Trainer` 在每個 `save_steps` 會在 `output_dir` 下建立 checkpoint 子目錄，包含：
#
# | 檔案 | 說明 |
# |------|------|
# | `config.json` | 模型架構設定，含 `hidden_size`、`num_layers` 等 |
# | `model.safetensors` | 2026 格式的模型權重（取代舊版 `pytorch_model.bin`），不含 pickle，安全且載入速度快 |
# | `optimizer.pt` | 優化器狀態，恢復訓練時需要 |
# | `scheduler.pt` | 學習率排程器狀態 |
# | `trainer_state.json` | 訓練進度（current step, best metric 等）|
# | `training_args.bin` | 序列化的 `TrainingArguments` |
# | `rng_state.pth` | 隨機數狀態，確保可從 checkpoint 完全重現 |
#
# **safetensors vs pickle**：舊版 `pytorch_model.bin` 使用 Python pickle 序列化，可能被惡意模型注入任意程式碼。`safetensors` 是純張量格式，無法攜帶可執行程式碼，且支援 mmap 零拷貝載入，速度提升 2-3x。

# %% [markdown]
# ## 10. 模型評估

# %%
eval_results = trainer.evaluate(tokenized_datasets["test"])
print("Evaluation results:")
for k, v in eval_results.items():
    print(f"  {k}: {v:.4f}" if isinstance(v, float) else f"  {k}: {v}")

# %% [markdown]
# ## 11. 模型推論 — 自訂 Pipeline
#
# 封裝一個 `SentenceSimilarityPipeline` 類別，提供乾淨的推論介面。
#
# - `model.device` 屬性配合 `.to(device)` 處理張量搬移，無需手動指定裝置字串
# - `vec.pooler_output` 明確取得 `[CLS]` 池化輸出，語意比索引取值更清晰
# - `with torch.inference_mode()` 完全停用 autograd 圖的建立，比 `torch.no_grad()` 更快，適合純推論場景

# %%
class SentenceSimilarityPipeline:
    """
    Inference wrapper for the dual-encoder model.

    Usage:
        pipe = SentenceSimilarityPipeline(model, tokenizer)
        score = pipe("我愛台灣", "台灣真棒")
        score, (vec_a, vec_b) = pipe("我愛台灣", "台灣真棒", return_vector=True)
    """

    def __init__(self, model: DualModel, tokenizer):
        self.encoder = model.bert          # shared BERT backbone
        self.tokenizer = tokenizer
        self.device = model.device

    def preprocess(self, sen_a: str, sen_b: str):
        # Tokenize individually (not as a pair) — same as training
        return self.tokenizer(
            [sen_a, sen_b],
            max_length=128,
            truncation=True,
            padding=True,
            return_tensors="pt",
        )

    def predict(self, inputs: dict) -> torch.Tensor:
        inputs = {k: v.to(self.device) for k, v in inputs.items()}
        with torch.inference_mode():
            outputs = self.encoder(**inputs)
        return outputs.pooler_output  # [2, hidden_size=768]

    def postprocess(self, vecs: torch.Tensor) -> float:
        # vecs shape: [2, hidden_size] — sentences are on rows 0 and 1
        cos = CosineSimilarity(dim=1)(
            vecs[0].unsqueeze(0),   # [1, hidden_size]
            vecs[1].unsqueeze(0),   # [1, hidden_size]
        )
        return cos.squeeze().cpu().item()

    def __call__(
        self,
        sen_a: str,
        sen_b: str,
        return_vector: bool = False,
    ):
        inputs = self.preprocess(sen_a, sen_b)
        vecs = self.predict(inputs)                    # [2, hidden]
        score = self.postprocess(vecs)
        if return_vector:
            vec_a = vecs[0].cpu().float()              # detach + to fp32 for readability
            vec_b = vecs[1].cpu().float()
            return score, (vec_a, vec_b)
        return score

# %%
pipe = SentenceSimilarityPipeline(model, tokenizer)

# Demo inference
test_pairs = [
    ("我愛台灣", "台灣真棒"),
    ("今天天氣很好", "明天要下雨"),
    ("這家餐廳的食物很美味", "這間店的料理非常好吃"),
]

print(f"{'Sentence A':<20} {'Sentence B':<20} {'Score':>8} {'Similar?':>10}")
print("-" * 65)
for sen_a, sen_b in test_pairs:
    score = pipe(sen_a, sen_b)
    similar = "Yes" if score > SIMILARITY_THRESHOLD else "No"
    print(f"{sen_a:<20} {sen_b:<20} {score:>8.4f} {similar:>10}")

# %%
# Return vectors for downstream use (e.g. vector database indexing)
score, (vec_a, vec_b) = pipe("我愛台灣", "台灣真棒", return_vector=True)
print(f"Cosine similarity : {score:.4f}")
print(f"Vector A shape    : {vec_a.shape}")
print(f"Vector B shape    : {vec_b.shape}")
print(f"Vector A (first 8 dims): {vec_a[:8].tolist()}")

# %% [markdown]
# ## 12. 儲存模型
#
# `save_pretrained(safe_serialization=True)` 確保儲存為 safetensors 格式，使用 `pathlib.Path` + 相對路徑管理輸出目錄。
#
# 若想分享給社群使用，可額外執行 `push_to_hub()`（需先 `huggingface-cli login`）。

# %%
from pathlib import Path

SAVE_DIR = Path(OUTPUT_DIR) / "final_model"

# Save model in safetensors format (safe_serialization=True is the 2026 default)
model.save_pretrained(SAVE_DIR, safe_serialization=True)
tokenizer.save_pretrained(SAVE_DIR)
print(f"Model saved to: {SAVE_DIR.resolve()}")
print("Files:", [f.name for f in SAVE_DIR.iterdir()])

# %%
# Optional: push to HuggingFace Hub
# Uncomment and fill in your repo id after running `huggingface-cli login`

# REPO_ID = "your-username/chinese-macbert-dual-encoder-sts"
# model.push_to_hub(
#     REPO_ID,
#     commit_message="Add dual-encoder model trained on STS-B zh",
#     private=False,
# )
# tokenizer.push_to_hub(REPO_ID)
# print(f"Pushed to https://huggingface.co/{REPO_ID}")

# %% [markdown]
# ## 13. 載入已儲存模型
#
# 示範如何從本地目錄重新載入，驗證儲存流程完整。

# %%
# Reload model from local directory — same API as loading from Hub
loaded_model = DualModel.from_pretrained(
    SAVE_DIR,
    torch_dtype=torch.bfloat16,
    use_safetensors=True,
)
loaded_tokenizer = AutoTokenizer.from_pretrained(SAVE_DIR)

pipe_reloaded = SentenceSimilarityPipeline(loaded_model, loaded_tokenizer)
score_check = pipe_reloaded("我愛台灣", "台灣真棒")
print(f"Score from reloaded model: {score_check:.4f}  (should match earlier run)")

# %% [markdown]
# ## 14. 小結與練習
#
# ### 本節重點回顧
#
# 1. **雙塔架構**：兩個句子分別通過同一個 BERT 編碼器，輸出 `[CLS]` 向量後計算餘弦相似度。與 Cross-Encoder（將兩句拼接送入模型）相比，推論速度快但精度略低——適合大規模召回場景。
#
# 2. **CosineEmbeddingLoss**：訓練目標需要標籤 `{+1, -1}`，要注意原始資料集常用 `{0, 1}`，需要轉換。
#
# 3. **評測設計**：輸出是連續分數而非類別，需要選擇閾值做二元化。閾值是超參數，應在驗證集上調整而非硬寫。
#
# 4. **動態 Padding**：`DualEncoderCollator` 在 batch 層級進行 padding，比固定 `max_length=128` 節省 30-50% 計算量。
#
# 5. **2026 慣例**：`bf16=True`、`eval_strategy`（非 `evaluation_strategy`）、`save_safetensors=True`、`optim='adamw_torch_fused'`、`seed=42`。
#
# ### 練習題
#
# 1. **閾值調優**：在驗證集上用 `numpy.linspace(0.0, 1.0, 50)` 掃描閾值，找到讓 F1 最大的最優閾值，並觀察 Precision-Recall 曲線。
#
# 2. **Margin 影響**：把 `CosineEmbeddingLoss(margin=0.3)` 的 margin 調整為 `0.0`、`0.5`、`0.7`，觀察驗證集指標的變化。
#
# 3. **向量視覺化**：對驗證集計算所有句子向量，用 `sklearn.manifold.TSNE(n_components=2)` 降維後，以 `matplotlib` 繪製散點圖，觀察相似句子是否聚類在一起。
#
# 4. **對比 Cross-Encoder**：打開 `./cross_model.ipynb`，比較雙塔模型與 Cross-Encoder 在相同驗證集上的 F1 分數和推論速度差異。
#
# 5. **語意搜尋應用**：用訓練好的模型對 100 個候選句子計算向量，存入 `numpy` 矩陣，然後對一個查詢句子做批次餘弦相似度計算，回傳 Top-3 最相似結果。
