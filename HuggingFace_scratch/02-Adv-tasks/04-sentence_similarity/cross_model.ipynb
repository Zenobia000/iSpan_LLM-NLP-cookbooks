# %% [markdown]
# # 文本相似度 — Cross-Encoder 微調（2026 版）
#
# ## 學習目標
#
# 1. 理解 **Cross-Encoder** 架構：如何把兩個句子拼接後送進 BERT 做相似度回歸。
# 2. 掌握 2026 版 Hugging Face 資料管線：`load_dataset` + `map(batched=True)` + `DataCollatorWithPadding`（動態 padding）。
# 3. 使用現代化 `TrainingArguments`（`bf16`、`eval_strategy`、`adamw_torch_fused`、`save_safetensors` 等）設定訓練流程。
# 4. 正確評測回歸任務：同時計算 **Pearson 相關係數**（連續分數）與 **閾值二元化準確率 / F1**（業務用途）。
# 5. 用 `safetensors` 格式儲存，並示範 `push_to_hub` 與最小 model card。
#
# ## 前置條件
#
# - 建議 GPU VRAM >= 6 GB（`hfl/chinese-macbert-base` 約佔 800 MB + 訓練 overhead）。
# - 無 GPU 時可把 `bf16=True` 改為 `fp32=True`，並縮小 batch size。
#
# ## 與相鄰 Notebook 的銜接
#
# - 上一個：[`dual_model.ipynb`](./dual_model.ipynb) — Bi-Encoder 架構，兩個句子分別編碼後取餘弦相似度。
# - 下一個：[`05-retrieval_chatbot/retrieval_bot.ipynb`](../05-retrieval_chatbot/retrieval_bot.ipynb) — 把訓練好的 Bi-Encoder 用在向量檢索場景。
#
# > **Cross-Encoder vs Bi-Encoder**：Cross-Encoder 每次推論都要把兩句一起過模型，精度高但無法預先建向量索引，適合 reranking；Bi-Encoder 可離線建索引，適合大規模候選集召回。

# %%
# Cell 0 — 版本鎖定（2026 統一環境）
# 執行一次即可；已安裝符合版本者不會重裝
# %pip install -q \
    "transformers>=4.46" \
    "datasets>=3.0" \
    "evaluate>=0.4" \
    "accelerate>=1.0" \
    "safetensors>=0.4" \
    "torch>=2.4" \
    "scipy>=1.13"

# %% [markdown]
# ## Step 1 — 載入套件
#
# `scipy` 提供 `pearsonr`，用於評測回歸任務的連續分數品質（詳見 Step 6）。

# %%
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
    set_seed,
)
from datasets import load_dataset
import evaluate
from scipy.stats import pearsonr

set_seed(42)  # reproducibility: covers Python random / NumPy / PyTorch

print("torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0),
          f"| VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %% [markdown]
# ## Step 2 — 下載資料集
#
# 我們使用 **`shibing624/nli_zh`（STS-B 子集）**，直接從 HF Hub 拉取，環境無關、可重現：
#
# - 欄位：`sentence1`、`sentence2`、`label`（float，0–5）
# - 共 5749 筆訓練資料，與 simCLUE 規模相近且公開可重現。
# - 標籤為 0–5 連續分數，後面正規化到 0–1 再做回歸。

# %%
raw_dataset = load_dataset("shibing624/nli_zh", "STS-B", split="train")
print(raw_dataset)
print("\n範例：")
print(raw_dataset[0])

# %% [markdown]
# ## Step 3 — 切分資料集
#
# 回歸任務無法使用 `stratify_by_column`（連續標籤），直接用 `train_test_split` 固定 seed 保證可重現性即可。

# %%
# 正規化標籤：STS-B 原始分數為 0–5，統一對映到 0–1
def normalize_label(examples):
    examples["label"] = [float(l) / 5.0 for l in examples["label"]]
    return examples

norm_dataset = raw_dataset.map(normalize_label, batched=True)

datasets = norm_dataset.train_test_split(test_size=0.2, seed=42)
print(datasets)
print("\n正規化後範例 label:", datasets["train"][0]["label"])

# %% [markdown]
# ## Step 4 — 資料集預處理
#
# ### 2026 資料管線重點
#
# - `map(batched=True)`：一次處理一批，速度比逐筆快 3–5 倍（底層向量化 tokenizer）。
# - `remove_columns`：丟掉原始文字欄，只留 `input_ids / attention_mask / token_type_ids / labels`。
# - `DataCollatorWithPadding`（Step 8 使用）：**動態 padding**，每個 batch 只補到該 batch 最長序列，比固定 128 更省記憶體。
# - `max_length=128`：Cross-Encoder 把兩句拼接，中文短句通常 < 128 token；若語料較長可改 256。

# %%
MODEL_ID = "hfl/chinese-macbert-base"  # 約 400M 參數，fp32 ~1.6 GB，bf16 ~800 MB

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

def process_function(examples):
    # Cross-Encoder 核心：把 sentence1 + sentence2 拼接成單一輸入
    # tokenizer 自動加入 [CLS] sent1 [SEP] sent2 [SEP]
    tokenized = tokenizer(
        examples["sentence1"],
        examples["sentence2"],
        max_length=128,
        truncation=True,
        # 不在此 padding，改由 DataCollatorWithPadding 動態處理
    )
    tokenized["labels"] = [float(label) for label in examples["label"]]
    return tokenized

tokenized_datasets = datasets.map(
    process_function,
    batched=True,
    remove_columns=datasets["train"].column_names,
)
print(tokenized_datasets)
print("\nTrain 第一筆 labels:", tokenized_datasets["train"][0]["labels"])

# %% [markdown]
# ## Step 5 — 建立模型
#
# ### 2026 載入慣例
#
# ```python
# model = AutoModelForSequenceClassification.from_pretrained(
#     MODEL_ID,
#     num_labels=1,
#     device_map="auto",
#     torch_dtype=torch.bfloat16,
#     use_safetensors=True,
# )
# ```
#
# **為何 bfloat16 優於 float16 / float32？**
#
# | 格式 | 指數位元 | 小數位元 | 動態範圍 | 精度 | 備註 |
# |------|---------|---------|---------|------|---------||
# | fp32 | 8 | 23 | 大 | 高 | 訓練標準基準 |
# | fp16 | 5 | 10 | 小（易溢位）| 中 | 需 loss scaling |
# | bf16 | 8 | 7 | 同 fp32 | 略低 | 無需 loss scaling，Ampere+ GPU 原生加速 |
#
# bf16 保留與 fp32 相同的指數範圍，不易在訓練中出現 `inf`/`nan`，是 2026 微調的首選。
#
# **`device_map='auto'` 語意**：transformers + accelerate 根據可用 VRAM 自動決定每一層放 GPU / CPU / disk（offload），無需手動 `.cuda()`。
#
# **`use_safetensors=True`**：優先下載 `.safetensors` 格式，載入速度比 `.bin`（pickle）快 2–3 倍，且不會執行任意 Python 程式碼（安全性保障）。
#
# > `num_labels=1` 表示輸出單一 logit，搭配 `MSELoss` 做回歸——這是 Cross-Encoder 相似度的正確設計。

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_ID,
    num_labels=1,           # 回歸輸出：單一連續分數
    device_map="auto",      # 自動分配 GPU/CPU，取代 .cuda() 或 device=0
    torch_dtype=torch.bfloat16,  # bf16：省 VRAM、穩定訓練
    use_safetensors=True,   # 優先 safetensors；舊 checkpoint 無此格式時會自動 fallback
)
print(model.config)
print("\ndevice:", next(model.parameters()).device)
print("dtype: ", next(model.parameters()).dtype)

# %% [markdown]
# ## Step 6 — 建立評估函數
#
# ### 設計決策：回歸任務的評測策略
#
# 回歸輸出需要兩層評測：
#
# 1. **連續分數**：`pearsonr` 衡量預測分數與真實標籤的線性相關，反映模型分數的排序品質。
# 2. **業務閾值**：accuracy / F1 對二元化後的結果（threshold 0.5）評估「相似 / 不相似」的分類品質。
#
# | 指標 | 說明 | 用途 |
# |------|------|---------||
# | `pearson_r` | 連續預測分數與真實標籤的線性相關 | 回歸品質；STS-B 官方指標 |
# | `accuracy` | 二元化（閾值 0.5）後的準確率 | 業務判斷「相似 / 不相似」|
# | `f1` | 二元化後的 F1 | 不平衡語料下比 accuracy 更穩 |

# %%
acc_metric = evaluate.load("accuracy")
f1_metric  = evaluate.load("f1")

def eval_metric(eval_predict):
    predictions, labels = eval_predict
    # predictions shape: (N, 1) from num_labels=1; squeeze to (N,)
    predictions = predictions.squeeze(-1)

    # -- 連續分數：Pearson 相關係數 --
    pearson_r, _ = pearsonr(predictions, labels)

    # -- 業務用途：閾值 0.5 二元化 --
    binary_preds  = [int(p > 0.5) for p in predictions]
    binary_labels = [int(l > 0.5) for l in labels]

    acc = acc_metric.compute(predictions=binary_preds, references=binary_labels)
    f1  = f1_metric.compute( predictions=binary_preds, references=binary_labels)

    return {
        "pearson_r": round(float(pearson_r), 4),
        "accuracy":  acc["accuracy"],
        "f1":        f1["f1"],
    }

# %% [markdown]
# ## Step 7 — TrainingArguments
#
# **Effective batch size = `per_device_train_batch_size` × `gradient_accumulation_steps` × GPU 數**
#
# 若 VRAM 不足，可把 `per_device_train_batch_size=8` + `gradient_accumulation_steps=4` 等效替代原本的 32。
#
# 主要參數說明：
#
# - `bf16=True`：省 VRAM、加速收斂，Ampere+ GPU 原生支援。
# - `optim="adamw_torch_fused"`：torch fused kernel，比標準 AdamW 快 ~10%。
# - `lr_scheduler_type="cosine"`：末期平滑衰減，優於 linear。
# - `warmup_ratio=0.1`：前 10% steps 線性 warmup，防止初期 loss spike。
# - `max_grad_norm=1.0`：梯度裁剪，穩定 bf16 訓練。
# - `eval_strategy="steps"`：依步數評估。
# - `save_safetensors=True`：輸出 `.safetensors` 取代 `.bin`（pickle），安全且快速。
# - `seed=42`：固定所有隨機源，確保可重現性。

# %%
from pathlib import Path

OUTPUT_DIR = Path("./cross_model_output")

train_args = TrainingArguments(
    output_dir=str(OUTPUT_DIR),
    # -- 批次設定 --
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    gradient_accumulation_steps=1,   # effective batch = 32 × 1 = 32
    # -- 訓練排程 --
    num_train_epochs=3,
    learning_rate=2e-5,
    weight_decay=0.01,
    warmup_ratio=0.1,                # 前 10% steps 線性 warmup
    lr_scheduler_type="cosine",      # cosine 衰減，末期平滑
    max_grad_norm=1.0,               # 梯度裁剪
    # -- 精度與優化器 --
    bf16=True,                       # bfloat16，Ampere+ GPU；CPU 會自動 fallback fp32
    optim="adamw_torch_fused",       # torch fused AdamW，比 adamw_torch 快 ~10%
    # -- 評估與儲存 --
    eval_strategy="steps",
    eval_steps=100,
    save_strategy="steps",
    save_steps=100,
    save_total_limit=3,
    metric_for_best_model="pearson_r",  # 以連續分數排名為主指標
    greater_is_better=True,
    load_best_model_at_end=True,
    # -- 日誌與可重現性 --
    logging_steps=50,
    seed=42,
    # -- 儲存格式 --
    save_safetensors=True,           # 輸出 .safetensors 取代 .bin
)
print(train_args)

# %% [markdown]
# ## Step 8 — 建立 Trainer
#
# `DataCollatorWithPadding` 接受 `tokenizer` 並在每個 batch 動態補齊到該 batch 最長序列，比固定 `max_length=128` 節省 10–30% 計算量（短句子不用補到 128）。

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

trainer = Trainer(
    model=model,
    args=train_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    compute_metrics=eval_metric,
)
print("訓練集大小:", len(tokenized_datasets["train"]))
print("驗證集大小:", len(tokenized_datasets["test"]))

# %% [markdown]
# ## Step 9 — 模型訓練

# %%
trainer.train()

# %% [markdown]
# ## Step 10 — 模型評估
#
# `trainer.evaluate()` 使用 `compute_metrics` 同時回報 `pearson_r`、`accuracy`、`f1`。
#
# - **`pearson_r`**：STS-B 官方評測指標，目標 > 0.85。
# - **`accuracy` / `f1`**：業務角度的分類品質（threshold 0.5）。

# %%
eval_results = trainer.evaluate(tokenized_datasets["test"])
print("評估結果：")
for k, v in eval_results.items():
    print(f"  {k}: {v}")

# %% [markdown]
# ## Step 11 — 儲存模型
#
# 使用 `pathlib` 管理本地路徑，並以 `safe_serialization=True` 強制輸出 `.safetensors` 格式，確保安全性與載入速度。同時持久化 `id2label` 與 `problem_type`，方便推論時直接讀取 config。

# %%
# 持久化 id2label（方便推論時直接讀取）
model.config.id2label = {0: "相似度分數"}  # 回歸任務只有一個輸出
model.config.problem_type = "regression"

SAVE_PATH = OUTPUT_DIR / "best_model"
model.save_pretrained(SAVE_PATH, safe_serialization=True)
tokenizer.save_pretrained(SAVE_PATH)
print("模型已儲存至:", SAVE_PATH.resolve())

# -- 可選：push_to_hub --
# trainer.push_to_hub(
#     commit_message="2026 cross-encoder chinese-macbert-base STS",
# )

# %% [markdown]
# ## Step 12 — 模型預測（pipeline）
#
# 從剛才儲存的 `best_model` 重新載入，以 `device_map='auto'` 讓 accelerate 自動決定最佳設備。`function_to_apply="none"` 讓 pipeline 直接回傳原始 logit（回歸分數），不通過 softmax。

# %%
from transformers import pipeline

# 從剛才儲存的 best_model 重新載入，示範完整推論路徑
inference_pipe = pipeline(
    "text-classification",
    model=str(SAVE_PATH),
    tokenizer=str(SAVE_PATH),
    device_map="auto",           # 自動選擇最佳設備
    torch_dtype=torch.bfloat16,
    function_to_apply="none",    # 回歸：直接回傳 logit，不套 sigmoid/softmax
)

# 測試句對
test_pairs = [
    {"text": "我喜歡台灣",   "text_pair": "台灣是個好地方"},
    {"text": "我喜歡台灣",   "text_pair": "今天天氣不好"},
    {"text": "這部電影很好看", "text_pair": "這部片非常精彩"},
]

for pair in test_pairs:
    result = inference_pipe(pair)
    score  = result[0]["score"]  # 回歸分數，理論範圍 [0, 1]
    label  = "相似" if score > 0.5 else "不相似"
    print(f"[{label}] score={score:.4f}  |  '{pair['text']}' vs '{pair['text_pair']}'")

# %% [markdown]
# ## 小結
#
# 本 notebook 示範了 Cross-Encoder 文本相似度微調的完整 2026 流程：
#
# 1. **資料**：`load_dataset` 從 HF Hub 取得公開中文 STS 資料，`map(batched=True)` 快速 tokenize。
# 2. **模型**：`device_map='auto'` + `torch_dtype=bfloat16` + `use_safetensors=True`，一行搞定裝置/精度/格式。
# 3. **訓練**：`TrainingArguments` 補齊 `bf16`、`eval_strategy`、`optim='adamw_torch_fused'`、`warmup_ratio`、`save_safetensors` 等現代化參數。
# 4. **評測**：同時計算 Pearson 相關係數（回歸品質）與 accuracy / F1（業務閾值）。
# 5. **儲存**：`save_pretrained(safe_serialization=True)` 輸出 safetensors，pipeline 用 `device_map='auto'` 推論。
#
# ## 延伸練習
#
# 1. 把 `metric_for_best_model` 改為 `"f1"`，觀察選出的 checkpoint 是否與 `pearson_r` 最佳的一致。
# 2. 在 `process_function` 中把 `max_length` 從 128 調整為 64 / 256，觀察速度與效果的 trade-off。
# 3. 把本 notebook 的 Cross-Encoder 與 `dual_model.ipynb` 的 Bi-Encoder 在相同測試集上比較 Pearson 分數，驗證「Cross-Encoder 精度更高但速度更慢」的理論。
# 4. （進階）在 `eval_metric` 中加入 Spearman 相關係數（`scipy.stats.spearmanr`），與 Pearson 比較，看哪個更能反映模型的排序品質。
