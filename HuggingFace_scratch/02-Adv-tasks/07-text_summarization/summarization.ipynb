# %% [markdown]
# # T5 Encoder-Decoder 文本摘要（2026 版）
#
# ## 學習目標
#
# 1. 理解 Seq2Seq（編碼器-解碼器）架構在摘要任務上的工作原理
# 2. 掌握 2026 統一載入慣例：`device_map='auto'`、`torch.bfloat16`、`use_safetensors=True`
# 3. 使用 `evaluate` 函式庫取代 `rouge_chinese`，標準化 ROUGE 評測
# 4. 以完整 `Seq2SeqTrainingArguments`（含 bf16、cosine warmup、AdamW fused）取代最簡設定
# 5. 正確理解 `DataCollatorForSeq2Seq` 的動態 padding 與 `-100` 標籤遮罩機制
#
# ## 前置知識
#
# - 熟悉 HuggingFace `Trainer` 基本用法（參見 `02-Adv-tasks/05-token_classification/`）
# - 了解 Tokenizer 基礎與 `input_ids` / `labels` 對應關係
#
# ## 相鄰 notebook
#
# - 上一個：`../06-question_answering/question_answering.ipynb`
# - 下一個：`../08-machine_translation/translation.ipynb`
#
# ## 資料集
#
# NLPCC 2017 中文新聞標題生成（本機磁碟）——輸入為新聞全文，目標為標題（即摘要）。

# %% [markdown]
# ## 環境鎖版本
#
# 以下版本組合經過測試，可穩定執行本 notebook。首次執行時取消註解安裝。

# %%
# pip install 版本鎖定（首次執行取消註解）
# !pip install \
#   "transformers>=4.46" \
#   "datasets>=3.0" \
#   "evaluate>=0.4" \
#   "accelerate>=1.0" \
#   "safetensors>=0.4" \
#   "sentencepiece>=0.2" \
#   "torch>=2.4" \
#   "rouge_score>=0.1.2"

# 注意：rouge_chinese 已不維護且與 evaluate 不相容；
# 2026 統一改用 evaluate.load('rouge') + rouge_score 後端。

# %% [markdown]
# ## Step 1  匯入套件
#
# 2026 套件選擇說明：
#
# - 評測：`evaluate.load('rouge')`——`evaluate` 統一介面、支援 batch，`rouge_score` 後端積極維護
# - 訓練參數：`eval_strategy='steps'`——`transformers >= 4.46` 的正式參數名稱
# - 裝置指定：`device_map='auto'`——可透明處理 CPU-only 環境，不需手動判斷 GPU 編號

# %%
import os
import numpy as np
import torch
import evaluate
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    DataCollatorForSeq2Seq,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    EarlyStoppingCallback,
    set_seed,
)
from datasets import load_from_disk

# 全域種子，保證可重現性
set_seed(42)

print(f"torch version  : {torch.__version__}")
print(f"CUDA available : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU            : {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ## Step 2  載入資料集
#
# 原 notebook 從本機磁碟讀取預先下載的 NLPCC 2017 資料集。
# 若尚未下載，可改用 HuggingFace Hub 上的公開版本（取消下方 `load_dataset` 那段的註解）。
#
# **關於 train/test 分割**
#
# 原程式碼使用 `train_test_split(100, seed=42)` 將「整個資料集」切出 100 筆作測試集，
# 其餘全部作訓練集。本版保留這個行為，但明確改寫成 `test_size=100` 讓意圖清晰。

# %%
# 方案 A：從本機磁碟讀取（原始寫法，路徑改成 pathlib 管理）
from pathlib import Path

DATA_DIR = Path(os.environ.get("NLPCC_DATA_DIR", "./nlpcc_2017"))

# 方案 B（備用）：HuggingFace Hub 公開資料集，取消下面兩行的註解並刪除方案 A
# from datasets import load_dataset
# raw_ds = load_dataset("supremacy/nlpcc_2017", split="train")  # 依實際 Hub ID 調整

raw_ds = load_from_disk(str(DATA_DIR))
print(raw_ds)

# %%
# 檢視一筆樣本
print(raw_ds[0])

# %%
# 切出測試集（100 筆），其餘作訓練
ds = raw_ds.train_test_split(test_size=100, seed=42)
print(ds)
print("\n訓練集筆數:", len(ds["train"]))
print("測試集筆數:", len(ds["test"]))

# %% [markdown]
# ## Step 3  Tokenizer 初始化
#
# **2026 統一載入慣例**
#
# Tokenizer 本身不需要 `device_map` / `torch_dtype`，但後續模型載入一律使用：
#
# ```python
# AutoModelForSeq2SeqLM.from_pretrained(
#     model_id,
#     device_map='auto',      # 自動分配 GPU / CPU / disk offload
#     torch_dtype=torch.bfloat16,  # bf16 優於 fp16：更大動態範圍、無梯度溢位
#     use_safetensors=True,   # 取代 pickle 格式，安全且載入速度快 2-3x
# )
# ```
#
# **為何選 bf16 而非 fp16 或 fp32？**
# - `fp32`：全精度，記憶體佔用最高（4 bytes/param）
# - `fp16`：半精度，指數位元只有 5 bit，訓練時容易梯度溢位（underflow/overflow）
# - `bf16`：Brain Float 16，指數位元與 fp32 相同（8 bit），尾數精度略低但訓練穩定，A100/H100/RTX 3090+ 原生支援

# %%
MODEL_ID = "Langboat/mengzi-t5-base"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
print(tokenizer)

# %%
# 確認 pad_token_id（DataCollatorForSeq2Seq 與 compute_metrics 都需要用到）
print("pad_token_id :", tokenizer.pad_token_id)
print("eos_token_id :", tokenizer.eos_token_id)

# %% [markdown]
# ## Step 4  資料前處理
#
# ### Tokenize 函式設計重點
#
# 1. **Prefix**：`'摘要生成: \n'` 告訴 T5 執行哪種任務。T5 原論文對每項任務都有獨立 prefix，這是 Seq2Seq 的標準做法。
# 2. **截斷長度**：`max_length=384`（輸入）與 `max_length=64`（標籤）。新聞標題通常短，64 token 足夠。
# 3. **Labels**：`tokenizer(text_target=...)` 是推薦寫法，比手動指定 `labels` 更清晰。
#    `DataCollatorForSeq2Seq` 在組 batch 時會把 `labels` 中的 padding 位置替換成 `-100`，
#    讓 `CrossEntropyLoss` 自動忽略 padding token，不列入 loss 計算。
# 4. **batched=True**：向量化批次處理，比逐筆快 3-5 倍。
#
# **為何不用固定長度 padding？**
# `DataCollatorForSeq2Seq` 採用動態 padding：每個 batch 只 pad 到該 batch 最長序列，
# 節省記憶體並加快訓練速度，相較固定 128/512 padding 可省 30-50% 的無效計算。

# %%
MAX_INPUT_LENGTH = 384
MAX_TARGET_LENGTH = 64
TASK_PREFIX = "摘要生成: \n"


def process_func(examples):
    """Tokenize source content and target title for Seq2Seq training."""
    # 加入任務前綴
    contents = [TASK_PREFIX + text for text in examples["content"]]

    # tokenize 輸入
    model_inputs = tokenizer(
        contents,
        max_length=MAX_INPUT_LENGTH,
        truncation=True,
        # 不在此 padding：由 DataCollatorForSeq2Seq 動態 padding
    )

    # tokenize 標籤（text_target 參數，語意清晰）
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            examples["title"],
            max_length=MAX_TARGET_LENGTH,
            truncation=True,
        )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_ds = ds.map(
    process_func,
    batched=True,
    num_proc=1,      # 若 CPU 多核心可調高，Windows WSL 建議保持 1
    remove_columns=ds["train"].column_names,  # 移除原始文字欄，減少記憶體
    desc="Tokenizing",
)
print(tokenized_ds)

# %%
# 驗證：還原 input_ids 與 labels，確認 tokenize 結果正確
print("=== 輸入 (input_ids) ===")
print(tokenizer.decode(tokenized_ds["train"][0]["input_ids"]))
print("\n=== 標籤 (labels) ===")
print(tokenizer.decode(tokenized_ds["train"][0]["labels"]))

# %% [markdown]
# ## Step 5  載入模型
#
# ### VRAM 需求估算
#
# | 精度 | mengzi-t5-base（~250M params）| 備用方案 |
# |---|---|---|
# | fp32 | ~1.0 GB | — |
# | bf16 | ~0.5 GB | — |
# | 4-bit (nf4) | ~0.3 GB | 適合 < 4 GB VRAM |
#
# `mengzi-t5-base` 很小，bf16 在任何現代 GPU（甚至 CPU）都跑得動。
# 若改為大型模型（如 mT5-large / FLAN-T5-XL），則需考慮 `BitsAndBytesConfig` 量化。
#
# **safetensors vs pickle**
# - `use_safetensors=True`：格式驗證嚴格，不執行任意程式碼，載入速度快 2-3x
# - 舊 `.bin` 格式（pickle）：理論上可嵌入惡意程式碼，不建議在生產環境使用

# %%
# 2026 統一載入慣例
# device_map='auto' 自動決定是否用 GPU；bf16 節省記憶體且訓練穩定
# mengzi-t5-base 的 Hub 可能尚未有 safetensors 版本，
# 若出現 OSError 請改為 use_safetensors=False
model = AutoModelForSeq2SeqLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    use_safetensors=False,  # mengzi-t5-base 目前無 safetensors；有則改 True
)
print(model.config.model_type)
print(f"參數量: {model.num_parameters() / 1e6:.1f} M")

# %% [markdown]
# ## Step 6  評估函式
#
# ### ROUGE 指標說明
#
# | 指標 | 計算方式 | 適合場景 |
# |---|---|---|
# | ROUGE-1 | unigram 重疊率 | 字彙覆蓋程度 |
# | ROUGE-2 | bigram 重疊率 | 短語順序保留 |
# | ROUGE-L | 最長公共子序列 | 整體語序相似度 |
#
# **`evaluate.load('rouge')` 的優勢**
#
# - `evaluate` 函式庫的 `rouge` 後端使用 `rouge_score`，支援空格分詞（中文逐字加空格）
# - 介面與 `Trainer.compute_metrics` 直接相容，不需手動 import
# - 積極維護，與最新 `tokenizers` / `transformers` 完整相容
#
# **中文 ROUGE 的字元分詞**：中文沒有空格，需要先把每個字元用空格分開，
# `rouge_score` 才能正確計算 unigram/bigram 重疊。

# %%
rouge_metric = evaluate.load("rouge")


def compute_metrics(eval_pred):
    """Compute ROUGE scores for Chinese summarization.

    Labels contain -100 at padding positions (set by DataCollatorForSeq2Seq);
    we replace them with pad_token_id before decoding.
    """
    predictions, labels = eval_pred

    # decode predictions
    decoded_preds = tokenizer.batch_decode(
        predictions, skip_special_tokens=True
    )

    # 把 -100 還原成 pad_token_id，再 decode
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(
        labels, skip_special_tokens=True
    )

    # 中文逐字加空格，讓 rouge_score 能正確計算 unigram/bigram
    decoded_preds = [" ".join(p) for p in decoded_preds]
    decoded_labels = [" ".join(l) for l in decoded_labels]

    result = rouge_metric.compute(
        predictions=decoded_preds,
        references=decoded_labels,
        use_stemmer=False,
    )
    # 只保留 F1（rouge_score 預設回傳 precision/recall/fmeasure）
    return {
        "rouge1": result["rouge1"],
        "rouge2": result["rouge2"],
        "rougeL": result["rougeL"],
    }

# %% [markdown]
# ## Step 7  訓練參數設定
#
# ### 2026 完整 `Seq2SeqTrainingArguments`
#
# **關鍵參數說明**
#
# | 參數 | 值 | 原因 |
# |---|---|---|
# | `bf16=True` | True | bf16 訓練穩定，A100/H100/RTX 30xx+ 原生支援 |
# | `optim='adamw_torch_fused'` | — | PyTorch 2.0+ fused kernel，比標準 AdamW 快 10-15% |
# | `warmup_ratio=0.1` | — | 前 10% steps 線性 warmup，防止初期大 LR 破壞預訓練權重 |
# | `lr_scheduler_type='cosine'` | — | cosine decay 收斂比 linear 更平滑 |
# | `max_grad_norm=1.0` | — | 梯度裁剪，防止 Seq2Seq 常見的梯度爆炸 |
# | `eval_strategy='steps'` | 'steps' | `transformers >= 4.46` 的正式參數名稱 |
# | `save_safetensors=True` | True | checkpoint 以 safetensors 格式儲存 |
# | `load_best_model_at_end=True` | True | 訓練結束自動載入最佳 checkpoint |
# | `seed=42` | 42 | 固定全域種子（與 `set_seed(42)` 雙保險）|
# | `predict_with_generate=True` | True | Seq2Seq 必須：用 generate() 解碼，而非直接取 logits |
#
# **Effective Batch Size 計算**
#
# ```
# effective_batch = per_device_train_batch_size × gradient_accumulation_steps × GPU 數量
#                 = 4 × 8 × 1 = 32
# ```
#
# 梯度累積（`gradient_accumulation_steps`）讓小顯卡模擬大 batch，
# 每 `gradient_accumulation_steps` 個 mini-batch 才做一次參數更新。

# %%
OUTPUT_DIR = "./summary_2026"

args = Seq2SeqTrainingArguments(
    output_dir=OUTPUT_DIR,
    # ------- batch & gradient -------
    per_device_train_batch_size=4,
    per_device_eval_batch_size=8,
    gradient_accumulation_steps=8,      # effective batch = 4 × 8 = 32
    # ------- precision -------
    bf16=True,                          # bf16 優於 fp16，訓練更穩定
    # ------- optimizer & scheduler -------
    optim="adamw_torch_fused",          # PyTorch 2.0+ fused AdamW
    learning_rate=5e-4,
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    max_grad_norm=1.0,
    # ------- logging & eval -------
    num_train_epochs=3,
    logging_steps=8,
    eval_strategy="steps",              # transformers >= 4.46 正式參數名稱
    eval_steps=50,
    save_strategy="steps",
    save_steps=50,
    save_total_limit=2,                 # 只保留最近 2 個 checkpoint
    # ------- best model -------
    metric_for_best_model="rougeL",
    greater_is_better=True,
    load_best_model_at_end=True,
    # ------- safetensors & reproduce -------
    save_safetensors=True,
    seed=42,
    # ------- Seq2Seq 特有 -------
    predict_with_generate=True,
    generation_max_length=MAX_TARGET_LENGTH,
)
print(args)

# %% [markdown]
# ## Step 8  建立 Trainer
#
# ### `DataCollatorForSeq2Seq` 的作用
#
# - **動態 padding**：每個 batch 只 pad 到該 batch 最長序列，不浪費計算
# - **-100 標籤遮罩**：自動把 labels 的 padding 位置設成 `-100`，
#   讓 `CrossEntropyLoss` 忽略這些位置（不計入 loss）
# - **decoder_input_ids**：自動為 decoder 生成右移（right-shifted）的輸入
#
# ### EarlyStoppingCallback
#
# `patience=3`：若連續 3 次 eval 的 `rougeL` 沒有改善，提早停止訓練，節省時間。

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    train_dataset=tokenized_ds["train"],
    eval_dataset=tokenized_ds["test"],
    compute_metrics=compute_metrics,
    processing_class=tokenizer,         # transformers >= 4.46 取代 tokenizer=
    data_collator=DataCollatorForSeq2Seq(
        tokenizer=tokenizer,
        model=model,
        padding=True,                   # 動態 padding
        pad_to_multiple_of=8,           # bf16/tf32 對齊，略提升硬體效率
    ),
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %% [markdown]
# ## Step 9  模型訓練
#
# 訓練前先確認：
# - VRAM 是否足夠（mengzi-t5-base bf16 約需 1-2 GB）
# - `bf16=True` 需要 CUDA compute capability >= 8.0（Ampere 以上）；
#   若低於此版本請改 `fp16=True`

# %%
# 開始訓練
# 預計時間視 GPU 而定：RTX 3090 約 5-10 分鐘（3 epoch, 100 test samples）
train_result = trainer.train()

# 儲存訓練統計
trainer.log_metrics("train", train_result.metrics)
trainer.save_metrics("train", train_result.metrics)

# %%
# 儲存最佳模型（safetensors 格式）
trainer.save_model(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)
print(f"模型已儲存至 {OUTPUT_DIR}")

# %% [markdown]
# ## Step 10  模型推理
#
# ### 2026 pipeline 慣例
#
# ```python
# pipe = pipeline("text2text-generation", model=model, tokenizer=tokenizer, device_map="auto")
# ```
#
# `device_map='auto'` 讓 HuggingFace 自動決定最佳裝置，在 CPU-only 或多 GPU 環境都能正確運行，不需手動指定裝置編號。

# %%
from transformers import pipeline

# device_map='auto' 自動選擇裝置
pipe = pipeline(
    "text2text-generation",
    model=model,
    tokenizer=tokenizer,
    device_map="auto",
)

# %%
# 取測試集最後一筆做示範
test_sample = ds["test"][-1]
input_text = TASK_PREFIX + test_sample["content"]

prediction = pipe(
    input_text,
    max_new_tokens=MAX_TARGET_LENGTH,
    do_sample=False,    # 摘要任務通常用 greedy/beam，不用 sampling
    num_beams=4,        # beam search：平衡品質與速度
)

print("=== 模型預測 ===")
print(prediction[0]["generated_text"])
print("\n=== 參考標題 ===")
print(test_sample["title"])

# %%
# 批次推理：評估整個測試集（可選）
test_contents = [TASK_PREFIX + item["content"] for item in ds["test"]]
test_titles = [item["title"] for item in ds["test"]]

predictions_batch = pipe(
    test_contents[:10],  # 先取前 10 筆示範
    max_new_tokens=MAX_TARGET_LENGTH,
    do_sample=False,
    num_beams=4,
    batch_size=8,
)

for i, (pred, ref) in enumerate(zip(predictions_batch, test_titles[:10])):
    print(f"[{i+1:02d}] 預測: {pred['generated_text']}")
    print(f"      參考: {ref}")
    print()

# %% [markdown]
# ## 小結
#
# ### 本 notebook 涵蓋的 2026 要點
#
# 1. **統一載入慣例**：`device_map='auto'` + `torch.bfloat16` + `use_safetensors`
#    確保 CPU/GPU/多 GPU 環境都能透明運行
#
# 2. **評測標準化**：`evaluate.load('rouge')` 提供統一介面、積極維護、與 HuggingFace 生態系完整相容
#
# 3. **完整 TrainingArguments**：`bf16`、`cosine` scheduler、`adamw_torch_fused`、
#    `eval_strategy='steps'`、`save_safetensors=True` 構成現代化訓練配置
#
# 4. **動態 padding**：`DataCollatorForSeq2Seq(padding=True, pad_to_multiple_of=8)`
#    節省記憶體，比固定長度 padding 有效
#
# 5. **EarlyStoppingCallback**：避免過擬合，節省訓練時間
#
# ### 練習題
#
# 1. 把 `MODEL_ID` 改成 `'google/flan-t5-base'`（英文模型），用英文新聞摘要資料集（如 `cnn_dailymail`）重跑一遍，比較 ROUGE 差距。
#
# 2. 加入 `generation_num_beams=4`（在 `Seq2SeqTrainingArguments` 中），觀察 beam search 對 eval ROUGE 的影響。
#
# 3. 在 `compute_metrics` 中加入平均預測長度（`mean_pred_length`），分析模型是否有「縮短輸出」的傾向。
#
# 4. （進階）改用 `mT5-small`（多語言 T5）並調整 `MAX_INPUT_LENGTH=512`，觀察更長上下文對 ROUGE-L 的改善幅度。
