# %% [markdown]
# # 文本分類微調與訓練優化 (2026 版)
#
# ## 學習目標
#
# 1. 掌握使用 HuggingFace `Trainer` 進行監督式文本分類微調的完整十步流程。
# 2. 理解訓練記憶體的組成：模型權重、優化器狀態、梯度、激活值。
# 3. 學會三大記憶體優化技術：梯度累加（gradient accumulation）、梯度檢查點（gradient checkpointing）、參數凍結（parameter freezing）。
# 4. 掌握 2026 現代化慣例：`bf16`、`adamw_torch_fused`、動態 padding、`eval_strategy`。
#
# ## 前置需求
#
# - Python 3.10+
# - CUDA 可用 GPU（推薦 VRAM >= 16GB；VRAM < 8GB 請參考本 notebook 的輕量替代方案）
# - 已完成：`01-pipeline-tasks` 模組（了解 pipeline 基礎）
#
# ## 與相鄰 notebook 的銜接
#
# - 上一個：`../00-intro/` 介紹 HuggingFace 生態系
# - 下一個：`02 LoRA_finetune_demo.ipynb` — 以 LoRA 做參數高效微調（PEFT），進一步減少 VRAM 需求

# %% [markdown]
# ## 版本鎖定
#
# 確保所有人使用相同的套件版本，避免 API 不兼容。

# %%
# Install pinned versions for reproducibility
# Run once; restart kernel afterward if installing fresh
# %pip install -q \
    "transformers>=4.46" \
    "datasets>=3.0" \
    "evaluate>=0.4" \
    "accelerate>=1.0" \
    "safetensors>=0.4" \
    "scikit-learn>=1.4" \
    "torch>=2.4"

# %% [markdown]
# ## 訓練參數記憶體速算
#
# 在開始動手之前，先建立「訓練時 GPU 記憶體去哪了」的直覺：
#
# | 組成 | 每參數位元組數 | 說明 |
# |---|---|---|
# | 模型權重（bf16） | 2 B | 推論與訓練皆需要 |
# | 梯度（fp32） | 4 B | 反向傳播計算 |
# | AdamW 優化器狀態 | 8 B | 一階動量 + 二階動量各 4B |
# | 前向激活值 | 取決於 batch size × 序列長度 × 隱藏維度 | 最難控制的變數 |
#
# **範例**：`chinese-macbert-large`（330M 參數）完整訓練在 bf16 下，僅權重+梯度+優化器就需要約 `330M × (2+4+8) = 4.6 GB`，激活值另計。這就是為什麼梯度累加與梯度檢查點如此重要。

# %% [markdown]
# ## 完整十步流程概覽
#
# ```
# STEP 1  安裝/匯入函式庫
# STEP 2  下載數據集（HF Hub，移除硬路徑）
# STEP 3  切分數據集（stratify 避免類別不平衡）
# STEP 4  資料預處理（tokenizer + batched map + 動態 padding）
# STEP 5  載入預訓練模型（device_map='auto', torch_dtype=bfloat16）
# STEP 6  定義評估函數（accuracy + precision + recall + F1）
# STEP 7  配置訓練參數（TrainingArguments 2026 完整版）
# STEP 8  建立 Trainer（DataCollatorWithPadding + EarlyStopping）
# STEP 9  訓練 / 評估 / 預測 + 混淆矩陣分析
# STEP 10 推論 + 模型儲存（safetensors）
# ```

# %% [markdown]
# ## Step 1 — 匯入函式庫

# %%
import torch
import numpy as np
import evaluate
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
    EarlyStoppingCallback,
    set_seed,
)
from datasets import load_dataset
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Reproducibility: fix all random seeds (Python / NumPy / PyTorch / CUDA)
set_seed(42)

# %% [markdown]
# ## Step 2 — 下載數據集
#
# **2026 慣例**：移除所有 Google Drive mount 與 `d:/` 本機硬路徑。改用 HuggingFace Hub 的 dataset id，環境無關、可重現。
#
# `ChnSentiCorp` 是酒店評論情感分類資料集（正面/負面），原始來源與本 notebook 教學主題完全一致。
#
# > 若網路受限，可改用 `load_dataset("csv", data_files="your_local.csv")` 或透過環境變數 `HF_DATASETS_CACHE` 指定快取路徑。

# %%
# Load ChnSentiCorp from HF Hub — no local path needed
# The dataset has 'text' and 'label' columns (0=negative, 1=positive)
raw_dataset = load_dataset("seamew/ChnSentiCorp")
print(raw_dataset)
print(raw_dataset["train"][0])

# %% [markdown]
# ## Step 3 — 切分數據集
#
# **2026 慣例**：使用 `stratify_by_column` 確保訓練集與驗證集的類別比例一致，避免因隨機分割導致類別不平衡而高估 accuracy。
#
# HF Hub 上的 `seamew/ChnSentiCorp` 已附帶 train/validation/test split，直接使用即可；若只有 train split，才需要手動 `train_test_split`。

# %%
# Use the pre-split train/validation/test from the Hub
train_ds = raw_dataset["train"]
val_ds   = raw_dataset["validation"]
test_ds  = raw_dataset["test"]

print(f"Train: {len(train_ds)}, Val: {len(val_ds)}, Test: {len(test_ds)}")
print("Label distribution (train):",
      {label: train_ds["label"].count(label) for label in set(train_ds["label"])})

# %% [markdown]
# **備用：若資料集只有 train split，如何做分層切分**
#
# ```python
# # stratify_by_column ensures equal class ratio in both subsets
# splits = raw_dataset["train"].train_test_split(
#     test_size=0.1,
#     stratify_by_column="label",
#     seed=42,
# )
# train_ds, val_ds = splits["train"], splits["test"]
# ```

# %% [markdown]
# ## Step 4 — 資料預處理
#
# **2026 慣例**：tokenize 時不做 padding，交給 `DataCollatorWithPadding` 在每個 batch 組裝時動態對齊，並以 `num_proc` 啟用多核加速，`remove_columns` 移除原始文字欄位。
#
# **為何動態 padding 更好**：固定長度會把短句填充至最大長度，浪費計算；動態 padding 只對齊當前 batch 的最長序列，可節省 20-40% 的 FLOP。

# %%
MODEL_ID = "hfl/chinese-macbert-large"  # ~330M params; VRAM ~4GB (bf16 inference)
# Lightweight alternative for VRAM < 8 GB:
# MODEL_ID = "hfl/chinese-macbert-base"  # ~102M params

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

def tokenize_fn(examples):
    # No padding here — DataCollatorWithPadding handles it per batch (dynamic)
    # truncation=True caps at model max length (512 for BERT-family)
    return tokenizer(
        examples["text"],
        max_length=512,
        truncation=True,
    )

# batched=True: ~3-5x faster than row-by-row; num_proc uses all CPU cores
tokenized_train = train_ds.map(tokenize_fn, batched=True,
                               num_proc=4, remove_columns=["text"])
tokenized_val   = val_ds.map(tokenize_fn,   batched=True,
                             num_proc=4, remove_columns=["text"])
tokenized_test  = test_ds.map(tokenize_fn,  batched=True,
                              num_proc=4, remove_columns=["text"])

print(tokenized_train)
print(tokenized_train[0])

# %% [markdown]
# ## Step 5 — 載入預訓練模型
#
# **2026 慣例**：使用 `device_map='auto'` 搭配 `torch_dtype=torch.bfloat16` 載入模型。
#
# ### 為何 bf16 優於 fp16 / fp32？
#
# | 精度 | 指數位元 | 小數位元 | 優點 | 缺點 |
# |---|---|---|---|---|
# | fp32 | 8 | 23 | 數值穩定 | VRAM 消耗最大 |
# | fp16 | 5 | 10 | 省 VRAM | 指數範圍小，易 overflow/underflow；需 loss scaling |
# | **bf16** | **8** | **7** | 指數範圍與 fp32 相同，訓練穩定；Ampere 以上 GPU 原生支援 | 精度略低於 fp16，但實務上對 NLP 任務無影響 |
#
# **結論**：Ampere（A100/3090/4090）以上優先選 bf16；older GPU 才考慮 fp16。
#
# ### `device_map='auto'` 的語意
#
# `accelerate` 根據可用 VRAM 自動決定每一層放 GPU / CPU / 磁碟，無需手動指定 device id。多 GPU 環境同樣適用。

# %%
# id2label / label2id — persisted into model config for proper pipeline output
id2label = {0: "負面", 1: "正面"}
label2id = {v: k for k, v in id2label.items()}

# 2026 unified loading convention
# device_map='auto': auto-places layers across GPU/CPU/disk based on available VRAM
# torch_dtype=torch.bfloat16: halves VRAM vs fp32 with better stability than fp16
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_ID,
    num_labels=2,
    id2label=id2label,
    label2id=label2id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)
print(f"Model dtype  : {model.dtype}")
print(f"Model device : {next(model.parameters()).device}")

# %% [markdown]
# ## Step 6 — 定義評估函數
#
# **2026 做法**：用 `evaluate.load()` 統一載入所有指標，在 `compute_metrics` 同時回傳 accuracy、precision、recall、F1，方便 Trainer 自動記錄至 log，也能完整診斷假陽性 vs 假陰性的取捨。

# %%
# Load all metrics via evaluate (unified API)
acc_metric  = evaluate.load("accuracy")
f1_metric   = evaluate.load("f1")          # fixed typo: was f1_metirc
prec_metric = evaluate.load("precision")
rec_metric  = evaluate.load("recall")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {
        **acc_metric.compute(predictions=predictions, references=labels),
        **f1_metric.compute(predictions=predictions,   references=labels, average="binary"),
        **prec_metric.compute(predictions=predictions, references=labels, average="binary"),
        **rec_metric.compute(predictions=predictions,  references=labels, average="binary"),
    }

# %% [markdown]
# ## Step 7 — 配置訓練參數 (TrainingArguments)
#
# 本節整合原 notebook 四個分散的「訓練計畫」，以**一份完整的 2026 TrainingArguments**並在 markdown 說明每個重要旗標的原理。
#
# ### 核心概念
#
# **effective batch size = per_device_train_batch_size × gradient_accumulation_steps × GPU 數量**
#
# - 想要 effective batch 32，但 VRAM 只允許 per_device=4 → 設 `gradient_accumulation_steps=8`
# - 梯度在 8 個 mini-batch 後才做一次參數更新，效果等同 batch 32，但記憶體峰值只需 batch 4
#
# **為何用 AdamW 而不是 Adam？**
#
# Adam 的 weight decay 實作有缺陷（與自適應學習率耦合），AdamW 修正了這個問題（Loshchilov & Hutter, 2019）。`adamw_torch_fused` 是 PyTorch 2.x 的融合 kernel，在相同效果下速度快 10-20%。
#
# **為何需要 warmup？**
#
# 訓練初期梯度估計雜訊大，若直接用峰值學習率容易破壞預訓練權重。Warmup 讓學習率從 0 線性升至峰值，再透過 cosine schedule 緩慢下降至接近 0，避免初期「過激更新」。
#
# **梯度檢查點（gradient checkpointing）**
#
# 正向傳播時只保留部分層的激活值（checkpoint），反向傳播時重算其餘層。代價是約 33% 的額外計算，換取顯著的記憶體節省（可省去 60-70% 的激活值記憶體）。

# %%
# 2026 unified TrainingArguments
# Demonstrates the memory-optimization progression discussed in the lecture
training_args = TrainingArguments(
    output_dir="./checkpoints",

    # --- Batch & accumulation ---
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    # effective batch = 16 * 2 = 32; reduce per_device to 4 and set accum=8
    # on VRAM < 8 GB to keep effective batch constant
    gradient_accumulation_steps=2,

    # --- Memory optimization ---
    # gradient checkpointing trades ~33% compute for ~60% activation memory savings
    gradient_checkpointing=True,
    bf16=True,                          # bfloat16: stable + half VRAM vs fp32

    # --- Optimizer & scheduler ---
    # adamw_torch_fused: same math as AdamW but 10-20% faster via PyTorch 2.x fused kernel
    optim="adamw_torch_fused",
    learning_rate=2e-5,
    weight_decay=0.01,
    max_grad_norm=1.0,                  # gradient clipping for training stability
    # warmup_ratio=0.1: learning rate ramps from 0 to peak over 10% of training steps
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",         # cosine decay after warmup

    # --- Epochs & logging ---
    num_train_epochs=3,
    logging_steps=50,

    # --- Evaluation & checkpointing ---
    eval_strategy="steps",              # 2026: replaces deprecated 'evaluation_strategy'
    eval_steps=200,
    save_strategy="steps",
    save_steps=200,
    save_total_limit=3,
    save_safetensors=True,              # save in safetensors format (not pickle)
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,

    # --- Reproducibility ---
    seed=42,
    data_seed=42,

    # --- Reporting ---
    report_to="none",                   # change to 'wandb' or 'tensorboard' as needed
)

# %% [markdown]
# ### 訓練優化選項對照表
#
# 以下是原 notebook 四個「訓練計畫」的整合說明：
#
# | 優化技術 | TrainingArguments 參數 | 記憶體影響 | 計算影響 | 何時使用 |
# |---|---|---|---|---|
# | 基線 | `per_device_batch=32` | 最高 | 最快 | VRAM 充裕（>= 24GB） |
# | 梯度累加 | `gradient_accumulation_steps=N` | 降低峰值 | 幾乎不變 | VRAM 不足但想維持 effective batch |
# | 梯度檢查點 | `gradient_checkpointing=True` | 顯著降低激活值記憶體 | +33% 計算 | VRAM 嚴重不足 |
# | 融合優化器 | `optim='adamw_torch_fused'` | 無變化 | 略快 10-20% | 永遠開啟（無副作用） |
# | 參數凍結 | 手動 `requires_grad=False` | 省去凍結層梯度 | 快 | 只微調分類頭時 |

# %% [markdown]
# ## Step 8 — 建立 Trainer
#
# ### DataCollatorWithPadding — 動態 padding
#
# `DataCollatorWithPadding` 在每個 batch 組裝時，只把序列 pad 到**當前 batch 的最長序列長度**，而非固定的全局最大長度。這讓短文本不會被大量填充，節省 FLOP。
#
# ### 參數凍結（Parameter Freezing）
#
# 凍結 BERT 底層的 encoder，只訓練最上層的分類頭（`classifier`）。優點：
# - 大幅減少需要梯度的參數數量 → 省記憶體、省時間
# - 適合資料量少、怕過擬合的場景
#
# 缺點：領域差異大時效果可能不如全量微調。
#
# ### EarlyStoppingCallback
#
# 連續 `early_stopping_patience` 次評估未改善就停止訓練，避免過擬合並節省時間。

# %%
# --- Optional: freeze BERT encoder, only train classification head ---
# Uncomment the block below to enable parameter freezing
# Frozen parameters have no gradient computed -> saves memory proportionally
#
# for name, param in model.bert.named_parameters():
#     param.requires_grad = False
# trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
# total     = sum(p.numel() for p in model.parameters())
# print(f"Trainable: {trainable:,} / {total:,} ({100*trainable/total:.1f}%)")

# Dynamic padding: only pad to the longest sequence in the current batch
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[
        # Stop if 'f1' does not improve for 3 consecutive evaluations
        EarlyStoppingCallback(early_stopping_patience=3)
    ],
)

# %% [markdown]
# ## Step 9 — 訓練、評估、預測

# %%
# Start fine-tuning
# Estimated time: ~15 min on A100 (macbert-large, full fine-tune)
# On VRAM < 8 GB: switch MODEL_ID to 'hfl/chinese-macbert-base' (~3 min on T4)
train_result = trainer.train()
print(train_result.metrics)

# %%
# Evaluate on validation set (Trainer automatically uses the best checkpoint)
val_metrics = trainer.evaluate(tokenized_val)
print("Validation metrics:", val_metrics)

# %%
# Evaluate on held-out test set
test_metrics = trainer.evaluate(tokenized_test)
print("Test metrics:", test_metrics)

# %%
# Full prediction output (includes logits for custom analysis)
pred_output = trainer.predict(tokenized_test)
print("Test metrics from predict():", pred_output.metrics)

# %% [markdown]
# ### 混淆矩陣分析
#
# 混淆矩陣讓我們看到哪類錯誤最多：
# - **假陽性（FP）**：模型說「正面」但其實是「負面」
# - **假陰性（FN）**：模型說「負面」但其實是「正面」
#
# 在情感分析場景中，FP 與 FN 的業務成本不同，矩陣幫助我們決定是否調整分類閾值。

# %%
# Confusion matrix on test set
y_pred = np.argmax(pred_output.predictions, axis=-1)
y_true = pred_output.label_ids

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[id2label[i] for i in range(len(id2label))],
)
fig, ax = plt.subplots(figsize=(5, 4))
disp.plot(ax=ax, colorbar=False, cmap="Blues")
ax.set_title("Confusion Matrix (Test Set)")
plt.tight_layout()
plt.show()

print(f"FP (predicted positive, actually negative): {cm[0, 1]}")
print(f"FN (predicted negative, actually positive): {cm[1, 0]}")

# %% [markdown]
# ## Step 10 — 推論與模型儲存
#
# ### 2026 儲存慣例：safetensors
#
# **2026 慣例**：`save_pretrained(safe_serialization=True)` 使用 safetensors 格式：
# - 不執行任意 Python 程式碼（無 pickle 安全漏洞）
# - 記憶體對映載入（`mmap`），速度快 2-10x
# - 已成為 HF Hub 的預設格式

# %%
# --- Single-sample inference without pipeline ---
# 2026: use model's device via next(model.parameters()).device
device = next(model.parameters()).device
id2label_local = {0: "負面", 1: "正面"}

sen = "這家酒店不錯，服務周到，餐點好吃！"

model.eval()
with torch.inference_mode():
    inputs = tokenizer(sen, return_tensors="pt", truncation=True, max_length=512)
    # Move inputs to the same device as model (handles CPU/GPU/multi-GPU automatically)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    logits = model(**inputs).logits
    pred_label = id2label_local[torch.argmax(logits, dim=-1).item()]

print(f"Input : {sen}")
print(f"Label : {pred_label}")

# %%
# --- Pipeline inference ---
# id2label is already stored in model.config, so pipeline outputs the label names
from transformers import pipeline

pipe = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    device_map="auto",
)
print(pipe(sen))
print(pipe(["房間乾淨舒適，強力推薦！", "服務態度極差，不會再來。"]))

# %% [markdown]
# ### 儲存模型

# %%
SAVE_DIR = "./my_sentiment_model"

# safe_serialization=True: saves in safetensors format (not pickle)
# This is the 2026 unified convention; Trainer already does this when save_safetensors=True
model.save_pretrained(SAVE_DIR, safe_serialization=True)
tokenizer.save_pretrained(SAVE_DIR)
print(f"Model and tokenizer saved to {SAVE_DIR}")

# %%
# Reload the saved model — same unified loading convention
from transformers import AutoModelForSequenceClassification, AutoTokenizer

loaded_model = AutoModelForSequenceClassification.from_pretrained(
    SAVE_DIR,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)
loaded_tokenizer = AutoTokenizer.from_pretrained(SAVE_DIR)
print("Loaded model config:", loaded_model.config.id2label)

# %% [markdown]
# ### (選用) 推送到 HuggingFace Hub
#
# 將模型公開發布或在團隊間共享，`trainer.push_to_hub()` 會自動生成基本 model card。

# %%
# Push to Hub (optional — requires huggingface-cli login)
# trainer.push_to_hub(
#     commit_message="fine-tuned chinese-macbert-large on ChnSentiCorp (2026)",
#     language="zh",
#     license="apache-2.0",
#     tags=["text-classification", "sentiment-analysis", "chinese"],
# )

# %% [markdown]
# ## 小結
#
# 本 notebook 完成了：
#
# 1. **十步完整流程**：從 HF Hub 載入資料、tokenize、訓練到推論，全程無硬路徑依賴。
# 2. **2026 現代化寫法**：
#    - `device_map='auto'` + `torch_dtype=bfloat16` 統一管理裝置與精度
#    - `eval_strategy='steps'` 搭配 `save_strategy='steps'` 同步評估與存檔
#    - `optim='adamw_torch_fused'`、`warmup_ratio`、`lr_scheduler_type='cosine'`、`max_grad_norm`
#    - `DataCollatorWithPadding` 動態 padding，節省 20-40% FLOP
#    - `save_pretrained(safe_serialization=True)` 輸出 safetensors 格式
# 3. **記憶體優化三技術**：梯度累加、梯度檢查點、參數凍結，含對照表說明適用場景。
# 4. **完整評估**：accuracy + precision + recall + F1 + 混淆矩陣錯誤分析。
#
# ## 練習題
#
# 1. **輕量實驗**：將 `MODEL_ID` 換成 `hfl/chinese-macbert-base`，比較兩者在 ChnSentiCorp 上的 F1 與訓練時間。
# 2. **梯度累加實驗**：把 `per_device_train_batch_size` 設為 4，`gradient_accumulation_steps` 設為 8，確認 effective batch size 不變，觀察 VRAM 使用量的變化。
# 3. **參數凍結實驗**：啟用 Step 8 中的參數凍結區塊，記錄 trainable parameter 比例，比較與全量微調的 F1 差異。
# 4. **混淆矩陣應用**：觀察模型的 FP 與 FN 案例，找出 3 個模型預測錯誤的評論，分析為何模型會出錯。
# 5. **自訂閾值**：預設分類閾值為 0.5。修改推論程式碼，將正面閾值調高至 0.7（更保守地預測正面），觀察 precision 與 recall 的變動。
