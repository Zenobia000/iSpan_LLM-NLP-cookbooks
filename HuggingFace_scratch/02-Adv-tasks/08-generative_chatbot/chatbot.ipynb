# %% [markdown]
# # 生成式對話機器人（指令微調）
#
# ## 學習目標
#
# 1. 理解指令微調（instruction fine-tuning）的核心概念：如何讓預訓練語言模型學會遵循人類指令。
# 2. 掌握 2026 年的標準作法：`apply_chat_template()` 取代手寫 prompt 格式，`SFTTrainer` 取代手刻 `-100` 標籤遮罩。
# 3. 了解為什麼 `device_map='auto'` + `torch_dtype=torch.bfloat16` 是現代載入模型的標準起手式。
# 4. 能夠比較「底層手刻版」與「SFTTrainer 高階版」的差異，理解兩者的取捨。
#
# ## 前置知識
#
# - 基本 Transformers 使用（`AutoTokenizer`, `AutoModelForCausalLM`）
# - 了解語言模型的 causal language modeling 目標函數
# - 了解 HuggingFace `datasets` 的基本操作
#
# ## 銜接說明
#
# - 上一個主題 `07-text_generation/` 示範了純生成（zero-shot prompting），本 notebook 進一步示範如何透過微調讓模型「聽得懂指令」。
# - 下一個主題 `09-PEFT/` 會在本 notebook 基礎上加入 LoRA，讓指令微調能在消費級 GPU 執行。

# %% [markdown]
# ## 版本鎖定
#
# 確保環境一致性。若在 Colab 或新環境執行，先跑此 cell。

# %%
# Install / upgrade to 2026 compatible versions
# Run this cell first in a fresh environment
# !pip install -q \
    "transformers>=4.46" \
    "datasets>=3.0" \
    "trl>=0.12" \
    "peft>=0.13" \
    "accelerate>=1.0" \
    "bitsandbytes>=0.44" \
    "evaluate>=0.4" \
    "safetensors>=0.4" \
    "torch>=2.4"

# %% [markdown]
# ## Step 1 匯入套件與固定隨機種子
#
# `set_seed(42)` 確保 data shuffle、weight initialization 可重現，是所有訓練 notebook 的必備開頭。

# %%
import torch
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    TrainingArguments,
    Trainer,
    DataCollatorForSeq2Seq,
    set_seed,
)
from trl import SFTTrainer, SFTConfig

set_seed(42)

# %% [markdown]
# ## Step 2 下載資料集
#
# 使用 `shibing624/alpaca-zh`，一個中文版的 Stanford Alpaca 資料集，包含 `instruction`、`input`、`output` 三個欄位。所有資料來源改用 HuggingFace Hub，確保可在任何環境重現。

# %%
ds = load_dataset("shibing624/alpaca-zh", split="train")
print(ds)
print(ds[0])

# %% [markdown]
# ### 資料集探索
#
# 了解欄位長度分布，幫助決定後續的 `max_seq_length`。

# %%
# Quick length analysis using native datasets API (no pandas needed)
output_lengths = [len(x) for x in ds["output"]]
instruction_lengths = [len(x) for x in ds["instruction"]]

print(f"output   max chars : {max(output_lengths)}")
print(f"output   mean chars: {sum(output_lengths) / len(output_lengths):.0f}")
print(f"instruction max   : {max(instruction_lengths)}")
print(f"instruction mean  : {sum(instruction_lengths) / len(instruction_lengths):.0f}")

# %% [markdown]
# ## Step 3 載入 Tokenizer
#
# 我們使用 `Langboat/bloom-389m-zh`，一個約 389M 參數的中文 BLOOM 模型，適合教學示範（VRAM 需求低）。

# %%
MODEL_ID = "Langboat/bloom-389m-zh"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
print(tokenizer)
print(f"eos_token: {repr(tokenizer.eos_token)}")

# %% [markdown]
# ## Step 4 資料預處理：兩種方式的對比
#
# 本節是本 notebook 的教學核心。我們先展示「底層手刻版」（理解原理），再展示「2026 SFTTrainer 版」（實際使用）。
#
# ### 4a 底層手刻版（教學用，理解 -100 遮罩機制）
#
# **`-100` 遮罩的原理：**
#
# Causal LM 的損失函數計算所有 token 的 cross-entropy loss。但在指令微調時，我們只希望模型學習「如何回應」，而不是學習「如何重複指令」。將 instruction 部分的 label 設為 `-100`，PyTorch 的 `CrossEntropyLoss` 就會自動忽略這些位置，只對 response 部分計算損失。

# %%
# --- PEDAGOGICAL: low-level version to illustrate -100 masking ---
# Do NOT use this in production; use SFTTrainer (Step 5) instead.

MAX_LENGTH = 256

def process_func_lowlevel(example):
    """Tokenize one alpaca example and apply -100 label masking.

    The instruction part gets labels=-100 (ignored in loss).
    Only the response part contributes to the training objective.
    """
    # Construct prompt manually — kept here only for illustration
    instruction_text = (
        "\n".join(["Human: " + example["instruction"], example["input"]]).strip()
        + "\n\nAssistant: "
    )
    response_text = example["output"] + tokenizer.eos_token

    instruction_enc = tokenizer(instruction_text, add_special_tokens=False)
    response_enc = tokenizer(response_text, add_special_tokens=False)

    input_ids = instruction_enc["input_ids"] + response_enc["input_ids"]
    attention_mask = instruction_enc["attention_mask"] + response_enc["attention_mask"]
    # -100 on instruction tokens => excluded from loss
    labels = [-100] * len(instruction_enc["input_ids"]) + response_enc["input_ids"]

    # Truncate to MAX_LENGTH
    input_ids = input_ids[:MAX_LENGTH]
    attention_mask = attention_mask[:MAX_LENGTH]
    labels = labels[:MAX_LENGTH]

    return {"input_ids": input_ids, "attention_mask": attention_mask, "labels": labels}


# batched=False here for clarity in the pedagogical version
tokenized_ds_lowlevel = ds.map(
    process_func_lowlevel,
    remove_columns=ds.column_names,
    desc="Tokenizing (low-level)",
)
print(tokenized_ds_lowlevel)

# %%
# Verify: decoded input_ids should show full prompt + response
print("=== input_ids decoded ===")
print(tokenizer.decode(tokenized_ds_lowlevel[0]["input_ids"]))
print()
print("=== labels decoded (response only, -100 filtered) ===")
response_tokens = [t for t in tokenized_ds_lowlevel[0]["labels"] if t != -100]
print(tokenizer.decode(response_tokens))

# %% [markdown]
# ### 4b 2026 版：`apply_chat_template()` 統一 prompt 格式
#
# **為什麼要用 `apply_chat_template()`？**
#
# 每個模型的對話格式不同（BLOOM、Llama-3、Qwen2.5、Mistral 的特殊 token 各異），手寫格式導致訓練時與推論時格式不一致，換模型就要重寫資料處理程式碼。
#
# `apply_chat_template()` 讓 tokenizer 自己知道正確格式：
#
# ```python
# messages = [
#     {"role": "user",      "content": "你好"},
#     {"role": "assistant", "content": "你好！有什麼我可以幫你的嗎？"},
# ]
# prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
# ```
#
# 這同一套介面在 2026 年也支援多模態訊息（`image`、`audio` token），是 `05-Multimodal` 的重要基礎。
#
# > **注意**：`Langboat/bloom-389m-zh` 的 tokenizer 尚未內建 chat template（這是 2022 年的模型），因此下方示範會先設定一個 ChatML-style template，再呼叫 `apply_chat_template()`。新模型（Qwen2.5、Llama-3 等）的 tokenizer 已內建，無需手動設定。

# %%
# Set a ChatML-style template for older tokenizers that lack one.
# Modern models (Qwen2.5, Llama-3, Mistral-v0.3+) already have this built in.
if tokenizer.chat_template is None:
    tokenizer.chat_template = (
        "{% for message in messages %}"
        "{% if message['role'] == 'user' %}"
        "Human: {{ message['content'] }}\n\nAssistant: "
        "{% elif message['role'] == 'assistant' %}"
        "{{ message['content'] }}{{ eos_token }}"
        "{% endif %}"
        "{% endfor %}"
        "{% if add_generation_prompt %}Assistant: {% endif %}"
    )

# Demo: apply_chat_template for a single example
example_messages = [
    {"role": "user",      "content": ds[0]["instruction"]},
    {"role": "assistant", "content": ds[0]["output"]},
]
prompt_str = tokenizer.apply_chat_template(
    example_messages, tokenize=False, add_generation_prompt=False
)
print(prompt_str)

# %% [markdown]
# ## Step 5 載入模型
#
# 使用 `device_map='auto'` 讓 Accelerate 自動分配層到可用設備（GPU → CPU → disk offload），搭配 `torch_dtype=torch.bfloat16` 節省 VRAM 並提升數值穩定性，以及 `use_safetensors=True` 避免 pickle 安全風險並加快載入速度。
#
# **三個參數的意義：**
#
# | 參數 | 說明 |
# |---|---|
# | `device_map='auto'` | Accelerate 自動分配層到可用設備（GPU → CPU → disk offload） |
# | `torch_dtype=torch.bfloat16` | bf16 比 fp16 數值範圍更大（不易溢位），比 fp32 節省一半 VRAM；在現代 GPU（Ampere+）速度與 fp16 相當 |
# | `use_safetensors=True` | safetensors 格式不含 Python pickle，無任意程式碼執行風險，且載入速度快約 2-5 倍 |
#
# **VRAM 估算**（bloom-389m-zh）：
# - fp32：約 1.5 GB
# - bf16/fp16：約 0.8 GB
# - 訓練時（含 optimizer state）：bf16 約 3-4 GB

# %%
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    use_safetensors=True,
)
model.config.use_cache = False  # disable KV-cache during training
print(model.dtype)
print(model.hf_device_map)

# %% [markdown]
# ## Step 6 使用 SFTTrainer 進行指令微調（推薦路徑）
#
# `SFTTrainer`（來自 `trl` 庫）是 2026 年指令微調的標準工具，相比手刻 `Trainer` 有以下優勢：
#
# | 功能 | 手刻 Trainer | SFTTrainer |
# |---|---|---|
# | `-100` label 遮罩 | 手動實作 | 自動（`DataCollatorForCompletionOnlyLM`）|
# | chat template 套用 | 手動 | 自動（指定 `formatting_func` 或 `dataset_text_field`）|
# | sequence packing | 手動 | 內建（`packing=True`，可提升 GPU 利用率）|
# | LoRA / PEFT 整合 | 手動 `get_peft_model()` | 直接傳 `peft_config` 參數 |
#
# ### SFTConfig（現代 TrainingArguments）
#
# 下方 `SFTConfig` 補齊了原本 notebook 缺失的重要訓練超參數：
#
# - `bf16=True`：啟用混合精度訓練（需 Ampere+ GPU）
# - `warmup_ratio=0.1`：前 10% 步數線性 warmup，避免初期 loss spike
# - `lr_scheduler_type='cosine'`：cosine decay 比固定 LR 收斂更穩定
# - `max_grad_norm=1.0`：梯度裁剪，防止梯度爆炸
# - `optim='adamw_torch_fused'`：fused AdamW 比標準 AdamW 快約 10-15%（PyTorch 2.0+）
# - `save_safetensors=True`：儲存為 safetensors 格式
# - `eval_strategy='steps'`：每 N 步做一次驗證（需有 eval_dataset 時生效）
# - `seed=42`：固定 data shuffle 種子

# %%
def formatting_func(example):
    """Convert one alpaca example to a chat-formatted string using apply_chat_template.

    SFTTrainer calls this function per example and uses the returned string
    as the full training text. The -100 label masking on the prompt portion
    is handled internally by DataCollatorForCompletionOnlyLM.
    """
    input_text = example["input"].strip() if example["input"] else ""
    user_content = example["instruction"]
    if input_text:
        user_content = user_content + "\n" + input_text

    messages = [
        {"role": "user",      "content": user_content},
        {"role": "assistant", "content": example["output"]},
    ]
    return tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=False
    )


# Quick sanity check
print(formatting_func(ds[0]))

# %%
sft_config = SFTConfig(
    output_dir="./chatbot-sft",
    # --- batch & accumulation ---
    per_device_train_batch_size=4,
    gradient_accumulation_steps=16,   # effective batch = 4 x 16 = 64
    # --- precision & optimizer ---
    bf16=True,
    optim="adamw_torch_fused",
    max_grad_norm=1.0,
    # --- learning rate schedule ---
    learning_rate=2e-4,
    num_train_epochs=1,
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    # --- logging & saving ---
    logging_steps=10,
    save_strategy="epoch",
    save_safetensors=True,
    # --- sequence length ---
    max_seq_length=256,
    # --- reproducibility ---
    seed=42,
    data_seed=42,
    # --- SFT-specific ---
    packing=False,  # set True for efficiency when dataset is large
    dataset_num_proc=4,
)

trainer = SFTTrainer(
    model=model,
    args=sft_config,
    train_dataset=ds,
    processing_class=tokenizer,
    formatting_func=formatting_func,
)

print(trainer)

# %% [markdown]
# ## Step 7 開始訓練

# %%
trainer.train()

# %% [markdown]
# ## Step 8 儲存模型
#
# 儲存時加上 `safe_serialization=True`（`SFTTrainer` 的 `save_safetensors=True` 已涵蓋），並示範如何推送到 HuggingFace Hub。
#
# > 若不想推送到 Hub，只執行 `trainer.save_model()` 即可。

# %%
# Save locally
trainer.save_model("./chatbot-sft-final")
tokenizer.save_pretrained("./chatbot-sft-final")

# (Optional) Push to HuggingFace Hub
# Requires: huggingface-cli login  or  HF_TOKEN environment variable
#
# trainer.push_to_hub(
#     "your-username/bloom-389m-zh-alpaca",
#     language=["zh"],
#     license="apache-2.0",
#     tags=["instruction-tuning", "alpaca", "chinese"],
# )

# %% [markdown]
# ## Step 9 模型推理
#
# 推論時使用 `pipeline` 搭配 `device_map='auto'`，Accelerate 自動處理多 GPU 與 CPU offload。同樣使用 `apply_chat_template()` 組裝 prompt，確保與訓練時格式完全一致（training-inference alignment）。

# %%
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device_map="auto",
)

def chat(instruction: str, input_text: str = "") -> str:
    """Run inference with the fine-tuned model.

    Uses apply_chat_template to construct the prompt, ensuring the same
    format as training (training-inference alignment).
    """
    user_content = instruction
    if input_text.strip():
        user_content = instruction + "\n" + input_text.strip()

    messages = [{"role": "user", "content": user_content}]
    prompt = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )

    outputs = pipe(
        prompt,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.1,
        return_full_text=False,  # return only the generated portion
    )
    return outputs[0]["generated_text"]


# Test inference
result = chat("考试有哪些技巧？")
print(result)

# %%
# Additional test examples
test_questions = [
    "如何提高英语听力水平？",
    "请介绍一下Python的优点。",
    "怎么保持健康的生活方式？",
]

for q in test_questions:
    print(f"Q: {q}")
    print(f"A: {chat(q)}")
    print("-" * 60)

# %% [markdown]
# ## 小結
#
# 本 notebook 示範了 2026 年指令微調的完整標準流程：
#
# - **模型載入**：`from_pretrained(..., device_map='auto', torch_dtype=torch.bfloat16, use_safetensors=True)` 自動分配設備、節省 VRAM、安全載入。
# - **Prompt 格式**：`tokenizer.apply_chat_template(messages, ...)` 統一訓練與推論的格式，避免 training-inference mismatch。
# - **-100 遮罩**：`SFTTrainer` 自動處理，只對 response 部分計算損失。
# - **Pipeline 推論**：`device_map='auto'` 自動處理多 GPU / CPU offload。
# - **訓練超參數**：完整設定 bf16、warmup、cosine LR、fused AdamW、梯度裁剪。
# - **儲存格式**：`save_safetensors=True` 輸出 safetensors，無 pickle 安全風險。
#
# ## 進階練習
#
# 1. **換模型**：將 `MODEL_ID` 改為 `Qwen/Qwen2.5-0.5B-Instruct`（已內建 chat template，不需要手動設定 `chat_template`），比較訓練與推論品質。
# 2. **加入 LoRA**：在 `SFTTrainer` 中加入 `peft_config=LoraConfig(r=16, lora_alpha=32, target_modules='all-linear')` 參數，觀察 VRAM 需求的變化（見下一個主題 `09-PEFT/`）。
# 3. **多輪對話**：修改 `formatting_func`，支援多輪對話資料格式（`messages` 欄位為 list），使用 `apply_chat_template` 直接接收 list of messages。
# 4. **Packing**：將 `SFTConfig` 的 `packing=True` 開啟，觀察訓練速度變化，理解 sequence packing 對 GPU 利用率的影響。
# 5. **底層驗證**：在 `process_func_lowlevel` 的輸出上，手動驗算 loss：只對非 `-100` 的 label token 計算 cross-entropy，確認與 `SFTTrainer` 的 loss 數值相近。
