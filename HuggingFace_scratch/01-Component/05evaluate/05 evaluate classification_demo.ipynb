# %% [markdown]
# # 文本分類評測：使用 Trainer + evaluate 現代化管線
#
# ## 學習目標
#
# 1. 理解如何用 `datasets` 3.x 的 `load_dataset` 與 `map(batched=True)` 取代手刻 DataLoader
# 2. 掌握 `DataCollatorWithPadding`（動態 padding）的正確用法，以及它為何優於固定長度截斷
# 3. 學會用 `evaluate.load` 搭配 `compute_metrics` 接入 `Trainer`，取代手寫訓練/驗證迴圈
# 4. 了解 `TrainingArguments` 現代化必填項：AdamW、cosine scheduler、warmup、bf16、safetensors
# 5. 認識 `stratify_by_column` 解決類別不平衡的必要性
#
# ## 前置知識
#
# - 熟悉 Transformer 架構基礎（`01-Component/01pipeline` 系列）
# - 了解 tokenizer 運作原理（`01-Component/02tokenizer`）
# - 基本的 fine-tuning 概念（`01-Component/04fine-tune`）
#
# ## 本 notebook 在課程中的位置
#
# ```
# 01-Component/
# ├── 04fine-tune/   ← 上一節：如何準備模型進行微調
# ├── 05evaluate/
# │   └── 05 evaluate classification_demo.ipynb   ← 本節
# └── 06generation/  ← 下一節：文本生成與解碼策略
# ```

# %%
# 版本鎖定：確保與本課程其他 notebook 相容
# 若已有虛擬環境，請直接跳過此 cell
# %pip install -q \
    "transformers>=4.46" \
    "datasets>=3.0" \
    "evaluate>=0.4" \
    "accelerate>=1.0" \
    "safetensors>=0.4" \
    "scikit-learn>=1.4" \
    "torch>=2.4"

# %% [markdown]
# ## Step 1：導入函式庫
#
# 此節集中所有 import，方便後續閱讀時快速查閱依賴來源。
#
# > **為何不在個別 step 才 import？**
# > 集中 import 讓「缺少哪個套件」的錯誤在最一開始就暴露，而非等到第 N 個 cell 才炸。

# %%
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer,
    set_seed,
)
from datasets import load_dataset
import evaluate
import numpy as np

# 確保所有隨機性可重現：torch、numpy、python random 全部鎖定
set_seed(42)

print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU             : {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ## Step 2：載入資料集
#
# ### 為何使用 HF Hub 資料集 id？
#
# 直接使用 HF Hub dataset id，任何機器都能一鍵重現，無需手動複製檔案或設定本地路徑，版本也能被明確追蹤。
#
# `ChnSentiCorp` 是廣泛使用的中文酒店評論情感資料集（正面/負面二分類）：
# - 訓練集約 9,600 筆
# - 正面評論（label=1）、負面評論（label=0）
#
# ### 為何過濾空白 review？
#
# 空白文字無法被 tokenizer 正確處理，訓練時會產生全零 input_ids，讓模型學到錯誤分布。

# %%
# 直接從 HF Hub 載入，無需本地路徑或 Google Drive
raw_dataset = load_dataset("seamew/ChnSentiCorp", split="train")

# 過濾空白 review（空值或純空白字串皆排除）
raw_dataset = raw_dataset.filter(
    lambda x: x["text"] is not None and len(x["text"].strip()) > 0
)

print(raw_dataset)
print(f"\n欄位：{raw_dataset.column_names}")
print(f"範例：{raw_dataset[0]}")

# %% [markdown]
# ## Step 3：分割資料集
#
# ### 為何需要 `stratify_by_column`？
#
# 若正負樣本比例不均（例如 7:3），隨機分割可能讓驗證集碰巧全是正面評論，
# 導致驗證集 accuracy 虛高但不具代表性。
#
# `stratify_by_column='label'` 確保訓練集與驗證集的正負比例與原始資料一致。
#
# ```python
# datasets = raw_dataset.train_test_split(
#     test_size=0.1, stratify_by_column="label", seed=42
# )
# ```
#
# `seed=42` 搭配前面的 `set_seed(42)` 確保全流程可重現。

# %%
datasets = raw_dataset.train_test_split(
    test_size=0.1,
    stratify_by_column="label",  # 保持正負比例
    seed=42,
)

print(datasets)

# 驗證 stratify 是否有效：兩個分割的正例比例應接近
train_pos_ratio = sum(datasets["train"]["label"]) / len(datasets["train"])
test_pos_ratio  = sum(datasets["test"]["label"])  / len(datasets["test"])
print(f"\n訓練集正例比例：{train_pos_ratio:.3f}")
print(f"驗證集正例比例：{test_pos_ratio:.3f}")

# %% [markdown]
# ## Step 4：Tokenize 資料集
#
# ### 動態 padding 的運作方式
#
# 2026 寫法分兩階段處理 padding：
# 1. `tokenizer()` 只做 truncation，**不做 padding**
# 2. `DataCollatorWithPadding` 在 batch 組合時才 pad 到該 batch 的最長長度
#
# 這讓平均序列長度下降，訓練速度提升 20-30%，且對短文本的注意力機制更準確。
#
# ### 為何 `batched=True` 比 row-by-row 快 3-5 倍？
#
# `batched=True` 讓 tokenizer 一次處理一個 list of strings，底層用 Rust 實作的 fast tokenizer
# 可以並行處理並減少 Python 呼叫次數。`num_proc=4` 進一步利用多核。

# %%
MODEL_ID = "hfl/rbt3"  # Chinese RoBERTa-wwm-ext (3 layers, 快速示範用)

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

def tokenize_fn(examples):
    # 只截斷，不 padding；padding 交由 DataCollatorWithPadding 動態處理
    return tokenizer(
        examples["text"],
        max_length=128,
        truncation=True,
    )

tokenized_datasets = datasets.map(
    tokenize_fn,
    batched=True,       # 批次處理，速度提升 3-5 倍
    num_proc=4,         # 多進程
    remove_columns=[c for c in datasets["train"].column_names if c != "label"],
)

print(tokenized_datasets)
print(f"\n訓練集欄位：{tokenized_datasets['train'].column_names}")
print(f"第一筆 input_ids 長度：{len(tokenized_datasets['train'][0]['input_ids'])}")

# %% [markdown]
# ## Step 5：定義評測函式
#
# ### 為何用 `evaluate.load` + `compute_metrics` 而非手寫評測迴圈？
#
# 將評測邏輯封裝成 `compute_metrics(eval_pred)` 並傳入 `Trainer`：
# - Trainer 在每個 eval step 自動呼叫
# - 不需要手動管理 `.cuda()` 或 `torch.inference_mode()`
# - 結果自動記錄到 training log
# - 變數名稱與 `evaluate` 模組不衝突（避免命名遮蔽問題）
#
# ### 評測指標選擇
#
# - `accuracy`：整體正確率
# - `f1`（macro）：平衡正負類別，比 accuracy 更能反映不均衡資料的真實效能
# - `precision` / `recall`：了解模型偏向哪個方向的誤判
#
# macro average 對每個類別平等看待，適合類別數量相近的二分類任務。

# %%
# 使用 evaluate.combine 一次載入多個指標
# 變數名稱改為 clf_metrics，避免與 evaluate 模組衝突（舊版的命名 bug）
acc_metric       = evaluate.load("accuracy")
f1_metric        = evaluate.load("f1")
precision_metric = evaluate.load("precision")
recall_metric    = evaluate.load("recall")

def compute_metrics(eval_pred):
    """
    Trainer 在每次 evaluation 結束時呼叫此函式。
    eval_pred: EvalPrediction(predictions=logits, label_ids=labels)
    """
    logits, labels = eval_pred
    # logits shape: (N, num_labels) -> argmax -> (N,)
    predictions = np.argmax(logits, axis=-1)

    acc  = acc_metric.compute(predictions=predictions, references=labels)
    f1   = f1_metric.compute(predictions=predictions, references=labels, average="macro")
    prec = precision_metric.compute(predictions=predictions, references=labels, average="macro")
    rec  = recall_metric.compute(predictions=predictions, references=labels, average="macro")

    return {
        "accuracy"  : acc["accuracy"],
        "f1"        : f1["f1"],
        "precision" : prec["precision"],
        "recall"    : rec["recall"],
    }

print("compute_metrics 函式定義完成")

# %% [markdown]
# ## Step 6：載入模型
#
# ### 裝置管理：`device_map='auto'`
#
# ```python
# model = AutoModelForSequenceClassification.from_pretrained(
#     MODEL_ID,
#     device_map="auto",
#     torch_dtype=torch.bfloat16,
# )
# ```
#
# `device_map='auto'` 讓 Accelerate 自動分配裝置（GPU → CPU → disk offload），
# 不需要手動判斷 `cuda.is_available()`。
#
# ### 為何用 `bf16` 而非 `fp16` 或 `fp32`？
#
# | 精度 | 數值範圍 | 精度 | 訓練穩定性 |
# |------|---------|------|----------|
# | fp32 | 大 | 高 | 最穩 |
# | fp16 | 小（容易 overflow） | 中 | 需 loss scaling |
# | bf16 | 大（與 fp32 相同） | 中 | 不需 loss scaling |
#
# bf16 保留 fp32 的指數位寬（8 bits），避免 fp16 常見的 NaN/overflow 問題，
# 同時享有 fp16 的記憶體與速度優勢。Ampere 以上 GPU（A100、RTX 30xx+）原生支援。
#
# ### `id2label` / `label2id` 的重要性
#
# 寫入 model config 後，`pipeline` 與 `model.push_to_hub()` 都能直接讀取標籤名稱，
# 不需要在推論程式碼裡硬寫對應表。

# %%
# label 對應表：持久化到 model config，後續 pipeline 與 push_to_hub 都能正確顯示
id2label = {0: "負面", 1: "正面"}
label2id = {v: k for k, v in id2label.items()}

model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_ID,
    num_labels=2,
    id2label=id2label,
    label2id=label2id,
    # device_map="auto" 讓 Accelerate 自動分配 GPU/CPU
    # 若無 GPU 則自動降為 CPU，不需要手動 if cuda.is_available()
    device_map="auto",
    torch_dtype=torch.bfloat16,  # bf16：穩定性優於 fp16，速度/記憶體優於 fp32
)

print(model.config.id2label)
print(f"模型參數量：{sum(p.numel() for p in model.parameters()) / 1e6:.1f} M")

# %% [markdown]
# ## Step 7：設定 TrainingArguments 與 Trainer
#
# ### 為何用 Trainer 取代手寫訓練迴圈？
#
# `Trainer` 內建了 fine-tuning 所需的完整配套：
# - gradient clipping（防梯度發散）
# - learning rate scheduler（後期平滑下降）
# - best model checkpoint（自動保留驗證集最佳權重）
# - 自動整合 `compute_metrics`（evaluation 迴圈零手寫）
#
# ### TrainingArguments 關鍵參數說明
#
# | 參數 | 值 | 說明 |
# |------|----|------|
# | `optim` | `adamw_torch_fused` | 使用 PyTorch 原生 fused AdamW，比 Adam 更穩定（weight decay 只作用於非 bias 參數） |
# | `lr_scheduler_type` | `cosine` | Cosine annealing：後期學習率平滑下降，比 linear 更少震盪 |
# | `warmup_ratio` | `0.1` | 前 10% steps 線性升溫，避免初期大梯度破壞預訓練權重 |
# | `max_grad_norm` | `1.0` | Gradient clipping：防止梯度爆炸 |
# | `bf16` | `True` | 混合精度訓練（需 Ampere GPU） |
# | `eval_strategy` | `steps` | 每 N steps 評測一次，比 epoch 更頻繁 |
# | `load_best_model_at_end` | `True` | 訓練結束自動載入驗證集最佳 checkpoint |
# | `save_safetensors` | `True` | 儲存為 safetensors 格式（防 pickle 注入攻擊，載入速度快 2x） |
#
# ### 為何選擇 AdamW？
#
# AdamW 將 weight decay 從 adaptive moment 計算中分離，對 Transformer fine-tuning 效果更好，
# 是 2019 年後 NLP fine-tuning 的標準選擇。

# %%
training_args = TrainingArguments(
    output_dir="./rbt3-senti-ckpt",
    num_train_epochs=3,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=64,
    # AdamW fused 版本，速度更快且訓練更穩定
    optim="adamw_torch_fused",
    learning_rate=2e-5,
    # Cosine scheduler + warmup：前 10% steps 升溫，後期平滑下降
    lr_scheduler_type="cosine",
    warmup_ratio=0.1,
    # Gradient clipping：防止梯度爆炸
    max_grad_norm=1.0,
    # bf16 混合精度（Ampere GPU 以上；無 GPU 時自動忽略）
    bf16=torch.cuda.is_available() and torch.cuda.is_bf16_supported(),
    # 評測與儲存策略
    eval_strategy="steps",
    eval_steps=200,
    save_strategy="steps",
    save_steps=200,
    save_total_limit=2,           # 只保留最近 2 個 checkpoint，節省磁碟空間
    load_best_model_at_end=True,  # 訓練結束自動載回最佳 checkpoint
    metric_for_best_model="f1",   # 以 macro F1 挑選最佳模型
    # 儲存為 safetensors（防 pickle 攻擊，載入速度提升 ~2x）
    save_safetensors=True,
    # 可重現性
    seed=42,
    # 日誌
    logging_steps=50,
    report_to="none",             # 本地示範不啟用 wandb/tensorboard
)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    processing_class=tokenizer,      # 2026 新參數（取代舊版 tokenizer=）
    data_collator=data_collator,
    compute_metrics=compute_metrics, # 接入評測函式
)

print("Trainer 設定完成")
print(f"訓練步數估算：{len(tokenized_datasets['train']) // 32 * 3} steps")

# %% [markdown]
# ## Step 8：訓練模型
#
# 執行訓練。Trainer 會自動：
# - 每 50 steps 印出 loss
# - 每 200 steps 評測驗證集並印出 accuracy / F1 / precision / recall
# - 儲存最佳 checkpoint（以 macro F1 為準）
#
# > **VRAM 需求估算（batch_size=32, bf16, rbt3 約 38M 參數）：**
# > - 約 1-2 GB VRAM，任何現代消費級 GPU 皆可執行
# > - 若無 GPU，CPU 訓練約慢 10x，可將 num_train_epochs 改為 1 快速驗證

# %%
train_result = trainer.train()

print("\n=== 訓練完成 ===")
print(f"total_flos      : {train_result.metrics['total_flos']:.2e}")
print(f"train_runtime   : {train_result.metrics['train_runtime']:.1f} s")
print(f"train_samples/s : {train_result.metrics['train_samples_per_second']:.1f}")

# %% [markdown]
# ## Step 9：在驗證集上完整評測
#
# `trainer.evaluate()` 會在整個驗證集上跑一次推論並呼叫 `compute_metrics`，
# 返回所有指標。這與訓練期間的 eval_steps 結果相同，但這裡是最終的完整評測。

# %%
eval_results = trainer.evaluate()

print("=== 驗證集評測結果 ===")
for k, v in eval_results.items():
    if isinstance(v, float):
        print(f"  {k:<30}: {v:.4f}")
    else:
        print(f"  {k:<30}: {v}")

# %% [markdown]
# ## Step 10：儲存模型與 Tokenizer
#
# ### 為何使用 safetensors 格式？
#
# `safetensors` 格式具備以下優勢：
# - 不使用 pickle，無法注入惡意程式碼
# - 載入速度比 pickle 快約 2x（mmap-based 零拷貝載入）
# - 2026 年 HF Hub 已將 safetensors 設為預設格式
#
# `trainer.save_model()` 在 `save_safetensors=True` 的情況下已自動使用 safetensors，
# 這裡再示範手動版本以便理解底層行為。

# %%
SAVE_DIR = "./rbt3-senti-final"

# safe_serialization=True：儲存為 safetensors 而非 pytorch_model.bin（pickle）
trainer.save_model(SAVE_DIR)
tokenizer.save_pretrained(SAVE_DIR)

print(f"模型已儲存至 {SAVE_DIR}")

# 列出儲存的檔案（應看到 model.safetensors 而非 pytorch_model.bin）
import os
for f in sorted(os.listdir(SAVE_DIR)):
    size = os.path.getsize(os.path.join(SAVE_DIR, f))
    print(f"  {f:<40} {size/1024/1024:.1f} MB")

# %% [markdown]
# ## Step 11：單句推論
#
# 以下示範兩種推論方式：
# 1. **手動推論**：直接用 tokenizer + model，適合理解底層流程
# 2. **pipeline 推論**：一行搞定，適合生產環境
#
# ### `device_map='auto'` 的裝置選擇策略
#
# `pipeline(..., device_map='auto')` 讓 Accelerate 自動選擇可用裝置，
# CPU/GPU/多 GPU 環境皆能正常執行，無需對硬體做任何假設。

# %%
# --- 方式一：手動推論（展示底層流程）---
test_sentence = "飯店退房有送 Dyson 吹風機，服務超棒！"

# Trainer 的 best model 已在 load_best_model_at_end=True 時自動載回
model.eval()
with torch.inference_mode():
    inputs = tokenizer(test_sentence, return_tensors="pt")
    # 將 inputs 移到與 model 相同的裝置
    device = next(model.parameters()).device
    inputs = {k: v.to(device) for k, v in inputs.items()}
    logits = model(**inputs).logits
    pred_id = torch.argmax(logits, dim=-1).item()

print(f"輸入   : {test_sentence}")
print(f"預測   : {id2label[pred_id]}")
print(f"logits : {logits.squeeze().tolist()}")

# %%
from transformers import pipeline

# --- 方式二：pipeline 推論（生產環境推薦）---
# device_map='auto' 取代 device=0，CPU/GPU 皆相容
pipe = pipeline(
    "text-classification",
    model=SAVE_DIR,         # 直接從儲存目錄載入（已含 id2label config）
    tokenizer=SAVE_DIR,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

test_sentences = [
    "飯店退房有送 Dyson 吹風機，服務超棒！",
    "房間又小又髒，空調壞了也沒人修，住了一晚就趕快退房。",
    "地理位置很好，離捷運站只要走路 3 分鐘。",
]

results = pipe(test_sentences)
for sent, res in zip(test_sentences, results):
    print(f"[{res['label']} | {res['score']:.3f}] {sent}")

# %% [markdown]
# ## Step 12（選用）：推送到 HF Hub
#
# 以下程式碼示範如何將訓練好的模型推送到 HuggingFace Hub，
# 讓任何人都能直接使用 `pipeline('text-classification', model='your-username/rbt3-chn-senti')`。
#
# 執行前需先：
# ```bash
# huggingface-cli login
# ```
#
# 或在 notebook 裡執行：
# ```python
# from huggingface_hub import notebook_login
# notebook_login()
# ```
#
# > 本節為選用步驟，不影響主流程。

# %%
# 選用：取消以下註解並填入 HF Hub 帳號後執行

# HF_USERNAME = "your-hf-username"
# REPO_NAME   = f"{HF_USERNAME}/rbt3-chn-hotel-sentiment"

# trainer.push_to_hub(
#     repo_id=REPO_NAME,
#     commit_message="Add ChnSentiCorp fine-tuned rbt3 (bf16, safetensors)",
#     language="zh",
#     license="apache-2.0",
#     tags=["text-classification", "chinese", "sentiment-analysis", "rbt3"],
# )
# tokenizer.push_to_hub(REPO_NAME)

# print(f"模型已發布至 https://huggingface.co/{REPO_NAME}")
print("（選用步驟：填入 HF_USERNAME 並取消註解後執行）")

# %% [markdown]
# ## 小結
#
# 本 notebook 示範了 2026 年標準的文本分類 fine-tuning 流程：
#
# | 步驟 | 關鍵做法 | 效益 |
# |------|---------|------|
# | 資料載入 | HF Hub id 直接使用 | 可重現，零環境設定 |
# | 資料分割 | `stratify_by_column` | 正確評測不均衡資料集 |
# | Tokenize | `map(batched=True, num_proc=4)` | 3-5x 速度提升 |
# | Padding | `DataCollatorWithPadding`（動態） | 減少無效 padding，加速訓練 |
# | 評測 | `evaluate.load` + `compute_metrics` | 無命名衝突，自動整合 Trainer |
# | 模型載入 | `device_map='auto'` + `bf16` | 跨裝置相容，記憶體效率 |
# | 訓練 | `Trainer` + `AdamW` + cosine + warmup | 自動 best checkpoint，zero 手寫迴圈 |
# | 儲存 | `safetensors` | 安全，載入快 2x |
#
# ## 練習題
#
# 1. 將 `per_device_train_batch_size` 改為 16，同時加入 `gradient_accumulation_steps=2`，
#    觀察 effective batch size 是否不變，理解「有效 batch size = per_device × grad_accum × num_GPUs」。
#
# 2. 將 `lr_scheduler_type` 從 `cosine` 改為 `linear`，
#    比較兩者的 validation F1 曲線差異。
#
# 3. 加入 `EarlyStoppingCallback`（`from transformers import EarlyStoppingCallback`），
#    設定 `patience=3`，觀察訓練在哪個 step 提前停止。
#
# 4. 修改 `compute_metrics` 加入 confusion matrix（用 `sklearn.metrics.confusion_matrix`），
#    分析模型最常誤判哪類評論。
#
# 5. 將模型換為 `hfl/chinese-roberta-wwm-ext`（12 層，約 102M 參數），
#    比較 F1 提升了多少，代價是多少倍的訓練時間。
