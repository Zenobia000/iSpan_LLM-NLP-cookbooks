# %% [markdown]
# # 文本分類：以 Trainer 訓練序列分類模型（2026 版）
#
# ## 學習目標
#
# 1. 使用 `load_dataset` 從 HuggingFace Hub 載入中文情感資料集，取代 Google Drive 掛載與硬路徑。
# 2. 以 `train_test_split(stratify_by_column=..., seed=42)` 做分層切分，確保類別分布一致。
# 3. 使用 `dataset.map(batched=True)` 加速 tokenization，並以 `DataCollatorWithPadding` 做動態 padding。
# 4. 以完整 2026 `TrainingArguments`（bf16、cosine schedule、AdamW fused、步數評估、safetensors 儲存）取代舊版省略參數的寫法。
# 5. 以 `evaluate.load` + `compute_metrics` 接入 Trainer，同時追蹤 accuracy、precision、recall、F1。
# 6. 補充 `EarlyStoppingCallback`、`set_seed`、`push_to_hub` 的正確使用方式。
#
# ## 前置套件
#
# ```
# transformers>=4.46
# datasets>=3.0
# evaluate>=0.4
# accelerate>=1.0
# safetensors>=0.4
# torch>=2.4
# ```
#
# ## 與相鄰 notebook 的銜接
#
# - 上一個：`../05Pipeline/05_pipeline_demo.ipynb` — 介紹 pipeline 推論 API
# - 本 notebook：示範如何在純監督任務用 Trainer 取代手刻訓練迴圈
# - 下一個：`../07LoRA/07_lora_demo.ipynb` — 以 PEFT + SFTTrainer 做指令微調

# %% [markdown]
# ## 版本鎖定
#
# 以下 cell 固定各套件最低版本，確保 2026 API 語意正確。執行一次即可；CI 環境建議寫入 `requirements.txt`。

# %%
# Pin package versions for 2026 API compatibility
# %pip install -q \
    "transformers>=4.46" \
    "datasets>=3.0" \
    "evaluate>=0.4" \
    "accelerate>=1.0" \
    "safetensors>=0.4" \
    "torch>=2.4" \
    scikit-learn

# %% [markdown]
# ## Step 1：匯入函式庫與設定全域隨機種子
#
# `set_seed(42)` 讓 PyTorch、NumPy、Python random 同時固定，確保每次執行結果可重現。

# %%
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
    EarlyStoppingCallback,
    set_seed,
)
from datasets import load_dataset
import evaluate

set_seed(42)

# %% [markdown]
# ## Step 2：載入資料集
#
# 使用 HuggingFace Hub 上的公開資料集，優點：
# - 無需掛載 Google Drive 或維護本機路徑，任何環境直接重現。
# - `datasets` 3.x 自動快取、多進程下載，首次後秒速重用。
# - 欄位名稱一致（`text`、`label`），減少手動對齊成本。
#
# 資料集說明：ChnSentiCorp 是中文酒店評論情感分析資料集，label 0 = 負面，label 1 = 正面，共約 9600 筆。

# %%
# Load dataset from HuggingFace Hub; no local path or Drive mount needed
raw_dataset = load_dataset("lansinuote/ChnSentiCorp", split="train")

# Remove samples with missing review text
raw_dataset = raw_dataset.filter(lambda x: x["text"] is not None and x["text"].strip() != "")

print(raw_dataset)
print(raw_dataset[0])

# %% [markdown]
# ## Step 3：分層切分資料集
#
# ### 為什麼要 `stratify_by_column`？
#
# 隨機切分在類別不平衡時，測試集的類別比例可能偏離訓練集，導致評估指標失真。
# `stratify_by_column='label'` 確保每個子集的正負比例與原始分布一致。
#
# `seed=42` 讓切分結果可重現，與 `set_seed(42)` 共同構成全程可重現性。

# %%
# Stratified split: ensures label distribution is consistent across train/test
datasets = raw_dataset.train_test_split(
    test_size=0.1,
    stratify_by_column="label",
    seed=42,
)
print(datasets)

# Verify label distribution
for split_name, split_data in datasets.items():
    total = len(split_data)
    pos = sum(split_data["label"])
    print(f"{split_name}: total={total}, positive={pos} ({pos/total:.1%}), negative={total-pos} ({(total-pos)/total:.1%})")

# %% [markdown]
# ## Step 4：Tokenization 與動態 Padding
#
# ### 為什麼用 `batched=True`？
#
# `batched=True` 讓 tokenizer 以批次向量化運算，速度比逐筆處理快 3-5 倍。
# `num_proc` 可進一步利用多核 CPU，大型資料集（>100 萬筆）時尤其有效。
#
# ### 動態 Padding（DataCollatorWithPadding）
#
# Tokenization 只做 `truncation=True`，不在此處 padding；由 `DataCollatorWithPadding` 在 collate 時對每個 batch 動態填到「該 batch 最長序列」的長度。短序列多的 batch 計算量顯著下降，比固定填到 `max_length` 更省算力。

# %%
MODEL_ID = "hfl/rbt3"
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

def process_function(examples):
    # Truncate only; dynamic padding is handled by DataCollatorWithPadding at collation time
    tokenized = tokenizer(
        examples["text"],
        max_length=128,
        truncation=True,
        # Do NOT pad here — DataCollatorWithPadding will pad dynamically per batch
    )
    tokenized["labels"] = examples["label"]
    return tokenized

tokenized_datasets = datasets.map(
    process_function,
    batched=True,             # vectorized processing: ~3-5x faster than row-by-row
    num_proc=2,               # leverage multiple CPU cores
    remove_columns=datasets["train"].column_names,  # drop raw text columns
)
print(tokenized_datasets)

# %% [markdown]
# ## Step 5：建立模型
#
# 使用 `AutoModelForSequenceClassification.from_pretrained` 載入模型，並指定以下三個 2026 關鍵參數：
#
# | 參數 | 意義 |
# |---|---|
# | `device_map='auto'` | 自動分配 GPU/CPU，甚至 disk offload；省去 `.cuda()` 並支援多卡 |
# | `torch_dtype=torch.bfloat16` | bf16 比 fp16 數值範圍更寬（不易溢位），比 fp32 省一半 VRAM；現代 GPU（Ampere+）原生支援 |
# | `use_safetensors=True` | 載入 `.safetensors` 格式：不執行任意 Python 程式碼（pickle 安全漏洞），且 mmap 載入速度更快 |
#
# **VRAM 估算**：rbt3（約 102M 參數）以 bf16 載入約需 204 MB VRAM，一般 4GB 顯卡可輕鬆容納。
#
# `id2label` / `label2id` 寫入 config，讓 `push_to_hub` 後的 model card 和 pipeline 推論都能直接顯示標籤名稱，無需額外說明文件。

# %%
# id2label / label2id are persisted in config.json so push_to_hub and pipeline inference
# can display human-readable label names without extra documentation.
id2label = {0: "NEGATIVE", 1: "POSITIVE"}
label2id = {v: k for k, v in id2label.items()}

model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_ID,
    num_labels=2,
    id2label=id2label,
    label2id=label2id,
    device_map="auto",          # auto-dispatch to GPU/CPU; replaces .cuda()
    torch_dtype=torch.bfloat16, # bf16: same memory as fp16 but wider dynamic range
    use_safetensors=True,       # safe format: no pickle exec, faster mmap load
)

print(model.config)

# %% [markdown]
# ## Step 6：定義評估函數
#
# ### 修正：`f1_metirc` 拼字錯誤
#
# 原 notebook 有一個拼字 bug：`f1_metirc`（metirc → metric）。雖不影響執行（只是變數名），但在程式碼審查和搜尋時容易引起混淆，本版本一律修正為 `f1_metric`。
#
# ### 為什麼同時追蹤 Accuracy、Precision、Recall、F1？
#
# - **Accuracy** 在類別不平衡時會誤導（全猜多數類仍有高準確率）。
# - **Precision**：預測為正中真正為正的比例；**Recall**：真正為正中被找出的比例。
# - **F1**：Precision 與 Recall 的調和平均，是不平衡分類任務最常用的單一指標。
# - 四者同時呈現才能完整診斷模型行為。

# %%
# Load all metrics once; reuse across compute_metrics calls
acc_metric = evaluate.load("accuracy")
precision_metric = evaluate.load("precision")
recall_metric = evaluate.load("recall")
f1_metric = evaluate.load("f1")  # fixed: was 'f1_metirc' (typo) in original

def compute_metrics(eval_predict):
    logits, labels = eval_predict
    predictions = logits.argmax(axis=-1)

    acc = acc_metric.compute(predictions=predictions, references=labels)
    precision = precision_metric.compute(predictions=predictions, references=labels, average="binary")
    recall = recall_metric.compute(predictions=predictions, references=labels, average="binary")
    f1 = f1_metric.compute(predictions=predictions, references=labels, average="binary")

    return {
        "accuracy": acc["accuracy"],
        "precision": precision["precision"],
        "recall": recall["recall"],
        "f1": f1["f1"],
    }

# %% [markdown]
# ## Step 7：撰寫 TrainingArguments（2026 完整版）
#
# ### 參數說明
#
# | 參數 | 值 | 原因 |
# |---|---|---|
# | `bf16=True` | True | 配合 `torch_dtype=bfloat16`，訓練全程 bf16；比 fp16 不易 NaN |
# | `optim='adamw_torch_fused'` | - | PyTorch 2.x fused AdamW：比預設的 `adamw_torch` 快約 10%，減少 kernel launch 開銷 |
# | `warmup_ratio=0.1` | 0.1 | 前 10% 步線性升溫；避免初期大梯度破壞預訓練權重 |
# | `lr_scheduler_type='cosine'` | cosine | cosine decay 比 linear 結尾更平滑，通常帶來更好的最終指標 |
# | `max_grad_norm=1.0` | 1.0 | 梯度裁剪防止梯度爆炸；分類任務標準值 |
# | `eval_strategy='steps'` | steps | 按步數評估比 epoch 更細緻，使用正確的現行參數名稱 |
# | `save_strategy='steps'` | steps | 與 `eval_strategy` 保持一致，才能讓 `load_best_model_at_end=True` 正確運作 |
# | `eval_steps=100` | 100 | 每 100 步評估一次 |
# | `save_steps=100` | 100 | 與 eval_steps 對齊 |
# | `save_safetensors=True` | True | 儲存 `.safetensors` 而非 `.bin`（pickle），安全且載入更快 |
# | `seed=42` | 42 | Trainer 內部的 dropout/shuffle 種子；與 set_seed(42) 共同確保全程可重現 |
#
# **有效 batch size** = `per_device_train_batch_size` × `gradient_accumulation_steps` × GPU 數。
# 本範例：64 × 1 × 1 = 64；若 VRAM 不足可將 per_device 降至 16、gradient_accumulation_steps 設 4，效果等價。

# %%
train_args = TrainingArguments(
    output_dir="./checkpoints",

    # --- batch & steps ---
    per_device_train_batch_size=64,
    per_device_eval_batch_size=128,
    # effective batch = per_device_train_batch_size x gradient_accumulation_steps x num_gpus
    # 64 x 1 x 1 = 64 here; reduce per_device and increase grad_accum if OOM
    gradient_accumulation_steps=1,

    # --- optimizer & scheduler ---
    learning_rate=2e-5,
    weight_decay=0.01,                  # AdamW weight decay
    optim="adamw_torch_fused",          # PyTorch 2.x fused kernel: ~10% faster
    warmup_ratio=0.1,                   # linear warmup for first 10% of training
    lr_scheduler_type="cosine",         # cosine decay after warmup
    max_grad_norm=1.0,                  # gradient clipping

    # --- precision ---
    bf16=True,                          # bfloat16 training: wider range than fp16, no NaN risk

    # --- evaluation & saving ---
    eval_strategy="steps",              # replaces deprecated evaluation_strategy
    eval_steps=100,
    save_strategy="steps",              # must match eval_strategy for load_best_model_at_end
    save_steps=100,
    save_total_limit=3,
    save_safetensors=True,              # save .safetensors instead of pickle .bin
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,

    # --- logging ---
    logging_steps=10,
    report_to="none",                   # disable wandb/tensorboard by default

    # --- reproducibility ---
    seed=42,
)

print(train_args)

# %% [markdown]
# ## Step 8：建構 Trainer 訓練器
#
# `DataCollatorWithPadding` 在此扮演關鍵角色：它在每個 mini-batch 被組裝時，才將序列 pad 到該 batch 最長的長度，而不是全資料集的最大長度。這是「動態 padding」策略的實作位置。
#
# `EarlyStoppingCallback` 監看 `metric_for_best_model`（本例為 F1），若連續 `early_stopping_patience` 個評估點未改善，則提前停止訓練，避免過擬合並節省算力。

# %%
trainer = Trainer(
    model=model,
    args=train_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    processing_class=tokenizer,                        # replaces deprecated tokenizer= kwarg
    data_collator=DataCollatorWithPadding(tokenizer),  # dynamic padding per batch
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(
            early_stopping_patience=3,    # stop if no F1 improvement for 3 eval steps
            early_stopping_threshold=0.001,  # minimum improvement to count as progress
        )
    ],
)

# %% [markdown]
# ## Step 9：模型訓練
#
# Trainer 自動處理：
# - 裝置搬移（配合 `device_map='auto'`）
# - bf16 混合精度
# - 梯度裁剪
# - LR scheduler（cosine with warmup）
# - 定期評估與 checkpoint 儲存
# - 最佳模型載入（`load_best_model_at_end=True`）

# %%
trainer.train()

# %% [markdown]
# ## Step 10：模型評估
#
# 訓練結束後對測試集進行完整評估，取得 accuracy、precision、recall、F1 四項指標。

# %%
eval_results = trainer.evaluate(tokenized_datasets["test"])
print(eval_results)

# %% [markdown]
# ## Step 11：模型預測
#
# `trainer.predict()` 回傳 `PredictionOutput`，包含三個欄位：
# - `.predictions`：原始 logits（shape: `[N, num_labels]`）
# - `.label_ids`：真實標籤
# - `.metrics`：同 `evaluate()` 的指標字典

# %%
prediction_output = trainer.predict(tokenized_datasets["test"])

print("Logits shape:", prediction_output.predictions.shape)
print("Label IDs shape:", prediction_output.label_ids.shape)
print("Metrics:", prediction_output.metrics)

# Convert logits to predicted class indices
import numpy as np
pred_labels = prediction_output.predictions.argmax(axis=-1)
print("Sample predictions (first 10):", [id2label[p] for p in pred_labels[:10]])
print("Sample true labels  (first 10):", [id2label[l] for l in prediction_output.label_ids[:10]])

# %% [markdown]
# ## Step 12：儲存模型與 Tokenizer（本機 + Hub 示範）
#
# ### 本機儲存
#
# `save_safetensors=True` 已在 TrainingArguments 中全域設定，Trainer 的 checkpoint 一律輸出 `.safetensors`。
# 手動呼叫 `save_pretrained` 時需再指定 `safe_serialization=True` 以保持一致。
#
# ### 推送至 HuggingFace Hub
#
# `push_to_hub` 會自動產生最小 model card，並帶入 `id2label`、`label2id`、`num_labels`，讓 `pipeline('text-classification', model=...)` 直接可用。
# 執行前需先 `huggingface-cli login` 或設定 `HF_TOKEN` 環境變數。

# %%
from pathlib import Path

OUTPUT_DIR = Path("./final_model")

# Save to local disk with safetensors format
trainer.model.save_pretrained(OUTPUT_DIR, safe_serialization=True)
tokenizer.save_pretrained(OUTPUT_DIR)

print(f"Model saved to {OUTPUT_DIR.resolve()}")
print("Files:", [f.name for f in OUTPUT_DIR.iterdir()])

# %%
# Optional: push to HuggingFace Hub
# Requires: huggingface-cli login  OR  export HF_TOKEN=hf_...
#
# trainer.push_to_hub(
#     repo_id="your-username/rbt3-chn-senticorp",
#     commit_message="Add ChnSentiCorp fine-tuned model (2026)",
#     language="zh",
#     license="apache-2.0",
#     tags=["text-classification", "chinese", "sentiment-analysis"],
# )
#
# After push, use it directly:
# from transformers import pipeline
# clf = pipeline(
#     "text-classification",
#     model="your-username/rbt3-chn-senticorp",
#     device_map="auto",
#     torch_dtype=torch.bfloat16,
# )
# print(clf("房間乾淨整潔，服務態度很好！"))

# %% [markdown]
# ## 小結
#
# ### 本 notebook 涵蓋的 2026 關鍵做法
#
# | 項目 | 2026 寫法 | 說明 |
# |---|---|---|
# | 資料載入 | `load_dataset("lansinuote/ChnSentiCorp")` | 可重現、無環境依賴 |
# | 資料切分 | `train_test_split(stratify_by_column='label', seed=42)` | 類別分布一致、可重現 |
# | Tokenization | 只做 truncation，交由 DataCollatorWithPadding 動態 pad | 減少無效計算 |
# | 模型載入 | `device_map='auto', torch_dtype=bfloat16, use_safetensors=True` | 多卡/CPU offload、更安全快速 |
# | 評估指標 | accuracy + precision + recall + F1 | 完整診斷模型行為 |
# | TrainingArguments | bf16/cosine/warmup/fused AdamW/safetensors/seed | 現代化訓練最佳實踐 |
# | 儲存格式 | `.safetensors`（`save_safetensors=True`） | 安全、mmap 快速載入 |
# | 早停 | `EarlyStoppingCallback(patience=3)` | 防過擬合、節省算力 |
#
# ### 練習題
#
# 1. **精度實驗**：將 `torch_dtype` 改為 `torch.float32`，重跑訓練，比較 VRAM 用量、訓練速度與最終 F1。為什麼 bf16 在 Ampere+ GPU 上更快？
# 2. **有效 batch size**：將 `per_device_train_batch_size=16, gradient_accumulation_steps=4`，理論上有效 batch 大小與原本 64 相同。實際訓練結果是否相近？速度差異為何？
# 3. **多分類**：找一個三類別的中文文本分類資料集，將 `compute_metrics` 中的 `average="binary"` 改為 `average="macro"`，觀察 precision/recall/F1 的變化。
# 4. **混淆矩陣**：在 `compute_metrics` 中引入 `sklearn.metrics.confusion_matrix`，觀察哪一類最常被誤判，並思考改進資料或模型的方向。
# 5. **Hub 整合**：完成 `push_to_hub` 並以 `pipeline('text-classification', model='your-username/...')` 驗證推論結果，確認 `id2label` 標籤是否正確顯示。
