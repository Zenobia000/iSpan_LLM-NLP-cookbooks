# %% [markdown]
# # 文本分類完整流程（2026 版）
#
# ## 學習目標
#
# 1. 使用 `datasets` 3.x 從 HuggingFace Hub 載入資料，以 `map(batched=True)` 高效分詞。
# 2. 以 `train_test_split(stratify_by_column=..., seed=42)` 做分層切分，避免類別不平衡。
# 3. 以 `DataCollatorWithPadding` 做動態 padding，取代固定 `max_length` 截斷。
# 4. 以 `Trainer + TrainingArguments`（2026 完整設定）取代手刻 epoch/batch 迴圈。
# 5. 以 `evaluate.load()` + `compute_metrics` 在 Trainer 內統一評測（accuracy + F1）。
# 6. 以 `AdamW`（`adamw_torch_fused`）取代裸 `Adam`，補上 warmup 與 cosine scheduler。
# 7. 示範 `push_to_hub` + 最小 model card（id2label / label2id 持久化）。
#
# ## 前置知識
# - [01 Pipeline 基礎](../01Pipeline/01_pipeline_demo.ipynb)
# - [03 Tokenizer](../03Tokenizer/03_tokenizer_demo.ipynb)
#
# ## 相鄰 Notebook
# - 上一個：`03 Datasets basic_demo.ipynb`（資料集基本操作）
# - 下一個：`05 Datasets text_similarity_demo.ipynb`（文本相似度）

# %% [markdown]
# ## Step 0：鎖定版本
#
# 確保可重現性。固定關鍵套件版本，CI / 協作者安裝時行為一致。

# %%
# Version pinning — run once, then restart kernel if versions changed
# %pip install -q \
    "transformers>=4.46" \
    "datasets>=3.0" \
    "evaluate>=0.4" \
    "accelerate>=1.0" \
    "safetensors>=0.4" \
    "torch>=2.4" \
    "scikit-learn>=1.4"

# %% [markdown]
# ## Step 1：匯入套件與全域設定
#
# `set_seed(42)` 讓 DataLoader shuffle、權重初始化、dropout 全部可重現。

# %%
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    DataCollatorWithPadding,
    set_seed,
    pipeline,
)
from datasets import load_dataset
import evaluate
import numpy as np

set_seed(42)

MODEL_ID = "hfl/rbt3"          # Chinese RoBERTa-Tiny; ~38 M params, fits on CPU
DATASET_ID = "lansinuote/ChnSentiCorp"  # HF Hub 上的中文情感分析資料集（替代本地 CSV）
OUTPUT_DIR = "rbt3-sentiment"   # local checkpoint dir

# %% [markdown]
# ## Step 2：下載資料集
#
# ### 為什麼從 HF Hub 取，而非本機 CSV？
#
# 原 notebook 掛載 Google Drive 並寫死 `/content/drive/.../ChnSentiCorp_htl_all.csv`，導致：
# - 換環境即失效
# - 無法在 CI 重現
# - 需要手動上傳
#
# `load_dataset('lansinuote/ChnSentiCorp')` 從 HF Hub 取同份資料，任何機器可直接執行。
# 若需自訂 CSV，使用 `load_dataset('csv', data_files={'train': 'path/to/file.csv'})`。

# %%
raw_dataset = load_dataset(DATASET_ID)
print(raw_dataset)
# Dataset already has train/validation/test splits on Hub;
# we will re-split from 'train' to match the original demo flow.

# %% [markdown]
# ## Step 3：資料探索
#
# 在切分前先了解類別分布，確認是否需要分層切分（stratified split）。

# %%
# Inspect raw structure
print("Column names:", raw_dataset["train"].column_names)
print("Features:", raw_dataset["train"].features)
print("\nFirst sample:")
print(raw_dataset["train"][0])

# Label distribution
from collections import Counter
label_counts = Counter(raw_dataset["train"]["label"])
print("\nLabel distribution (train):", label_counts)
# Imbalanced? stratify_by_column is critical if ratio > 3:1

# %% [markdown]
# ## Step 4：切分資料集
#
# ### 為什麼用 `stratify_by_column`？
#
# 隨機切分若遇到類別不平衡，驗證集可能幾乎全是多數類，導致 accuracy 虛高、F1 極低。
# `stratify_by_column='label'` 保證每個 split 的類別比例一致，是工業界標準做法。
#
# ```python
# datasets = dataset.train_test_split(
#     test_size=0.1, stratify_by_column="label", seed=42
# )
# ```

# %%
# Use the Hub's pre-split train set, then re-split for demo consistency
source = raw_dataset["train"].filter(lambda x: x["text"] is not None)

datasets = source.train_test_split(
    test_size=0.1,
    stratify_by_column="label",
    seed=42,
)
print(datasets)
print("Train label dist:", Counter(datasets["train"]["label"]))
print("Test  label dist:", Counter(datasets["test"]["label"]))

# %% [markdown]
# ## Step 5：Tokenization
#
# ### 動態 padding vs 固定截斷
#
# `map` 時只做 truncation（`max_length=128` 只截長句，不 pad 短句），由 `DataCollatorWithPadding` 在 collate 時動態 pad 到**該 batch 最長序列**，平均可省 20–40% 計算量。
#
# ### `batched=True` 為什麼快 3–5 倍？
#
# `map(batched=True)` 把一批樣本打包成 list 傳入 tokenizer，tokenizer 內部以 Rust 批次處理（fast tokenizer）。逐一處理每個樣本都要經過 Python GIL，速度慢很多。

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

# Column name on Hub is 'text'; original CSV used 'review'
TEXT_COL = "text"

def process_function(examples):
    # Truncate only here; dynamic padding happens in DataCollator
    tokenized = tokenizer(
        examples[TEXT_COL],
        max_length=128,
        truncation=True,
        # No padding=True here — handled by DataCollatorWithPadding
    )
    tokenized["labels"] = examples["label"]
    return tokenized

tokenized_datasets = datasets.map(
    process_function,
    batched=True,
    remove_columns=datasets["train"].column_names,
    desc="Tokenizing",
)
print(tokenized_datasets)

# %% [markdown]
# ## Step 6：Data Collator
#
# `DataCollatorWithPadding` 會在每個 batch 組裝時，把序列 pad 到 **該 batch 內的最長長度**（而非全域最長），確保 GPU 利用率最高。

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Sanity check: inspect one collated batch shape
from torch.utils.data import DataLoader

sample_loader = DataLoader(
    tokenized_datasets["train"].select(range(8)),
    batch_size=4,
    collate_fn=data_collator,
)
sample_batch = next(iter(sample_loader))
for k, v in sample_batch.items():
    print(f"{k}: {v.shape}")
# input_ids shape should be [4, dynamic_len], not [4, 128]

# %% [markdown]
# ## Step 7：載入模型
#
# ### 2026 統一載入慣例
#
# ```python
# model = AutoModelForSequenceClassification.from_pretrained(
#     MODEL_ID,
#     num_labels=2,
#     id2label=ID2LABEL,
#     label2id=LABEL2ID,
#     device_map="auto",
#     torch_dtype=torch.bfloat16,
# )
# ```
#
# ### 為什麼 `bfloat16`？
# - `fp32`：精度最高，但 GPU VRAM 用量是 bf16 的 2 倍，速度較慢。
# - `fp16`：VRAM 是 fp32 的一半，但 fp16 的動態範圍只有 ≈5 個數量級，大梯度容易 overflow（需要 `loss_scaler`）。
# - `bfloat16`：與 fp32 同等動態範圍（8 bit 指數），精度略低（7 bit 尾數），但 A100/H100/H200 原生支援，不需 loss scaling，是 2026 訓練首選精度。
#
# ### 為什麼 `device_map='auto'`？
# - 單 GPU：等同 `.to('cuda')`，但不需寫死裝置 id。
# - 多 GPU / CPU offload：自動依 VRAM 分層放置模型層，無需手動 `device_map` 指定。
# - CPU only（無 GPU）：自動放 CPU，程式碼不需改動。
#
# ### `id2label` / `label2id` 為什麼要在載入時設定？
# 持久化到 `config.json`，`push_to_hub` 後推理端可直接 `pipeline('text-classification', model=...)` 獲得可讀標籤，不需另行傳入對應表。

# %%
ID2LABEL = {0: "負評", 1: "正評"}
LABEL2ID = {v: k for k, v in ID2LABEL.items()}

model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_ID,
    num_labels=2,
    id2label=ID2LABEL,
    label2id=LABEL2ID,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    # use_safetensors=True  # uncomment when Hub repo has safetensors weights
)
print(model.config)
print("Device map:", model.hf_device_map)

# %% [markdown]
# ## Step 8：設定評測指標
#
# `evaluate` 套件同時計算 accuracy 與 macro F1。
#
# ### 為什麼需要 F1？
#
# Accuracy 在類別不平衡時會騙人：若 90% 都是正評，模型全預測正評也有 90% accuracy，但 F1 會立刻揭穿它（負評 F1 = 0）。
#
# `compute_metrics` 是 Trainer 的標準回調：每個 evaluation step 結束後，Trainer 自動把 logits 傳進來，你回傳一個 `dict`，Trainer 記錄到訓練日誌。

# %%
accuracy_metric = evaluate.load("accuracy")
f1_metric = evaluate.load("f1")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    acc = accuracy_metric.compute(predictions=predictions, references=labels)["accuracy"]
    f1 = f1_metric.compute(
        predictions=predictions, references=labels, average="macro"
    )["f1"]
    return {"accuracy": acc, "f1_macro": f1}

# %% [markdown]
# ## Step 9：設定 TrainingArguments 並訓練
#
# ### 為什麼 `AdamW` 而非 `Adam`？
# `Adam` 把 weight decay 加在梯度動量上（L2 regularization），而 `AdamW` 把 weight decay 直接加在參數更新上，解耦正則化與自適應學習率，實驗上在 Transformer 微調任務有更好的收斂性。`adamw_torch_fused` 是 PyTorch 2.x 的 fused 實作，比純 Python loop 快約 10–20%。
#
# ### 為什麼需要 `warmup_ratio`？
# 前幾步學習率從 0 線性升到目標值，避免剛開始參數不穩定就用大 lr 破壞預訓練權重。`warmup_ratio=0.1` 表示前 10% steps 做 warmup。
#
# ### `cosine` lr scheduler
# Warmup 結束後，lr 以 cosine 曲線從最大值降到 0，比線性下降更平滑，微調任務普遍有更好的最終 loss。
#
# ### `effective_batch_size = per_device_train_batch_size × gradient_accumulation_steps × num_GPUs`
# 在單 GPU / CPU 上設 `gradient_accumulation_steps=4`、`per_device_train_batch_size=32`，等效 batch size = 128，減少記憶體需求。
#
# `Trainer` 自動處理：裝置搬移、混合精度、梯度累積、評測週期、checkpoint 儲存、早停等。

# %%
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    # --- Training schedule ---
    num_train_epochs=3,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=64,
    gradient_accumulation_steps=1,   # increase if OOM; effective_batch = 32 * 1
    # --- Optimizer ---
    learning_rate=2e-5,
    optim="adamw_torch_fused",        # faster than default adamw_torch on PyTorch 2.x
    weight_decay=0.01,
    max_grad_norm=1.0,
    # --- LR schedule ---
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    # --- Precision ---
    bf16=torch.cuda.is_bf16_supported(),  # True on A100/H100; falls back to fp32 on older GPU
    fp16=False,
    # --- Evaluation & checkpointing ---
    eval_strategy="steps",
    eval_steps=200,
    save_strategy="steps",
    save_steps=200,
    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    greater_is_better=True,
    save_total_limit=2,
    save_safetensors=True,            # save in safetensors format (faster, safer than pickle)
    # --- Reproducibility ---
    seed=42,
    data_seed=42,
    # --- Logging ---
    logging_steps=50,
    report_to="none",                 # set to 'wandb' or 'tensorboard' if needed
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    processing_class=tokenizer,       # replaces deprecated tokenizer= kwarg in Trainer 4.46+
    compute_metrics=compute_metrics,
)

trainer.train()

# %% [markdown]
# ## Step 10：評測結果
#
# `trainer.evaluate()` 在 test set 上跑一次完整評測，回傳 loss、accuracy、F1。

# %%
metrics = trainer.evaluate()
print(metrics)
# Expected: eval_accuracy > 0.90, eval_f1_macro > 0.88 on ChnSentiCorp

# %% [markdown]
# ## Step 11：混淆矩陣分析
#
# 光看 accuracy / F1 不夠，混淆矩陣告訴你：模型在哪種類別上犯了什麼錯誤。
# 例如：負評被誤判成正評（假正例）在電商場景比正評誤判成負評（假負例）更嚴重，需要分開關注。

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Get predictions on test set
preds_output = trainer.predict(tokenized_datasets["test"])
y_pred = np.argmax(preds_output.predictions, axis=-1)
y_true = preds_output.label_ids

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)
print()
print(classification_report(
    y_true, y_pred,
    target_names=[ID2LABEL[i] for i in sorted(ID2LABEL)]
))

# %% [markdown]
# ## Step 12：單句推論
#
# 推論時使用 `model.device` 取得模型目前所在裝置，再以 `.to(model.device)` 將 inputs 搬移過去，不需寫死 `.cuda()`，CPU、單 GPU、多 GPU 環境皆可無縫執行。

# %%
model.eval()

def predict_sentiment(text: str) -> str:
    """Single-sentence inference with device-agnostic tensor placement."""
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=128)
    # Move to the same device as the model — works on CPU, single GPU, multi-GPU
    inputs = {k: v.to(model.device) for k, v in inputs.items()}
    with torch.inference_mode():
        logits = model(**inputs).logits
    pred_id = torch.argmax(logits, dim=-1).item()
    return ID2LABEL[pred_id]

test_sentences = [
    "這家酒店的服務不錯，按摩非常到位，非常舒爽！",
    "房間主臥的衣櫥有大量的老鼠和蟑螂!!",
    "床很舒服，但隔音很差，半夜吵死人。",
]
for sen in test_sentences:
    print(f"輸入：{sen}")
    print(f"預測：{predict_sentiment(sen)}")
    print()

# %% [markdown]
# ## Step 13：用 Pipeline 推論
#
# `pipeline` 是最高階的推論介面，自動處理 tokenization + inference + decoding。
#
# ```python
# pipe = pipeline("text-classification", model=model, tokenizer=tokenizer, device_map="auto")
# ```
#
# `device_map='auto'` 自動選擇可用裝置，CPU 環境也能運行，不需寫死裝置 id。

# %%
# id2label is already in model.config, so pipeline output labels are human-readable
pipe = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    device_map="auto",
)

results = pipe(test_sentences)
for sen, res in zip(test_sentences, results):
    print(f"輸入：{sen}")
    print(f"結果：{res}")
    print()

# %% [markdown]
# ## Step 14：儲存模型並示範 push_to_hub
#
# ### 為什麼用 `safetensors`？
#
# 傳統 `.bin` 格式基於 Python `pickle`，pickle 檔案可以嵌入任意程式碼，存在安全風險且載入慢。`safetensors` 格式：
# - 純張量序列化，無法執行任意程式碼
# - memory-mapped 載入，速度比 pickle 快 2–5 倍
# - `save_safetensors=True`（TrainingArguments）已在訓練時啟用

# %%
# Save locally (safetensors already enabled via TrainingArguments)
trainer.save_model(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)
print(f"Model saved to {OUTPUT_DIR}")

# --- push_to_hub (optional) ---
# Requires: huggingface-cli login  OR  hf_token env var
# Uncomment to push:
# trainer.push_to_hub(
#     commit_message="2026 fine-tuned rbt3 on ChnSentiCorp",
#     language="zh",
#     license="apache-2.0",
#     tags=["text-classification", "sentiment-analysis", "chinese"],
# )

# %% [markdown]
# ## Step 15：從本機重新載入並驗證
#
# 確認儲存後的 model card 完整，`id2label` 正確持久化，pipeline 可直接使用可讀標籤。

# %%
loaded_model = AutoModelForSequenceClassification.from_pretrained(
    OUTPUT_DIR,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)
loaded_tokenizer = AutoTokenizer.from_pretrained(OUTPUT_DIR)

verify_pipe = pipeline(
    "text-classification",
    model=loaded_model,
    tokenizer=loaded_tokenizer,
    device_map="auto",
)
print(verify_pipe("這間飯店乾淨又舒適，強烈推薦！"))
# Expected: [{'label': '正評', 'score': ...}]

# %% [markdown]
# ## 小結
#
# | 步驟 | 關鍵 API | 2026 要點 |
# |------|----------|-----------|
# | 資料載入 | `load_dataset(HUB_ID)` | 取代硬路徑 CSV、任何機器可重現 |
# | 分層切分 | `train_test_split(stratify_by_column=, seed=42)` | 保持類別比例，避免 accuracy 虛高 |
# | 分詞 | `map(batched=True)` | Rust fast tokenizer，速度 3–5x |
# | Padding | `DataCollatorWithPadding` | 動態 padding，省 20–40% 算力 |
# | 模型載入 | `device_map='auto', torch_dtype=bfloat16` | 自動裝置、bf16 精度 |
# | 訓練 | `Trainer + TrainingArguments` | 取代手刻迴圈；AdamW+cosine+warmup |
# | 評測 | `evaluate.load + compute_metrics` | accuracy + macro F1 + 混淆矩陣 |
# | 儲存 | `save_safetensors=True` | 安全、快速的張量序列化 |
#
# ## 練習題
#
# 1. **進階評測**：在 `compute_metrics` 中加入 per-class F1（`average=None`），觀察哪個類別最難學。
# 2. **資料增強**：對少數類別（負評）做 back-translation 擴充，觀察 macro F1 的變化。
# 3. **更大模型**：把 `MODEL_ID` 換成 `hfl/chinese-roberta-wwm-ext`（102 M params），比較準確率提升與訓練時間。
#    - VRAM 估計：bf16 模型約 200 MB，加上 optimizer state 約 600 MB，單 4 GB GPU 可運行。
# 4. **Early Stopping**：加入 `EarlyStoppingCallback(early_stopping_patience=3)`，觀察訓練提前停止的時機。
# 5. **多類別**：找一個多分類情感資料集（如 `tyqiangz/multilingual-sentiments`），把 `num_labels` 改為 3（負 / 中性 / 正），重跑完整流程。
