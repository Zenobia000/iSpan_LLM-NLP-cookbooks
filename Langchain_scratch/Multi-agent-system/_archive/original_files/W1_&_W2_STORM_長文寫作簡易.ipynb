# %% [markdown]
# ## Multi-Agent System for News Writing (基於運算思維的新聞寫作多智能體系統)

# %%
# "protobuf<5" 是修正 protobuf 版本衝突的語法
# 安裝套件後，會彈出詢問是否【重新啟動工作階段】的訊息，不需理會，此訊息是因為套件會移除 colab 預設的 pillow & httpx package，改用較舊版本引起。
! pip install qdrant-client==1.12.2 litellm==1.56.6 tavily-python==0.5.0 fastembed==0.5.0 "protobuf<5"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qdrant-client==1.12.2 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (1.12.2)
# Requirement already satisfied: litellm==1.56.6 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (1.56.6)
# Requirement already satisfied: tavily-python==0.5.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (0.5.0)
# Requirement already satisfied: fastembed==0.5.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (0.5.0)
# Requirement already satisfied: protobuf<5 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (4.25.6)
# Requirement already satisfied: grpcio>=1.41.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from qdrant-client==1.12.2) (1.70.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from qdrant-client==1.12.2) (1.62.3)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from httpx[http2]>=0.20.0->qdrant-client==1.12.2) (0.26.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from qdrant-client==1.12.2) (1.23.5)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from qdrant-client==1.12.2) (2.10.1)
# Requirement already satisfied: pydantic>=1.10.8 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from qdrant-client==1.12.2) (2.10.6)
# Requirement already satisfied: urllib3<3,>=1.26.14 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from qdrant-client==1.12.2) (2.2.1)
# Requirement already satisfied: aiohttp in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (3.8.4)
# Requirement already satisfied: click in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (8.1.7)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (8.6.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (3.1.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (4.23.0)
# Requirement already satisfied: openai>=1.55.3 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (1.60.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (1.0.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (0.8.0)
# Requirement already satisfied: tokenizers in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from litellm==1.56.6) (0.21.0)
# Requirement already satisfied: requests in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from tavily-python==0.5.0) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (0.23.3)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (0.7.3)
# Requirement already satisfied: mmh3<5.0.0,>=4.1.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (4.1.0)
# Requirement already satisfied: onnx>=1.15.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (1.15.0)
# Requirement already satisfied: onnxruntime!=1.20.0,>=1.17.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (1.17.1)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (10.4.0)
# Requirement already satisfied: py-rust-stemmers<0.2.0,>=0.1.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (0.1.3)
# Requirement already satisfied: tqdm<5.0,>=4.66 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from fastembed==0.5.0) (4.67.1)
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client==1.12.2) (65.3.0)
# Requirement already satisfied: anyio in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (3.6.2)
# Requirement already satisfied: certifi in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (1.0.2)
# Requirement already satisfied: idna in c:\program files\python310\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (3.4)
# Requirement already satisfied: sniffio in c:\program files\python310\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from httpx[http2]>=0.20.0->qdrant-client==1.12.2) (4.1.0)
# Requirement already satisfied: filelock in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0,>=0.20->fastembed==0.5.0) (3.12.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0,>=0.20->fastembed==0.5.0) (2024.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0,>=0.20->fastembed==0.5.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0,>=0.20->fastembed==0.5.0) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0,>=0.20->fastembed==0.5.0) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from importlib-metadata>=6.8.0->litellm==1.56.6) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.56.6) (2.1.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.56.6) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.56.6) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.56.6) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.56.6) (0.18.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from loguru<0.8.0,>=0.7.2->fastembed==0.5.0) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from loguru<0.8.0,>=0.7.2->fastembed==0.5.0) (1.1.0)
# Requirement already satisfied: coloredlogs in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed==0.5.0) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed==0.5.0) (23.5.26)
# Requirement already satisfied: sympy in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed==0.5.0) (1.12)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from openai>=1.55.3->litellm==1.56.6) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from openai>=1.55.3->litellm==1.56.6) (0.8.2)
# Requirement already satisfied: pywin32>=226 in c:\program files\python310\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client==1.12.2) (304)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.8->qdrant-client==1.12.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.8->qdrant-client==1.12.2) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from requests->tavily-python==0.5.0) (3.1.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from tiktoken>=0.7.0->litellm==1.56.6) (2023.12.25)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from aiohttp->litellm==1.56.6) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from aiohttp->litellm==1.56.6) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from aiohttp->litellm==1.56.6) (1.9.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from aiohttp->litellm==1.56.6) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from aiohttp->litellm==1.56.6) (1.3.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.0 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.12.2) (4.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed==0.5.0) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from sympy->onnxruntime!=1.20.0,>=1.17.0->fastembed==0.5.0) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\xdxd2\appdata\roaming\python\python310\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed==0.5.0) (3.4.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\xdxd2\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\xdxd2\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\xdxd2\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\xdxd2\appdata\roaming\python\python310\site-packages)

# %%
# 取得 環境變數
from dotenv import load_dotenv
import os

# 載入 .env 檔案
load_dotenv()

# 讀取環境變數
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')

# 檢查是否成功讀取
if OPENAI_API_KEY is None:
    raise ValueError("找不到 OPENAI_API_KEY")
if TAVILY_API_KEY is None:
    raise ValueError("找不到 TAVILY_API_KEY")

# 使用金鑰
print("金鑰讀取成功！")
# Out:
# 金鑰讀取成功！

# %% [markdown]
# # 程式說明一、建立相關主題以及相對應問題

# %% [markdown]
# ![](data:image/png;base64,...)

# %%
from litellm import completion, acompletion
import json

# %%
def generate_related_topics(topic: str) -> list[str]:
    system_prompt = """我想寫一篇關於某個主題的長篇文章。我會給你主題，我希望你能提出 3 個相關的子主題來擴展內容。
    
    請以 JSON 格式回應，格式如下:
    {
        "subtopics": [
            {"title": "子主題1", "description": "簡短描述"},
            {"title": "子主題2", "description": "簡短描述"},
            {"title": "子主題3", "description": "簡短描述"}
        ]
    }
    """

    user_prompt = """這裏是主題:\n\n主題:{topic}"""
    try:
        response = completion(
            api_key=OPENAI_API_KEY,
            model="gpt-3.5-turbo",
            messages=[{"content": system_prompt, "role": "system"}, {"content": user_prompt.format(topic=topic), "role": "user"}],
            temperature=0.5,
            max_tokens=1000,
            response_format={"type": "json_object"}  # 啟用 JSON 模式
        )
        response_content = response.choices[0].message.content
        
        # 解析JSON回應
        import json
        parsed_response = json.loads(response_content)
        
        # 返回結構化數據
        return parsed_response["subtopics"]
    except Exception as e:
        print(f"Error in generating related topics: {e}")
        return []

# %%
topic = '建立一個專業的 LinkIn 首頁'
related_topics = generate_related_topics(topic)

# %%
from pprint import pprint

pprint(related_topics)
# Out:
# [{'description': '如何設計一個專業的個人資料頁面', 'title': '設計個人資料'},
#  {'description': '如何撰寫引人注目的個人簡介及經歷', 'title': '內容豐富'},
#  {'description': '如何擴展人脈及建立專業形象', 'title': '網絡建立'}]

# %%
def generate_perspectives(topic: str, related_topics: str) -> list[dict]:
    system_prompt = """
    你需要選擇一組由 3 位作家組成的團隊，他們將共同撰寫一篇關於這個主題的綜合性文章。
    每位作家都代表與此主題相關的不同觀點、角色或隸屬關係。
    你可以使用其他相關主題作為靈感。對於每個角色，添加他們將重點關注的描述。
    
    請以 JSON 格式回應，格式如下:
    {
        "writers": [
            {"title": "第一位作家的職稱", "perspective": "第一位作家的觀點描述"},
            {"title": "第二位作家的職稱", "perspective": "第二位作家的觀點描述"},
            {"title": "第三位作家的職稱", "perspective": "第三位作家的觀點描述"}
        ]
    }
    """

    user_prompt = """這裏是主題:\n\n
                    主題:{topic}\n\n
                    相關主題: {related_topics}"""
    try:
        print(user_prompt.format(topic=topic, related_topics=related_topics))
        print("-------------")
        response = completion(
            api_key = OPENAI_API_KEY,
            model="gpt-3.5-turbo",
            messages=[{ "content": system_prompt, "role": "system"},
                      { "content": user_prompt.format(topic=topic, related_topics=related_topics), "role": "user"}],
            temperature=0.5,
            max_tokens=1000,
            response_format={"type": "json_object"}  # 啟用 JSON 模式
        )
        response_content = response.choices[0].message.content
        
        # 解析JSON回應
        import json
        parsed_response = json.loads(response_content)
        
        # 返回結構化數據
        return parsed_response["writers"]
    except Exception as e:
        print(f"Error in generating perspectives: {e}")
        return []

# %%
perspectives = generate_perspectives(topic, related_topics)

pprint(perspectives)
# Out:
# 這裏是主題:
#
#
#                     主題:建立一個專業的 LinkIn 首頁
#
#
#                     相關主題: [{'title': '設計個人資料', 'description': '如何設計一個專業的個人資料頁面'}, {'title': '內容豐富', 'description': '如何撰寫引人注目的個人簡介及經歷'}, {'title': '網絡建立', 'description': '如何擴展人脈及建立專業形象'}]
# -------------
# [{'perspective': '專注於如何設計一個專業的個人資料頁面，包括佈局、顏色選擇和視覺元素的設計', 'title': '設計師'},
#  {'perspective': '專注於如何撰寫引人注目的個人簡介及經歷，確保內容豐富、有吸引力並突出重點', 'title': '內容編輯'},
#  {'perspective': '專注於如何擴展人脈及建立專業形象，包括與他人互動、分享內容以及網絡建立的技巧', 'title': '社交專家'}]

# %%
perspectives
# Out:
# [{'title': '設計師', 'perspective': '專注於如何設計一個專業的個人資料頁面，包括佈局、顏色選擇和視覺元素的設計'},
#  {'title': '內容編輯', 'perspective': '專注於如何撰寫引人注目的個人簡介及經歷，確保內容豐富、有吸引力並突出重點'},
#  {'title': '社交專家', 'perspective': '專注於如何擴展人脈及建立專業形象，包括與他人互動、分享內容以及網絡建立的技巧'}]

# %%
system_prompt = """
你是一位經驗豐富的作家，想要編輯一篇關於特定主題的長篇文章。除了作為作家的身份外，你在研究主題時還有一個特定的觀點。
現在，你正在與一位專家交談以獲取資訊。請提出好問題以獲取更有用的訊息。
你一次只問一個問題，不要重複之前已經問過的問題。除了生成問題外，不要添加任何額外內容。
你的問題應該與你想寫的主題相關。

請以 JSON 格式回應，格式如下:
{{
    "question": "你生成的問題"
}}

對話歷史：{history}
"""

# 初始化對話歷史
history = []

# 將歷史記錄轉換為字符串
context = "\n".join(history)

# 格式化系統提示
formatted_prompt = system_prompt.format(history=context)


formatted_prompt
# Out:
# '\n你是一位經驗豐富的作家，想要編輯一篇關於特定主題的長篇文章。除了作為作家的身份外，你在研究主題時還有一個特定的觀點。\n現在，你正在與一位專家交談以獲取資訊。請提出好問題以獲取更有用的訊息。\n你一次只問一個問題，不要重複之前已經問過的問題。除了生成問題外，不要添加任何額外內容。\n你的問題應該與你想寫的主題相關。\n\n請以 JSON 格式回應，格式如下:\n{\n    "question": "你生成的問題"\n}\n\n對話歷史：\n'

# %%
def generate_question(topic: str, perspective: dict, history: list[str]):
    system_prompt = """
    你是一位經驗豐富的作家，想要編輯一篇關於特定主題的長篇文章。除了作為作家的身份外，你在研究主題時還有一個特定的觀點。
    現在，你正在與一位專家交談以獲取資訊。請提出好問題以獲取更有用的訊息。
    你一次只問一個問題，不要重複之前已經問過的問題。除了生成問題外，不要添加任何額外內容。
    你的問題應該與你想寫的主題相關。
    
    請以 JSON 格式回應，格式如下:
    {{
        "question": "你生成的問題"
    }}

    對話歷史：{history}
    """

    user_prompt = """這裏是主題:\n\n
                    主題:{topic}\n\n
                    你的身份: {title}\n\n
                    你的特定觀點: {perspective}\n\n
                    問題:"""

    context = "\n".join(history)

    try:
        # 從 perspective 字典中提取標題和觀點
        writer_title = perspective.get("title", "未指定職稱")
        writer_perspective = perspective.get("perspective", "未指定觀點")
        
        response = completion(
            api_key = OPENAI_API_KEY,
            model="gpt-4o",
            messages=[
                {"content": system_prompt.format(history=context), "role": "system"},
                {"content": user_prompt.format(
                    topic=topic, 
                    title=writer_title,
                    perspective=writer_perspective
                ), "role": "user"}
            ],
            temperature=0.5,
            max_tokens=1000,
            response_format={"type": "json_object"}  # 啟用 JSON 模式
        )
        response_content = response.choices[0].message.content
        

        # 解析JSON回應
        import json
        parsed_response = json.loads(response_content)
        
        # 返回問題
        return parsed_response["question"]
    except Exception as e:
        print(f"Error in generating question: {e}")
        return "無法生成問題，請重試。"

# %%
res = generate_question(topic, perspectives[0], [])
res
# Out:
# '在設計 LinkedIn 個人資料頁面的佈局時，哪些元素應該被優先考慮以確保專業性和視覺吸引力？'

# %% [markdown]
# # 同學的練習
# - 思考你要撰寫的幾個主題
# - 重複執行上面幾個動作
# - 給同學 5 分鐘的時間練習

# %% [markdown]
# # 程式說明二、與領域專家的討論

# %% [markdown]
# ![](data:image/png;base64,...)

# %%
def generate_answer(topic: str, question: str, context: str):
    system_prompt = """
    你是一位能有效運用資訊的專家。你正在與一位作家交談，該作家想撰寫一篇關於你所熟悉的主題的文章。
    你已經收集了相關資訊，現在將使用這些資訊來形成回應。請確保你的回應盡可能提供豐富資訊，並確保每個句子都由收集到的資訊支持。

    相關資訊：{context}
    """

    user_prompt = """這裏是主題:\n\n
                    主題:{topic}\n\n
                    問題: {question}"""
    try:

        response = completion(
            api_key = OPENAI_API_KEY,
            model="gpt-4o",
            messages=[{ "content": system_prompt.format(context=context),"role": "system"},{ "content": user_prompt.format(topic=topic, question=question),"role": "user"}],
            temperature=0.5,
            max_tokens=1000,
        )
        response = response.choices[0].message.content

        return response
    except Exception as e:
        print(f"Error in translation: {e}")

# %%
# 設定環境變數
# from google.colab import userdata
from tavily import TavilyClient

# 建立 Tavily Search 的用戶端
# TAVILY_API_KEY = userdata.get('TAVILY_API_KEY')

tavily = TavilyClient(api_key=TAVILY_API_KEY)

# %% [markdown]
# ## 爬蟲模式 + tavily

# %%
all_conversations = []  # 這裏記錄的是所有的對話記錄
references = [] # 這裏記錄所有網路搜尋的結果
duplicate_references = set()
total_questions = 3 # 這裏設定每個觀點的問題詢問數量

# 使用 requests 和 BeautifulSoup 獲取完整網頁內容
import requests
from bs4 import BeautifulSoup
import time

def get_full_content(url, max_retries=3):
    """獲取網頁的完整內容"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    for attempt in range(max_retries):
        try:
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
            
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 移除不需要的元素
            for tag in soup.find_all(['script', 'style', 'nav', 'footer', 'header']):
                tag.decompose()
                
            # 嘗試找到主要內容區域
            main_content = None
            for selector in ['main', 'article', '.content', '#content', '.post', '.article']:
                main_content = soup.select_one(selector)
                if main_content:
                    break
            
            # 如果找不到特定內容區，使用 body
            if not main_content:
                main_content = soup.body
                
            if main_content:
                # 提取文本並清理
                text = main_content.get_text(separator='\n', strip=True)
                # 移除多餘空行
                text = '\n'.join(line for line in text.split('\n') if line.strip())
                return text
            return "無法提取內容"
            
        except Exception as e:
            if attempt < max_retries - 1:
                time.sleep(1)  # 重試前等待
            else:
                return f"提取失敗: {str(e)}"

# 這裏處理所有的特殊觀點
# 如果要產生所有觀點的問題請打開下面註解
for p in perspectives:
# for p in perspectives[:1]:
    print(f'產生 {p} 觀點問題：')

    history = []  # 這裏記錄目前這個觀點的對話記錄

    # 每個觀點都會詢問 {total_questions} 個問題
    for i in range(total_questions):
        # 產生問題
        question = generate_question(topic, p, history)
        print(f"QUESTION: {question}")

        # 增加問題記錄
        history.append(question)

        # 使用 Tavily search 來搜尋問題的網路資源
        try:
            # 如果查詢過長，截斷到900字元
            safe_query = question[:900] if len(question) > 900 else question
            tavily_response = tavily.search(query=safe_query, max_results=3, search_depth="advanced")
            results = tavily_response['results']
        except Exception as e:
            print(f"Tavily 搜索出錯: {e}")
            results = []

        # 所有搜尋到的資料我們會將它彙整到一個 context 結構裏面
        all_context = ""
        for result in results:
            print(f"標題: {result['title']}")
            print(f"URL: {result['url']}")
            
            # 嘗試獲取完整內容
            try:
                full_content = get_full_content(result['url'])
                # 如果獲取成功，使用完整內容；否則使用 Tavily 提供的摘要
                if "提取失敗" not in full_content and len(full_content) > len(result['content']):
                    content = full_content
                    print(f"使用完整內容 ({len(content)} 字元)")
                else:
                    content = result['content']
                    print(f"使用 Tavily 摘要 ({len(content)} 字元)")
            except Exception as e:
                content = result['content']
                print(f"內容提取出錯，使用 Tavily 摘要: {e}")
            
            all_context += content + "\n\n"

            # 是否之前已經有查詢到一樣的網絡資源？ 有重複的就跳過它
            if result['url'] in duplicate_references:
                continue

            # for 重複網絡資源判斷
            duplicate_references.add(result['url'])

            # 參考的儲存結果 for RAG system
            references.append({"title": result['title'], "source": result['url'], "content": content})

        # 領域專家的回答
        answer = generate_answer(topic, question, all_context)

        # 將回覆記錄增加到 history 對話歷史記錄中
        print(f"ANSWER: {answer}")
        print("-------")
        history.append(answer)

    # 將這次觀點的對話記錄存到所有對話記錄的結構中
    all_conversations.append(history)
print("DONE.")
# Out:
# 產生 {'title': '設計師', 'perspective': '專注於如何設計一個專業的個人資料頁面，包括佈局、顏色選擇和視覺元素的設計'} 觀點問題：
# QUESTION: 在設計一個專業的 LinkedIn 頁面時，哪些佈局元素最能有效地吸引潛在雇主的注意？
# 標題: LinkedIn公司專頁| 5個錦囊妙計，設計出有吸引力的公司頁面
# URL: https://www.shutterstock.com/zh-Hant/blog/tips-designing-company-linkedin-profile
# 使用 Tavily 摘要 (100 字元)
# 標題: LinkedIn 個人品牌：職業成功策略- PLAG - 剽竊。學習。人工智慧.
# URL: https://blog.plag.ai/zh-TW/linkedin-personal-branding
# 使用完整內容 (9673 字元)
# 標題: 如何建立职业页面？+ 11 个职业网站范例为您提供灵感 - Recruit CRM
# URL: https://recruitcrm.io/zh-hans/blogs-zh/careers-page/
# 使用完整內容 (7941 字元)
# ANSWER: 在設計一個專業的 LinkedIn 頁面時，有幾個關鍵的佈局元素可以有效地吸引潛在雇主的注意：
#
# 1. **個人資料圖片和橫幅**：選擇一張清晰、專業的個人照片，這是給潛在雇主的第一印象。橫幅圖片應該反映您的專業身份或行業精神，增強專業形象。
#
# 2. **引人注目的標題**：您的標題不僅僅是職位名稱，還應該簡潔地傳達您的專業知識和獨特價值。這是吸引潛在雇主的關鍵元素之一。
#
# 3. **摘要部分**：使用摘要來講述一個使您的職業道路栩栩如生的故事，重點介紹您獨特的見解和成功。這是展示您個人品牌和專業成就的絕佳機會。
#
# 4. **詳細的經驗描述**：在經驗部分，不僅僅列出職位名稱，還要詳細描述您的角色和成就，並使用可量化的指標來展示您的影響力。
#
# 5. **多媒體元素**：在您的經驗部分中加入影片、簡報和作品圖像等多媒體元素，以生動地展示您的專業貢獻和影響。
#
# 6. **技能和推薦**：列出相關的技能，並獲得同事或客戶的推薦，這不僅提高了您的可信度，也展示了您的專業能力。
#
# 7. **動態參與**：定期分享展示您專業知識的原創內容和見解，並積極參與與您的職業目標相符的內容，將自己定位為所在領域的思想領袖。
#
# 透過這些佈局元素，您可以建立一個強大的 LinkedIn 個人資料，展示您的歷史和能力，吸引潛在雇主的注意。
# -------
# QUESTION: 在設計 LinkedIn 個人資料頁面時，如何選擇合適的顏色來增強專業形象並吸引潛在雇主的注意？
# 標題: 什麼是LinkedIn？LinkedIn照片怎麼拍怎麼選？教你打造出專業第一印象
# URL: https://www.chunshan.tw/linkedin-cvportrait/
# 使用完整內容 (93 字元)
# 標題: 如何建立令人印象深刻的LinkedIn 个人资料 - 芊芊简历
# URL: https://qqjl.cn/blog/how-to-build-a-great-linkedIn-profile/
# 使用完整內容 (15039 字元)
# 標題: How to Choose the Right LinkedIn Background
# URL: https://www.linkedin.com/pulse/how-choose-right-linkedin-background-philip-horne-wxsdc
# 使用完整內容 (10707 字元)
# ANSWER: 在設計 LinkedIn 個人資料頁面時，選擇合適的顏色是增強專業形象並吸引潛在雇主注意的關鍵之一。以下是一些建議，幫助你選擇合適的顏色：
#
# 1. **藍色調的運用**：
#    - 藍色通常被視為專業和可信賴的顏色。它能夠營造出一種穩重和可靠的氛圍，非常適合用於專業平台如 LinkedIn。淡藍色可以帶來清新感，而深藍色則顯得莊重。
#
# 2. **暖色調的選擇**：
#    - 暖色調如橙色或紅色可以使你的個人資料更具吸引力和活力。這些顏色可以傳達出熱情和積極的態度，但應該謹慎使用，避免過於刺眼或分散注意力。
#
# 3. **保持簡潔和一致性**：
#    - 無論選擇何種顏色，保持頁面整體的簡潔和一致性非常重要。過多的顏色可能會讓人感到混亂，因此應選擇一到兩種主色調，並搭配中性色如白色或灰色來平衡。
#
# 4. **考慮行業特性**：
#    - 不同行業對顏色的接受度可能不同。例如，創意行業可能更偏好大膽的顏色，而金融行業可能更傾向於保守的色調。在選擇顏色時，考慮你所屬行業的特性和文化。
#
# 5. **品牌一致性**：
#    - 如果你代表某個公司或品牌，考慮使用與公司品牌一致的顏色，這不僅能展示你的職業身份，還能增強品牌認同感。
#
# 6. **測試和反饋**：
#    - 嘗試不同的顏色組合，並從同事或專業人士那裡獲取反饋。這可以幫助你找到最能代表你專業形象的顏色。
#
# 總之，選擇合適的顏色不僅能提升你的專業形象，還能讓潛在雇主對你的個人資料留下深刻印象。記住，顏色不僅僅是視覺上的選擇，它還傳達了你的個人品牌和專業態度。
# -------
# QUESTION: 在設計 LinkedIn 個人資料頁面時，如何有效利用視覺元素來展示個人品牌並吸引潛在雇主的注意？
# 標題: 如何建立令人印象深刻的LinkedIn 个人资料 - 芊芊简历
# URL: https://qqjl.cn/blog/how-to-build-a-great-linkedIn-profile/
# 使用完整內容 (15039 字元)
# 標題: LinkedIn 個人品牌：職業成功策略- PLAG - 剽竊。學習。人工智慧.
# URL: https://blog.plag.ai/zh-TW/linkedin-personal-branding
# 使用完整內容 (9673 字元)
# 標題: 【職場升級秘訣】善用LinkedIn打造個人品牌，掌握薪資談判優勢
# URL: https://www.gut-haode.com/linkedin-tips-2/
# 使用完整內容 (4577 字元)
# ANSWER: 在設計 LinkedIn 個人資料頁面時，有效利用視覺元素可以大大提升您的個人品牌，並吸引潛在雇主的注意。以下是一些策略來幫助您達成這一目標：
#
# 1. **專業的個人資料照片**：
#    - 選擇一張清晰且專業的頭像，這是您給潛在雇主的第一印象。照片應該在一個簡單的背景下拍攝，確保您的臉部清晰可見。這樣的照片能夠傳達出您對細節的關注和專業的形象。
#
# 2. **橫幅圖片**：
#    - 利用 LinkedIn 提供的橫幅圖片功能來增強個人資料的視覺吸引力。選擇一張能夠反映您的職業身份或行業精神的圖片，例如您的工作環境、行業相關的圖像或抽象設計。這有助於強化您的專業形象。
#
# 3. **一致的視覺風格**：
#    - 確保您使用的所有視覺元素（包括個人資料照片和橫幅圖片）在風格和色調上保持一致。這樣可以建立一個連貫的品牌形象，讓您的個人資料看起來更專業和整潔。
#
# 4. **多媒體內容**：
#    - 在您的個人資料中加入多媒體內容，如影片、簡報和圖片，展示您的專業成就和項目。這些元素可以使您的經歷更具體和生動，並幫助潛在雇主更好地了解您的工作能力和成就。
#
# 5. **使用信息圖表和圖表**：
#    - 如果適用，您可以使用信息圖表和圖表來展示您的技能和成就。這不僅能夠更有效地傳達信息，還能增加您的個人資料的視覺吸引力。
#
# 6. **品牌顏色**：
#    - 如果您有個人品牌顏色或您所屬公司的品牌顏色，可以在您的個人資料設計中使用這些顏色。這種做法有助於增強品牌識別度。
#
# 通過這些策略，您可以有效地利用視覺元素來增強您的 LinkedIn 個人資料，從而吸引潛在雇主的注意，並展示您的專業品牌。
# -------
# 產生 {'title': '內容編輯', 'perspective': '專注於如何撰寫引人注目的個人簡介及經歷，確保內容豐富、有吸引力並突出重點'} 觀點問題：
# QUESTION: 在撰寫 LinkedIn 個人簡介時，有哪些關鍵要素可以幫助提升吸引力和專業性？
# 標題: 如何撰寫專業的LinkedIn 個人簡介
# URL: https://ambitious-learner.com/%F0%9F%9A%80-%E5%A6%82%E4%BD%95%E6%92%B0%E5%AF%AB%E5%B0%88%E6%A5%AD%E7%9A%84-linkedin-%E5%80%8B%E4%BA%BA%E7%B0%A1%E4%BB%8B/
# 使用 Tavily 摘要 (118 字元)
# 標題: 6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！
# URL: https://jason-career.com/linkedin/?srsltid=AfmBOoqWlEFuDMRDCItvni13LHKQBzkdbaOIT-Gm-tRu5817JLgethl2
# 使用完整內容 (17924 字元)
# 標題: 领英个人简历撰写指南：外贸专业人士必备(内含模板)
# URL: https://snovio.cn/blog/linkedin-summary-examples/
# 使用完整內容 (14642 字元)
# ANSWER: 在撰寫 LinkedIn 個人簡介時，有幾個關鍵要素可以幫助提升吸引力和專業性：
#
# 1. **優化標題（Headline）**：這是HR和其他用戶首先看到的內容。除了職位名稱，加入你的專長與價值，例如：「數據分析師｜精通 Python、SQL｜專注於商業洞察」，這樣的描述可以讓你的專業形象更具吸引力。
#
# 2. **撰寫個人摘要（About Section）**：用2-3段簡單明瞭的語言，概述你的職業背景、成就和未來目標。可以用故事化的方式呈現，讓人讀起來更有吸引力。避免使用艱澀的行話，專注於突顯你的特質、熱忱和價值觀。
#
# 3. **專業的頭像和背景照片**：選用清晰、自然且帶有微笑的照片，背景簡單乾淨，建議穿著符合職業形象的衣服。背景照片可以選擇與你的行業或專業相關的圖片，以展示你的個人品牌。
#
# 4. **工作經歷摘要**：這部分應量化地描述成就和工作的總結，而不是簡單的職位描述。可以考慮用「說故事」的方式，或上傳媒體、作品等，讓你的經歷更具說服力。
#
# 5. **教育背景**：列出你的畢業學校、系所、排名、GPA（如果大於3.5），以及修過的課程、研究或社團活動，這些都能強化你的專業形象。
#
# 6. **添加精選內容（Featured Section）**：這一欄提供展示自己的空間，你可以放上工作成就和成果，或置頂一些你之前發布過的文章，讓你的形象更立體。
#
# 7. **設定技能與推薦（Skills & Endorsements）**：列出與你的目標領域高度相關的技能，並獲得同事或朋友的推薦，這能增強你的專業可信度。
#
# 8. **自訂個人專屬的 URL**：修改LinkedIn主頁URL，使其接近你的名字，這展示了你對細節的關注，也是區別於其他候選人的標誌。
#
# 這些要素不僅能提升你的LinkedIn個人簡介的專業性，還能增加被潛在雇主或合作夥伴發現的機會。
# -------
# QUESTION: 在撰寫引人注目的LinkedIn個人摘要時，有哪些技巧可以幫助突出個人品牌並吸引潛在雇主的注意？
# 標題: 10个最大化影响力的LinkedIn简介模板 - pipl.ai
# URL: https://resources.pipl.ai/zh/linkedin-summary-examples/
# 使用 Tavily 摘要 (3778 字元)
# 標題: 如何建立令人印象深刻的LinkedIn 个人资料 - 芊芊简历
# URL: https://qqjl.cn/blog/how-to-build-a-great-linkedIn-profile/
# 使用完整內容 (15039 字元)
# 標題: 【職場升級秘訣】善用LinkedIn打造個人品牌，掌握薪資談判優勢
# URL: https://www.gut-haode.com/linkedin-tips-2/
# 使用完整內容 (4577 字元)
# ANSWER: 在撰寫引人注目的LinkedIn個人摘要時，有多種技巧可以幫助突出個人品牌並吸引潛在雇主的注意：
#
# 1. **強有力的開頭**：一個引人入勝的開頭可以立即吸引讀者的注意。可以使用大膽的聲明或引人入勝的問題來引起讀者的好奇心。例如，開頭可以是“通過創新的SaaS解決方案改變企業”或“你是否曾想過數據驅動的潛在客戶生成如何改變你的營銷策略？”這樣的開頭能夠設置基調並鼓勵讀者繼續閱讀。
#
# 2. **展示你的獨特價值主張**：在摘要中突出你的優勢、技能和經驗，這些使你與眾不同。結合相關的SEO關鍵詞以提高可見性。比如，可以強調你的核心價值觀如熱情、誠信和創新，並用具體的成就來展示你的價值，如“通過有針對性的營銷活動，第三季度銷售額增加了40%”。
#
# 3. **講述你的故事**：利用你的職業背景和個人興趣來建立情感聯繫。這不僅能讓你的個人資料更具人性化，還能讓人感到親切和引人入勝。例如，可以提到你在某一領域的多年經驗，以及你在工作之外的興趣愛好，如徒步旅行或探索AI技術。
#
# 4. **適當的格式和風格**：使用項目符號或段落來有效地組織內容，保持專業但親切的語氣。確保段落簡短，使用標題或副標題以便於導航，這能提高可讀性並保持讀者的興趣。
#
# 5. **保持摘要的長度和可讀性**：理想的LinkedIn摘要應在1000字符以內。利用空白來提高可讀性，避免使用行話，並用第一人稱寫作以展示個性，這樣的做法可以確保信息清晰且有影響力。
#
# 6. **靈感示例**：借鑒其他行業的成功案例可以提供寫作靈感。例如，一位IT專業人員的摘要可能會強調其在多種編程語言的專長和成功優化系統性能的經驗。
#
# 通過這些技巧，你可以打造一個引人注目的LinkedIn個人摘要，展示你的專業形象，並有效吸引潛在雇主的注意。
# -------
# QUESTION: 在撰寫LinkedIn個人簡介時，如何有效地選擇和運用SEO關鍵詞來提高個人資料的搜尋可見性？
# 標題: 在LinkedIn 發表之文章或電子報的SEO 設定
# URL: https://www.linkedin.com/help/linkedin/answer/a6272792?lang=zh-TW
# 使用完整內容 (422 字元)
# 標題: 领英个人简历撰写指南：外贸专业人士必备(内含模板)
# URL: https://snovio.cn/blog/linkedin-summary-examples/
# 使用完整內容 (14642 字元)
# 標題: 整合行銷必學的5個SEO技巧，讓你的網站在搜尋結果中搶眼有招！
# URL: https://cybermkt.com.tw/marketing/integrated-marketing-5-seo-tips/
# 使用 Tavily 摘要 (83 字元)
# ANSWER: 在撰寫LinkedIn個人簡介時，選擇和運用SEO關鍵詞是提高個人資料搜尋可見性的關鍵步驟。以下是一些有效的方法：
#
# 1. **關鍵字研究**：首先，進行關鍵字研究是必要的。了解哪些詞語最能代表你的專業領域、技能和目標職位。這可以通過使用工具如Google Keyword Planner或直接在LinkedIn搜尋框中進行相關搜尋來完成。
#
# 2. **整合關鍵字**：一旦確定了關鍵字，將它們自然地整合到你的個人簡介中。這包括在標題、摘要、經歷描述和技能部分使用這些關鍵詞。確保關鍵字的使用不僅僅是為了迎合搜尋引擎，而是能夠真實地反映你的專業能力和經驗。
#
# 3. **專業標題優化**：你的LinkedIn標題是搜尋引擎優化的黃金地段。使用關鍵字來描述你的職業角色和專業領域。例如，如果你是一名數據科學家，確保在標題中包含“數據科學家”這一關鍵詞。
#
# 4. **摘要中的關鍵字**：在個人簡介的摘要部分，使用關鍵字來闡述你的專業背景和職業目標。這段文字應該清晰地總結你的專業身份，並吸引潛在的雇主或合作夥伴。
#
# 5. **量化成就**：在描述工作經歷時，使用關鍵字並量化你的成就。這不僅提高了可見性，也增加了你的資料的可信度。例如，“在XYZ公司擔任數據分析師，提升了20%的數據處理效率”。
#
# 6. **持續更新**：SEO不是一次性的工作。定期更新你的個人資料，以反映最新的職業發展和技能，並確保新的關鍵詞也能夠被整合進來。
#
# 通過這些策略，你可以有效地提高LinkedIn個人資料的搜尋可見性，吸引更多的職業機會和人脈資源。
# -------
# 產生 {'title': '社交專家', 'perspective': '專注於如何擴展人脈及建立專業形象，包括與他人互動、分享內容以及網絡建立的技巧'} 觀點問題：
# QUESTION: 在建立一個專業的 LinkedIn 首頁時，應該如何選擇和撰寫個人簡介以最佳地展示專業形象？
# 標題: 如何撰寫專業的LinkedIn 個人簡介
# URL: https://ambitious-learner.com/%F0%9F%9A%80-%E5%A6%82%E4%BD%95%E6%92%B0%E5%AF%AB%E5%B0%88%E6%A5%AD%E7%9A%84-linkedin-%E5%80%8B%E4%BA%BA%E7%B0%A1%E4%BB%8B/
# 使用 Tavily 摘要 (87 字元)
# 標題: 6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！
# URL: https://jason-career.com/linkedin/?srsltid=AfmBOop6ovJB80lYFtG61fQKsPuM54m3FZAvs6ljejWiuS82oM6BmzFy
# 使用完整內容 (17924 字元)
# 標題: LinkedIn新手必學！5招提升你的個人檔案能見度
# URL: https://vocus.cc/article/676ad0b0fd89780001a115d9
# 使用完整內容 (7936 字元)
# ANSWER: 在建立一個專業的 LinkedIn 首頁時，選擇和撰寫個人簡介是至關重要的，因為這是HR和其他用戶最先看到的內容，直接影響他們是否有興趣繼續瀏覽你的Profile。以下是一些關鍵建議，幫助你最佳地展示專業形象：
#
# 1. **簡潔且具有影響力**：最佳的LinkedIn個人簡介應該簡潔且具有影響力，通常建議在150-300字之間。確保內容直擊重點，不拖泥帶水。
#
# 2. **撰寫吸引人的標題**：你的標題應不僅限於職位名稱，還應該加入你的專長與價值。例如：「數據分析師｜精通 Python、SQL｜專注於商業洞察」。這樣的標題可以立即讓訪客了解你的專業背景和獨特價值。
#
# 3. **個人摘要**：用2-3段簡單明瞭的語言，概述你的職業背景、成就和未來目標。可以用故事化的方式呈現，讓人讀起來更有吸引力。這不僅展示了你的專業能力，也能傳達你的職業熱情和願景。
#
# 4. **展示成就和目標**：在個人簡介中，強調你職業生涯中最相關的成就，並明確表達你未來的職業目標。這可以幫助潛在的雇主或合作夥伴看到你的潛力和動機。
#
# 5. **避免使用行話**：避免使用艱澀難懂的行話 (Jargon)，確保你的語言清晰易懂，讓各行各業的人都能理解你的專業價值。
#
# 通過這些策略，你可以有效地在LinkedIn上建立一個專業的個人品牌，吸引更多的職業機會和人脈連結。
# -------
# QUESTION: 在 LinkedIn 上，除了撰寫專業的個人簡介外，還有哪些有效的方法可以擴展人脈並建立專業形象？
# 標題: 如何高效利用LinkedIn领英拓展人脉？  实用技巧分享 - 淘宝百科
# URL: https://bk.taobao.com/k/lingying_702/c205405d9e7a5b49e02026361bd7004c.html
# 使用 Tavily 摘要 (75 字元)
# 標題: 如何在领英建立有效人脉 - LinkedIn
# URL: https://www.linkedin.com/pulse/%E5%A6%82%E4%BD%95%E5%9C%A8%E9%A2%86%E8%8B%B1%E5%BB%BA%E7%AB%8B%E6%9C%89%E6%95%88%E4%BA%BA%E8%84%89-%E9%A2%86%E8%8B%B1-%E7%8E%A9%E8%BD%AC
# 使用完整內容 (3557 字元)
# 標題: 誰說認識才能送邀請？如何運用LinkedIn Connections 拓展自己的 ...
# URL: https://medium.com/linkedin-taiwan-non-official-community/%E8%AA%B0%E8%AA%AA%E8%AA%8D%E8%AD%98%E6%89%8D%E8%83%BD%E9%80%81%E9%82%80%E8%AB%8B-%E5%A6%82%E4%BD%95%E9%81%8B%E7%94%A8-linkedin-connections-%E6%8B%93%E5%B1%95%E8%87%AA%E5%B7%B1%E7%9A%84%E5%B0%88%E6%A5%AD%E4%BA%BA%E8%84%88%E7%B6%B2%E7%B5%A1-17c581b69463
# 使用完整內容 (4451 字元)
# ANSWER: 在LinkedIn上，除了撰寫專業的個人簡介外，還有多種有效的方法可以擴展人脈並建立專業形象：
#
# 1. **擴充和篩選高質量人脈網絡**：
#    - **擴充人脈**：使用LinkedIn的推薦功能和搜索工具，從你的電子郵件或通訊錄中同步聯絡人，並主動添加可能對職業發展有幫助的人脈，如前同事、同學、業界專家等。
#    - **篩選人脈**：在發送好友邀請前，查看對方的檔案，根據其所在行業、公司、學校及動態內容，判斷其是否屬於你感興趣的人脈圈。
#
# 2. **讓人脈了解你**：
#    - **個性化邀請信息**：在添加好友時，使用個性化邀請信息介紹自己和加好友的原因，以提高邀請通過率並留下深刻印象。
#    - **維護LinkedIn檔案**：隨時更新你的職位和狀態，並撰寫專業的個人簡介，讓潛在人脈更好地了解你的專長和職業目標。
#    - **發布內容並參與話題討論**：定期發布職場相關的動態和文章，並參與熱門話題討論，這不僅能展示你的專業知識，也能吸引志同道合的職場伙伴。
#
# 3. **維持和經營有效人脈**：
#    - **保持互動**：定期與人脈互動，如點贊或評論他們的動態，在他們的紀念日或職位變動時送上祝福，這些小小的互動能有效維持人脈關係。
#    - **互幫互助**：在職場上，優質的人脈資源應該是互利共贏的，主動為他人提供價值，並在需要時請求幫助，這樣的關係更穩定且長久。
#
# 4. **參加行業相關的活動和討論**：
#    - 參加LinkedIn上的行業小組和討論，這不僅能拓展人脈，還能讓你在同行中建立專業形象，獲得行業最新資訊。
#
# 透過這些策略，你可以在LinkedIn上有效地擴展人脈並建立起專業形象，為你的職業生涯帶來更多機會和資源。
# -------
# QUESTION: 在LinkedIn上，如何有效地利用內容分享來展示專業知識並吸引相關人脈？
# 標題: 创建令人信服的LinkedIn 内容：撰写能提高参与度的帖子 - Ranktracker
# URL: https://www.ranktracker.com/zh/blog/creating-compelling-linkedin-content-a-guide-to-crafting-posts-articles-and-videos-that-drive-engagement/
# 使用完整內容 (14028 字元)
# 標題: 分享內容| LinkedIn 說明
# URL: https://www.linkedin.com/help/linkedin/topic/a148004?lang=zh-TW
# 使用完整內容 (11882 字元)
# 標題: 6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！
# URL: https://jason-career.com/linkedin/?srsltid=AfmBOoqMnoy0yIM4j0Jp8vg8-FrMQkq8F3iRZc7msKX6ru6jIVjsKbjC
# 使用完整內容 (17924 字元)
# ANSWER: 在LinkedIn上，利用內容分享來展示專業知識並吸引相關人脈是一個有效的策略。以下是一些具體步驟和建議，幫助您在LinkedIn上建立專業形象並擴展人脈：
#
# 1. **確定目標受眾**：在創建內容之前，首先要明確您的目標受眾是誰。考慮行業、職業角色、興趣和人口統計等因素。這將幫助您創作出能引起受眾共鳴的內容。例如，如果您是一名數字營銷顧問，您的受眾可能是25-35歲之間的科技專業人士。
#
# 2. **創作引人注目的內容**：撰寫能提高參與度的貼文、文章和視頻。確保內容具有價值，分享行業見解、趨勢和實用建議，以展示您的專業知識。內容應該能夠激發讀者的興趣和互動。
#
# 3. **使用引人注目的標題**：撰寫簡明扼要且描述性強的標題，以吸引讀者的注意力。使用有力的詞語、數字或問題來突出文章的重點，使其在LinkedIn動態中脫穎而出。
#
# 4. **利用多媒體元素**：在文章中使用圖片、影片和其他多媒體文件，增加內容的吸引力和信息量。LinkedIn允許嵌入YouTube、SlideShare等平台的內容，這樣可以豐富您的文章。
#
# 5. **分享個人經歷和故事**：分享您的職業歷程、面對的挑戰或成功故事。通過講故事的方式使內容更具親和力，與讀者建立情感聯繫。
#
# 6. **積極參與互動**：在貼文中提出開放式問題，鼓勵互動。及時回覆評論，培養社區意識。這不僅能增加內容的曝光度，還能促進與受眾的聯繫。
#
# 7. **分析和調整策略**：使用LinkedIn的分析工具來跟踪內容的表現。分析受眾的反應和參與度，調整內容策略以滿足受眾的需求和興趣。
#
# 8. **建立一致的內容計劃**：制定內容日曆，保持穩定的內容流，確保不會錯過重要機會。持續分享高質量內容，能夠增強您的專業形象。
#
# 9. **參與社群和討論**：參與行業相關的LinkedIn群組和討論，分享您的見解和專業知識，擴大您的影響力。
#
# 通過以上策略，您可以在LinkedIn上有效地展示專業知識，吸引相關人脈，並在您的行業中建立持久的影響力。
# -------
# DONE.

# %% [markdown]
# ## tavily mode

# %%
all_conversations = []  # 這裏記錄的是所有的對話記錄
references = [] # 這裏記錄所有網路搜尋的結果
duplicate_references = set()
total_questions = 3 # 這裏設定每個觀點的問題詢問數量

# 這裏處理所有的特殊觀點
# 如果要產生所有觀點的問題請打開下面註解
#for p in perspectives:
for p in perspectives[:1]:
    print(f'產生 {p} 觀點問題：')

    history = []  # 這裏記錄目前這個觀點的對話記錄

    # 每個觀點都會詢問 {total_questions} 個問題
    for i in range(total_questions):
        # 產生問題
        question = generate_question(topic, p, history)
        print(f"QUESTION: {question}")

        # 增加問題記錄
        history.append(question)

        # 使用 Tavily search 來搜尋問題的網路資源
        tavily_response = tavily.search(query=question, max_results=3, search_depth="advanced")
        results = tavily_response['results']

        # 所有搜尋到的資料我們會將它彙整到一個 context 結構裏面
        all_context = ""
        for result in results:

            print(result)
            
            all_context += result['content'] + "\n"

            # 是否之前已經有查詢到一樣的網絡資源？ 有重複的就跳過它
            if result['url'] in duplicate_references:
                continue

            # for 重複網絡資源判斷
            duplicate_references.add(result['url'])

            # 參考的儲存結果 for RAG system
            references.append({"title": result['title'], "source": result['url'], "content": result['content']})

        # 領域專家的回答
        answer = generate_answer(topic, question, all_context)

        # 將回覆記錄增加到 history 對話歷史記錄中
        print(f"ANSWER: {answer}")
        print("-------")
        history.append(answer)

    # 將這次觀點的對話記錄存到所有對話記錄的結構中
    all_conversations.append(history)
print("DONE.")
# Out:
# 產生 {'title': '設計師', 'perspective': '專注於如何設計一個專業的個人資料頁面，包括佈局、顏色選擇和視覺元素的設計'} 觀點問題：
# QUESTION: 在設計一個專業的 LinkedIn 個人資料頁面時，您認為哪些佈局元素對於提升整體專業形象最為重要？
# {'url': 'https://www.shutterstock.com/zh-Hant/blog/tips-designing-company-linkedin-profile', 'title': 'LinkedIn公司專頁| 5個錦囊妙計，設計出有吸引力的公司頁面', 'content': '你有沒有發現視覺效果對LinkedIn公司專頁很重要？新增橫幅圖片並上傳商標以增加存在感是個妙策。當會員搜尋你的公司或你的員工資料時，商標就會出現。', 'score': 0.63452125, 'raw_content': None}
# {'url': 'https://www.facebook.com/groups/213880764995293/posts/300729616310407/', 'title': '5分钟手把手教你学会制作高级感LinkedIn Banner图 ... - Facebook', 'content': '根据B2B性质和LinkedIn banner图的排版布局，我给大家整理了几个非常适合大 家使用的模板（所有用户可使用）： （大家可以搜索右上角的关键词，直接搜出这三个', 'score': 0.2423988, 'raw_content': None}
# {'url': 'https://business.linkedin.com/content/dam/me/business/zh-cn/marketing-solutions/campaign/2020/may/sophisticated-marketers-guide-to-global-content_CN_final.pdf', 'title': '[PDF] 全球内容挑战 - LinkedIn Business', 'content': '横跨不同市场有效调动和利用品牌内容，是. 大有可为的。如果能合理全球内容策略，您. 就可以创造更多有效内容，实现更好营销效. 果，超额完成本地营销目标。相反，如果未.', 'score': 0.07777658, 'raw_content': None}
# ANSWER: 在設計一個專業的 LinkedIn 個人資料頁面時，視覺效果是提升整體專業形象的關鍵元素之一。首先，新增橫幅圖片是非常重要的。橫幅圖片不僅能夠增強視覺吸引力，還能夠傳達品牌或個人專業的核心價值。選擇與職業背景或行業相關的圖片，可以讓訪客更直觀地了解您的專業領域。
#
# 其次，上傳商標也是提升專業形象的一個重要步驟。當其他會員搜尋您的公司或員工資料時，商標會出現在搜索結果中，這不僅增加了品牌的存在感，還有助於建立一種專業的品牌形象。
#
# 此外，合理利用全球內容策略，可以有效調動和利用品牌內容，從而創造更多有效內容，實現更好的營銷效果。這意味著您可以針對不同市場調整內容，以達到超額完成本地營銷目標的效果。
#
# 總之，精心設計的橫幅圖片和商標，結合合理的內容策略，是提升 LinkedIn 個人資料頁面專業形象的關鍵元素。這些元素不僅能夠增強視覺吸引力，還能夠有效傳達專業信息，提升整體形象。
# -------
# QUESTION: 在選擇顏色時，您認為哪種顏色方案最能有效地傳達專業形象，同時又能保持個人風格？
# {'url': 'https://vocus.cc/article/6507b185fd8978000199e36d', 'title': '品牌色彩學之旅：Logo設計和色彩選擇的策略性思考 - 方格子', 'content': '高對比的配色能產生強烈的視覺效果，可以有效傳達品牌的核心概念，同時這種配色方案十分適合用網頁視覺方面，無論是資訊圖表類型的統計資料或是多媒體平台，能凸顯重要訊息。', 'score': 0.40344992, 'raw_content': None}
# {'url': 'https://www.jcolor.com.tw/blog_post/logocolor?srsltid=AfmBOopd81N0BV1pDYF6reE0h_DMZRTzvapqfQoa20Z5BeM_SAuJxCQL', 'title': '品牌色彩學之旅：Logo設計和色彩選擇的策略性思考 - 捷可印', 'content': '三、運用對比色建立出品牌代表色\u200b 高對比的配色能產生強烈的視覺效果，可以有效傳達品牌的核心概念，同時這種配色方案十分適合用網頁視覺方面，無論是資訊圖', 'score': 0.3659556, 'raw_content': None}
# {'url': 'https://vocus.cc/article/65010f4cfd89780001f949a7', 'title': '品牌色彩大揭秘：品牌和產品如何通過色彩說故事，並提升品牌價值', 'content': '色彩心理學：每種顏色都有其特定的情感和心理反應。例如，紅色通常與激情、能量和行動相關聯，而藍色則與信任、平靜和專業相關聯。 與競爭', 'score': 0.32222784, 'raw_content': None}
# ANSWER: 在選擇顏色方案以建立一個專業的 LinkedIn 首頁時，考慮高對比的配色方案是非常有效的策略。高對比的配色能產生強烈的視覺效果，有助於有效傳達品牌的核心概念，這對於想要在專業平台上脫穎而出的個人而言尤其重要。
#
# 首先，藍色是 LinkedIn 的主色調，也是傳統上與信任、平靜和專業相關聯的顏色。因此，選擇藍色作為主要顏色可以增強與平台的整體一致性，並傳遞出專業性。同時，運用對比色來補充藍色，例如使用較亮的色調如橙色或綠色，可以增加頁面的活力和個人風格。這些對比色不僅能突顯重要訊息，還能在不失專業的前提下，展現出個人的創意和獨特性。
#
# 此外，色彩心理學指出每種顏色都有其特定的情感和心理反應。因此，在選擇顏色時，應該考慮到這些反應如何與你的個人品牌相符。例如，如果你希望傳達激情和行動力，可以選擇紅色作為輔助色，這能夠激發觀眾的情感回應。
#
# 總結來說，選擇一個結合藍色與高對比輔助色的配色方案，不僅能夠傳達專業形象，還能保持你的個人風格，使你的 LinkedIn 首頁既專業又有個性。
# -------
# QUESTION: 在設計 LinkedIn 個人資料頁面時，您認為使用哪些字體風格可以有效地平衡專業性與個人風格？
# {'url': 'https://qqjl.cn/blog/how-to-build-a-great-linkedIn-profile/', 'title': '如何建立令人印象深刻的LinkedIn 个人资料 - 芊芊简历', 'content': '在构建个人资料页面的视觉风格时，LinkedIn 个人资料图片可能是最简单的起点。最好的效果通常是由专业摄影师拍摄的头像提供的。它可能看起来很虚荣或过度，但在大多数', 'score': 0.5185224, 'raw_content': None}
# {'url': 'https://cn.linkedin.com/pulse/%E8%AE%93linkedin%E8%B2%BC%E6%96%87%E6%9C%89%E8%BE%A8%E8%AD%98%E5%BA%A6%E7%9A%84%E6%96%B9%E6%B3%95-tzu-chien-su-fwjyc', 'title': '讓LinkedIn貼文有辨識度的方法| 蘇資茜 - 领英', 'content': '在LinkedIn上，一定要善用寫作風格讓讀者記得你。 在教學的時候，我都會跟我的學生提醒說：「保留你的寫作風格，寫作風格是建立個人品牌很重要的元素。」.', 'score': 0.32114106, 'raw_content': None}
# {'url': 'https://business.linkedin.com/content/dam/me/business/zh-cn/marketing-solutions/campaign/2020/may/sophisticated-marketers-guide-to-global-content_CN_final.pdf', 'title': '[PDF] 全球内容挑战 - LinkedIn Business', 'content': '横跨不同市场有效调动和利用品牌内容，是. 大有可为的。如果能合理全球内容策略，您. 就可以创造更多有效内容，实现更好营销效. 果，超额完成本地营销目标。相反，如果未.', 'score': 0.0764423, 'raw_content': None}
# ANSWER: 在設計 LinkedIn 個人資料頁面時，選擇合適的字體風格對於平衡專業性與個人風格至關重要。儘管 LinkedIn 本身對字體的選擇較為有限，以下是一些建議，可以幫助您達到這一平衡：
#
# 1. **Sans-Serif 字體**：這類字體如 Arial、Helvetica 和 Calibri，通常被認為是專業且易讀的選擇。它們的簡潔和現代感能夠很好地體現專業形象。
#
# 2. **Serif 字體**：如果 LinkedIn 支持，您可以考慮使用如 Times New Roman 或 Georgia 的 Serif 字體，這些字體在某些情況下可以傳達出一種更為傳統和正式的感覺，但仍然保持專業性。
#
# 3. **個人風格的體現**：在 LinkedIn 個人資料中，您可以通過內容的排版和格式來體現個人風格，例如使用粗體或斜體來強調關鍵信息或標題，這樣可以在不偏離專業性的基礎上，增添一些個人特色。
#
# 4. **一致性**：無論您選擇哪種字體，保持整體頁面的一致性非常重要。這意味著在不同的段落和標題中使用相同的字體和格式，以確保頁面看起來整潔且專業。
#
# 5. **品牌一致性**：如果您有自己的品牌，考慮在 LinkedIn 上反映這一點，例如使用與您品牌一致的顏色和字體風格，這有助於在不同市場中有效調動和利用品牌內容，增強您的個人品牌形象。
#
# 總之，選擇字體時應考慮易讀性、專業性和個人風格之間的平衡，這樣才能在 LinkedIn 上打造一個既專業又獨特的個人資料頁面。
# -------
# DONE.

# %%
references[0]["content"]
# Out:
# '你有沒有發現視覺效果對LinkedIn公司專頁很重要？新增橫幅圖片並上傳商標以增加存在感是個妙策。當會員搜尋你的公司或你的員工資料時，商標就會出現。'

# %%
## Q A
all_conversations
# Out:
# [['在設計 LinkedIn 個人資料頁面時，哪些佈局策略可以幫助突出專業形象並增強可讀性？',
#   '在設計 LinkedIn 個人資料頁面以突出專業形象並增強可讀性時，有幾個佈局策略可以考慮：\n\n1. **專業的個人頭像與背景圖**：選擇一張能代表您專業形象的頭像，保持乾淨簡潔的風格。背景圖可以用來展示企業的業務範疇或核心產品，進一步強化您的專業身份。\n\n2. **引人入勝的封面故事**：在 LinkedIn 個人資料中添加影片介紹，使其更具吸引力和風度。這不僅能顯著提高參與度，還能給訪客留下深刻印象。\n\n3. **精心撰寫的摘要**：利用個人資料的摘要部分來講述您的職業故事，展示關鍵職業時刻、克服的挑戰和實現的里程碑。這種敘事策略能夠吸引讀者的注意，並增強您的專業形象。\n\n4. **定期更新與反映現狀**：保持個人資料的動態性，定期更新以準確反映您目前的職業狀態和能力。這能夠保持其相關性和吸引力，對潛在雇主和合作者更具吸引力。\n\n5. **使用關鍵字進行SEO優化**：在個人資料中使用與您行業和技能相關的關鍵字，這能提高在 LinkedIn 和外部搜尋引擎上的可見度，吸引合適的受眾。\n\n6. **隱私和設定管理**：管理您的隱私設置，以控制哪些資訊是公開的，以及誰可以看到您的活動和聯繫。這有助於維護您的個人品牌的完整性。\n\n透過這些策略，您可以確保您的 LinkedIn 個人資料不僅專業且具吸引力，還能有效地傳達您的職業價值和成就，成為促進職業關係和發展的有力工具。',
#   '在選擇 LinkedIn 個人資料的顏色方案時，有哪些顏色能夠有效傳達專業性並與品牌形象相符？',
#   '在選擇 LinkedIn 個人資料的顏色方案時，考慮到專業性和品牌形象的傳達，以下幾種顏色是有效的選擇：\n\n1. **LinkedIn Blue**：LinkedIn 的標誌性藍色是專業和信任的象徵，這使得它成為 LinkedIn 個人資料的理想選擇。這種顏色不僅與平台的整體設計相匹配，還能有效提升品牌一致性。\n\n2. **黑色**：黑色是一種經典且永不過時的顏色，能夠傳達出專業性和權威感。它適合作為強調色或背景色，特別是在需要突出其他元素時。\n\n3. **白色**：白色背景能夠提供清晰和整潔的外觀，讓其他顏色和內容更加突出。使用白色作為背景可以提高 LinkedIn 標誌和其他圖形元素的可讀性和影響力。\n\n在選擇顏色方案時，還應考慮與您個人或公司品牌的整體色彩一致性。這樣可以確保您的 LinkedIn 個人資料不僅專業，還能有效地反映您的品牌形象。使用這些顏色策略，您可以創建一個既專業又具有個人品牌特色的 LinkedIn 首頁。',
#   '在設計 LinkedIn 個人資料頁面時，哪些視覺元素可以用來增強品牌一致性和專業性？',
#   '在設計 LinkedIn 個人資料頁面時，使用視覺元素來增強品牌一致性和專業性是至關重要的。以下是一些可以考慮的視覺元素：\n\n1. **封面圖片**：選擇一個具有吸引力且與您的專業品牌一致的封面圖片。封面圖片的尺寸應為1,128像素x191像素，以確保最佳顯示效果。這是第一眼吸引訪客注意力的關鍵元素。\n\n2. **個人頭像**：使用專業的個人頭像，這應該是高質量的圖像，並且與您的職業形象相符。確保頭像清晰且集中，給人以專業和可信賴的印象。\n\n3. **品牌徽標**：如果您代表某個品牌或公司，將品牌徽標作為封面圖片的一部分或在背景中使用，可以增強品牌的可識別性。\n\n4. **一致的配色方案**：在整個個人資料中使用一致的配色方案，這應該反映您的個人品牌或公司品牌。這種一致性可以增強品牌識別度，讓訪客更容易記住您。\n\n5. **字體選擇**：選擇清晰且專業的字體，確保所有文本易於閱讀。字體的一致性也有助於維持專業形象。\n\n6. **影片介紹**：在您的個人資料中添加影片介紹，使其更具吸引力和風度。這不僅可以提高參與度，還能給訪客留下深刻印象。\n\n7. **內容一致性**：在發布文章和更新時，保持視覺和內容的一致性，這可以進一步強化您的品牌形象。\n\n通過整合這些視覺元素，您可以在 LinkedIn 上建立一個專業且一致的品牌形象，這不僅能增強您的個人品牌，還能吸引更多潛在的雇主和合作者。']]

# %% [markdown]
# # 同學的練習
# - 挑選一個自己想要測試的主題
# - 依序執行，並且確認正確無誤
# - 給同學 5 分鐘的時間練習

# %% [markdown]
# # 程式說明三、建立大綱

# %% [markdown]
# ![](data:image/png;base64,...)

# %%
def generate_outline(topic: str) -> str:
    """
    產生初版文章大綱，請注意提示詞有做改進。
    """

    # system_prompt = """
    # 為一個特定主題撰寫文章大綱。
    # 這是你寫作的格式：
    # 使用“# 標題”來指示節的標題，“## 標題”來指示小節的標題，“### 標題”來指示小小節的標題，依此類推。
    # 不要包含其他資訊。請使用繁體中文。
    # """

    system_prompt = """
    為一個特定主題撰寫文章大綱。下方是你寫作的格式：

    1. 使用“# 標題”來指示節的標題。
    2. 使用“## 標題”來指示小節的標題。
    3. 使用“-”符號來列出小節中的要點。
    4. 每個節和小節之間請確保有空行。
    5. 大綱應僅包含標題和要點，不應包含其他額外資訊。
    6. 請使用繁體中文。
    """

    user_prompt = """這裏是主題:\n\n主題:{topic}"""

    try:

        response = completion(
            api_key = OPENAI_API_KEY,
            model="gpt-3.5-turbo",
            messages=[{ "content": system_prompt,"role": "system"},{ "content": user_prompt.format(topic=topic),"role": "user"}],
            temperature=0.5,
            max_tokens=500,
        )
        response = response.choices[0].message.content

        return response
    except Exception as e:
        print(f"Error in translation: {e}")

# %%
# 使用使用者指定的主題，產生主題大綱初版
outline = generate_outline(topic)

# %%
print(outline) # generated outline
# Out:
# # 建立一個專業的 LinkIn 首頁
#
# ## 簡介
# - 介紹LinkedIn的重要性
# - 目的是建立專業形象和職場網絡
#
# ## 個人資料
# - 更新個人照片
# - 撰寫引人注目的個人簡介
# - 確保個人資訊完整
#
# ## 封面圖片
# - 選擇專業且具吸引力的封面圖片
# - 可以展示個人特色或興趣
#
# ## 經歷與學歷
# - 詳細列出工作經歷
# - 強調成就和專業技能
# - 更新學歷資訊
#
# ## 推薦信
# - 獲取同事或上司的推薦信
# - 互相推薦以建立信任
#
# ## 社交互動
# - 主動參與社群討論
# - 分享專業知識和文章
# - 互動回應他人的貼文
#
# ## 專業頭銜
# - 使用具體和專業的頭銜
# - 可以突顯個人專業性和能力
#
# ## 聯絡資訊
# - 確保聯絡資訊是最新的
# - 方便他人與你取得聯繫
#
# ## 精選作品
# - 上傳展示自己專業能力的作品
# - 可以是文章、研究報告、演講錄像等
#
# ## 頻繁更新
# - 定期更新個人資訊和動態
# - 保持與職場趨

# %%
def refine_outline(topic: str, outline: str, conversation: list[list[str]]) -> str:
    system_prompt = """
    我希望你改善一篇關於【{topic}】主題的文章大綱。
    你已經有一個涵蓋了一般資訊的初稿大綱，現在你希望基於與專家的對話中學到的資訊來改進它，使其更加全面。

    這是你寫作的格式：
    使用“# 標題”來指示節的標題，“## 標題”來指示小節的標題，“### 標題”來指示小小節的標題，依此類推。不要包含其他資訊。請使用繁體中文。

    初稿大綱：{outline}
    """

    user_prompt = """學到的資訊: {conversation}"""
    flattened_list = [item for sublist in conversation for item in sublist]
    context = ''.join(flattened_list)
    try:
        response = completion(
            api_key = OPENAI_API_KEY,
            model="gpt-4o",
            messages=[{ "content": system_prompt.format(topic=topic, outline=outline),"role": "system"},
                      { "content": user_prompt.format(conversation=context),"role": "user"}],
            temperature=0.5,
            max_tokens=1000,
        )
        response = response.choices[0].message.content

        return response
    except Exception as e:
        print(f"Error in translation: {e}")

# %%
refined_outline = refine_outline(topic, outline, all_conversations)

# %%
print(outline) # initial outline
# Out:
# # 建立一個專業的 LinkIn 首頁
#
# ## 簡介
# - 介紹LinkedIn的重要性
# - 目的是建立專業形象和職場網絡
#
# ## 個人資料
# - 更新個人照片
# - 撰寫引人注目的個人簡介
# - 確保個人資訊完整
#
# ## 封面圖片
# - 選擇專業且具吸引力的封面圖片
# - 可以展示個人特色或興趣
#
# ## 經歷與學歷
# - 詳細列出工作經歷
# - 強調成就和專業技能
# - 更新學歷資訊
#
# ## 推薦信
# - 獲取同事或上司的推薦信
# - 互相推薦以建立信任
#
# ## 社交互動
# - 主動參與社群討論
# - 分享專業知識和文章
# - 互動回應他人的貼文
#
# ## 專業頭銜
# - 使用具體和專業的頭銜
# - 可以突顯個人專業性和能力
#
# ## 聯絡資訊
# - 確保聯絡資訊是最新的
# - 方便他人與你取得聯繫
#
# ## 精選作品
# - 上傳展示自己專業能力的作品
# - 可以是文章、研究報告、演講錄像等
#
# ## 頻繁更新
# - 定期更新個人資訊和動態
# - 保持與職場趨

# %%
print(refined_outline) # refined outline
# Out:
# # 建立一個專業的 LinkedIn 首頁
#
# ## 簡介
# - 介紹LinkedIn的重要性
# - 目的是建立專業形象和職場網絡
#
# ## 個人資料
# - 更新專業的個人照片
# - 撰寫引人注目的個人簡介
# - 確保個人資訊完整
#
# ## 專業佈局策略
# - 專業的個人頭像與背景圖
# - 引人入勝的封面故事
# - 精心撰寫的摘要
# - 定期更新與反映現狀
# - 使用關鍵字進行SEO優化
# - 隱私和設定管理
#
# ## 視覺元素
# - 選擇專業且具吸引力的封面圖片
# - 使用品牌徽標增強品牌識別
# - 一致的配色方案與字體選擇
# - 添加影片介紹以提高參與度
# - 內容一致性
#
# ## 經歷與學歷
# - 詳細列出工作經歷
# - 強調成就和專業技能
# - 更新學歷資訊
#
# ## 推薦信
# - 獲取同事或上司的推薦信
# - 互相推薦以建立信任
#
# ## 社交互動
# - 主動參與社群討論
# - 分享專業知識和文章
# - 互動回應他人的貼文
#
# ## 專業頭銜
# - 使用具體和專業的頭銜
# - 可以突顯個人專業性和能力
#
# ## 聯絡資訊
# - 確保聯絡資訊是最新的
# - 方便他人與你取得聯繫
#
# ## 精選作品
# - 上傳展示自己專業能力的作品
# - 可以是文章、研究報告、演講錄像等
#
# ## 頻繁更新
# - 定期更新個人資訊和動態
# - 保持與職場趨勢同步
#
# ## 顏色方案
# - LinkedIn Blue作為信任象徵
# - 黑色傳達專業性和權威感
# - 白色背景提供清晰和整潔的外觀
#
# 通過這些策略和元素，您可以確保您的 LinkedIn 個人資料不僅專業且具吸引力，還能有效地傳達您的職業價值和成就，成為促進職業關係和發展的有力工具。

# %% [markdown]
# # 同學的練習
# - 延續剛剛挑選的主題
# - 接續執行，並且確認正確無誤
# - 給同學 5 分鐘的時間練習

# %% [markdown]
# # 程式說明四、RAG & 段落內容的撰寫

# %% [markdown]
# ![](data:image/png;base64,...)

# %%
# 切割為撰寫段落
rr = refined_outline.split("\n\n")
rr
# Out:
# ['# 建立一個專業的 LinkedIn 首頁',
#  '## 簡介\n- 介紹LinkedIn的重要性\n- 目的是建立專業形象和職場網絡',
#  '## 個人資料\n- 更新專業的個人照片\n- 撰寫引人注目的個人簡介\n- 確保個人資訊完整',
#  '## 專業佈局策略\n- 專業的個人頭像與背景圖\n- 引人入勝的封面故事\n- 精心撰寫的摘要\n- 定期更新與反映現狀\n- 使用關鍵字進行SEO優化\n- 隱私和設定管理',
#  '## 視覺元素\n- 選擇專業且具吸引力的封面圖片\n- 使用品牌徽標增強品牌識別\n- 一致的配色方案與字體選擇\n- 添加影片介紹以提高參與度\n- 內容一致性',
#  '## 經歷與學歷\n- 詳細列出工作經歷\n- 強調成就和專業技能\n- 更新學歷資訊',
#  '## 推薦信\n- 獲取同事或上司的推薦信\n- 互相推薦以建立信任',
#  '## 社交互動\n- 主動參與社群討論\n- 分享專業知識和文章\n- 互動回應他人的貼文',
#  '## 專業頭銜\n- 使用具體和專業的頭銜\n- 可以突顯個人專業性和能力',
#  '## 聯絡資訊\n- 確保聯絡資訊是最新的\n- 方便他人與你取得聯繫',
#  '## 精選作品\n- 上傳展示自己專業能力的作品\n- 可以是文章、研究報告、演講錄像等',
#  '## 頻繁更新\n- 定期更新個人資訊和動態\n- 保持與職場趨勢同步',
#  '## 顏色方案\n- LinkedIn Blue作為信任象徵\n- 黑色傳達專業性和權威感\n- 白色背景提供清晰和整潔的外觀',
#  '通過這些策略和元素，您可以確保您的 LinkedIn 個人資料不僅專業且具吸引力，還能有效地傳達您的職業價值和成就，成為促進職業關係和發展的有力工具。']

# %%
# fastembed 是 qdrant 預設使用的 embedding 工具, 細節可參考： https://github.com/qdrant/fastembed
from fastembed import TextEmbedding
from typing import List

# %%
# 建立 RAG data source
documents = []
metadata = []
ids = []
for i in range(len(references)):
    documents.append(references[i]['title'] + " " + references[i]["content"])
    metadata.append({"source":references[i]["source"]})
    ids.append(i)

# %%
references
# Out:
# [{'title': 'B2B行銷最佳平台? 透過LinkedIn 高效發展客戶關係: 策略',
#   'source': 'https://vocus.cc/article/670d573dfd89780001aed318',
#   'content': '個人頁面優化:建立專業形象 · 建立專業的個人頭像與背景圖：盡量選擇能代表專業形象的照片，以乾淨簡潔的風格為主；背景圖則可展示企業的業務範疇或核心產品。'},
#  {'title': 'LinkedIn 個人品牌：職業成功策略- PLAG - 剽竊。學習。人工智慧.',
#   'source': 'https://blog.plag.ai/zh-TW/linkedin-personal-branding',
#   'content': 'LinkedIn 個人品牌：職業成功的策略 努力讓您的 LinkedIn 個人資料為您服務，讓機會來敲您的門！ 為什麼 LinkedIn 在個人品牌建立方面脫穎而出 策略性地打造您的 LinkedIn 身分涉及幾個關鍵要素： 有效打造 LinkedIn 品牌的實用技巧 優化您的 LinkedIn 個人資料 封面故事。在您的 LinkedIn 個人資料中添加影片介紹，使其更具吸引力和風度。這可以顯著提高參與度並給個人資料訪客留下難忘的印象。 LinkedIn 個人品牌傳播策略 LinkedIn 上的有效人際網絡不僅是擴大您的聯絡人列表，還在於策略性地建立聯繫。專注於與符合您職涯目標並能影響您職涯發展的個人建立關係。參與與您的領域相關的小組和討論，以提高您的知名度並讓自己成為思想領袖。 利用 LinkedIn 分析 在優化您的 LinkedIn 個人資料並積極參與社群後，現在是時候利用這些改進來實現更具策略性和目的性的網路了。本節將重點從一般參與轉向專門建立和促進直接支持您的職業抱負的網絡，並製定與可以極大影響您的職業軌蹟的關鍵個人和團體建立聯繫的策略。 識別有影響力的成員。使用 LinkedIn 的搜尋和過濾工具來尋找您所在行業的關鍵人物並參與他們的內容。 團體參與。加入相關的 LinkedIn 群組，了解產業趨勢並建立思想領導。 透過整合這些策略，您可以將 LinkedIn 形象轉變為促進職業關係和發展職業生涯的動態工具。 使用 LinkedIn 分析 假設一位行銷顧問分析了其 LinkedIn 貼文的參與度，發現有關行業趨勢的文章產生了顯著更多的互動。透過圍繞這些主題制定內容策略，假設他的粉絲數量在三個月內增加了一倍，展示了將內容與受眾興趣結合的力量。 定期檢查您的個人資料和貼文的表現，重點關注哪些類型的內容最受關注。使用更高級的工具（例如群體分析和未來趨勢預測）來發現網路中的趨勢和機會。根據數據告訴您的訊息，根據需要更改您的計劃和發布的內容，以保持您的 LinkedIn 活動有效。 透過將分析整合到您的 LinkedIn 策略中，您不僅可以優化您的內容，還可以在您的職業生涯中建立更有意義的聯繫和機會。這種分析方法可以改善您的線上形象，確保您的個人品牌努力和專業互動盡可能具有影響力。 LinkedIn 進階功能 展示新技能。透過新增透過 LinkedIn 學習獲得的新技能，提高您的個人資料的吸引力。展示這些技能表明您對專業發展的承諾，並使您成為對潛在雇主或合作者更具吸引力的候選人。 隨時了解情況並通知他人。跟上最新的行業趨勢並透過 LinkedIn 電子報分享這些知識可以讓您成為思想領袖。訂閱相關時事通訊或建立自己的時事通訊，定期直接向同儕和追蹤者的收件匣提供有洞察力的內容。 建立新聞通訊。如果您有獨特的見解並希望建立專門的受眾群體，請考慮建立 LinkedIn 電子報。該平台允許您透過向訂閱者提供有價值、及時的內容來定期與他們互動。 透過活動建立聯繫。 LinkedIn 的活動功能可讓您發現並專注於與您的職業興趣相符的專業活動和網路研討會。這些活動不僅是學習機會，也是有意義的交流平台。 LinkedIn 群組和直播 Linkedin 上講個人故事的藝術 敘事策略簡介。使用 LinkedIn 個人資料的摘要部分來啟動您的故事。您可以在此處準備引人入勝的開場白，以反映您的專業本質並吸引讀者的注意。詳細闡述您職業生涯的關鍵時刻——克服的挑戰、實現的里程碑以及指導您職業生涯的核心價值——創建一幅生動的圖畫來慶祝您的旅程。 這種講述個人故事的方法可以改善您的 LinkedIn 個人資料並增強您的專業形象。它使您的互動更具吸引力，並使您的職業故事成為令人印象深刻且強大的工具。這種講故事的方式可以吸引人們，並在您的人脈中建立更牢固的聯繫，展示您獨特的職業道路和成就。 校對和風格修正。風格和清晰度經過提煉，確保寫作符合專業標準，並針對 LinkedIn 上的目標受眾量身定制。 使用這些服務可以顯著提高 LinkedIn 個人資料的專業性，使其對招募人員、合作者和行業領導者更具吸引力。透過確保您的個人資料的每個元素都經過精心設計和精確格式化，您可以呈現出引人入勝的敘述，展示您獨特的職業經歷和技能。 保持動態的 LinkedIn 個人資料。定期更新您的個人資料，以準確反映您目前的職業狀態和能力。不斷完善您的個人資料有助於保持其相關性和吸引力，使其對潛在雇主和合作者更具吸引力。 擁抱平台更新與產業趨勢。隨時了解 LinkedIn 的新功能和產業發展。在您的個人資料中整合新工具並反映特定行業的趨勢表明您對專業發展和相關性的承諾。 利用回饋來增強個人資料。積極尋求並整合同事或導師對你在 LinkedIn 上的表現的回饋。這些回饋可以為改善您在平台上的自我展示和參與方式提供寶貴的見解。 SEO優化。使用相關關鍵字優化您的個人資料，以提高 LinkedIn 和外部搜尋引擎上的可見度。這有助於根據您的行業和技能吸引合適的受眾到您的個人資料中。 遵守這些準則，您可以保證您的 LinkedIn 個人資料始終生動、準確地反映您的職業歷程，無縫適應不斷發展的數位環境。 在優化您的 LinkedIn 個人資料並積極參與您的人脈後，最後一個關鍵步驟是管理您的隱私和設定。這可確保您控制哪些資訊是公開的，以及誰可以看到您的活動、聯繫或詳細的職業見解。正確管理這些設定對於控制您的個人資訊和有效管理您的職業形象至關重要。 個人資料可見性。導航至 LinkedIn 個人資料上的隱私設置，以控制誰可以查看您的個人資料以及電子郵件或電話號碼等特定元素。將它們設定為對所有人、僅您的聯絡人或僅您可見。 活動分享。決定誰可以查看您在 LinkedIn 上的聯絡人清單、貼文和活動。您可以選擇公開您的貼文以最大限度地擴大影響範圍，也可以選擇將其限制在您的聯絡人範圍內以保護隱私。 多場會議管理。定期檢查和管理您登入 LinkedIn 的位置，並從您不再使用或識別的裝置中註銷，以防止未經授權的存取。 保持知情。 LinkedIn 定期更新其隱私和安全功能。定期檢查您的設置，以確保它們仍然符合您的偏好，並利用任何可能提高您的隱私和安全性的新控制項。 認真管理這些設定有助於維護 LinkedIn 個人資料的完整性，並確保您的個人品牌保持強大且私密，無縫適應不斷發展的數位環境。 請記住，準備出色的 LinkedIn 個人資料是一項持續的工作，需要定期更新和策略性參與。它涉及不斷完善您的形象，以便在動態的職業環境中保持領先地位——擁抱新趨勢、利用分析並整合反饋，以確保您的個人資料與您的職業生涯一起發展。 主動創造一個真正反映您的職業歷程和個人價值觀的敘述。這種積極主動的方法將幫助您的 LinkedIn 個人資料記錄過去的成就，並為未來的機會鋪平道路。'},
#  {'title': '6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！',
#   'source': 'https://jason-career.com/linkedin/?srsltid=AfmBOorvAc-5n1wXt1ku4MM-1GROxPIZpwZroVKKVZ-XRoCaDo4MJWke',
#   'content': '6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！ · 客製化邀請訊息 · 保持更新 · 分享專業內容、心得感想、職場體悟，建立個人品牌 · 頭銜 · 位置和行業'},
#  {'title': 'Logo - LinkedIn Brand Guidelines',
#   'source': 'https://brand.linkedin.com/content/brand/global/en_us/index/visual-identity/logo',
#   'content': 'The LinkedIn logo uses three colors: LinkedIn Blue, black, and white. Primarily the logo should be used on a white background for maximum impact and clarity.'},
#  {'title': 'LinkedIn 個人資料圖片背景以及製作精美個人資料照片需要考慮的 ...',
#   'source': 'https://engage-ai.co/zh-TW/linkedin-%E5%80%8B%E4%BA%BA%E8%B3%87%E6%96%99%E5%9C%96%E7%89%87%E8%83%8C%E6%99%AF-%E5%84%AA%E7%A7%80%E5%80%8B%E4%BA%BA%E8%B3%87%E6%96%99%E7%85%A7%E7%89%87%E9%9C%80%E8%A6%81%E8%80%83%E6%85%AE%E7%9A%84%E5%85%B6%E4%BB%96%E4%BA%8B%E9%A0%85/',
#   'content': 'LinkedIn 個人資料圖片背景以及製作精美個人資料照片需要考慮的其他事項 |參與人工智慧 LinkedIn 個人資料圖片背景以及製作精美個人資料照片需要考慮的其他事項 2024 年 1 月 11 日 今天我們將學習有關 LinkedIn 個人資料圖片的所有知識、其背景以及讓您的個人資料圖片令人印象深刻所需的所有內容。 首先，請記住一些有關 LinkedIn 個人資料照片的重要提示： 現在，我們已經清除了最初的戒律，讓我們更深入地了解您的 LinkedIn 個人資料圖片背景。 您的 LinkedIn 個人資料圖片背景應該如何 許多專業人士經常忽略 LinkedIn 個人資料圖片背景的重要性。 您可以使用家中或辦公室的明亮彩色牆壁作為背景來拍攝 LinkedIn 個人資料照片。 想要戶外環境作為 LinkedIn 個人資料圖片背景嗎？ LinkedIn 個人資料圖片背景的最佳顏色是什麼 因此，如果您仍然想知道 LinkedIn 個人資料圖片的最佳背景是什麼，並希望立即得到答案，我們已經為您提供了答案！ 這些是最適合 LinkedIn 個人資料圖片的純色背景顏色和陰影： LinkedIn 個人資料圖片的長寬比 LinkedIn 個人資料圖片的建議圖長寬比為 1:1。 LinkedIn 個人資料照片大小限制約為 8MB。 LinkedIn 個人資料背景照片或 LinkedIn 橫幅尺寸應為 1584 像素 x 396 像素。   LinkedIn 個人資料橫幅照片的長寬比為 4:1。 LinkedIn 個人資料橫幅的重要性 位於我們個人資料頂部的個人資料橫幅也稱為 LinkedIn 背景照片或封面照片，是 LinkedIn 的主要資產。 考慮聘請一位在創建 LinkedIn 橫幅圖像方面經驗豐富的專業平面設計師，而不是使用其他人都在使用的常見庫存圖像。 LinkedIn Twitter 2025 年 1 月 1 日 2024 年 12 月 19 日 精選中的精選 – 2024 年 SaaS 黑色星期五和網路星期一特惠 2024 年 11 月 26 日 5 年您需要了解的 LinkedIn 2024 大提示與策略 2024 年，利用最新的 LinkedIn 策略對於建立更強大的個人品牌、提高知名度以及與行業領導者建立聯繫至關重要。 LinkedIn 上的 ChatGPT 和 AI LinkedIn 標籤分析 LinkedIn 標籤趨勢小工具 LinkedIn Facebook Youtube X 社群媒體白色圓形圖標'},
#  {'title': '为品牌建立一致的LinkedIn 形象的重要性',
#   'source': 'https://doisz.com/zh-CN/blog/presenca-consistente-no-linkedin-2/',
#   'content': '拥有优化的个人资料对于吸引注意力至关重要LinkedIn。使用很重要视觉元素有吸引力的，例如徽标和封面图片。它们的尺寸必须正确，例如封面图像为1.128 像素x'},
#  {'title': '掌握社交媒體品牌：有效線上存在的策略',
#   'source': 'https://tw.strikingly.com/blog/posts/mastering-social-media-branding-strategies-for-effective-online-presence',
#   'content': '在視覺元素(如配色方案、字體和圖像)上的一致性對於在社交媒體上建立強大的品牌標識至關重要。通過在所有帖子和個人資料設計中使用一致的視覺元素，您可以增強品牌識別，並讓'}]

# %%
from qdrant_client import QdrantClient

client = QdrantClient(":memory:")

# 如果想要使用其他 embedding model，可如下指定
# client.set_model("sentence-transformers/all-MiniLM-L6-v2")
# 中文 embedding model
client.set_model("BAAI/bge-small-zh-v1.5")

# fastembed 支援的 models: https://qdrant.github.io/fastembed/examples/Supported_Models
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model_optimized.onnx:   0%|          | 0.00/94.8M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/739 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/439k [00:00<?, ?B/s]
# c:\Users\SUNNIE.GD.WENG\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:140: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\SUNNIE.GD.WENG\AppData\Local\Temp\fastembed_cache\models--Qdrant--bge-small-zh-v1.5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
client.delete_collection(collection_name="demo_collection")
# Out:
# True

# %%
# 建立 vector db
ids = client.add(
    collection_name="demo_collection",
    documents=documents,
    metadata=metadata,
    ids=ids
)

# %%
query = rr[1]
query
# Out:
# '## 簡介\n- 介紹LinkedIn的重要性\n- 目的是建立專業形象和職場網絡'

# %% [markdown]
# ## RAG 檢索測試

# %%
search_result = client.query(
    collection_name="demo_collection",
    query_text=rr[1],
    limit=5
)

for s in search_result:
    print(s.metadata['source'])
    print(s.id)
# Out:
# https://vocus.cc/article/670d573dfd89780001aed318
# 0
# https://blog.plag.ai/zh-TW/linkedin-personal-branding
# 1
# https://jason-career.com/linkedin/?srsltid=AfmBOorvAc-5n1wXt1ku4MM-1GROxPIZpwZroVKKVZ-XRoCaDo4MJWke
# 2
# https://tw.strikingly.com/blog/posts/mastering-social-media-branding-strategies-for-effective-online-presence
# 6
# https://doisz.com/zh-CN/blog/presenca-consistente-no-linkedin-2/
# 5

# %%
search_result
# Out:
# [QueryResponse(id=0, embedding=None, sparse_embedding=None, metadata={'document': 'B2B行銷最佳平台? 透過LinkedIn 高效發展客戶關係: 策略 個人頁面優化:建立專業形象 · 建立專業的個人頭像與背景圖：盡量選擇能代表專業形象的照片，以乾淨簡潔的風格為主；背景圖則可展示企業的業務範疇或核心產品。', 'source': 'https://vocus.cc/article/670d573dfd89780001aed318'}, document='B2B行銷最佳平台? 透過LinkedIn 高效發展客戶關係: 策略 個人頁面優化:建立專業形象 · 建立專業的個人頭像與背景圖：盡量選擇能代表專業形象的照片，以乾淨簡潔的風格為主；背景圖則可展示企業的業務範疇或核心產品。', score=0.7029507513866668),
#  QueryResponse(id=1, embedding=None, sparse_embedding=None, metadata={'document': 'LinkedIn 個人品牌：職業成功策略- PLAG - 剽竊。學習。人工智慧. LinkedIn 個人品牌：職業成功的策略 努力讓您的 LinkedIn 個人資料為您服務，讓機會來敲您的門！ 為什麼 LinkedIn 在個人品牌建立方面脫穎而出 策略性地打造您的 LinkedIn 身分涉及幾個關鍵要素： 有效打造 LinkedIn 品牌的實用技巧 優化您的 LinkedIn 個人資料 封面故事。在您的 LinkedIn 個人資料中添加影片介紹，使其更具吸引力和風度。這可以顯著提高參與度並給個人資料訪客留下難忘的印象。 LinkedIn 個人品牌傳播策略 LinkedIn 上的有效人際網絡不僅是擴大您的聯絡人列表，還在於策略性地建立聯繫。專注於與符合您職涯目標並能影響您職涯發展的個人建立關係。參與與您的領域相關的小組和討論，以提高您的知名度並讓自己成為思想領袖。 利用 LinkedIn 分析 在優化您的 LinkedIn 個人資料並積極參與社群後，現在是時候利用這些改進來實現更具策略性和目的性的網路了。本節將重點從一般參與轉向專門建立和促進直接支持您的職業抱負的網絡，並製定與可以極大影響您的職業軌蹟的關鍵個人和團體建立聯繫的策略。 識別有影響力的成員。使用 LinkedIn 的搜尋和過濾工具來尋找您所在行業的關鍵人物並參與他們的內容。 團體參與。加入相關的 LinkedIn 群組，了解產業趨勢並建立思想領導。 透過整合這些策略，您可以將 LinkedIn 形象轉變為促進職業關係和發展職業生涯的動態工具。 使用 LinkedIn 分析 假設一位行銷顧問分析了其 LinkedIn 貼文的參與度，發現有關行業趨勢的文章產生了顯著更多的互動。透過圍繞這些主題制定內容策略，假設他的粉絲數量在三個月內增加了一倍，展示了將內容與受眾興趣結合的力量。 定期檢查您的個人資料和貼文的表現，重點關注哪些類型的內容最受關注。使用更高級的工具（例如群體分析和未來趨勢預測）來發現網路中的趨勢和機會。根據數據告訴您的訊息，根據需要更改您的計劃和發布的內容，以保持您的 LinkedIn 活動有效。 透過將分析整合到您的 LinkedIn 策略中，您不僅可以優化您的內容，還可以在您的職業生涯中建立更有意義的聯繫和機會。這種分析方法可以改善您的線上形象，確保您的個人品牌努力和專業互動盡可能具有影響力。 LinkedIn 進階功能 展示新技能。透過新增透過 LinkedIn 學習獲得的新技能，提高您的個人資料的吸引力。展示這些技能表明您對專業發展的承諾，並使您成為對潛在雇主或合作者更具吸引力的候選人。 隨時了解情況並通知他人。跟上最新的行業趨勢並透過 LinkedIn 電子報分享這些知識可以讓您成為思想領袖。訂閱相關時事通訊或建立自己的時事通訊，定期直接向同儕和追蹤者的收件匣提供有洞察力的內容。 建立新聞通訊。如果您有獨特的見解並希望建立專門的受眾群體，請考慮建立 LinkedIn 電子報。該平台允許您透過向訂閱者提供有價值、及時的內容來定期與他們互動。 透過活動建立聯繫。 LinkedIn 的活動功能可讓您發現並專注於與您的職業興趣相符的專業活動和網路研討會。這些活動不僅是學習機會，也是有意義的交流平台。 LinkedIn 群組和直播 Linkedin 上講個人故事的藝術 敘事策略簡介。使用 LinkedIn 個人資料的摘要部分來啟動您的故事。您可以在此處準備引人入勝的開場白，以反映您的專業本質並吸引讀者的注意。詳細闡述您職業生涯的關鍵時刻——克服的挑戰、實現的里程碑以及指導您職業生涯的核心價值——創建一幅生動的圖畫來慶祝您的旅程。 這種講述個人故事的方法可以改善您的 LinkedIn 個人資料並增強您的專業形象。它使您的互動更具吸引力，並使您的職業故事成為令人印象深刻且強大的工具。這種講故事的方式可以吸引人們，並在您的人脈中建立更牢固的聯繫，展示您獨特的職業道路和成就。 校對和風格修正。風格和清晰度經過提煉，確保寫作符合專業標準，並針對 LinkedIn 上的目標受眾量身定制。 使用這些服務可以顯著提高 LinkedIn 個人資料的專業性，使其對招募人員、合作者和行業領導者更具吸引力。透過確保您的個人資料的每個元素都經過精心設計和精確格式化，您可以呈現出引人入勝的敘述，展示您獨特的職業經歷和技能。 保持動態的 LinkedIn 個人資料。定期更新您的個人資料，以準確反映您目前的職業狀態和能力。不斷完善您的個人資料有助於保持其相關性和吸引力，使其對潛在雇主和合作者更具吸引力。 擁抱平台更新與產業趨勢。隨時了解 LinkedIn 的新功能和產業發展。在您的個人資料中整合新工具並反映特定行業的趨勢表明您對專業發展和相關性的承諾。 利用回饋來增強個人資料。積極尋求並整合同事或導師對你在 LinkedIn 上的表現的回饋。這些回饋可以為改善您在平台上的自我展示和參與方式提供寶貴的見解。 SEO優化。使用相關關鍵字優化您的個人資料，以提高 LinkedIn 和外部搜尋引擎上的可見度。這有助於根據您的行業和技能吸引合適的受眾到您的個人資料中。 遵守這些準則，您可以保證您的 LinkedIn 個人資料始終生動、準確地反映您的職業歷程，無縫適應不斷發展的數位環境。 在優化您的 LinkedIn 個人資料並積極參與您的人脈後，最後一個關鍵步驟是管理您的隱私和設定。這可確保您控制哪些資訊是公開的，以及誰可以看到您的活動、聯繫或詳細的職業見解。正確管理這些設定對於控制您的個人資訊和有效管理您的職業形象至關重要。 個人資料可見性。導航至 LinkedIn 個人資料上的隱私設置，以控制誰可以查看您的個人資料以及電子郵件或電話號碼等特定元素。將它們設定為對所有人、僅您的聯絡人或僅您可見。 活動分享。決定誰可以查看您在 LinkedIn 上的聯絡人清單、貼文和活動。您可以選擇公開您的貼文以最大限度地擴大影響範圍，也可以選擇將其限制在您的聯絡人範圍內以保護隱私。 多場會議管理。定期檢查和管理您登入 LinkedIn 的位置，並從您不再使用或識別的裝置中註銷，以防止未經授權的存取。 保持知情。 LinkedIn 定期更新其隱私和安全功能。定期檢查您的設置，以確保它們仍然符合您的偏好，並利用任何可能提高您的隱私和安全性的新控制項。 認真管理這些設定有助於維護 LinkedIn 個人資料的完整性，並確保您的個人品牌保持強大且私密，無縫適應不斷發展的數位環境。 請記住，準備出色的 LinkedIn 個人資料是一項持續的工作，需要定期更新和策略性參與。它涉及不斷完善您的形象，以便在動態的職業環境中保持領先地位——擁抱新趨勢、利用分析並整合反饋，以確保您的個人資料與您的職業生涯一起發展。 主動創造一個真正反映您的職業歷程和個人價值觀的敘述。這種積極主動的方法將幫助您的 LinkedIn 個人資料記錄過去的成就，並為未來的機會鋪平道路。', 'source': 'https://blog.plag.ai/zh-TW/linkedin-personal-branding'}, document='LinkedIn 個人品牌：職業成功策略- PLAG - 剽竊。學習。人工智慧. LinkedIn 個人品牌：職業成功的策略 努力讓您的 LinkedIn 個人資料為您服務，讓機會來敲您的門！ 為什麼 LinkedIn 在個人品牌建立方面脫穎而出 策略性地打造您的 LinkedIn 身分涉及幾個關鍵要素： 有效打造 LinkedIn 品牌的實用技巧 優化您的 LinkedIn 個人資料 封面故事。在您的 LinkedIn 個人資料中添加影片介紹，使其更具吸引力和風度。這可以顯著提高參與度並給個人資料訪客留下難忘的印象。 LinkedIn 個人品牌傳播策略 LinkedIn 上的有效人際網絡不僅是擴大您的聯絡人列表，還在於策略性地建立聯繫。專注於與符合您職涯目標並能影響您職涯發展的個人建立關係。參與與您的領域相關的小組和討論，以提高您的知名度並讓自己成為思想領袖。 利用 LinkedIn 分析 在優化您的 LinkedIn 個人資料並積極參與社群後，現在是時候利用這些改進來實現更具策略性和目的性的網路了。本節將重點從一般參與轉向專門建立和促進直接支持您的職業抱負的網絡，並製定與可以極大影響您的職業軌蹟的關鍵個人和團體建立聯繫的策略。 識別有影響力的成員。使用 LinkedIn 的搜尋和過濾工具來尋找您所在行業的關鍵人物並參與他們的內容。 團體參與。加入相關的 LinkedIn 群組，了解產業趨勢並建立思想領導。 透過整合這些策略，您可以將 LinkedIn 形象轉變為促進職業關係和發展職業生涯的動態工具。 使用 LinkedIn 分析 假設一位行銷顧問分析了其 LinkedIn 貼文的參與度，發現有關行業趨勢的文章產生了顯著更多的互動。透過圍繞這些主題制定內容策略，假設他的粉絲數量在三個月內增加了一倍，展示了將內容與受眾興趣結合的力量。 定期檢查您的個人資料和貼文的表現，重點關注哪些類型的內容最受關注。使用更高級的工具（例如群體分析和未來趨勢預測）來發現網路中的趨勢和機會。根據數據告訴您的訊息，根據需要更改您的計劃和發布的內容，以保持您的 LinkedIn 活動有效。 透過將分析整合到您的 LinkedIn 策略中，您不僅可以優化您的內容，還可以在您的職業生涯中建立更有意義的聯 ...
#  QueryResponse(id=2, embedding=None, sparse_embedding=None, metadata={'document': '6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！ 6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！ · 客製化邀請訊息 · 保持更新 · 分享專業內容、心得感想、職場體悟，建立個人品牌 · 頭銜 · 位置和行業', 'source': 'https://jason-career.com/linkedin/?srsltid=AfmBOorvAc-5n1wXt1ku4MM-1GROxPIZpwZroVKKVZ-XRoCaDo4MJWke'}, document='6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！ 6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！ · 客製化邀請訊息 · 保持更新 · 分享專業內容、心得感想、職場體悟，建立個人品牌 · 頭銜 · 位置和行業', score=0.6592887297610746),
#  QueryResponse(id=6, embedding=None, sparse_embedding=None, metadata={'document': '掌握社交媒體品牌：有效線上存在的策略 在視覺元素(如配色方案、字體和圖像)上的一致性對於在社交媒體上建立強大的品牌標識至關重要。通過在所有帖子和個人資料設計中使用一致的視覺元素，您可以增強品牌識別，並讓', 'source': 'https://tw.strikingly.com/blog/posts/mastering-social-media-branding-strategies-for-effective-online-presence'}, document='掌握社交媒體品牌：有效線上存在的策略 在視覺元素(如配色方案、字體和圖像)上的一致性對於在社交媒體上建立強大的品牌標識至關重要。通過在所有帖子和個人資料設計中使用一致的視覺元素，您可以增強品牌識別，並讓', score=0.6343389589293686),
#  QueryResponse(id=5, embedding=None, sparse_embedding=None, metadata={'document': '为品牌建立一致的LinkedIn 形象的重要性 拥有优化的个人资料对于吸引注意力至关重要LinkedIn。使用很重要视觉元素有吸引力的，例如徽标和封面图片。它们的尺寸必须正确，例如封面图像为1.128 像素x', 'source': 'https://doisz.com/zh-CN/blog/presenca-consistente-no-linkedin-2/'}, document='为品牌建立一致的LinkedIn 形象的重要性 拥有优化的个人资料对于吸引注意力至关重要LinkedIn。使用很重要视觉元素有吸引力的，例如徽标和封面图片。它们的尺寸必须正确，例如封面图像为1.128 像素x', score=0.6157527145791315)]

# %% [markdown]
# ## 撰寫段落

# %%
def write_section(section: str) -> str:
    """
    撰寫段落文章
    """

    # 檢索該段落相關的網路資料
    search_result = client.query(
        collection_name="demo_collection",
        query_text=section,
        limit=5
    )

    # 產生參考文獻的文字格式
    references = generate_references_string(search_result)


    system_prompt = """
    你是寫作方面的專家。我會給你一個部落格的某一節的大綱和幾個參考資料。你需要使用提供的參考資料來生成該節的文章。
    你必須使用給定的來源來引用你的寫作。不要包含其他資訊。在這個格式中為每個句子包含“參考編號”：[ref_id]。你的回應必須以Markdown格式呈現。

    參考資料：{references}
    """


    user_prompt = """某一節的大綱: {section}"""

    try:
        response = completion(
            api_key = OPENAI_API_KEY,
            model="gpt-3.5-turbo",
            messages=[{ "content": system_prompt.format(references=references),"role": "system"},{ "content": user_prompt.format(section=section),"role": "user"}],
            temperature=0.5,
            max_tokens=1500,
        )
        response = response.choices[0].message.content

        return response
    except Exception as e:
        print(f"Error in translation: {e}")

# %%
def generate_references_string(references):
    output = []
    for ref in references:
        ref_id = ref.id
        ref_url = ref.metadata.get('source', '')
        ref_content = ref.metadata.get('document', '')

        # Construct a formatted string for each reference
        reference_str = f"Reference ID:\n {ref_id}\nURL: {ref_url}\nContent: {ref_content}\n"

        # Append the formatted reference string to the output list
        output.append(reference_str)

    return '\n'.join(output)

# %%
rr[1:]
# Out:
# ['## 簡介\n- 介紹LinkedIn的重要性\n- 目的是建立專業形象和職場網絡',
#  '## 個人資料\n- 更新專業的個人照片\n- 撰寫引人注目的個人簡介\n- 確保個人資訊完整',
#  '## 專業佈局策略\n- 專業的個人頭像與背景圖\n- 引人入勝的封面故事\n- 精心撰寫的摘要\n- 定期更新與反映現狀\n- 使用關鍵字進行SEO優化\n- 隱私和設定管理',
#  '## 視覺元素\n- 選擇專業且具吸引力的封面圖片\n- 使用品牌徽標增強品牌識別\n- 一致的配色方案與字體選擇\n- 添加影片介紹以提高參與度\n- 內容一致性',
#  '## 經歷與學歷\n- 詳細列出工作經歷\n- 強調成就和專業技能\n- 更新學歷資訊',
#  '## 推薦信\n- 獲取同事或上司的推薦信\n- 互相推薦以建立信任',
#  '## 社交互動\n- 主動參與社群討論\n- 分享專業知識和文章\n- 互動回應他人的貼文',
#  '## 專業頭銜\n- 使用具體和專業的頭銜\n- 可以突顯個人專業性和能力',
#  '## 聯絡資訊\n- 確保聯絡資訊是最新的\n- 方便他人與你取得聯繫',
#  '## 精選作品\n- 上傳展示自己專業能力的作品\n- 可以是文章、研究報告、演講錄像等',
#  '## 頻繁更新\n- 定期更新個人資訊和動態\n- 保持與職場趨勢同步',
#  '## 顏色方案\n- LinkedIn Blue作為信任象徵\n- 黑色傳達專業性和權威感\n- 白色背景提供清晰和整潔的外觀',
#  '通過這些策略和元素，您可以確保您的 LinkedIn 個人資料不僅專業且具吸引力，還能有效地傳達您的職業價值和成就，成為促進職業關係和發展的有力工具。']

# %%
article = ""

article = rr[0]
for section_outline in rr[1::]: # 列表切片語法，意思是從 rr 的第二個元素（索引為 1）開始，一直到列表的結尾
    sec = write_section(section_outline)
    article += sec + "\n\n"

print("article DONE!")
# Out:
# article DONE!

# %%
print(article)
# Out:
# # 建立一個專業的 LinkedIn 首頁## 簡介
# LinkedIn作為專業社交平台在建立個人品牌和職場網絡中扮演著重要的角色。通過LinkedIn，個人能夠展示專業形象、擴展職業圈子，並為職涯發展打下堅實基礎。本節將探討如何最大程度地利用LinkedIn來建立個人品牌，提升職業成功。
#
# ## 個人資料
#
# 在建立您的個人品牌時，LinkedIn 個人資料是一個至關重要的元素。以下是幾個關鍵步驟，幫助您打造出令人印象深刻的個人資料：
#
# 1. **更新專業的個人照片**
#    當更新您的 LinkedIn 個人照片時，選擇一張專業且具有視覺吸引力的照片至關重要。照片的背景應該簡潔，並確保您的形象展現出專業性[4]。
#
# 2. **撰寫引人注目的個人簡介**
#    您的個人簡介是展示您專業背景和價值主張的絕佳機會。著重於您的專業成就、技能和經驗，讓人一目了然您的價值[1]。
#
# 3. **確保個人資訊完整**
#    確保您的個人資訊完整且最新。包括您的教育背景、工作經驗、技能專長和其他相關資訊。完整的個人資料有助於展示您的專業度和可靠性[0]。
#
# ## 專業佈局策略
#
# 在 LinkedIn 上建立專業形象是成功的關鍵之一。以下是一些重要策略，可幫助您打造引人注目的個人品牌：
#
# ### 1. 專業的個人頭像與背景圖
# 建立專業形象的第一步是確保您的個人頭像和背景圖片符合業界標準。個人頭像應選擇能代表專業形象的照片，背景圖則可展示企業的業務範圍或核心產品[0]。
#
# ### 2. 引人入勝的封面故事
# 在您的個人資料中添加一段引人入勝的封面故事，可以吸引訪客的注意並留下深刻印象。這有助於提高個人資料的參與度，展示您的獨特價值主張[1]。
#
# ### 3. 精心撰寫的摘要
# 利用 LinkedIn 的摘要部分展示您的專業故事和成就。詳細描述您的職業生涯的關鍵時刻，克服的挑戰以及您的核心價值觀，這有助於強化您的專業形象並建立更深層次的連接[1]。
#
# ### 4. 定期更新與反映現狀
# 持續更新您的個人資料，以準確反映您的最新職業狀態和能力。透過定期的更新，您可以確保個人資料的相關性和吸引力，讓潛在雇主和合作夥伴對您更感興趣[2]。
#
# ### 5. 使用關鍵字進行SEO優化
# 優化您的個人資料中的關鍵字，有助於提高在 LinkedIn 和外部搜索引擎上的可見性。這可以吸引更多符合您專業技能和行業的目標受眾[2]。
#
# ### 6. 隱私和設定管理
# 管理您的隱私設定，確保您控制哪些資訊是公開的，以及誰可以查看您的活動和聯繫方式。正確管理這些設定是維護個人資訊安全性和有效管理職業形象的重要一環[2]。
#
# 透過遵循以上策略，您可以打造一個專業且引人注目的 LinkedIn 個人品牌，吸引更多機會和建立有意義的專業連接。
#
# ## 視覺元素
#
# 在建立個人品牌的過程中，視覺元素扮演著至關重要的角色。以下是幾個關鍵步驟來確保您在社交媒體上的視覺呈現能夠有效地塑造您的品牌形象：
#
# - **選擇專業且具吸引力的封面圖片**是吸引他人注意並展示您專業形象的重要一環。一張精心設計的封面圖片能夠讓您在眾多用戶中脫穎而出[5]。
#
# - **使用品牌徽標增強品牌識別**。徽標是您品牌識別的核心，因此在社交媒體上使用一致的品牌徽標能夠加強您的品牌辨識度，讓您在眾多帖子中更容易被識別和記住[6]。
#
# - **一致的配色方案與字體選擇**。確保在所有的帖子和個人資料設計中都使用一致的配色方案和字體，這有助於打造一致的視覺風格，提升您的品牌識別度，讓您在線上更具專業形象[6]。
#
# - **添加影片介紹以提高參與度**。在您的個人資料中添加影片介紹是一個吸引眼球並提高參與度的好方法。這不僅能讓您的個人資料更具吸引力，還能讓訪客對您留下深刻印象[1]。
#
# - 最後，確保**內容一致性**是維護您品牌形象的關鍵。無論是在發布帖子還是更新個人資料時，都要確保您的內容風格、語氣和資訊傳達一致，這有助於建立您的品牌信任度和專業形象[6]。
#
# ## 經歷與學歷
#
# 在LinkedIn個人主頁中，展示您的經歷和學歷是極為重要的。以下是幾個關鍵步驟來打造一個引人注目的經歷與學歷部分：
#
# 1. **詳細列出工作經歷**：在個人資料中清楚詳細地列出您的工作經歷。這包括公司名稱、職位、任職時間以及工作內容。這樣可以讓潛在雇主更好地了解您的專業背景和能力。[1]
#
# 2. **強調成就和專業技能**：除了列出工作經歷外，請務必強調您在每份工作中取得的成就和擅長的專業技能。這有助於突顯您的價值和能力，讓瀏覽您個人主頁的人更容易認識您。[0]
#
# 3. **更新學歷資訊**：確保您的學歷資訊是最新的。如果您有新的學位或課程證書，請及時更新到您的個人主頁中。這有助於展示您的專業進步和學習成果，提升個人品牌的可信度。[2]
#
# 通過精心編輯和更新您的經歷與學歷部分，您可以打造一個令人印象深刻的LinkedIn個人主頁，吸引更多的專業機會和聯繫。
#
# ## 推薦信
#
# 在 LinkedIn 上，獲取推薦信是建立個人品牌和專業形象的重要一環。這些推薦信可以增加他人對您的信任和認可，進而提升您在職場中的價值和影響力。以下是一些策略，可幫助您有效地獲取同事或上司的推薦信，並進行互相推薦以建立更緊密的聯繫：
#
# 1. **獲取同事或上司的推薦信**
#    - 主動請求：直接向您信任的同事或上司提出請求，誠懇地解釋您希望為您的個人品牌增添推薦信的重要性。
#    - 提供方便：為您的同事或上司提供撰寫推薦信的方便，例如提供您的履歷、工作成就或其他相關資料，以便他們撰寫具體且有力的推薦信。
#    - 感謝和追蹤：當您成功獲得推薦信後，記得向他們表示感謝並保持聯繫，這有助於建立長久的職業關係。
#
# 2. **互相推薦以建立信任**
#    - 互惠互利：建議您主動提出互相推薦的建議，這樣可以建立雙向的信任和支持，同時也有助於彼此的職業發展。
#    - 具體化：在互相推薦時，請盡量具體描述對方的優勢和特質，讓推薦信更加有說服力和具體。
#
# 透過這些策略，您可以有效地獲取推薦信並建立互相推薦的關係，進而在 LinkedIn 上構建更堅固的職業網絡和個人品牌。
#
# # 社交互動
#
# 在LinkedIn上建立有效的社交互動是提升個人品牌和職業發展的重要一環。以下是一些關鍵策略：
#
# - **主動參與社群討論：** 積極參與與您專業領域相關的LinkedIn小組和討論，這有助於提高知名度並建立有價值的聯繫[1]。
#
# - **分享專業知識和文章：** 定期分享您的專業知識、心得和文章，這不僅展示您的專業能力，還能吸引更多的關注和互動[2]。
#
# - **互動回應他人的貼文：** 積極回應他人的貼文，提出有價值的意見和建議，這有助於擴大您的人脈圈並建立良好的關係[4]。
#
# # 專業頭銜
#
# 在LinkedIn個人資料中，專業頭銜是至關重要的一部分，因為它可以直接展示您的專業性和能力。這一節將探討如何選擇和使用具體、專業的頭銜，以在LinkedIn上突顯您的專業形象和專業能力。
#
# ## 選擇具體和專業的頭銜
# 在LinkedIn個人資料中，選擇具體和專業的頭銜至關重要。這包括使用能夠清楚表明您的職業身份和專業能力的詞彙和詞組。通過選擇適當的頭銜，您可以讓瀏覽您個人資料的人立即了解您的專業背景和專業領域。
#
# ## 突顯個人專業性和能力
# 適當的專業頭銜可以有效地突顯您的個人專業性和能力。這有助於吸引潛在雇主、合作夥伴或客戶的注意，讓他們對您的專業能力和價值有更清晰的認識。通過在頭銜中展示您的專業特長和經驗，您可以在LinkedIn上建立更具吸引力和具說服力的個人品牌。
#
# 透過精心選擇和運用具體和專業的頭銜，您可以在LinkedIn個人資料中有效地展示您的專業形象和能力，吸引更多的注意和機會。
#
# ## 聯絡資訊
#
# 在建立您的 LinkedIn 個人主頁時，確保您的聯絡資訊是最新的。這包括您的電子郵件地址、電話號碼和其他方式，讓其他用戶可以輕鬆地與您取得聯繫。保持這些資訊的更新對於讓HR或其他專業人士主動聯繫您至關重要。[1][2][4]
#
# ---
#
# 這段文字結合了參考資料1、2和4中有關LinkedIn個人品牌建立和聯絡資訊更新的相關內容。
#
# ## 精選作品
#
# 在LinkedIn個人主頁上展示您的專業能力至關重要。這可以通過上傳各種作品來實現，這些作品可以是文章、研究報告、演講錄像等形式。這些精選作品將有助於展示您的專業知識和技能，吸引潛在雇主或合作夥伴的注意。
#
# ## 頻繁更新
#
# 在LinkedIn上保持個人資訊的更新是建立專業形象和吸引力的重要一環。定期更新您的個人資料可以讓潛在雇主或合作夥伴看到您的最新成就和能力。此外，持續更新個人資訊也有助於提高您在LinkedIn上的可見性和搜尋排名，使您更容易被其他用戶找到和聯繫。[0]
#
# 另外，隨著職場環境的不斷變化，保持與職場趨勢同步也是至關重要的。通過分享和討論最新的職場趨勢、行業動態和專業見解，您可以展現自己對行業的關注和專業知識，從而吸引更多的關注和互動。透過與其他專業人士的交流，您可以不僅保持自己的專業知識水平，還可以擴大人脈圈和建立更多的職業機會。[1]
#
# ## 顏色方案
# LinkedIn 在其品牌指南中強調了顏色的重要性，這些顏色包括LinkedIn Blue、黑色和白色。這些顏色的選擇不僅是為了視覺上的吸引力，還有特定的意義和效果。
#
# - **LinkedIn Blue**: 作為LinkedIn的主要品牌顏色，LinkedIn Blue 代表了信任和專業。這種藍色不僅是品牌的辨識度，還傳達了對客戶和合作夥伴的信心和可靠性[3]。
#
# - **黑色**: 在LinkedIn的色彩方案中，黑色被選用以傳達專業性和權威感。這種深沉的色調有助於凸顯品牌的專業形象，讓觀眾感受到穩重和可靠[3]。
#
# - **白色背景**: 白色被推薦作為LinkedIn logo 的背景色，以確保最大的視覺影響和清晰度。白色背景提供了整潔和清晰的外觀，讓品牌信息更容易被觀眾接受和理解[3]。這種對比鮮明的設計有助於突出品牌元素，使其更加引人注目。
#
# 這些精心挑選的顏色方案不僅在視覺上吸引人，還通過符号和情感意涵來加強LinkedIn品牌的形象和價值。LinkedIn Blue、黑色和白色的組合為品牌帶來了專業性、權威感和清晰度，使其在競爭激烈的B2B市場中脫穎而出。
#
# # 通過策略和元素打造專業吸引人的LinkedIn個人資料
#
# 在這個部分，我們將探討如何通過特定策略和元素來打造一個專業吸引人的LinkedIn個人資料，以有效地傳達您的職業價值和成就，使其成為促進職業關係和發展的有力工具。
#
# ## 建立專業形象
# - **優化個人頭像與背景圖**：選擇代表專業形象的照片，背景圖展示企業業務範疇或核心產品[ref_id: 0]。
# - **一致的視覺元素**：在所有設計中使用一致的視覺元素，增強品牌識別[ref_id: 6]。
#
# ## 提升專業價值
# - **分享專業內容**：發表心得感想、職場體悟，建立個人品牌[ref_id: 2]。
# - **展示新技能**：透過展示透過LinkedIn學習獲得的新技能，提高個人資料吸引力[ref_id: 1]。
#
# ## 建立職業成就
# - **講述個人故事**：在個人資料中講述關鍵時刻，強化專業形象[ref_id: 1]。
# - **校對和風格修正**：確保寫作符合專業標準，為目標受眾量身定制[ref_id: 1]。
#
# 通過這些策略和元素，您可以確保您的LinkedIn個人資料不僅專業且具吸引力，還能有效地傳達您的職業價值和成就，成為促進職業關係和發展的有力工具。

# %%
with open('article_claude_1.md', 'w', encoding='utf-8-sig') as fout:
    fout.write(article)

# %%
references
# Out:
# [{'title': 'LinkedIn公司專頁| 5個錦囊妙計，設計出有吸引力的公司頁面',
#   'source': 'https://www.shutterstock.com/zh-Hant/blog/tips-designing-company-linkedin-profile',
#   'content': '1.新增橫幅與商標 · 2.設立令人印象深刻的展示專區(Showcase Page) · 3.分享訊息豐富且具吸引力的內容 · 4.最佳化LinkedIn公司專頁上的文案 · 5.使用LinkedIn'},
#  {'title': 'LinkedIn 個人品牌：職業成功策略- PLAG - 剽竊。學習。人工智慧.',
#   'source': 'https://blog.plag.ai/zh-TW/linkedin-personal-branding',
#   'content': '←\n目錄\n目錄\n(\n)\n在當今的數位時代，在專業領域中脫穎而出不僅僅是一種必要，更是一種策略。這就是 LinkedIn，您的數位化平台\nCV\n網路巨頭介入。這是解鎖你的鑰匙\n職業潛力\n透過準備一個個人品牌，不僅能吸引你，也能讓你著迷和信服。您正在尋找夢想的工作或尋求將自己定位為行業領導者嗎？了解 LinkedIn 品牌的藝術是您邁向成功的第一步。\n在本指南中，我們將深入探討將您的 LinkedIn 個人資料從普通變為卓越的策略。您將學習如何完善個人資料的各個方面，從引人注目的標題到展示您專業知識的引人入勝的內容。此外，我們還將介紹如何有效地建立人際網絡並使用 LinkedIn 的豐富分析和高級功能來不斷適應並在您的職業生涯中蓬勃發展。\n努力讓您的 LinkedIn 個人資料為您服務，讓機會來敲您的門！\n為什麼 LinkedIn 在個人品牌建立方面脫穎而出\n與\nLinkedIn\n作為專業知名度的重要平台，透過策略性個人品牌來區分您的個人資料至關重要。與其他將個人軼事與專業內容結合的社交平台不同，LinkedIn 是職業發展和專業品牌的專用網路。在這裡，您創建的內容、建立的聯繫以及參與的互動都有助於塑造獨特的專業形象，以吸引招募人員、行業領導者和同行的注意。\n策略性地打造您的 LinkedIn 身分涉及幾個關鍵要素：\n量身訂製的視覺效果\n。確保您的個人資料圖片和橫幅立即傳達您的專業重點。無論您是創意人員、技術專家還是商業領袖，您的視覺效果都應該反映出您為所在領域帶來的卓越表現。\n吸引人的標題和摘要\n。使用標題簡潔地介紹您的專業專長，並使用摘要講述一個使您的職業道路栩栩如生的故事，重點介紹您獨特的見解和成功。\n展示詳細體驗\n。每項列出的經驗都應反映對您的成果做出貢獻的重大成就和具體技能，證明您對先前角色的影響。\n動態參與策略。\n除了定期發布更新之外，還可以策略性地參與與您的職業目標相符的內容。評論、分享和討論帖子，將自己定位為所在領域的思想領袖。\n透過將這些元素納入您的 LinkedIn 策略，您可以建立一個強大的個人資料，它不僅可以展示您的歷史，還可以積極參與您的人脈並吸引合適的職業機會。在以下部分中，我們將探討實用的策略和技巧，幫助您有效地實施每個關鍵要素，確保您的 LinkedIn 形象引人注目且具有影響力。\n有效打造 LinkedIn 品牌的實用技巧\n既然我們已經確定了獨特的 LinkedIn 身分的重要性，那麼讓我們深入探討您可以採取的提升個人品牌的實際步驟。 LinkedIn 提供了一個重要的平台，可協助您提高知名度並與各行業的主要參與者建立聯繫。\n優化您的 LinkedIn 個人資料\n透過以下策略最大限度地提高您的個人資料的影響力：\n個人資料圖片。\n選擇一張清晰、專業的照片，讓你的臉完全可見——這是你的第一印象。避免隨意或集體拍照。使用不會分散您臉部注意力的純色中性背景。為了增加品牌凝聚力，請考慮使用與您公司徽標相符的背景顏色。例如，建築師可能會使用背景為藍圖的專業頭像，巧妙地表明他們的職業。有關有效顏色使用的範例，請查看\n此 LinkedIn 個人資料\n其中紫色背景與 Persona Cognita 的品牌顏色一致，提高了專業辨識度。\n標題\n。這是您個人資料的關鍵要素。您的標題不僅僅是您的職位名稱，還應該簡潔地傳達您的專業知識和獨特價值。包括關鍵技能或主張，例如「數位行銷專家|搜尋引擎優化和內容策略專家。例如，“高級平面設計師| 「品牌發展和視覺敘事專家」有效地凸顯了專業知識。\n體驗區\n。不要只列出職位名稱；詳細描述您的角色和成就。突出結果並使用可量化的指標來展示您的影響力，例如，“領導一個團隊發起了成功的營銷活動，在六個月內將公司收入增加了 20%。”\n關鍵字和技巧\n。使用行業相關的關鍵字來提高您的個人資料的可搜尋性和吸引力。結合技術和軟技能，呈現全面的專業形象。例如，「JavaScript」、「雲端運算」和「團隊領導」等術語既展示了你的技術專長，也展現了你在團隊設定中的能力。\n改進的設定檔功能\n創作者模式\n。啟動此功能以展示您作為思想領袖的身份。定期分享見解和更新，以吸引您的人脈並吸引新的聯繫。\n發音指導\n。建立您的名字的錄音，以幫助其他人正確發音，從而提高您的個人資料的個人風格。\n封面故事\n。在您的 LinkedIn 個人資料中添加影片介紹，使其更具吸引力和風度。這可以顯著提高參與度並給個人資料訪客留下難忘的印象。\n融入視覺元素\n視覺效果大大提高了您的個人資料的吸引力：\n專業旗幟\n。選擇反映您的職業身份或行業精神的橫幅。這種視覺效果應該傳達您的專業重點或關鍵價值觀，從而增強識別度和專業印象。\n富媒體\n。使用影片、簡報和作品圖像等多媒體元素豐富您的體驗部分。這些有助於更生動地說明您的專業貢獻的影響和範圍。\n視覺效果的一致性\n。確保所有視覺元素遵循有凝聚力的風格，從而提高您的專業品牌。\n透過實施這些技巧並不斷完善您的個人資料，您將在 LinkedIn 上展現您的職業歷程並積極吸引您想要的受眾，從而為新的機會和聯繫鋪平道路。請繼續關注，我們將在接下來的部分中利用 LinkedIn 的社群功能來改善互動和可見性。\nLinkedIn 個人品牌傳播策略\n在優化您的 LinkedIn 個人資料以有效展示您的職業歷程後，積極參與 LinkedIn 社群就變得至關重要。本節概述了改善互動和可見性的策略—擴展專業網絡和機會的關鍵要素。\n建立並吸引您的網絡\n使用個人資料中詳細的經驗部分和引人注目的標題與過去的同事和行業中的其他人建立聯繫。養成關注公司和行業領導者的習慣，以了解最新趨勢並參與他們帖子的討論。例如，行銷專業人士可以評論思想領袖討論的最新數位行銷趨勢，分享他們個人資料中提到的自己經驗的見解。這種方法不僅可以提高您的知名度，還可以幫助您隨時了解您所在領域的最新動態。\n發文策略\n定期分享展示您專業知識的原創內容和見解，例如案例研究或您管理的專案的描述。這些應該突出顯示您在個人資料中列出的技能。此外，還可以分享慶祝您個人成就和職業發展的最新動態。例如，發布有關您使用雲端運算解決業務挑戰的專案的信息，並將其直接連結到您個人資料上的相關技能。\n與您的網路交互\n積極參與不僅僅是發文。回覆對您貼文的評論並與您的聯絡人分享的內容進行互動。這創建了一個雙向溝通管道，您不僅被視為資訊來源，而且被視為網路中的積極參與者。\n個人內容\n分享行業新聞和其他人的內容很有用，但發布自己的想法和專業技巧可以大大提高您的個人資料的價值。該內容應表達您獨特的專業風格和價值觀，提供使您與眾不同的新鮮視角。例如，您可以發布簡短的影片或撰寫有關行業中常見問題的創意解決方案的文章，展示您解決問題的能力。\n積極參與LinkedIn回答並發表文章\n透過參與 LinkedIn 回答和撰寫文章來參與 LinkedIn 社群。定期參與不僅可以展示您的專業知識，還有助於與對您所在領域感興趣的專業人士建立更深入的聯繫。直接在 LinkedIn 上發表文章以廣泛分享您的知識和見解可以提高您的專業聲譽並擴大您的人際網絡。\n透過內容參與\n保持對您感興趣的貼文和討論發表評論的習慣。這種互動可以促進更牢固的關係，並將臨時追隨者轉變為堅定的盟友。\n戰略網路技術\nLinkedIn 上的有效人際網絡不僅是擴大您的聯絡人列表，還在於策略性地建立聯繫。專注於與符合您職涯目標並能影響您職涯發展的個人建立關係。參與與您的領域相關的小組和討論，以提高您的知名度並讓自己成為思想領袖。\n利用 LinkedIn 分析\n在 LinkedIn 策略的這個階段，開始考慮分析如何為您提供資訊並增強您的參與度是有益的。利用基本的 LinkedIn 分析來簡要評估您的內容和互動的有效性。此初步分析將確定哪些類型的貼文最能引起受眾的興趣和參與。了解這些模式對於規劃有效的溝通策略至關重要。本指南後面的專門部分將詳細探討有關利用 LinkedIn Analytics 全面優化您的個人資料和活動的更全面的策略和更深入的見解。\n戰略網路技術\n在優化您的 LinkedIn 個人資料並積極參與社群後，現在是時候利用這些改進來實現更具策略性和目的性的網路了。本節將重點從一般參與轉向專門建立和促進直接支持您的職業抱負的網絡，並製定與可以極大影響您的職業軌蹟的關鍵個人和團體建立聯繫的策略。\n選擇性連接\n注重相關性\n。與與您的行業和職業抱負直接相關的個人建立聯繫，例如同行、導師、行業領導者和招聘人員。\n識別有影響力的成員\n。使用 LinkedIn 的搜尋和過濾工具來尋找您所在行業的關鍵人物並參與他們的內容。\n連接標準\n。設定建立聯繫的具體標準，以增強您的職業軌跡。\n參與策略\n貼心互動\n。發表反映您理解的見解，培養有意義的關係。\n團體參與\n。加入相關的 LinkedIn 群組，了解產業趨勢並建立思想領導。\n介紹和推薦\n。定期更新您的個人資料，並透過評論、分享或個人化訊息與新的和現有的聯絡人互動。\n內容策略與分析\n內容分享例程\n。制定內容日曆來安排符合行業興趣的貼文。目標是每週發布 1-2 篇帖子，利用 LinkedIn 分析的見解根據受眾興趣自訂內容。\n最佳發文時間\n。分析您的貼文何時獲得最多的參與度，以最大限度地提高可見度。\n案例研究和例子\n成功案例\n。分享簡短的案例研究，展示策略網絡的好處，例如透過有針對性的參與擴展網絡並找到職業機會的用戶。\n特 ...
#  {'title': '如何建立职业页面？+ 11 个职业网站范例为您提供灵感 - Recruit CRM',
#   'source': 'https://recruitcrm.io/zh-hans/blogs-zh/careers-page/',
#   'content': '目录\n什么是职业页面？\n明星职业页面的 8 个基本要素\n1.展示价值观和使命\n2.强调员工福利\n3.支持建设人才社区\n4.重点奖项和表彰\n5.提供吸引人的内容\n6.分享推荐信和成功故事\n7.允许与观众互动\n8.特色社会证明\n拥有引人入胜的职业页面的 5 大好处\n1.增强候选人体验\n2.人才的持续参与\n3.提高品牌知名度\n4.节约成本和时间\n5.提高申请人质量\n建立优秀招聘页面的 6 个步骤\n步骤 1：确定您的需求和目标\n第 2 步：规划页面布局和内容\n步骤 3：编写内容\n步骤 4：设计页面\n步骤 5：整合应用系统\n第 6 步：测试、发布和推广您的职业页面\n建立有效职业页面的 6 个最佳做法\n1.提供方便用户的导航\n2.采用响应式设计\n3.实践个性化和目标定位\n4.与申请人跟踪系统（ATS）整合\n5.不断优化\n6.策划引人注目的视觉效果\n保持职业页面领先地位的 5 个简单方法\n1.创建候选人角色\n2.简化申请程序\n3.引入聊天机器人和常见问题\n4.与社交媒体整合\n5.展示虚拟参观和访谈\n值得借鉴的 11 个最佳职业网站范例\n1.Recruit CRM – ATS + CRM 软件供应商\n2.微软 – 计算机软件巨头\n3.Slack – 专业交流平台\n4.Airbnb – 在线民宿中介\n5.Adobe – 创意软件公司\n6.HubSpot – CRM 平台\n7.Netflix – 流媒体服务\n8.IBM – 科技型跨国公司\n9.Spotify – 音乐和播客数字应用程序\n10.CVS Health – 美国领先的医疗保健公司\n11.强生公司 – 全球医疗保健行业的领导者\n常见问题\n1.如何为移动用户优化我的职业页面？\n2.如何利用我的职业页面吸引多样化人才？\n3.职业页面上的职位列表应包括哪些内容？\n4.如何让我的招聘页面在竞争中脱颖而出？\n如何建立职业页面？+ 11 个职业网站范例为您提供灵感\n制作一个有效的职业页面是企业吸引一流人才的关键一步。\n本指南将为您提供知识和灵感，帮助您从零开始构建一个引人注目的职业网站。\n我们还将带您参观在招聘领域树立黄金标准的顶级职业网站范例。\n让我们开始吧！\n什么是职业页面？\n职业页面是公司网站上的一个部分\n网站\n致力于展示就业机会。\n它为求职者提供了一个中心枢纽，让他们在了解公司文化和价值观的同时，探索和申请空缺职位。\n精心设计的招聘页面允许求职者根据工作地点、职位名称或部门搜索和筛选职位列表。\n它还提供每个职位的详细信息，包括职责和资格。\n应聘者还可以通过该网站填写申请表或按照提交说明轻松申请职位。\n招聘网站在吸引优秀人才、传播雇主品牌方面发挥着重要作用。\n雇主品牌\n以及提供无缝的\n求职者体验\n.\nIt gives potential candidates a glimpse of what it’s like to work with a company and how it manages to stand out from the crowd.\n这为企业展示其独特的文化、价值观和福利创造了空间，使其具有不可抗拒的吸引力，从而推动招聘工作取得成功。\n注意事项\n第一印象很重要，一个吸引人的职业页面可以决定是吸引顶尖人才还是让他们流失到竞争对手那里。\n明星职业页面的 8 个基本要素\n1.展示价值观和使命\n职业页面是阐述公司价值观、使命和愿景的平台。\n这有助于候选人了解组织的宗旨，以及是否与自己的愿望和信念相一致。\n此外，这也反映了公司除了促进个人和职业发展之外，还致力于培养人才、\n使其雇主品牌更具吸引力\n.\n2.强调员工福利\n明确传达员工在组织中享有的福利和津贴。\n这可能包括\n医疗保健\n福利、灵活的工作安排、职业发展机会以及使公司与众不同的独特服务。\n展示企业对员工福利和成长的承诺，可以加强企业作为首选雇主的权威性。\n3.支持建设人才社区\n鼓励候选人加入\n人才社区\n或订阅您的时事通讯，分享最新信息、行业见解和独家工作机会。\n通过培养这些关系，您可以将自己打造成行业权威，成为杰出的思想领袖。\n它还可以帮助您维持一个参与候选人库，以\n使您的人才渠道保持温暖\n以满足未来的招聘需求，从而实现双赢。\n4.重点奖项和表彰\n如果公司员工获得了荣誉或表彰，职业页面就是展示这些成就的理想场所。\n介绍在组织中茁壮成长的员工的成功故事。\n重点介绍他们的成就、职业发展以及产生的影响。\n炫耀成功是加强公司作为可靠雇主声誉的有效方法。\n这不仅能建立信任，还能凸显企业的发展潜力和机遇。\n员工表彰计划对招聘工作的 5 种帮助\n5.提供吸引人的内容\n创建引人入胜、信息丰富的内容\n在公司的职业页面上。\n这可以包括博文、文章或视频，提供对行业的见解，提供职业建议，或让受众了解最新的职业信息。\n最新趋势\n和更新。\n通过提供有价值的内容，您可以将自己的公司定位为在利基市场中具有适当专业知识和知名度的旗帜，吸引那些有兴趣与行业领导者合作的求职者。\n6.分享推荐信和成功故事\n求职者花费多达 37% 的时间\n职业网站上的视频推荐。\n因此，请利用\n讲故事的力量\n在您的页面上介绍它们。\n介绍团队成员的推荐信，让求职者从真实的角度了解公司的工作文化和真正的优势。\n让他们深入了解员工的经历、挑战和胜利，以内部人士的视角介绍与贵组织合作的感受。\n7.允许与观众互动\n为候选人提供与贵公司接触的途径。\n这可以包括参加虚拟活动或网络研讨会、参加候选人测验以获得奖励、关注社交媒体以定期了解最新情况等选项。\n积极与应聘者接触有助于给人留下您重视他们的兴趣并致力于与他们建立有意义关系的印象。\n8.特色社会证明\n展示任何奖项、表彰或\n行业认证\n贵公司从外部机构获得的奖项或行业认证。\n这些第一手资料可以证明贵组织的成就，并增加雇主品牌的可信度。\n它还能使外部的重要认可成为焦点，从而加强雇主品牌的权威性和声誉。\n拥有引人入胜的职业页面的 5 大好处\n1.增强候选人体验\n精心设计的招聘页面可以吸引潜在应聘者，并给他们留下积极的第一印象。\n吸引人的视觉效果、引人入胜的内容和用户友好的导航可以大大提升候选人的体验。\n通过提供有关公司、工作机会和员工福利的相关信息，您可以让候选人参与进来，并鼓励他们申请您的空缺职位。\n8 个免费的候选人体验调查模板\n2.人才的持续参与\n职业页面可作为一站式解决方案，帮助候选人持续\n候选人参与\n.\n您可以通过职业网站让潜在求职者了解公司新闻、活动和即将到来的工作机会。\n通过提供加入人才网络或订阅职位提醒的选项，您可以随着时间的推移培养与候选人的关系，即使他们还没有准备好立即申请。\n3.提高品牌知名度\n职业页面可以扩大您的影响力，使您能够从更广泛的人才库中吸引求职者。\n通过正确的搜索引擎优化策略和在线推广，您的职业网站可以在搜索引擎结果中排名靠前，让潜在求职者更容易发现您的工作机会。\n通过这种接触，您可以与大量合格的求职者建立联系，并最终帮助您扩大网络，发掘\n多样化的候选人\n.\n4.节约成本和时间\n建立职业页面可以减少对传统招聘方法的依赖，如招聘网站和平面广告。\n这可能导致\n显著节约成本\n随着时间的推移，可节省大量成本。\n此外，一个经过优化的招聘网站还应配\n申请人跟踪系统\n(ATS) 简化了申请流程，为求职者和人力资源团队节省了时间。\n5.提高申请人质量\n通过专门的职业页面，您可以提供全面的\n职位描述\n明确的要求以及对每个职位的期望。\n这种清晰度吸引了具备适当资格和技能的求职者，从而产生了更高质量的真正求职者。\n通过有效传达您的需求，您可以\n简化招聘流程\n并从一开始就确定最合适的候选人。\n建立优秀招聘页面的 6 个步骤\n步骤 1：确定您的需求和目标\n第一步是要明确自己在寻找什么。\n贵公司目前有哪些职位空缺？\n您需要哪些技能和资质？\n贵公司的企业文化是什么，哪种类型的人会适合贵公司的企业文化？\n收集完所有这些信息后，您还应该列出职业页面的目标。\n这可能包括吸引高素质的求职者、宣传公司文化，或\n提升品牌形象\n.\n第 2 步：规划页面布局和内容\n清楚了解自己的需求和目标后，就可以开始规划职业页面的布局和内容。\n这可能包括\n向潜在应聘者介绍贵公司的引人入胜的欢迎信息。\n空缺职位列表，每个职位都有详细的职位描述、所需资格和申请说明。\n介绍贵公司的文化和价值观，如有可能，请附上图片或视频。\n在职员工的感言。\n常见问题和联系方式，以便进一步咨询。\n步骤 3：编写内容\n现在，是为页面撰写和收集内容的时候了。\n在欢迎词中，尽量做到友好和吸引人。\n解释为什么贵公司是一个理想的工作场所，以及它的与众不同之处。\n在撰写职位描述时，要具体说明角色和职责，以及必要的技能和资格。\n可以通过与团队进行简短访谈来收集员工推荐信。\n这将提供一种个人风格，让应聘者了解贵公司的内部情况。\n开发常见问题版块，涵盖有关招聘流程、工作环境、福利等方面的常见问题。\n步骤 4：设计页面\n与你的网页设计师合作，或使用\n人工智能网页设计工具\n来创建你的\n网页\n。\n请记住，网页应简洁、美观、易于浏览。\n确保空缺职位列表易于查找和阅读。\n使用图片、视频和信息图表，使页面更吸引人。\n将贵公司的颜色和徽标融入设 ...
#  {'title': '什麼是LinkedIn？LinkedIn照片怎麼拍怎麼選？教你打造出專業第一印象',
#   'source': 'https://www.chunshan.tw/linkedin-cvportrait/',
#   'content': '有些人為了展示自己重視團隊精神或人際關係非常好，以團隊照片作為自己 LinkedIn 的頭像照，可是 HR 會不知道哪一個才是你。\n如果想要讓人資一眼就能認識你認出你，建議還是使用獨照。'},
#  {'title': '如何建立令人印象深刻的LinkedIn 个人资料 - 芊芊简历',
#   'source': 'https://qqjl.cn/blog/how-to-build-a-great-linkedIn-profile/',
#   'content': "如何建立令人印象深刻的 LinkedIn 个人资料\n随着职业世界变得越来越数字化（并且以闪电般的速度发展），将求职和网络扩展到在线空间比以往任何时候都更加重要。\n招聘人员和招聘经理在考虑候选人时将 LinkedIn 作为主要信息来源之一，因此您的 LinkedIn 个人资料可以成为与简历、求职信甚至个人推荐信一样强大的工具。它本质上是 LinkedIn 简历。\n与更传统的文档相比，LinkedIn 个人资料页面的优势在于其“交互”性质。除了详细介绍您的工作经验和技能外，您还可以用引人注目的图像来修饰您的职业故事，展示最近的社交帖子，通过视频添加一些个性，并获得您的专业关系的认可。\n那么，让我们看看如何增强这种交互式“在线简历”，并利用您的 LinkedIn 帐户赢得工作面试和\n职业转变\n机会。我们将介绍以下内容：\n为什么良好的 LinkedIn 个人资料至关重要\n创建强大的 LinkedIn 个人资料的 10 个技巧，涉及以下方面：\n照片和标题图片\n标题\n“关于”个人总结\n“精选”部分\n活动\n工作经验\n开放工作\n技能、认可和建议\n选择视频内容\n什么是新的\n如何通过视觉品牌元素和格式在 LinkedIn 上脱颖而出并获得关注\n恢复操作方法\n将您的简历上传至 LinkedIn\n将您的简历附加到 LinkedIn 求职申请中\n使用 LinkedIn 创建您的简历\n为什么需要良好的 LinkedIn 个人资料？\nLinkedIn 是专业人士的社交媒体网络。招聘人员去那里寻找潜在的候选人；雇主正在积极推广他们的品牌，这是迄今为止求职者最好的社交媒体平台。\n招聘人员和招聘经理会在各种平台和社交媒体上寻找资源，你在 Facebook 和 Twitter 上的活动肯定会产生一定的影响力，但 LinkedIn 是任何企业求职者应该居住的求职社交品牌。\n首先，您必须创建 LinkedIn 个人资料。\n如果你花时间去创造一个好的机会，你永远不知道哪些机会会降临到你身上。这就是社交媒体的美妙之处。如果你建造得好，他们就会来。\n专家提示\n初学者应该如何使用LinkedIn？\n对于任何 LinkedIn 初学者来说，最大的错误之一就是创建一个最小的 LinkedIn 个人资料。该平台提供了与其他可以在职业生涯中为您提供帮助的人联系的绝佳机会，因此请充分利用所提供的一切。充满信心，让您的经历大放异彩。\n相关文章\n资格声明：它是什么？我需要一个吗？\n资格声明可能是您工作申请的必需部分，或者是您对如何最好地展示您的技能所做的选择。它包含什么以及您如何创建一个？请阅读下面的博客以获取提示和示例。\n如何创建强大的 LinkedIn 个人资料：10 个技巧\n当您点击个人资料按钮并考虑您的 LinkedIn 个人资料向潜在新雇主或自由职业客户发送的消息时，您对所读内容满意吗？\n首先，让我们考虑一个好的 LinkedIn 个人资料页面的基本要素。以下是需要仔细思考的10个方面：\n专业拍摄 LinkedIn 个人资料照片和个人资料标题图片\n有影响力的标题传达您的个人品牌\nLinkedIn 个人资料的“关于”部分作为个人摘要\n如何选择要包含在“精选”部分中的内容\n请记住，您的活动也会显示在您的 LinkedIn 个人资料中\n相关且令人印象深刻的以往工作经历示例\n工作偏好、服务亮点和招聘要求\n技能、认可和建议\n视频在 LinkedIn 个人资料中的作用 - 包含哪些内容以及避免哪些内容\n随时了解变化（您现在可以添加 30 秒的介绍视频）\n博客 - 如何建立令人印象深刻的 LinkedIn 个人资料 - 强大的 LinkedIn 个人资料\n1. 您的 LinkedIn 个人资料照片和个人资料标题图片\n考虑到在许多国家（特别是美国和加拿大）已经逐步淘汰在简历中使用头像，求职者常常忽视专业照片的重要性。\n并不是每个人都会费心在干净的白色背景上创建个人资料图片，甚至很少有人会足够关心地订购摄影师的专业照片。后者可能看起来不必要地昂贵，直到您考虑投资价值。从长远来看，高质量的“爆头照片”在积极的形象收益方面会带来数倍的回报。\n考虑到 LinkedIn 是一个社交网络，您的个人资料图片应该对您有利。招聘经理会阅读你的简历并立即查看你的 LinkedIn。您的照片可能不会出现在您的简历中，但它会出现在您的个人资料的前面和中间。确保仔细选择和/或创建您的图像。\n专家提示\n将任何照片变成专业头像\n如果您已经在使用 芊芊简历 的简历生成器，我们有一个漂亮的功能，可以将任何照片变成专业照片：\n照片背景更改功能\n。您可以轻松拍摄任何效果良好的照片，然后只需按一个按钮即可切换背景。有多种背景可供选择：抽象背景、办公空间背景、纯色背景，甚至适合更具异国情调的职业的自然背景。\n2. LinkedIn 标题是你的电梯游说\nLinkedIn 标题是 LinkedIn 个人资料页面的一个非常重要的元素，因为它为整个 LinkedIn 帐户定下了基调。这是潜在雇主和招聘人员在您的个人资料照片后看到的第一件事。\n最好的 LinkedIn 个人资料让标题对他们有用，而不仅仅是显示他们的主要职位。在一个“标准”职位描述的意义逐年减少的世界里，有目的地打造一个专业品牌和“自定义头衔”或职位描述非常有意义。\n您的目标是概述您当前职位的通用职位名称（例如“凯特·威尔斯，会计师”或“吉姆\u200b\u200b·戈登，工程师”），并让访问您页面的招聘人员在众多候选人中真正记住您。\n专家提示\n打造令人难忘的 LinkedIn 个人资料标题以脱颖而出的 7 个技巧：\n包括您希望获得下一个职位的具体职位或领域。\n说出听众的需求并解释你如何解决他们的问题。\n用一个事实或主张来吸引读者，让他们想继续读下去。\n包括任何真正杰出成就的可量化事实或数据。\n使用一两个强有力的形容词，但不要使用多余的语言。\n不要滥用大写字母并避免使用表情符号（毕竟你不会将它们放入简历中）。\n使用整个分配的 220 个字符。您可能会认为“少即是多”，但在这种情况下并非如此。您的个人资料标题将被阅读。\n3.您的 LinkedIn 个人资料“关于”摘要部分\n就极其重要（但难以处理）的部分而言，LinkedIn“关于”部分是 LinkedIn 个人资料的基石。与传统简历中的个人\n资料\n（有时称为摘要或\n个人陈述\n）类似，这提供了您的候选人资格的最佳亮点。\nLinkedIn.com 上的摘要部分与传统简历中的摘要部分具有许多相同的特征。\n您可以在我们的综合简历写作指南\n或\n摘要\n博客中查看我们关于构建精彩摘要的建议，因为大多数相同的原则都适用。主要区别在于您的字符数限制为 2,000 个字符，而不是 100 到 200 个单词。\n诀窍是在引人入胜的叙述和专业资格之间取得平衡。赌注太有创意，你会被认为没有认真对待你的工作。只关注专业术语，即使是行业专家也会很快感到无聊并继续前进。\n另请记住，许多招聘人员和招聘经理在技术领域的知识并不像您是行业资深人士那样丰富。请小心，不要将您的 LinkedIn 个人资料摘要变成一堆晦涩难懂的缩写。\n需要注意的是，最初只有 LinkedIn“关于”部分的前三行可见，因此请让故事的开头尽可能有趣。读者有意识地选择点击“查看更多”按钮，因此请仔细选择开头句子中的用词。\n专家提示\n以下是 LinkedIn 个人资料主要部分的字符数：\n标题\n：220 个字符\n关于\n：（原摘要）2,000 个字符\n特色\n：每个标题 100 个字符，每个描述 500 个字符\n经验\n：每个标题 100 个字符，每个描述 2,000 个字符\n推荐\n：每条推荐 3,000 个字符\n如何建立令人印象深刻的 LinkedIn 个人资料 - 人物数 LinkedIn\n4.特色内容增加故事的深度\nLinkedIn 的主要好处是它允许会员发展他们的专业网络，与他人分享他们的想法并互相学习。社交更新帖子、长篇博客内容和视频帖子都是 LinkedIn 专业挂毯的一部分。\n您还可以在此特色部分中显示 LinkedIn 外部的内容，但我们的建议是分享相关且与您的职业网络特别共鸣的内容。社会证明在求职中令人印象深刻。如果您展示的内容在您的网络中很受欢迎，那么它比简单地分享您五年前在个人网站上撰写的博客更具影响力。\n可以肯定地说，与共享临时源更新相比，在这里观看视频的可能性要高得多。人们出现在您的 LinkedIn 个人资料页面上是有原因的，如果您将其包含在“信封上方”作为可见媒体之一，那么它肯定会获得浏览量。\n专家提示\n如果您目前在职，请勿过于频繁地更新您的个人资料。\n不断修改你的 LinkedIn 个人资料直到完美为止是很诱人的。但你永远不知道你现在的雇主是否会密切关注。各种各样的行为都会引起怀疑，心怀不满的员工在考虑新工作时往往会改善自己的在线形象。在您绝对确定要离开之前，不要这样做。出于同样的原因，也不要突然改变您的在线活动。\n相关文章\n如何在 LinkedIn 上宣布新工作\n对于想要表达对过去同事的感激之情并分享他们对新开始的兴奋的人来说，LinkedIn 上的新职位公告至关重要。以下是一些塑造您的信息的技巧。\n5. 最近的活动也会显示在您的 LinkedIn 个人资料中\nLinkedIn 个人资料是社交媒体平台的一个活生生的功能。它始终会发生变化，因为您最近的活动 ...
#  {'title': 'How to Choose the Right LinkedIn Background',
#   'source': 'https://www.linkedin.com/pulse/how-choose-right-linkedin-background-philip-horne-wxsdc',
#   'content': 'Your LinkedIn profile is often the first impression you make with potential clients, professional connections, and potential employers. While your profile picture is crucial and the image most people first notice, your background image is an often-overlooked opportunity to showcase you and what you offer. In this article, I’ll review the pros and cons of each of the four main LinkedIn profile background options to help you make the best choice for your LinkedIn profile.\n1. LinkedIn\'s Default Background\nThe default LinkedIn background is a safe choice, but it doesn\'t differentiate you from other professionals. While it ensures your profile looks neat, it also suggests you haven\'t invested thought or time in personalising your online presence.\nPros:\nRequires no effort at all\nIt avoids potential image selection mistakes\nEnsures a clean and professional look\nCons:\nMisses an opportunity to stand out\nFails to showcase your personality, brand, or uniqueness\nIt may come across as lazy\n2. Upload a Personal Image\nA personal image can be a powerful way to express your individuality and make a memorable impression. Whether it\'s a landscape that inspires you, or a personal image of you for personal branding reasons, a well-chosen personal background can spark conversations and help you connect with others on a more personal level.\nPros:\nIt allows you to showcase your personality\nIt helps you stand out from other profiles online\nIt provides flexibility in choosing an image that represents you\nCons:\nRequires careful selection to maintain professionalism\nIt may not align with company branding if you\'re representing an organisation\nIt could potentially be off-putting if not chosen wisely\n3. Upload a Company Branded Image\nUsing a company-branded background is ideal for those in a client-facing role. It shows commitment to the company and enables potential clients to experience consistent branding on employee accounts, the LinkedIn company page and the website, which builds confidence and trust.\nPros:\nEnsures consistent branding across employee profiles\nIt can look highly professional and polished\nDemonstrates company loyalty\nCons:\nIt may not differentiate you from colleagues\nIt could be seen as less authentic or personal\nLimits personal expression\n4. Create a Slideshow\nA slideshow background is a new feature added at the end of 2024 for the majority of LinkedIn users (some at the time of writing are waiting for it to be rolled out).\nRecommended by LinkedIn\nHow To Enhance your LinkedIn Profile In 10 Minutes\nISLAM ELHOSINY\n5 months ago\nUsing LinkedIn to Showcase Your Expertise\nEndeavour Marketing\n1 year ago\nYour LinkedIn Profile! \nWhen People Want to Know More…\nDerick Mildred\n1 year ago\nIt essentially allows users to add multiple images, which provides you with more opportunities to give a fuller picture of what you can help people with.\nPros:\nAllows for dynamic content presentation\nCan showcase multiple aspects of your brand or career\nEngages viewers and encourages profile exploration\nCons:\nMore work to create\nMore complex to get right\nIt could be distracting if not well-designed\nMaking Your Choice\nWhen selecting your LinkedIn background, also consider these factors:\nYour goals:\nAre you job hunting, building a personal brand, or representing your company?\nYour industry:\nSome sectors may expect more creativity, while others value traditional professionalism.\nYour role:\nBusiness leaders and client-facing professionals may benefit from more polished, branded backgrounds.\nYour audience:\nThink about who you want to impress and what would resonate with them.\nIn Summary\nThere is no right or wrong option. It’s a personal choice. What is best for you will depend on your unique situation, and perhaps for some, a hybrid version of personal and company may work best.  Whichever option you choose, keep your background professional, high-quality, and reflective of who you are a ...
#  {'title': '【職場升級秘訣】善用LinkedIn打造個人品牌，掌握薪資談判優勢',
#   'source': 'https://www.gut-haode.com/linkedin-tips-2/',
#   'content': '【職場升級秘訣】善用LinkedIn打造個人品牌，掌握薪資談判優勢\nBy\nGut! Haode\nPosted\n2024 年 11 月 20 日\nIn\n德國職涯\n,\n找工作準備\n【職場升級秘訣】善用LinkedIn打造個人品牌，掌握薪資談判優勢\n2024-11-20\n2024-11-20\nhttps://www.gut-haode.com/wp-content/uploads/2023/07/gut_layout-01.png\nGut! 好德\nhttps://www.gut-haode.com/wp-content/uploads/2024/11/pexels-airamdphoto-16450744-2.jpg\n200px\n200px\n0\nLinkedIn已成為現代職場中展示專業形象、建立人脈和拓展機會的重要平台。這不僅是儲存履歷的空間，更是你展示自我價值以及建立專業連結的強大工具。我們邀請到在德國求學工作生活將近20年的Grace(文中第一人稱)，與大家分享如何經營自己的LinkedIn：從建立個人品牌、有效經營人脈到持續的內容分享，每一步都能幫助你在職場更上一層樓。\n建立個人品牌：把自己當成一個值得被投資的品牌\n1. 完整填寫個人資料，打造鮮明專業形象\n在LinkedIn上，你的個人檔案就是你的職業名片，需清晰傳達你的專業背景和核心能力，讓人一眼便能了解你的專長和價值。例如，如果你是一位產品經理，不要僅寫「負責產品開發」，而是具體描述：「透過跨部門協作和用戶研究，成功將新產品的市場接受度提升30%」。包含重要關鍵字並將成果量化，不僅更能展現出你的專業成就，並使你的檔案更具吸引力。\n2. 利用標題和照片吸引目光，讓你的檔案一見難忘\n在LinkedIn上，照片和標題猶如檔案的門面。選擇一張專業照片和清晰表達你專業的標題，是吸引人深入了解你的關鍵。例如，可以使用「專注於SaaS產品開發的資深專家」或「跨文化行銷策略顧問」這類標題，既能明確傳達你的核心專業，又能提升在搜尋中的曝光度。此外，若你正在尋找新機會，可啟用「Open to Work」功能，以吸引潛在雇主的注意。\n3. 運用AI\n工具提升檔案品質：智慧簡化，專業升級\n如今的LinkedIn整合了多種AI工具，能協助你優化個人簡介和履歷。過去我會逐字撰寫自己的個人簡介，但現在建議先利用這些工具生成初稿，再依自身風格調整。這樣既能節省時間，又能充分展現你的專業能力。\n經營人脈：建立有價值的連結\n1. 發送個性化的連結邀請，展現誠意\n與他人建立連結時，不要只單純點擊「連結」按鈕，而應附上一段個人化的訊息，說明連結的原因。這種誠意更容易被對方接受。舉例來說：「您好，我聽了您在會議中的演講，對您的市場策略分享深受啟發，希望有機會與您交流。」簡單而真誠的話語能提升連結的價值。\n2. 參與專業群組，積極互助\nLinkedIn提供許多專業群組，加入與職涯相關的社群是拓展人脈的好方法。在這些群組中，不僅可以掌握行業動態，還能與其他專業人士交流經驗。分享觀點、參與討論，這些都有助於塑造你更具深度的專業形象。\n3. 定期互動，維繫人脈關係\n經營人脈並非一時之舉，而是需要持續維繫的過程。當某位連結人分享了職場成就、生日或其他重要時刻時，不妨送上祝福或支持。這些互動不僅能讓你在人脈圈中保持活躍，還能強化彼此的關係，為未來的合作奠定基礎。\n在LinkedIn\n上展示專業見解，提升你的職場影響力\n1. 定期分享有價值的內容，展現專業深度\n每週分享一到兩次專業內容，可以是你在專案中的心得、對市場趨勢的分析或是參加研討會的收穫。例如，我曾分享如何帶領國際團隊克服障礙進入市場，細述挑戰、行動和成果。這類內容不僅展示專業能力，還能引起同行的共鳴與討論。\n2. 善用標籤與關鍵字，擴大內容觸及面\n每次發文時記得加入相關標籤和關鍵字，讓內容更容易被相關專業人士看到。例如，若撰寫數位行銷文章，可用標籤如「#數位行銷」「#市場分析」，增加觸及率，吸引更多有興趣的人。\n3. 保持真實誠懇，打造可信賴的形象\nLinkedIn上的分享不只是展示成功經歷，更是與人連結的途徑。不要害怕談論你在專案中遇到的挑戰或學到的教訓。這種真實感會讓你更具親和力，也能吸引更多志同道合的人與你交流。\n善用LinkedIn\n的進階功能：探索職涯機會與提升個人形象\n1. 靈活運用「Open to Work\n」功能，隱性求職更安全\n若你在尋找新機會但不希望現任雇主或同事察覺，可以啟用隱性求職功能，限定只讓特定招聘人員看到你的求職意願。這樣既能保障隱私，又能提升在職場上的競爭優勢。\n2. 有效利用推薦功能，增強專業信任度\n來自同事、上司或合作夥伴的推薦，可以大幅提升你的可信度和專業形象。當請求推薦時，提供共事的具體事例，讓推薦內容更具體、更具說服力，進一步彰顯你的職業素養。你甚至可以主動先幫對方寫推薦文，會大大增加得到回饋的機會。\n經營LinkedIn\n注意事項：避免常見陷阱，保持專業形象\nLinkedIn是極具價值的職場平台，但和所有社群媒體一樣，需謹慎經營，以免損害個人形象和專業信任度。以下是一些經營LinkedIn時應避免的常見誤區，幫助你在職場平台上維持良好形象。\n1. 適度分享職場內容，專注專業形象\nLinkedIn是一個專業平台，而非個人生活分享空間。過多的私人生活細節可能會稀釋你的專業形象。你可以分享工作成就、專業觀點、職場經歷或學習心得，而避免日常瑣事。我通常只會發布與職業背景相關的內容，例如參加展會的體驗、公司動態，或是閱讀一本具有啟發性書籍的心得，這些都與我的職業背景相關，並有助於強化我的專業形象和可信度。\n2. 謹慎篩選連結邀請，避免與不可靠帳號連結\nLinkedIn上經常會收到來自陌生人的邀請。雖然擴展人脈是重要的，但需仔細篩選邀請，避免與可疑帳號連結。我個人曾遇到一些帳號，看似專業，但仔細查看後發現內容空洞，甚至可能是機器人或虛假帳號。這類連結可能對你的網絡安全和個人資訊構成風險。建議仔細檢視對方的資料、經歷及共同連結，若發現內容可疑或背景不真實，應拒絕邀請，以確保你維持值得信賴的人脈網絡。\n3. 合理運用LinkedIn\n功能，避免過度互動或不當內容\nLinkedIn是一個職場社群媒體，每次互動都可能影響你在網路上的形象。因此，保持適當的發布頻率和互動風格非常重要。過於頻繁地分享內容，特別是與職場無關或過於個人的訊息，可能會造成他人的困擾。在評論或按讚時，也要慎選與自己專業形象相符的內容，以避免對你的個人品牌造成負面影響。\n4. 分享真實且有價值的內容，避免炫耀或過度自誇\n在分享成功經歷或工作成果時，應保持真實和謙虛的態度。過於自誇或炫耀性的內容，可能會引起反感。反之，如果你分享的是實際經驗、具體數據或是從挑戰中學到的教訓，這樣的內容更具價值，且能引發共鳴。\n5. 保護個人資訊，提升資安意識\n隨著AI和網路工具的普及，個人資訊的安全愈發重要。從過往的工作經驗中，我學到了許多資安的要點，想提醒大家留意駭客可能會利用公開的個人資訊進行不當行為。在LinkedIn上分享時，應避免洩露過多的個人細節，如居住地址或具體行程。此外，對於陌生人發送的私信或連結邀請，應保持謹慎，避免點擊不明來源的連結，以保障資訊安全。\n6. 積極參與討論，謹慎發表言論\nLinkedIn 是一個展示專業見解和互動交流的理想平台。參與討論、點讚和留言能夠增加曝光率並擴大影響力。然而，發表的內容應始終符合職場道德和專業標準，避免極端、具爭議性或與專業形象不符的言論。確保每次互動都能增強你的專業形象，為人際網絡帶來正面影響，而不是產生負面觀感。\n面試與薪資談判的實戰策略\n薪資談判是求職過程中的重要關卡，也是展示自身價值和專業性的重要機會。進入這個話題前，務必做好充分準備，並以自信的心態靈活應對。\n談薪水的策略\n根據我的經驗，與獵頭或招聘人員的初步對話通常會涉及薪資問題。這一階段主要是\n確認你的薪資期望是否在其預算範圍內\n，以避免接下來的流程浪費時間。我的建議是：\n設定合理的薪資增幅：\n求職時，合理的薪資增幅應該比現有薪水高出10%-20%，這並非盲目開價，而是基於市場行情和你的經驗價值。例如，可以說：「我目前的薪資在X範圍內，基於我的經驗和市場趨勢，我希望能有XX%的提升。」\n表達靈活性與價值：\n初期談判時記得強調自身價值和貢獻潛力，這有助於爭取更好的薪資條件。可以說：「我對這份工作的職責和貴公司的發展方向非常有興趣，期待能夠貢獻我的經驗與技能，與公司共同成長。」\n薪資上限與其他條件的談判策略\n當薪資到達一定範圍或職位層級後，不是所有談判都能僅靠提高薪水來解決。尤其是管理職或高階職位，可能會遇到薪資上限的情況。此時應靈活應對，考量其他福利條件，例如：\n職位頭銜的提升\n：若薪資無法大幅提升，可考慮尋求職位頭銜的升級，這將有助於提升未來在職場中的市場價值，並可能帶來長期收益。\n額外福利或彈性條件\n：可協商其他彈性福利，例如工作時間的靈活性、額外培訓機會或額外假期，這些條件能有效提升職業滿意度，以及在工作和生活之間達到更好的平衡。\n行為式面試與薪資談判的關聯\n值得一提的是，許多公司在薪資談判前會進行所謂的行為式面試，這是一種透過具體情境來了解你的能力與特質的方式。例如，他們可能會要求你舉例說明在某個情境中如何發揮領導力。這類的問題，我建議使用\nSTAR法則\n來應對：描\n述當時的情境（Situatio ...
#  {'title': '如何撰寫專業的LinkedIn 個人簡介',
#   'source': 'https://ambitious-learner.com/%F0%9F%9A%80-%E5%A6%82%E4%BD%95%E6%92%B0%E5%AF%AB%E5%B0%88%E6%A5%AD%E7%9A%84-linkedin-%E5%80%8B%E4%BA%BA%E7%B0%A1%E4%BB%8B/',
#   'content': '1️⃣ 優化LinkedIn 標題（Headline） · 2️⃣ 添加精選內容（Featured Section） · 3️⃣ 設定技能與推薦（Skills & Endorsements） · 結論：優化你的LinkedIn 簡介，讓'},
#  {'title': '6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！',
#   'source': 'https://jason-career.com/linkedin/?srsltid=AfmBOoqWlEFuDMRDCItvni13LHKQBzkdbaOIT-Gm-tRu5817JLgethl2',
#   'content': '最後更新時間： 2025 年 01 月 18 日\n「具專業感的 LinkedIn 主頁竟然讓我收到 HR 主動發的面試邀約？！」\n擁有一個專業的 Profile 會提供人們一個額外了解你的機會，不只在求職和 Networking 過程中幫到你，也能在申請海外 MBA 的過程中增加錄取機會，甚至能收到 HR 的主動聯繫！\n這篇文章想分享 Networking 和申請哥大 MBA 時，LinkedIn 是如何幫助到我的！我自己在申請 MBA 或其他碩士項目時，部分學校有提供欄位讓申請人填寫 LinkedIn 領英網址。\n不管是主動在簡歷附上 LinkedIn URL，或是公司 HR、大學招生官在搜尋個人的 LinkedIn，正確且專業的使用 LinkedIn 會提供一個額外向他人展示個人品牌的機會。\n由於 LinkedIn 是偏向專業的社交媒體平台，所以在 LinkedIn 上建立一個專業的個人品牌，展示自身經歷、價值觀和興趣是至關重要的！\n內容目錄\nToggle\n事前準備\n關閉檔案更新通知\n在開始對 LinkedIn 個人資料進行修改之前，請確保你的 Network 不被打擾。\n請點擊「我」\n→\n設置和隱私\n→\n公開度\n→\n將檔案更新分享到人脈網【關閉】 設置個人專屬的 URL\n設置個人專屬的 URL\nLinkedIn 提供修改主頁 URL 的機會，這展示了對細節的關注，是一個區別於其他 LinkedIn 資料和候選人的標誌。若沒有修改的話，預設會是一串字母跟數字組成的亂碼。\n修改方式：個人主頁\n→\n右上角的方框內「編輯公開檔案和網址」\n→\n編輯自訂網址，將 URL 改為盡可能接近你的名字（羅馬拼音或英文名＋姓氏）。\n開始動工，翻修個人主頁 LinkedIn Profile\n撰寫吸引人的標題與個人摘要\n為什麼重要？標題與摘要是 HR 和其他用戶最先看到的內容，它們會直接影響他們是否有興趣繼續瀏覽下去你的 Profile。\n如何做？\n標題\n：除了職位名稱，加入你的專長與價值，例如：「數據分析師｜精通 Python、SQL｜專注於商業洞察」。\n摘要\n：用 2-3 段簡單明瞭的語言，概述你的職業背景、成就和未來目標。可以用故事化的方式呈現，讓人讀起來更有吸引力。\n範例摘要\n：\n我是一名具備 5 年經驗的數據分析師，擅長運用數據解決商業問題，幫助企業提升營收。我精通 Python 和 SQL，並在過去一年中完成了 3 項提升效率的專案，為公司節省 20% 的營運成本。目前，我希望透過數據驅動的洞察，助力更多企業成長。\n專業的個人頭像照片\nLinkedIn\n是一個專業的平台，個人資料必須有一張專業的頭貼，而不是集體照或生活照；個人建議是不要使用證件照（例如：身分證或護照大頭貼），會顯得有些突兀。根據網路上不可靠資料，有附帶照片的檔案被查看機率是沒有照片的數十倍。下面是我整理有關 LinkedIn 照片的一些 ”Do’s” 和 “Don’t”。\n最推薦的樣式是：一個人(only YOU) + 微笑，清楚、近期、背景單純。\n更進階的 tips 是可以嘗試符合產業⾵格，與你平常⼯作模樣相近的打扮。\n⭕ Do’s\n❌ Don’t\n近距離拍攝\n正裝照\n近期照片\n聘請專業攝影師（非必須）\n自拍\n團體照\n過時的照片\n其他的人/動物/動畫/虛擬頭像\n奇怪的背景\n背景圖片/封面\n選擇一個最能代表你的形象，比較常見的圖片可以是演講照片、志工服務、社團活動等等。也可⽤\nCanva\n設計自己的單色背景圖⽚，展現你的特質和專業領域。\n簡單來說，第一印象很關鍵！專業的頭像可以讓人覺得你值得信賴，而背景照片則是展示個人品牌的絕佳機會：\n頭像\n：選用清晰、自然且帶有微笑的照片，背景簡單乾淨，建議穿著符合職業形象的衣服。\n背景照片\n：選擇與你的行業或專業相關的圖片，例如公司活動、技術插畫，或自訂一張帶有你的個人標語的設計。\n注意\n：避免使用過度修圖或自拍照，這可能給人不專業的印象。\n關於（自我介紹）\n寫一篇令人過目不忘的自我介紹，嘗試突出你的專業、職業經驗、榮譽和領導能力。寫下你職業生涯中最相關的成就，避免使用艱澀難懂的行話 (Jargon)。把重點集中在前幾行，寫作方式可以參考 Elevator pitch，以第⼀⼈稱⾃我介紹：特質、熱忱、價值觀、近期⽬標、個人背景如何成就了現在的你。\n注意：不要混淆關於 About 和工作經歷 Experience，About 是總結、Experience 部分應該寫得更詳盡。\n我出版了三本電子書！分別是：\nSOP、CV、英文面試\n，每本都\n超高 CP 值、乾貨滿滿、銷售破百本\n，持續更新增補內容，陪伴大家走過留學＆求職！\n當你看到這邊，恭喜你獲得讀者專屬優惠碼！\n輸入優惠碼：BLOG100，\n每本電子書都折 $100\n，三本一起購買就可以折 $300！\n👉🏻\n點擊這裡\n一次搞懂申請需要的資源、撇步和知識吧！用傳統代辦 3% 不到的價格，獲得 300+% 價值\n工作經歷摘要\n這個區塊並非是讓人直接將簡歷複製上來，也不是 Job Description，而應該是量化地描述成就和工作的總結。此外，雖然只需要包括工作中最關鍵的方面，但不⽤像履歷那樣只有幾個 Bullet Point。可以考慮用「說故事」的方式，或是擬一個小段落，甚至可以上傳媒體、放上作品、網⾴等。\n教育背景\n列出你的畢業學校、系所、排名、GPA（建議如果大於 3.5 可以放上），也可以放上修過的課程等等。甚至，你也可以在上面描述你做的研究（例如，畢業論文、Research Project），以及你在大學期間參與過的社團活動。\n其他區塊\n【資格認證】列出與你的⽬標領域⾼度相關的項⽬即可，太多⼜雜反⽽失去焦點。\n【志願服務】將社區服務經驗寫上去可以讓人認識你專業方面以外的貢獻與付出。\n【精選 Featured】領英的 Featured 一欄提供了展示自己的空間，你可以在這裡放上你取得的工作成就和成果，或是置頂一些你之前發布過的文章。如果 Profile 全都是文字的話會顯得單調，放上一些精選可以補充一些媒體，讓你的形象更立體。\n成為領英 LinkedIn 大師，進階 Tips 秒變專業\n下面還有整理一些更進階的經營 Tips，讓大家成為領英大師，熟稔操作並增加曝光。\n客製化邀請\n訊息\n在你持續建立 Connection 時，可以使用更加個性化的好友邀請訊息，提及您與他們的共同興趣、參加的共同活動或學校或共同朋友等等。通常發送默認消息的好友通過率不高，並且其他人還需要點進你的頁面後回想他是否認識你。\n打招呼＆自我介紹＆說明目的，先揭露你自己、別人才會更願意揭露他自己！\n保持更新\n在畢業、找到新工作、完成專案、被學校錄取等各種時機，都可以發 post 跟大家分享好消息，並且分享自己的心得跟表達感謝。工作經歷等檔案也記得定期更新。LinkedIn 的 post 提供了另一種方式來提升您的影響力，並且讓他人了解你感興趣的領域，通過發布有影響力的內容來突出您的專業知識和興趣，並且積累更多相似興趣、想法的人脈。\n分享專業內容、心得感想、職場體悟，建立個人品牌\n主動分享高價值的內容，不僅能展現你的專業能力，還能提高你的主頁曝光率。\n分享文章\n：針對行業趨勢、案例分析或職場技能分享你的見解。\n撰寫文章\n：發布你的專業洞察，例如「如何用數據驅動業務增長」。\n參與討論\n：在別人的文章或貼文下發表有深度的評論，增加你的能見度。\n注意\n：保持內容專業且相關，不要過於頻繁地發布私人內容。\n頭銜\n可以用頭銜來突出你目前的職位和公司（例如：CB 公司的營運長）、突出您的專業知識或獎項，或展示技能（例如：分析師、講師、顧問）。\n位置和行業\n這兩個簡單的設置將幫助更多的人找到你，並幫助你找到更多相關的潛在 Connection。\n添加新區塊\nLinkedIn 允許添加多個部分，您可以添加志願服務、語言能力、榮譽和獎項、專利、學術期刊發布等部分。\n一致性\n如果整個領英 Profile 的內容高度一致且有深度，會更加有利於他人認識你。在語言使用上也需要注意，領英編輯時可以同時編輯中文和英文檔案，在編輯英文檔案時須注意公司名稱等欄位是否也變更成英文。\n在用領英做 Connection 時，歡迎參考這篇文章 👉🏻 教你如何\n問對問題脫穎而出，展現主動性！這些秘訣助你在留學和職場大放異彩！\n針對以上訣竅，該如何寫出自己專屬的 Profile 呢？\n學習行業前輩\n各個行業都有資深人士，可以查看並學習他們的 LinkedIn 個人頁面寫法，但是注意不要抄襲。個人建議可以多多查看英文母語使用者的 Profile，他們在用詞的架構跟精確度上都會比較好。\n用詞精確\n盡量避免過度使用太 General 的關鍵詞，應該適時加入精準的關鍵詞（職稱、產品、程式語言技能等），讓公司 HR 在搜尋時可以更清楚的了解你過往的經歷與能力。\n避免廣告\n發文時盡量不要大篇幅描述產品或者公司業務，在西方視角中，這類型的廣告用個人頁面發出並不恰當。可以嘗試具體化自己的行業經驗和專業技能，以及自己曾經涉及到的項目經驗，以提高個人專業度，甚至去分享自己的所學和感想。\n結語\n好的 LinkedIn 帶你上天堂，順利通過履歷篩選後，可以參考這篇文章進一步的了解\n面試時該如何向面試官提問\n！社會新鮮人如果缺乏工作經 ...
#  {'title': '领英个人简历撰写指南：外贸专业人士必备(内含模板)',
#   'source': 'https://snovio.cn/blog/linkedin-summary-examples/',
#   'content': '在这个超过\n10亿\n用户的领英世界中，保持与您的领域和客户的高度相关性是一项挑战。然而，通过精心撰写的个人简介，您可以脱颖而出，吸引别人的注意。\n在本文中，我们将向你展示如何制作吸引人的领英简介。无论你是高管、应届毕业生还是正处于职业转型期，我们的领英简介模板和例子都能激励你提升个人资料形象并实现目标。\n大纲：\n什么是领英简介？\n领英个人资料简介的重要性\n打造卓越领英简介：Snov.io 专家指南\n制定有说服力的领英简介的 9 个技巧\nSnov.io 提供的领英简介模板\n学生领英简介\n应届毕业生的领英简介\nIT 专业人员的领英简介\n销售经理和销售代表的领英简介\n思想领袖和企业家的领英简介\n职业教练的领英简介\nSaaS 专家的领英简介\n你的高光时刻\n什么是领英简介？\n领英个人简介（也就是“About”的部分）是\n领英个人资料\n的一部分，\n概述了你的职业历程、技能和目标。它是您专业形象的橱窗，使你能够向潜在雇主、客户或合作伙伴展示你的独特价值和专业身份。\n资料来源：\nNeil Patel on LinkedIn\n领英个人资料简介的重要性\n一个精心构思的领英简介不仅是个人品牌的展示窗口，更是您在平台上吸引关注和建立联系的强大工具。一个出色的简介能够显著提升您在领英上的可见度，为您带来宝贵的职业机遇和人脉资源。\n领英简介如何助力您的职业推广？\n1. 给人留下难忘的第一印象\n2. 塑造你的个人或职业品牌\n3. 提升个人资料吸引力\n4. 建立你的专业形象\n5. 促进交流互动\n1. 给人留下难忘的第一印象\n个人简介部分通常是人们访问你的资料页面时首先看到的内容。撰写一份吸引人的领英个人简介会给人留下持久的积极印象，推动他人与你建立联系。\n2. 塑造你的个人或职业品牌\n通过个人简介，您可以突出自己的独特优势和专业技能，吸引志同道合的联系人。\n3. 提升个人资料吸引力\n在个人资料中巧妙运用关键词，可以提高在领英搜索中的排名，增加被招聘人员、潜在客户和业务伙伴发现的机会。\n从领英个人资料页面里获取邮箱\n通过 Snov.io 领英客户开发工具，找到高质量的潜在客户\n免费试用\n4. 建立你的专业形象\n您的个人简介是展示专业成就、建立领域专家地位的有效平台。分享您的经验和见解，与潜在联系人建立信任，让自己在竞争中突出。\n来源 tenor\n5. 促进交流互动\n通过添加明确的号召性用语，您可以鼓励访问者与您就合作、工作机会或其他事宜进行对话，进一步增强您在领英上的影响力。\n利用 Snov.io 在领英上搭建你的人脉网络\n帮你安全轻松地收集包含联系人邮箱的领英用户列表\n现在就试用“领英客户开发工具”扩展程序\n打造卓越领英简介：Snov.io 专家指南\n想要在领英上留下深刻印象并提升互动吗？我们专家团队精心策划的建议将助您一臂之力。以下是创建一个吸引人的领英个人简介的关键要素，随时可以应用，让您的个人资料焕发光彩！\n如何撰写领英个人资料简介：\n☑️\xa0结构\n☑️ 强有力的开场白\n☑️ 价值观和目标\n☑️ 专业知识\n☑️ 特殊技能\n☑️ 数据和可衡量的结果\n☑️ 你目前的状态\n☑️ 专业兴趣\n☑️ 号召性用语和联系信息\n结构\n让文本简洁易读非常重要。意味着可以使用直白的语言和清晰的格式。例如：\n专业身份：\n定义你当前的角色或专业领域。\n成就和背景：\n突出你的主要成就和相关技能。\n职业目标：\n概述你的职业抱负。\n个人风格：\n添加一句话来反映你的软技能和价值观。\n号召行动：\n最后邀请大家建立联系和/或寻求机会。\n强有力的开场白\n从一开始\n就吸引观众的注意力\n。用一个强有力的开场白开始你的个人 简介，这个开场白要引人入胜，并且能够反映你的专业能力。以下是一些可以尝试的策略：\n大胆陈述：\n以一句引人入胜的话作为开场，体现你的专业价值观或重大成就。例如，\n“将复杂的挑战转化为创新的解决方案是我 10 年 IT 职业生涯的标志。”\n提示：\n使用一个能引起思考的问题或相关引言来反映你的职业道德或专业理念。例如，\n“你如何化挫折为东山再起？对我来说，关键在于坚持和学习。”\n叙述：\n以简短、有趣的方式开始，介绍你的职业生涯或影响你职业生涯的关键时刻。例如，\n“站在科技和教育的十字路口，我意识到我的使命是将两者结合起来。”\n统计数据或事实：\n利用与你所在领域相关的数据来吸引注意力并建立你的知识。例如，\n“90% 的企业没有有效利用数据。我的使命就是改变这一统计数据。”\n请记住，开场白的目的不仅是吸引读者的眼球，也是为了顺利过渡到简介的其余部分，为你的职业故事奠定基础。\n价值观和目标\n领英的个人简介部分应展示你的热情和动力。务必确保塑造你职业道路的核心价值观和经验，并解释这些元素如何在你当前的职位中融合在一起。\n专业知识\n为了建立信誉并\n吸引合适的联系人\n，请突出你的经验、具体角色、项目和你克服的挑战。\n分享你获得的独特知识和见解，并提及任何显著的成就或认可来增加可信度。最后，表达你对持续学习和发展的承诺，将自己定位为具有前瞻性思维的专业人士。\n特殊技能\n在撰写领英个人资料简介时，请强调你独特的优势和能力，这些优势和能力可直接应用于你的行业。提供具体例子和可衡量的成就，突出你与众不同的技能。\n此外，还要考虑目标受众的喜好和兴趣。根据潜在雇主、客户或合作者认为有价值的内容来定制你的技能。\n数据和可衡量的结果\n提供支持你成就的信息，以证明你的专业知识和可信度。包括清晰说明你角色的影响和有效的数据。因此，在讨论你的成就时，请务必包括数字、百分比等。\n你想更快找到更多的潜在客户线索吗？\nSnov.io 为你配备了全套潜在客户线索查找工具箱，可以从几乎所有线上的渠道来帮你搜罗客户。\n立即免费试用\n你目前的状态\n在你的领英个人简介中写关于你当前状态的信息（例如“招聘中”、“愿意工作”等）是明智的决定，因为它展示了你当前的目标，向查看者表明你的合作意愿。\n例如，如果你的状态是“招聘中”，请强调你正在\n寻找的具体职位或技能，并鼓励感兴趣的候选人\n与你联系或发起申请。\n专业兴趣\n讨论你所在领域中让你感到兴奋的部分、你正在积极学习的任何特定主题或你正在关注的趋势。这不仅可以为你的个人资料增加深度，还可以帮助你与志同道合的专业人士和潜在合作者建立联系。\n号召性用语和联系信息\n在你的领英个人简介中添加号召性用语（CTA）是鼓励观众参与的一种战略方法。它应该清晰、有吸引力且与你的职业目标相符。\n至于联系信息，它可以让感兴趣的人轻松联系到你。一定要指定联系你的最佳方式，无论是通过\n领英消息\n还是邮件等。\n几分钟内就有新的业务找上门！\n用 Snov.io 从领英、谷歌和企业官网中查找验证有效的邮箱\n去免费试用一下\n制定有说服力的领英简介的 9 个技巧\n这部分内容旨在帮助你在领英个人资料简介中有效地传达你的专业故事，并在平台上留下持久的印象。\n如何撰写领英简介：\n1. 字数控制在 1,000 个字符以内\n2. 添加 SEO 关键词\n3. 使用空白\n4. 以第一人称写作\n5. 关注“你”\n6. 展示你的个性\n7. 使用对话语气\n8. 说明你的“为什么”\n9 明确陈述你的目标\n1. 字数控制在 1,000 个字符以内\n我们建议将领英个人简介限制在 1,000 个字符（约 150-200 个单词）以内。简短的描述更有可能吸引读者的注意力，让每个字都成为塑造你的职业故事的关键。\n2.添加SEO关键词\n整合与你的行业和职位相关的\nSEO 关键字\n。这可以提高你的领英个人资料在搜索结果中的可见性，让你与合适的机会和人脉网络建立联系。选择潜在雇主或合作者在搜索你所在领域的专业人士时可能会使用的关键词。\n3.使用空格\n正如我们上面提到的，结构是关键，因此请充分利用空白来提高可读性。通过将大段文字分成小段、使用项目符号或创建单独的部分，可以让读者更轻松地浏览和理解。\n4. 用第一人称写作\n使用“我”有助于与读者建立直接联系，让你的个人资料看起来更像是一场对话，而不是一份正式文件。这种风格可以有效地使你的职业故事更人性化。\n5. 关注“你”\n将重点转移到如何让读者受益，无论是潜在雇主、客户还是同事。这种方法表明你了解他们的需求，以及你的技能如何满足这些需求。\n利用AI帮你生成有吸引力的邮件内容\n使用 Snov.io AI邮件撰写工具\n立刻试用\n6. 展现你的个性\n在领英简介中展现你的个性会让你更令人印象深刻。分享你的热情、兴趣或独特观点。这种个人风格将使你与众不同，并与你的受众建立更紧密的联系。\n7. 使用对话语气\n这可以帮助你与读者建立联系，使你的个人资料看起来更加真实可信。如果你从事创意行业，这种方法会很有帮助。\n8. 展示你的“为什么”\n解释职业选择背后的动机可以为你的领英简介增添深度。它可以帮助其他人了解你的职业驱动力和你的立场。\n9. 陈述你的目标\n明确你在寻求什么（工作机会、人脉或合作），可以让你的领英个人资料简介更有效。͏\n想要更多客户？更多订单？更多收入？\n如果你的目标是扩大业务规模，Snov.io 的销售工具箱和 CRM 平台将帮你实现增长\n免费注册使用\n既然您已经掌握了打造难忘领英简介的精髓，现在是时候将这些知识转化为实际行动了。\n看看下面领英个人资料的例子，它们有什么优点？如果是你，你会再 ...
#  {'title': '10个最大化影响力的LinkedIn简介模板 - pipl.ai',
#   'source': 'https://resources.pipl.ai/zh/linkedin-summary-examples/',
#   'content': '撰写引人注目的 LinkedIn 摘要：完整指南 跳至内容 博客 登录 注册 Choose a language   实用见解 10个最大化影响力的LinkedIn简介模板 Yaro 2024年7月22日 10个最大化影响力的LinkedIn简介模板 LinkedIn简介是一个简短的描述，讲述了你的职业生涯、技能和目标。它出现在你的个人资料顶部，快速概述了你的职业身份。这部分不仅仅是成就列表；它是你向招聘人员、招聘经理和其他专业人士介绍自己的机会。 为什么它很重要 拥有强大的LinkedIn简介可以显著影响他人对你的在线印象。以下是一些原因： 吸引注意：精心制作的简介可以吸引招聘人员的注意，使他们想了解更多关于你的信息。 脱颖而出：通过突出你的独特之处，你可以在查看你个人资料的人心中留下深刻印象。 展示你的专业知识：你的简介是展示你在领域中的知识和技能的机会。 但是，写出有效的LinkedIn简介不仅仅是了解其重要性。要真正产生影响，你需要理解某些对于职业成功至关重要的概念： 买家行为：了解潜在客户或顾客如何做出决策，可以帮助你调整简介以吸引他们。 销售绩效管理 (SPM)：了解如何推动销售并在行业中保持领导地位是需要包括的重要信息。 市场情报：展示你了解行业趋势和竞争对手分析，表明你具有战略思维。 无论你是在寻找销售机会还是试图建立个人品牌，将这些理念融入你的LinkedIn简介中可以极大地提升你的职业形象。通过与最佳实践对齐并突出相关专业知识，你将自己定位为潜在雇主、客户或合作者的宝贵资产。 所以，不要错过给人留下深刻第一印象的机会。利用你的LinkedIn简介展示你是谁以及你能带来什么。 打造有效的LinkedIn简介：分步指南 创建一个能够吸引注意并留下持久印象的LinkedIn简介至关重要。本节将分解强大简介的组成部分，提供结构和撰写每个部分的实用技巧。 成功LinkedIn简介的关键元素 一个强大的LinkedIn“关于”部分必须包括： 强有力的开头 展示你的独特价值主张 讲述你的故事 格式和风格 长度和可读性 灵感示例 1. 强有力的开头 从一开始就吸引注意至关重要。考虑以下策略来实现这一点： 大胆声明：“通过创新的SaaS解决方案改变企业。” 引人入胜的问题：“你是否曾想过数据驱动的潜在客户生成如何改变你的营销策略？” 一个有效的开头设定了基调并引发好奇心，鼓励读者继续阅读。 2. 展示你的独特价值主张 突出你的优势、技能和经验，使你与众不同。结合相关的SEO关键词以提高可见性： 核心价值观：热情、诚信、创新 主要成就：“通过有针对性的营销活动，第三季度销售额增加了40%。” 这一部分应反映出你在领域中的独特之处。使用具体示例和指标来展示你的价值。 3. 讲述你的故事 打造引人入胜的叙述与观众建立情感联系。包括职业背景和个人兴趣： 职业背景： “我在云计算领域有超过10年的经验，专注于开发可扩展的SaaS产品。” 个人兴趣： “除了工作外，我喜欢徒步旅行和探索AI集成的新技术。” 结合这些元素使你的个人资料更具人性化，令人感到亲切和引人入胜。 4. 格式和风格 使用项目符号或段落有效地组织内容，同时保持专业但亲切的语气： 使用项目符号以提高清晰度 保持段落简短 使用标题/副标题以便于导航 适当的格式确保可读性，并保持读者兴趣。 5. 长度和可读性 理想的简介应在1000字符以内。保持简洁可扫描的技巧： 利用空白 避免行话 用第一人称写作 关注读者的利益 展示个性 这些做法提高了可读性，确保你的信息清晰且有影响力。 6. 灵感示例 各行业的精选示例可以为你的写作过程提供灵感： 销售经理示例： “在销售管理领域拥有超过15年的经验，我专注于通过战略规划和关系建立推动收入增长。我的能力在于实现可衡量的结果，一直超额完成30%的目标。目前，我带领着一个充满活力的团队在[公司]，我们致力于不断创新我们的市场方法。” IT专业人员示例： “经验丰富的IT专业人员，精通包括Python、JavaScript和SQL在内的多种编程语言。擅长解决问题，拥有优化系统性能高达50%的成功记录。热衷于保持最新的技术趋势，如数据安全和AI集成。” 欲了解更多为不同职业或职业阶段量身定制简介的灵感，请访问资源，如pipl.ai的受限内容词汇表或数据驱动的潜在客户生成。 根据不同目标定制你的LinkedIn简介 LinkedIn简介并非一刀切。将你的简介与职业阶段和目标对齐可以显著增强其影响力。以下是为各种专业人士设计的特定模板： 1. 应届毕业生 _应届毕业生通常在没有实质性工作经验的情况下编写LinkedIn简介时会遇到困难。_通过突出学术成就、可转移技能和职业抱负可以弥补这一差距。 模板： 作为[你的专业]专业的[你的大学]毕业生，我在[技能1]、[技能2]和[技能3]方面磨练了我的能力。我的学术旅程以[具体成就或项目]为标志，这使我在[相关领域]有了坚实的基础。我对[行业/领域]充满热情，渴望在进入职场的过程中应用我的知识。目前，我正在寻找[期望的角色/行业]的机会，在那里我可以为创新项目做出贡献并继续学习。 2. 职业转换者 转行需要一个展示相关经验、对新行业的热情和适应能力的简介。 模板： 拥有在[以前的领域]的丰富背景，我正在转型到[新领域]，因为我对[新领域的特定方面]充满热情。我的以前的经验包括[突出相关经验或技能]，这使我具备了[技能1]和[技能2]等可转移的技能。在此转型过程中，我进行了[新技能或认证]的额外培训，使我能够在新角色中产生有意义的影响。我对可以利用我多样背景并为前瞻性组织的成功做出贡献的机会感到兴奋。 3. IT专业人员 IT专业人员需要强调技术专长、特定编程语言和成功项目。 模板： 作为一名专注于[特定领域]的经验丰富的IT专业人员，我在使用[技术1]、[技术2]和[技术3]等技术开发可扩展解决方案方面拥有超过[X年]的专业知识。我的作品集包括成功的项目，如[项目名称/描述]，我带领团队交付了一个增强用户体验的强大应用程序，提升了[%改进]。热衷于持续学习，我一直在探索AI集成和数据安全等前沿趋势。如果你在寻找一个在技术与创新交汇处茁壮成长的人，让我们联系吧。 4. 商业专家 商业专家应通过现实世界的例子突出分析和人际交往的优势。 模板： 在商业分析和战略方面有着良好记录，我擅长识别增长机会并实施数据驱动的解决方案。在[前公司]，我带头的举措通过有效的市场分析和跨职能协作使收入增长了[%增加]。我能够清晰地传达复杂的想法，这对推动团队成功和培养客户关系至关重要。我正在寻找能够挑战我分析能力并允许我与多元化团队密切合作以实现战略目标的角色。 5. 销售经理/代表 作为一名拥有超过[X年]经验的资深销售经理，我通过利用强大的客户关系和说服力沟通技巧，始终超越目标。在[前公司]，通过实施有针对性的外展策略，我的努力在一年内使销售额增加了[%增加]。我的方法结合了数据驱动的见解和个性化的客户参与。 作为[你的专业]专业的[你的大学]毕业生，我在[技能1]、[技能2]和[技能3]方面磨练了我的能力。我的学术旅程以[具体成就或项目]为标志，这使我在[相关领域]有了坚实的基础。我对[行业/领域]充满热情，渴望在进入职场的过程中应用我的知识。目前，我正在寻找[期望的角色/行业]的机会，在那里我可以为创新项目做出贡献并继续学习。 拥有在[以前的领域]的丰富背景，我正在转型到[新领域]，因为我对[新领域的特定方面]充满热情。我的以前的经验包括[突出相关经验或技能]，这使我具备了[技能1]和[技能2]等可转移的技能。在此转型过程中，我进行了[新技能或认证]的额外培训，使我能够在新角色中产生有意义的影响。我对可以利用我多样背景并为前瞻性组织的成功做出贡献的机会感到兴奋。 作为一名专注于[特定领域]的经验丰富的IT专业人员，我在使用[技术1]、[技术2]和[技术3]等技术开发可扩展解决方案方面拥有超过[X年]的专业知识。我的作品集包括成功的项目，如[项目名称/描述]，我带领团队交付了一个增强用户体验的强大应用程序，提升了[%改进]。热衷于持续学习，我一直在探索AI集成和数据安全等前沿趋势。如果你在寻找一个在技术与创新交汇处茁壮成长的人，让我们联系吧。 在商业分析和战略方面有着良好记录，我擅长识别增长机会并实施数据驱动的解决方案。在[前公司]，我带头的举措通过有效的市场分析和跨职能协作使收入增长了[%增加]。我能够清晰地传达复杂的想法，这对推动团队成功和培养客户关系至关重要。我正在寻找能够挑战我分析能力并允许我与多元化团队密切合作以实现战略目标的角色。 作为一名拥有超过[X年]经验的资深销售经理，我通过利用强大的客户关系和说服力沟通技巧，始终超越目标。在[前公司]，通过实施有针对性的外展策略，我的努力在一年内使销售额增加了[%增加]。我的方法结合了数据驱动的见解和个性化的客户参与。 +14154948838 support@pipl.ai © 保留所有权利。版权所有 © 2024 Pipl Software Inc。'},
#  {'title': '在LinkedIn 發表之文章或電子報的SEO 設定',
#   'source': 'https://www.linkedin.com/help/linkedin/answer/a6272792?lang=zh-TW',
#   'content': '在 LinkedIn 發表之文章或電子報的 SEO 設定\n更新日期：4 個月前\n您可以針對您在 LinkedIn 發表之文章或電子報的標題和描述自訂搜尋引擎最佳化 (SEO)，控制它們在搜尋引擎上的顯示方式，並使其他人更容易找到您的內容。\n從 LinkedIn 出版平台的 SEO 設定中，您可以新增：\nSEO 標題\n：新增\nSEO 標題\n，我們將用其來代替搜尋引擎結果頁面（例如 Google 搜尋）的文章標題。如果您的 SEO 標題超過 60 個字元，它將被截斷。\nSEO 描述\n：在搜尋引擎結果頁面上新增\nSEO 描述\n來代替文章的前幾行。我們建議使用關鍵字，總結您的寫作，並旨在編寫 140-160 個字元。\n相關任務\n在 LinkedIn 發佈文章\n管理 LinkedIn 電子報\n深入瞭解\n貼文、文章、轉發和電子報之間的區別\n此資訊有一部分已進行機器翻譯。請為翻譯內容和問題實用性評分，協助我們改善服務品質。\n主題標籤：\n建立者核心'},
#  {'title': '整合行銷必學的5個SEO技巧，讓你的網站在搜尋結果中搶眼有招！',
#   'source': 'https://cybermkt.com.tw/marketing/integrated-marketing-5-seo-tips/',
#   'content': 'SEO技巧在整合行銷中扮演著重要的角色。首先，您需要進行關鍵字研究，找到與您品牌和產品相關的熱門關鍵詞。接著，優化您的網站內容，包括標題、描述、標籤等，以便搜尋引擎更'},
#  {'title': '6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！',
#   'source': 'https://jason-career.com/linkedin/?srsltid=AfmBOop6ovJB80lYFtG61fQKsPuM54m3FZAvs6ljejWiuS82oM6BmzFy',
#   'content': '最後更新時間： 2025 年 01 月 18 日\n「具專業感的 LinkedIn 主頁竟然讓我收到 HR 主動發的面試邀約？！」\n擁有一個專業的 Profile 會提供人們一個額外了解你的機會，不只在求職和 Networking 過程中幫到你，也能在申請海外 MBA 的過程中增加錄取機會，甚至能收到 HR 的主動聯繫！\n這篇文章想分享 Networking 和申請哥大 MBA 時，LinkedIn 是如何幫助到我的！我自己在申請 MBA 或其他碩士項目時，部分學校有提供欄位讓申請人填寫 LinkedIn 領英網址。\n不管是主動在簡歷附上 LinkedIn URL，或是公司 HR、大學招生官在搜尋個人的 LinkedIn，正確且專業的使用 LinkedIn 會提供一個額外向他人展示個人品牌的機會。\n由於 LinkedIn 是偏向專業的社交媒體平台，所以在 LinkedIn 上建立一個專業的個人品牌，展示自身經歷、價值觀和興趣是至關重要的！\n內容目錄\nToggle\n事前準備\n關閉檔案更新通知\n在開始對 LinkedIn 個人資料進行修改之前，請確保你的 Network 不被打擾。\n請點擊「我」\n→\n設置和隱私\n→\n公開度\n→\n將檔案更新分享到人脈網【關閉】 設置個人專屬的 URL\n設置個人專屬的 URL\nLinkedIn 提供修改主頁 URL 的機會，這展示了對細節的關注，是一個區別於其他 LinkedIn 資料和候選人的標誌。若沒有修改的話，預設會是一串字母跟數字組成的亂碼。\n修改方式：個人主頁\n→\n右上角的方框內「編輯公開檔案和網址」\n→\n編輯自訂網址，將 URL 改為盡可能接近你的名字（羅馬拼音或英文名＋姓氏）。\n開始動工，翻修個人主頁 LinkedIn Profile\n撰寫吸引人的標題與個人摘要\n為什麼重要？標題與摘要是 HR 和其他用戶最先看到的內容，它們會直接影響他們是否有興趣繼續瀏覽下去你的 Profile。\n如何做？\n標題\n：除了職位名稱，加入你的專長與價值，例如：「數據分析師｜精通 Python、SQL｜專注於商業洞察」。\n摘要\n：用 2-3 段簡單明瞭的語言，概述你的職業背景、成就和未來目標。可以用故事化的方式呈現，讓人讀起來更有吸引力。\n範例摘要\n：\n我是一名具備 5 年經驗的數據分析師，擅長運用數據解決商業問題，幫助企業提升營收。我精通 Python 和 SQL，並在過去一年中完成了 3 項提升效率的專案，為公司節省 20% 的營運成本。目前，我希望透過數據驅動的洞察，助力更多企業成長。\n專業的個人頭像照片\nLinkedIn\n是一個專業的平台，個人資料必須有一張專業的頭貼，而不是集體照或生活照；個人建議是不要使用證件照（例如：身分證或護照大頭貼），會顯得有些突兀。根據網路上不可靠資料，有附帶照片的檔案被查看機率是沒有照片的數十倍。下面是我整理有關 LinkedIn 照片的一些 ”Do’s” 和 “Don’t”。\n最推薦的樣式是：一個人(only YOU) + 微笑，清楚、近期、背景單純。\n更進階的 tips 是可以嘗試符合產業⾵格，與你平常⼯作模樣相近的打扮。\n⭕ Do’s\n❌ Don’t\n近距離拍攝\n正裝照\n近期照片\n聘請專業攝影師（非必須）\n自拍\n團體照\n過時的照片\n其他的人/動物/動畫/虛擬頭像\n奇怪的背景\n背景圖片/封面\n選擇一個最能代表你的形象，比較常見的圖片可以是演講照片、志工服務、社團活動等等。也可⽤\nCanva\n設計自己的單色背景圖⽚，展現你的特質和專業領域。\n簡單來說，第一印象很關鍵！專業的頭像可以讓人覺得你值得信賴，而背景照片則是展示個人品牌的絕佳機會：\n頭像\n：選用清晰、自然且帶有微笑的照片，背景簡單乾淨，建議穿著符合職業形象的衣服。\n背景照片\n：選擇與你的行業或專業相關的圖片，例如公司活動、技術插畫，或自訂一張帶有你的個人標語的設計。\n注意\n：避免使用過度修圖或自拍照，這可能給人不專業的印象。\n關於（自我介紹）\n寫一篇令人過目不忘的自我介紹，嘗試突出你的專業、職業經驗、榮譽和領導能力。寫下你職業生涯中最相關的成就，避免使用艱澀難懂的行話 (Jargon)。把重點集中在前幾行，寫作方式可以參考 Elevator pitch，以第⼀⼈稱⾃我介紹：特質、熱忱、價值觀、近期⽬標、個人背景如何成就了現在的你。\n注意：不要混淆關於 About 和工作經歷 Experience，About 是總結、Experience 部分應該寫得更詳盡。\n我出版了三本電子書！分別是：\nSOP、CV、英文面試\n，每本都\n超高 CP 值、乾貨滿滿、銷售破百本\n，持續更新增補內容，陪伴大家走過留學＆求職！\n當你看到這邊，恭喜你獲得讀者專屬優惠碼！\n輸入優惠碼：BLOG100，\n每本電子書都折 $100\n，三本一起購買就可以折 $300！\n👉🏻\n點擊這裡\n一次搞懂申請需要的資源、撇步和知識吧！用傳統代辦 3% 不到的價格，獲得 300+% 價值\n工作經歷摘要\n這個區塊並非是讓人直接將簡歷複製上來，也不是 Job Description，而應該是量化地描述成就和工作的總結。此外，雖然只需要包括工作中最關鍵的方面，但不⽤像履歷那樣只有幾個 Bullet Point。可以考慮用「說故事」的方式，或是擬一個小段落，甚至可以上傳媒體、放上作品、網⾴等。\n教育背景\n列出你的畢業學校、系所、排名、GPA（建議如果大於 3.5 可以放上），也可以放上修過的課程等等。甚至，你也可以在上面描述你做的研究（例如，畢業論文、Research Project），以及你在大學期間參與過的社團活動。\n其他區塊\n【資格認證】列出與你的⽬標領域⾼度相關的項⽬即可，太多⼜雜反⽽失去焦點。\n【志願服務】將社區服務經驗寫上去可以讓人認識你專業方面以外的貢獻與付出。\n【精選 Featured】領英的 Featured 一欄提供了展示自己的空間，你可以在這裡放上你取得的工作成就和成果，或是置頂一些你之前發布過的文章。如果 Profile 全都是文字的話會顯得單調，放上一些精選可以補充一些媒體，讓你的形象更立體。\n成為領英 LinkedIn 大師，進階 Tips 秒變專業\n下面還有整理一些更進階的經營 Tips，讓大家成為領英大師，熟稔操作並增加曝光。\n客製化邀請\n訊息\n在你持續建立 Connection 時，可以使用更加個性化的好友邀請訊息，提及您與他們的共同興趣、參加的共同活動或學校或共同朋友等等。通常發送默認消息的好友通過率不高，並且其他人還需要點進你的頁面後回想他是否認識你。\n打招呼＆自我介紹＆說明目的，先揭露你自己、別人才會更願意揭露他自己！\n保持更新\n在畢業、找到新工作、完成專案、被學校錄取等各種時機，都可以發 post 跟大家分享好消息，並且分享自己的心得跟表達感謝。工作經歷等檔案也記得定期更新。LinkedIn 的 post 提供了另一種方式來提升您的影響力，並且讓他人了解你感興趣的領域，通過發布有影響力的內容來突出您的專業知識和興趣，並且積累更多相似興趣、想法的人脈。\n分享專業內容、心得感想、職場體悟，建立個人品牌\n主動分享高價值的內容，不僅能展現你的專業能力，還能提高你的主頁曝光率。\n分享文章\n：針對行業趨勢、案例分析或職場技能分享你的見解。\n撰寫文章\n：發布你的專業洞察，例如「如何用數據驅動業務增長」。\n參與討論\n：在別人的文章或貼文下發表有深度的評論，增加你的能見度。\n注意\n：保持內容專業且相關，不要過於頻繁地發布私人內容。\n頭銜\n可以用頭銜來突出你目前的職位和公司（例如：CB 公司的營運長）、突出您的專業知識或獎項，或展示技能（例如：分析師、講師、顧問）。\n位置和行業\n這兩個簡單的設置將幫助更多的人找到你，並幫助你找到更多相關的潛在 Connection。\n添加新區塊\nLinkedIn 允許添加多個部分，您可以添加志願服務、語言能力、榮譽和獎項、專利、學術期刊發布等部分。\n一致性\n如果整個領英 Profile 的內容高度一致且有深度，會更加有利於他人認識你。在語言使用上也需要注意，領英編輯時可以同時編輯中文和英文檔案，在編輯英文檔案時須注意公司名稱等欄位是否也變更成英文。\n在用領英做 Connection 時，歡迎參考這篇文章 👉🏻 教你如何\n問對問題脫穎而出，展現主動性！這些秘訣助你在留學和職場大放異彩！\n針對以上訣竅，該如何寫出自己專屬的 Profile 呢？\n學習行業前輩\n各個行業都有資深人士，可以查看並學習他們的 LinkedIn 個人頁面寫法，但是注意不要抄襲。個人建議可以多多查看英文母語使用者的 Profile，他們在用詞的架構跟精確度上都會比較好。\n用詞精確\n盡量避免過度使用太 General 的關鍵詞，應該適時加入精準的關鍵詞（職稱、產品、程式語言技能等），讓公司 HR 在搜尋時可以更清楚的了解你過往的經歷與能力。\n避免廣告\n發文時盡量不要大篇幅描述產品或者公司業務，在西方視角中，這類型的廣告用個人頁面發出並不恰當。可以嘗試具體化自己的行業經驗和專業技能，以及自己曾經涉及到的項目經驗，以提高個人專業度，甚至去分享自己的所學和感想。\n結語\n好的 LinkedIn 帶你上天堂，順利通過履歷篩選後，可以參考這篇文章進一步的了解\n面試時該如何向面試官提問\n！社會新鮮人如果缺乏工作經 ...
#  {'title': 'LinkedIn新手必學！5招提升你的個人檔案能見度',
#   'source': 'https://vocus.cc/article/676ad0b0fd89780001a115d9',
#   'content': '首頁\n💡職涯發展\n💡求職技巧\n💡職場互動\n💡關於三樓\n💡人資專業分享\n關於\nLinkedIn新手必學！5招提升你的個人檔案能見度\n3F Career三樓職涯\n發佈於\n💡求職技巧\n追蹤\n更新於\n2024/12/24\n發佈於\n2024/12/24\n閱讀時間約\n4\n分鐘\n想起之前曾經分享過「\n找工作除了人力銀行，還有哪些管道？\n」，文章中有提到要多運用網路及社群媒體的力量，加上以前也算是蠻常鼓勵大家可以多使用LinkedIn這個平台，不一定非得等到要找工作才來使用，透過平時使用逐步累積個人品牌，在平台上和領域專家進行更多交流，相信也都能讓你獲得不同視野，擴大你的人脈連結，說不定哪天就因為這樣還能幫你找到工作。所以今天就想來跟大家聊聊，如何提高你的LinkedIn個人檔案能見度，讓你有更多被看見的可能。\n\U000e0020\n即便坊間已經有不少專業課程或文章分享，不過今天的文章主要是想從過去個人經驗分享，提供給一些剛開始使用，或是想要開始嘗試建立個人檔案的樓友們參考。\n\U000e0020\n▌優化你的個人檔案\n完整填寫你的個人資料，包括個人亮點簡介(尤其是關於/About欄位真的很重要)、工作經歷與成果、教育背景、個人技能和專業證書等。可以把個人檔案就想成是一份自己的公開履歷，當你的資料越完整，就越有機會讓更多專業人士、人資、主管、獵頭看見你。\n\U000e0020\n▌積極參與建立關係\n在LinkedIn上要提高能見度與個人影響力，主動和別人建立關係也是很重要的一環，讓你不僅可以跟同業和相關領域的專業人士建立聯繫，對他人的內容和分享給予回饋、按讚和轉發，也都能建立良好的互動關係。\n不過這邊也要提醒大家，要送出「建立關係(connect)」邀請前，別忘了先完善自己的個人檔案，讓對方有機會認識了解你。如果能在送出邀請時附上說明為什麼想建立關係的訊息，也會提高對方接受的意願。\n\U000e0020\n▌主動更新分享你的狀態和活動\n定期更新個人狀態，分享工作心得和成就、參與的活動紀錄、獲得的獎項或認證、完成的培訓等等，保持個人檔案的活躍度也都會有助於提高你在LinkedIn的能見度，有時候在分享現職工作相關的內容時，無形之中除了建立個人品牌之外，如果是正面的內容，也有機會為自己任職的公司提升雇主品牌形象。\n\U000e0020\n▌活躍參與互動和分享內容\n定期發布和分享具有價值的內容，包含最新趨勢、專業見解、個人觀點等，也有助於吸引更多的關注和互動。\n另外LinkedIn上也不乏有許多專業群組和討論，無論是分享個人專業見解和意見，或是和他人的內容進行互動、留言、按讚、轉發等等，都有助於和專業人士甚至是KOL(關鍵意見領袖)們建立良好的專業互動關係，有助於拓展個人職業網絡。\n\U000e0020\n▌使用相關領域的關鍵字和標籤\n在發布的內容中標註和專業領域相關的關鍵字/標籤(hashtag)，因為LinkedIn上除了關注個人、關注公司、參與社團以外，也可以關注追蹤特定標籤關鍵字，所以運用這個技巧，有機會可以讓你的內容更容易被目標受眾看到、找到，提高你個人發布的內容和個人檔案的能見度和搜索排名，尤其是當你的個人檔案有開放在LinkedIn站外被搜索的情況下。(可在設定>公開度>個人檔案在LinkedIn站外的搜索和公開度中進行設定)\n\U000e0020\n希望今天分享的這些實用技巧，可以幫助大家更容易地開始並習慣使用LinkedIn這個專業社群平台，有效地提高在LinkedIn上的能見度，不僅拓個人的職業影響力，建立更廣泛的人脈，更有機會在職涯路上成為你的助力。\n如果想知道自己目前的LinkedIn競爭力 Social Selling Index (SSI)分數，可點選網址查看：\nhttps://business.linkedin.com/sales-solutions/social-selling/the-social-selling-index-ssi\n\U000e0020\n🌿在求職轉職的旅程中，三樓職涯都在這裡，陪伴你走過每一步。如果有任何關於職涯的困擾需要找人聊聊，也歡迎填寫1對1諮詢預約表單，邀你一起來三樓坐坐。\n👉 立即預約1對1職涯諮詢：\nhttps://bit.ly/45UcGh0\n#\nLinkedIn\n#\n履歷\n#\n能見度\n#\n影響力\n#\n職場\n#\n轉職\n#\n求職\n3F Career 三樓職涯 諮．尋．適\n💡求職技巧\n求職資源\n3F Career 三樓職涯 諮．尋．適\n24\n會員\n109\n內容數\n加入\n前往沙龍\n3F代表Facilitate • Find • Fit | 諮・尋・適\n透過諮詢協助你探尋適合的職涯道路，\n在職涯更上一層樓，邀你一起上樓聊聊。\n歡迎預約1對1職涯諮詢，我們將依據您的需求，提供職涯探索/轉職規劃/履歷優化/面試模擬等服務。\n加入\n前往沙龍\n留言\n留言分享你的想法！\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n\u200c\n3F Career 三樓職涯 諮．尋．適\n的其他內容\n找工作除了人力銀行，還有哪些管道？\n在找工作的過程中，除了人力銀行還能怎麼找理想職缺？從善用社群媒體拓展人脈，到參加專業活動與研究企業網站，再到與獵頭合作或使用政府資源，這篇文章將帶你掌握多元求職管道，提升成功率！\n#\n轉職\n#\n求職\n#\nLinkedIn\n2\n0\n選擇合適獵人頭顧問的要點\n隨著求職管道多元化，選擇合適的獵人頭顧問更顯重要。本文提供四個關鍵要點，幫助求職者評估獵人頭顧問的專業度、理解需求及建立信任。瞭解顧問的經驗、清晰陳述求職期待、注意顧問的回應態度及創建良好的夥伴關係，皆有助於找尋更符合的職涯機會。在求職過程中，良好的顧問關係將是你成功的關鍵。\n#\n顧問\n#\n求職\n1\n0\n除了主動投履歷，還能如何在求職市場中脫穎而出？\n求職不僅僅是投遞履歷，還有其他有效方法可以增加成功機率！建立人脈關係網絡，積極參與實習和競賽，打造個人品牌，以及持續提升技能，這些策略能幫助你在職場中獲得優勢。透過良好的人脈和豐富的經驗，讓自己成為僱主眼中的理想候選人。想要了解更多求職技巧嗎？\n#\n求職\n#\n轉職\n#\n履歷\n0\n0\n跟獵人頭合作的好處\n上一篇文章跟大家聊了如何跟獵人頭合作，透過限動也發現到原來有不少樓友還沒有跟獵頭合作的經驗，今天就來跟大家說說跟獵人頭合作有哪些好處，未來也可以當作你求職找工作的一個管道，多管齊下，隨時準備好，機會來了就可以好好把握。\n#\n獵頭\n#\n求職\n#\n轉職\n6\n0\n如何跟獵人頭開啟合作\n透過獵頭幫我找工作需要付費嗎？跟獵頭合作需要提供哪些資訊？應該和獵頭保持什麼樣的關係比較合適？要怎麼樣讓獵頭幫我找工作？\n如果你也有上述這些疑問，這篇文章有助於你可以快速了解你和獵頭/招募顧問的關係。\n#\n獵頭\n#\n招募\n#\n求職\n26\n0\n經營人脈存摺在職場上的重要性 - 實務做法\n本週我們分享了一些實用的人脈經營方法，包括深化專業連結、擴大弱連結、參與講座座談會和與合作廠商客戶持續聯繫。這些策略可以有效地幫助個人的人脈經營。\n#\n專業\n#\n人脈\n#\n經營\n4\n0\n找工作除了人力銀行，還有哪些管道？\n在找工作的過程中，除了人力銀行還能怎麼找理想職缺？從善用社群媒體拓展人脈，到參加專業活動與研究企業網站，再到與獵頭合作或使用政府資源，這篇文章將帶你掌握多元求職管道，提升成功率！\n#\n轉職\n#\n求職\n#\nLinkedIn\n2\n0\n選擇合適獵人頭顧問的要點\n隨著求職管道多元化，選擇合適的獵人頭顧問更顯重要。本文提供四個關鍵要點，幫助求職者評估獵人頭顧問的專業度、理解需求及建立信任。瞭解顧問的經驗、清晰陳述求職期待、注意顧問的回應態度及創建良好的夥伴關係，皆有助於找尋更符合的職涯機會。在求職過程中，良好的顧問關係將是你成功的關鍵。\n#\n顧問\n#\n求職\n1\n0\n除了主動投履歷，還能如何在求職市場中脫穎而出？\n求職不僅僅是投遞履歷，還有其他有效方法可以增加成功機率！建立人脈關係網絡，積極參與實習和競賽，打造個人品牌，以及持續提升技能，這些策略能幫助你在職場 ...
#  {'title': '如何高效利用LinkedIn领英拓展人脉？  实用技巧分享 - 淘宝百科',
#   'source': 'https://bk.taobao.com/k/lingying_702/c205405d9e7a5b49e02026361bd7004c.html',
#   'content': '加入行业相关的讨论，分享你的见解和经验。 不仅可以提高你的可见度，还能让你在同行中建立起专业形象。 别忘了点赞和回复他人的帖子，积极互动，让更多人注意'},
#  {'title': '如何在领英建立有效人脉 - LinkedIn',
#   'source': 'https://www.linkedin.com/pulse/%E5%A6%82%E4%BD%95%E5%9C%A8%E9%A2%86%E8%8B%B1%E5%BB%BA%E7%AB%8B%E6%9C%89%E6%95%88%E4%BA%BA%E8%84%89-%E9%A2%86%E8%8B%B1-%E7%8E%A9%E8%BD%AC',
#   'content': '日本企业家本田直之有一句“简单粗暴”的职场心得：“职场成功的道路上，人脉比知识更重要。”\n虽然他的话有夸大的成分，但确实有越来越多的职场人开始意识到“人脉”在个人职场发展上发挥的重要作用：职场前辈可以为你的职业规划建言献策，求职和跳槽时优秀的人脉资源可以帮你轻松内推拿offer，工作时有一个靠谱的职场朋友更可以让你事半功倍……\n那么，如何在领英平台建立有效人脉，并维护和利用好自己的职场人脉呢？快来查收这份“三步走”领英人脉宝典！👇\nStep 1:\xa0建立和筛选高质量人脉网络\n1.扩充你的人脉\n俗话说的好，巧妇难为无米之炊，如果连一定数量的Network都还没有建立，就更无从谈维护和利用有效人脉了。\n在领英，你可以通过各种方式扩充自己的人脉。举个例子来说，在管理人脉圈界面选择邮箱或通讯录选项，就可以自动同步你的手机和邮箱通讯录信息，为你一键推荐在领英活跃的朋友、同事和其他人脉。\n在此基础上，学会使用领英的各项推荐和搜索功能，也可以为你的人脉建设“添砖加瓦”。想要了解拓宽领英人脉的六大“宝藏渠道”，可以点击链接参考攻略《\n如何利用领英Networking找工作》\n2.筛选你的人脉\n有效人脉≠数量多的人脉，要学会辨别和筛选对自己的职业发展“有用”的人。\n在领英发送和浏览好友申请时，一定要先浏览其用户档案主页，根据所在地区、行业、就职公司、就读学校等信息，判断其是否属于自己感兴趣的人脉圈。此外，一个用户的文章和动态也是其职场能力和人脉圈的体现，在筛选自己的潜在人脉时可以特别关注。\nStep 2：让你的人脉了解你\n成功与感兴趣的人脉添加了好友，是不是就大功告成了？错！在领英建立有效人脉，最关键的是加好友后的跟进和经营，首先就是要让你的人脉了解你，加深自己在他们心中的印象。\n1.添加好友时自我介绍\n如何在提高好友邀请通过率的同时，再刷一波“存在感”？试试添加好友时选择“添加信息”并使用个性化邀请消息吧！你可以在300字以内简单介绍自己和加好友的原因。\n2.维护好自己的领英档案\n在领英，一个用户的档案就是ta的职场社交名片，记得随时更新自己的职位和状态，以便潜在人脉更好地了解你。想要更快捷有效地介绍自己的专长？记得编辑一段专业的个人简介吧！\n3.积极发布内容并参与话题讨论\n发布职场相关动态和文章，这不仅有利于建立人脉和展示个人职场形象，也是进一步塑造职场个人品牌的好机会。\n如果担心自己个人的文章内容曝光率不够，还可以点击“话题”功能，进入领英平台的话题广场，参与各种用户热议的话题，寻找志同道合的职场伙伴。\nStep 3：维持和经营你的有效人脉\n什么样的领英人脉最“有效”？领英用户\n@Nina Rong\n认为，是能够“保持友好并相互仰慕的关系”的人脉。如何维持你的有效人脉，并最大限度发挥人脉的作用呢？\n1.保持互动\n添加好友是第一步，只有当你和自己的人脉达成了良性互动，才算是建立了有效的Network。\n进行人脉互动的好时机：\n点赞或评论自己好友的动态和文章\n在好友的纪念日问候对方近况\n在看到相关领域的内容时“@”对方\n在好友职位变动的时候发表回应表示恭喜\n……\n这些互动也许只需要花费你几秒钟，但对人脉的维持却非常有效。\n2.互帮互助，合作共赢\n在职场，最优质的人脉资源，永远是双赢的。如果想要收获一份稳定而有效的人脉，一定要有“等价交换”的意识，在请求对方帮助的同时积极主动为对方提供价值。\n举个例子，很多领英用户会发布招聘职位等信息，如果你顺利通过领英人脉内推和介绍入职，一定要跟这位人脉follow up表示感谢，并在日后保持联系，能提供帮助或信息时主动“回报”ta的帮助。\n最后再为大家划个重点，在领英经营有效人脉是门学问，最重要的是三大步骤：\n一建立、二介绍、三维护\n。做好这三点，为自己未来职场进阶轻松积累优质人脉！\n下一篇，我们将聚焦领英的平台特点，为你介绍\n真名职场社交的优质bonus\n！详情请点击：\n【链接】\nLike\nComment\nCopy\nLinkedIn\nFacebook\nTwitter\nShare\n119\n14 Comments\n胡小东\n网媒 自媒体 双微 抖音 小红书等资源供应   微：18217003675\n3y\nReport this comment\n👍🏻\nLike\nReply\n1\xa0Reaction\nSee more comments\nTo view or add a comment,\nsign in\nMore articles by 玩转领英\n解锁领英实用技巧，定制属于你的职场社交体验\nSep 1, 2021\n解锁领英实用技巧，定制属于你的职场社交体验\n想看工作机会，如果被老板和同事发现怎么办？更新了自己的职业档案，但不想大张旗鼓的昭告天下怎么办？发布了一条动态信息，如何只能让自己的1度人脉看到？解锁领英实用技巧，通过账号设置和动态信息管理，这些问题都能由你来定。…\n53\n9 Comments\n基于真实身份的职场社交，与陌生人的距离由你决定\nSep 1, 2021\n基于真实身份的职场社交，与陌生人的距离由你决定\n实名社交和匿名社交的本质区别在哪里？举例来说，实名社交就像是一个沐浴在阳光中的广场，广场上的行为更清晰透明，人们彼此之间也可以更清楚的看到对方。尽管也存在阴影和角落，但也更容易被分辨和鉴别，你有更多机会对靠近你的“陌生人”和“骚扰行为”说不…\n71\n3 Comments\n带你揭秘超实用挖人小技巧\nAug 16, 2021\n带你揭秘超实用挖人小技巧\n猎头想要做的好，找到合适的候选人很重要！ 领英必备使用小技巧，快速锁定合适候选人！ 巧用“看过本页的会员还看了”功能 电脑端 - 点击会员头像 - 在页面右侧 手机端在页面最下方 熟悉领英的会员都知道：…\n53\n2 Comments\n使用Q&A快速获得经验分享\nDec 18, 2020\n使用Q&A快速获得经验分享\n工作中遇到的问题却只能小心翼翼“投石问路”？想入行某个领域但又不知如何迈开第一步？放心，在领英App「职场洞察」中的问答板块，你可以通过提问的方式探寻这些问题的答案。这个宝藏功能你还没有用过？我们整理了发布方法供你参考⬇️…\n16\n1 Comment\n领英上的华山论剑开始啦\nDec 18, 2020\n领英上的华山论剑开始啦\n👏👏👏领英PK功能内测中！快来体验>> 如果你最近发现，在使用领英App发布话题时，左下角出现了「PK」符号，恭喜你获得了领英新功能内测的机会！…\n23\n7 Comments\n如何打造优质公司主页\nNov 25, 2020\n如何打造优质公司主页\n职场中离不开部门和同事间的配合和协作，在管理你的领英主页时，也可以灵活运用各种管理经验，根据不同人员特点合理分配相关任务。…\n21\n1 Comment\n分析主页数据提升影响力\nNov 25, 2020\n分析主页数据提升影响力\n想要更好地规划和调整领英主页的传播策略，最基础的一步就是全面、深入地观察和分析主页现有的数据。只有通过数据充分了解了关注者和其他用户们的喜好、需求，才能更好地对症下药，提高在平台传播的效果。…\n25\n1 Comment\n如何提高公司主页关注度\nNov 25, 2020\n如何提高公司主页关注度\n在建立了领英主页的基础上，想要提高页面的影响力，吸引更多用户的关注，页面的内容更新是关键。 设想一下：同样的两个领英主页，一个充满了图文并茂的公司动态帖子，另一个除了公司名称外一片空白，作为求职者和客户，你是不是也会毫不犹豫地选择前者？…\n27\n17 Comments\n如何在领英创建公司主页\nNov 25, 2020\n如何在领英创建公司主页\n在领英，你不仅可以结交新的职场朋友和前辈，还有机会代表自己所在的公司或组织，在更广阔的平台上展示自己，提高影响力。 心动却不知如何行动？今天这篇攻略就带大家走进领英主页功能，手把手教你搭建自己公司、组织的专属界面！…\n91\n12 Comments\n四种高级账号怎么选\nNov 10, 2020\n四种高级账号怎么选\n经常使用领英平台助力自己的职场发展的用户可能已经注意到了，有一些领英用户的个人档案顶部右上角，会显示一个闪闪发光的金色领英图标，你知道这是什么吗？ 公布答案：这就是领英高级账号的身份徽章！…\n58\n27 Comments\nShow more\nSee all articles\nExplore topics\nSales\nMarketing\nIT Services\nBusiness Administration\nHR Management\nEngineering\nSoft Skills\nSee All'},
#  {'title': '誰說認識才能送邀請？如何運用LinkedIn Connections 拓展自己的 ...',
#   'source': 'https://medium.com/linkedin-taiwan-non-official-community/%E8%AA%B0%E8%AA%AA%E8%AA%8D%E8%AD%98%E6%89%8D%E8%83%BD%E9%80%81%E9%82%80%E8%AB%8B-%E5%A6%82%E4%BD%95%E9%81%8B%E7%94%A8-linkedin-connections-%E6%8B%93%E5%B1%95%E8%87%AA%E5%B7%B1%E7%9A%84%E5%B0%88%E6%A5%AD%E4%BA%BA%E8%84%88%E7%B6%B2%E7%B5%A1-17c581b69463',
#   'content': '誰說認識才能送邀請？如何運用 LinkedIn Connections 拓展自己的專業人脈網絡\nGiGi Huang\n·\nFollow\nPublished in\nLinkedIn Taiwan Non-official Community\n·\n10 min read\n·\nOct 7, 2018\n--\n2\nShare\n為何經營 LinkedIn 需要主動出擊找聯絡人？\n對我而言答案很簡單，分不同需求。\n以求職面來說，因為要「被看見」。\n我在 LinkedIn 上獲得的工作面試機會，不是因為我認識對方，而是因為我過去的經歷「被看見」。\n為何會被看見，有可能是對方從別人那邊發現我的個人檔案，或是在搜尋相關人才時，透過關鍵字看到了我。\n有時候會有朋友希望我能幫忙介紹聯絡人，他們希望透過跟要面試的公司內部員工聊聊，能進而認識與了解公司內部文化、員工氛圍與工作習慣。通常我不確定究竟當下哪個朋友在哪間公司，以及他們的職位可以和我這位朋友想了解的職位有關係。這時候我就會上 LinkedIn 搜尋，觀察與了解有哪些朋友符合條件，找到合適人選後再請教對方會否願意跟人選聊聊。\n以合作面來說，因為這是一種「投資」。\n一個人一生中平均會有幾份工作？\n若 22 歲大學畢業就踏入職場，做到 65 歲就退休。以平均每份工作待三年來算，一個人一輩子可能會做到 15 份工作。\n而工作這件事情幾乎都是越換越好，因此就好像是投資一樣，認識一個很不錯的職場朋友，日後都有機會可以合作或請教！\n每個人的職涯多多少少都會有變化，從現在開始就養成\n「經營專業人際網絡弱連結」\n的習慣，不要等到需要人脈時才出擊，才不會讓人感覺很勢利。\nFacebook 是分享日常生活的社交媒體，LinkedIn 則是分享職涯經驗的專業人脈網絡\n，因此，使用 LinkedIn 時，不能只是單純建立帳號、等待他人主動接洽，以下和大家分享有效新增 LinkedIn Connections（聯絡人） 的方法。\n有效新增 LinkedIn Connections（聯絡人）三步驟：\n弱連結也可以主動出擊\n什麼是「弱連結」？\n他可能是你曾經的工作夥伴，朋友的朋友，臉書好友，或是某個活動中打過一次招呼的朋友，你們彼此知道對方，但沒有太多交集跟互動的一個關係。\n暢銷書籍《Give and Take》的作者 Adam Grant 在書中就曾經根據研究指出，有 17% 的人透過強連結知道工作機會，而令人吃驚的是有 28% 的人透過弱連結獲得工作機會的資訊！\n近期出版的新書《弱連結》中也舉了著名社會學家、史丹佛大學教授馬克•格蘭諾維特（Mark Granovetter）的論文指出：\n格蘭諾維特在調查中發現，真正發揮作用的關係並不是人們想像中的經常見面、彼此熟悉的「強關係」，而是平時很少聯絡的「弱關係」，即所謂的「路人甲」。\n在依靠關係找到工作的群體中，只有16.7%的人能經常見到工作的介紹人，他們每週見兩次面；55.6%的人只能和介紹人偶爾見一面，另外27.8%的人，甚至一年都見不到介紹人一次。就是這些相對陌生的關係，幫助他們找到了滿意的工作。\n而 LinkedIn 可以讓你擁有更多的弱連結聯絡人，以下分享我的做法：\n第一步註冊信箱後，系統推薦的名單都可以挑挑看有沒有適合的。\n接著我會加的聯絡人為：\n1. 唸書時的同學/老師/教職員\n2. 之前在職場上有互動過的客戶或朋友。\n3. 前同事\n4. 同校的學長姐\n要補充的是，\n我個人不會加現職公司的同事\n。雖然有 LinkedIn 不代表就是要求職，但為了避免產生不必要的誤會，盡量不加現任職的公司的同事。\n個人形象建立\n首先，照片別亂放！照片適合選什麼樣的呢？\n挑能\n呈現專業形象\n的照片，但\n不要證件照也不要畢業照\n。\n照片放畢業照的謎之音就是：「\n我剛畢業我很嫩」\n。\n看到證件照會有的謎之音是：\n「嗯，很少證件照拍的很好看的。如果你堅持要放證件照當大頭照，那我就 show my respect…尊重你。」\n接著 LinkedIn URL 簡化美化，去掉那些後面沒意義的數字吧！\n1. 客製化更好分享（沒有 dash 或數字之類的）\n2. 放在 Email 當簽名檔，或是加在名片上\n如何更改 LinkedIn 個人頁面 URL 呢？\n1. 進到個人頁面\n2. 選擇大頭照右方的鉛筆圖示（編輯功能）\n3. 點入後下滑找到 Contact Info，點選旁邊的鉛筆圖示（編輯功能）\n4. 在最上方看到 Profile URL，可以直接點連結，或是連結旁邊的箭頭，會開一個新的視窗頁面。\n5. 點選進去後看到右上方的 Edit URL，點選旁邊的鉛筆圖示就可以修改\n6. 完成後記得按 Save 就好囉！\n別忘了，Title 就是你的個人 Slogan！\n搜尋列中找到你時，首先看到的會是\n姓名、照片、職稱\n。\n現在越來越多人不只會寫現任公司的職稱，也會加上自己的產業領域或其他身份，例如李開復先生的一行自介，不只是現在的職位還加上前公司，以及自己的作者身份。\n這部分的文字要放哪些資訊，視個人求職需求而異。如果一直想要在同個產業或是覺得讓他人知道自己在哪個產業，可以新增合作機會的話就加上去。我個人經營 LinkedIn 就是個看緣分，所以只會放上公司職稱。不過我兩年多前剛踏入 FInTech 產業時，為了希望可以獲取更多的產業知識，而主動搜尋有 FinTech 關鍵字的聯絡人，所以確實加了幾位常分享相關資訊的知識型分享者，對我在職場上獲取相關產業資訊很有幫助。\n當個好人，多多益善助人助己\n1. 多按讚留言互動\n不知道你開始用 Facebook 的時期是不是跟我一樣？\n早年若只要按Ａ朋友公開發文的讚或留言，Ｂ朋友即使不是Ａ朋友的臉書好友，Ｂ一樣會看到塗鴉牆上跳出Ａ的發文（感謝後來這功能只用在粉絲團）。\n目前 LinkedIn 的機制也是這樣，所有人在 LinkedIn 上的發文都是公開的，若是我有按讚或是留言的貼文，我的聯絡人們都會看得到。此外，你的發文、按讚、留言，都可以在你個人頁面的動態中看得到。\n也因此若是幫一個好的發文按讚或分享，對對方是有幫助的。聯絡人的頁面上有機會出現你按讚及留言的通知，也會出現你按讚及留言的那則發文。\n2. 幫他的技能點個肯定 (Endorsement)（最多50個）\n如果有人幫你肯定了你的技能，請也禮貌性地也根據他的工作職稱及技能，也幫他肯定幾個技能吧！\n點肯定的好處我之前一直感受不到，只是喜歡累積點數的成就感，希望每個技能都能有人認可。直到後來用了電腦網頁看 LinkedIn 職缺時，發現原來雇主可以在 LinkedIn 招募頁面列出該人選的期待技能，而\n系統會\n自動幫你配對你是否有該公司需要的技能\n。下一個問題是他怎麼知道你沒有這技能？難道有 AI 讀取每個職位列出的工作內容嗎？後來我才發現，原來是看下方的 Skills！\n有些招募人員會列出期待的技能需求，有些職缺不會，以抖音目前招募的人選來說，系統就會在頁面自動幫我列出我有哪些技能符合公司期望。\nEndorsement（肯定）的功能很久了，但近期有更新的客製化部分，那就是「\n可以讓用戶選擇三個最想要強調的熱門技能 Top Skills\n」。\n客製化的更新解決了我出社會後的痛點！\n之前提過我從研究所時期就開始使用 LinkedIn，而當年在校時的我的專業想走的是流行趨勢的專業：Social Media，而恰巧當時大家都幫我對於 Social Media 的專業 endorse，在我出社會後造成困擾，因為後來在台灣並沒有朝社群小編之路發展，但過去系統會主動設定前三個最多人肯定的技能放在最前面，結果不認識我的人可能會誤會我的專業是經營 Facebook，即使我已經不當小編好幾年了…\n這次的更新後，我把沒有的技能（例 SEO、SEM）刪除，然後釘選三個這幾年在職場上被肯定的技能，請看下圖：\n如果大家方便的話，會很\n感謝你\n順手也幫我肯定這三項技能：\nBusiness Development, Brand Development, Corporate Communications\n，先謝謝你！\n此外，目前 LinkedIn 也會寄系統信給用戶通知有哪些聯絡人被誰肯定了，這也可以增加你被看見的次數。\n最後當然要分享可以有哪些好習慣：\n先說明 LinkedIn 的聯絡人分成「一度、二度、三度」關係。\n「一度」表示你們雙方都接受彼此成為 LinkedIn 上的聯絡人\n2. 「二度」表示你們之前有共同認識的聯絡人\n3. 「三度」表示你們真的完全不認識彼此\n在工具列上呈現好友的選項，點印去後下方會有「你可能認識」，系統會推薦你可能會認識的二度聯絡人 ，我每週都會看一下有沒有適合成為聯絡人的名單，然後主動發出邀請。\n另外就是\n把握每次你主動加好友之後的頁面\n！\n例如我主動送出聯絡人邀請給在新創加速器做投資分析的主管，送出邀請後的頁面下方會有推薦其他的二度聯絡人。這些聯絡人的共通點會有兩個方面：「同公司」或是「同樣產業」。如果我加了在幣圈的創辦人，下方就會推薦我二度聯絡人是經營虛擬貨幣公司的執行長或高階主管。\n這個時候下方出現的名單，與前面所說好友頁面會出現的「您可能認識」的名單會有些不同，所以當下可以把握往下滑看看有沒有可以進一步交流的名單。\n希望以上這些方式可以幫大家獲得更多優質的聯絡人。\n2012 年 ...
#  {'title': '创建令人信服的LinkedIn 内容：撰写能提高参与度的帖子 - Ranktracker',
#   'source': 'https://www.ranktracker.com/zh/blog/creating-compelling-linkedin-content-a-guide-to-crafting-posts-articles-and-videos-that-drive-engagement/',
#   'content': 'ç¤¾äº¤åª\x92ä½\x93è\x90¥é\x94\x80å\x92\x8c LinkedIn æ\x88\x98ç\x95¥\nå\x88\x9bå»ºä»¤äººä¿¡æ\x9c\x8dç\x9a\x84 LinkedIn å\x86\x85å®¹ï¼\x9aæ\x92°å\x86\x99è\x83½æ\x8f\x90é«\x98å\x8f\x82ä¸\x8eåº¦ç\x9a\x84å¸\x96å\xad\x90ã\x80\x81æ\x96\x87ç«\xa0å\x92\x8cè§\x86é¢\x91æ\x8c\x87å\x8d\x97\nFelix Rose-Collins\nâ\x80¢\nNov 7, 2023\nâ\x80¢\n9 min read\nä»\x8bç»\x8d\nLinkedIn å·²æ\x88\x90ä¸ºä¸\x8eå\x90\x8cè¡\x8cã\x80\x81æ½\x9cå\x9c¨é\x9b\x87ä¸»å\x92\x8cè¡\x8cä¸\x9aå½±å\x93\x8dè\x80\x85å»ºç«\x8bè\x81\x94\x00\x00ç³»ç\x9a\x84é¦\x96é\x80\x89å¹³å\x8f°ã\x80\x82ç\x84¶è\x80\x8cï¼\x8cä»\x85ä»\x85å\x9c¨ LinkedIn ä¸\x8aå\x8d\xa0æ\x9c\x89ä¸\x80å¸\xadä¹\x8bå\x9c°è¿\x98ä¸\x8dè¶³ä»¥å\x9c¨äººç¾¤ä¸\xadè\x84±é¢\x96è\x80\x8cå\x87ºã\x80\x82è¦\x81æ\x83³ç\x9c\x9fæ\xad£äº§ç\x94\x9få½±å\x93\x8då¹¶å\x85\x85å\x88\x86å\x8f\x91æ\x8c¥è¿\x99ä¸\x80å¹³å\x8f°ç\x9a\x84æ½\x9cå\x8a\x9bï¼\x8cä½\xa0é\x9c\x80è¦\x81æ\x8e\x8cæ\x8f¡å\x88\x9bé\x80\xa0å¼\x95äººæ³¨ç\x9b®ç\x9a\x84å\x86\x85å®¹ç\x9a\x84è\x89ºæ\x9c¯ã\x80\x82\næ\x97\xa0è®ºä½\xa0æ\x98¯æ\x83³\næ\x8f\x90å\x8d\x87ä¸ªäººå\x93\x81ç\x89\x8c\nã\x80\x81æ\x8b\x93å±\x95è\x81\x8cä¸\x9aç½\x91ç»\x9cï¼\x8cè¿\x98æ\x98¯æ\x83³ä¸\x8eç\x9b®æ\xa0\x87å\x8f\x97ä¼\x97äº\x92å\x8a¨ï¼\x8cæ\x9c¬æ\x8c\x87å\x8d\x97é\x83½æ\x98¯ä½\xa0å\x9c¨ LinkedIn ä¸\x8aæ\x92°å\x86\x99æ\x96\x87ç«\xa0ã\x80\x81æ\x96\x87ç«\xa0å\x92\x8cè§\x86é¢\x91ç\x9a\x84è·¯çº¿å\x9b¾ï¼\x8cè®©ä½\xa0ç\x9a\x84æ\x96\x87ç«\xa0ã\x80\x81æ\x96\x87ç«\xa0å\x92\x8cè§\x86é¢\x91å\x90¸å¼\x95äººã\x80\x81æ¿\x80å\x8f\x91äººã\x80\x82é\x82£ä¹\x88ï¼\x8cè®©æ\x88\x91ä»¬å¼\x80å§\x8bæ\x8e¢ç´¢å¦\x82ä½\x95å\x9c¨è¿\x99ä¸ªæ\x9e\x81å\x85·å½±å\x93\x8då\x8a\x9bç\x9a\x84å¹³å\x8f°ä¸\x8aç\x95\x99ä¸\x8bæ\x8c\x81ä¹\x85ç\x9a\x84å\x8d°è±¡å¹¶æ\x8f\x90å\x8d\x87ä½\xa0ç\x9a\x84ä¸\x93ä¸\x9aå½¢è±¡å\x90§ã\x80\x82\nç¡®å®\x9a LinkedIn ä¸\x8aç\x9a\x84ç\x9b®æ\xa0\x87å\x8f\x97ä¼\x97\nå\x9c¨å\x88\x9bå»ºè\x83½å¼\x95èµ·å\x8f\x97ä¼\x97å\x85±é¸£ç\x9a\x84å\x86\x85å®¹ä¹\x8bå\x89\x8dï¼\x8cæ\x82¨å¿\x85é¡»é¦\x96å\x85\x88ç¡®å®\x9aè°\x81æ\x98¯æ\x82¨ç\x9a\x84å\x8f\x97ä¼\x97ã\x80\x82è\x80\x83è\x99\x91è¡\x8cä¸\x9aã\x80\x81å·¥ä½\x9cè§\x92è\x89²ã\x80\x81å\x85´è¶£å\x92\x8cäººå\x8f£ç»\x9fè®¡ç\xad\x89å\x9b\xa0ç´\xa0ã\x80\x82\næ¯\x94æ\x96¹è¯´ï¼\x8cä½\xa0æ\x98¯ä¸\x80å\x90\x8dæ\x95°å\xad\x97è\x90¥é\x94\x80é¡¾é\x97®ï¼\x8cä½\xa0ç\x9a\x84å\x88\x86æ\x9e\x90ç»\x93æ\x9e\x9cæ\x98¾ç¤ºï¼\x8cä½\xa0ç\x9a\x84 LinkedIn å\x85³æ³¨è\x80\x85å¤§å¤\x9aå\x9c¨ 25-35 å²\x81ä¹\x8bé\x97´ï¼\x8cä»¥ç\x94·æ\x80§ä¸ºä¸»ï¼\x8cå¹¶ä¸\x94ä½\x8däº\x8eç¡\x85è°·ã\x80\x82æ\x82¨å\x8f¯ä»¥é\x92\x88å¯¹ç§\x91æ\x8a\x80ä¸\xadå¿\x83ç\x9a\x84å¹´è½»ä¸\x93ä¸\x9aäººå£«æ\x89\x80é\x9d¢ä¸´ç\x9a\x84æ\x8c\x91æ\x88\x98å\x92\x8cè¶\x8bå\x8a¿å\x88\x9bå»ºå\x86\x85å®¹ï¼\x8cæ¯\x94å¦\x82 "ç¡\x85è°·ç§\x91æ\x8a\x80å\x88\x9då\x88\x9bå\x85¬å\x8f¸ç\x9a\x84 5 é¡¹æ\x88\x90ç\x86\x9fæ\x95°å\xad\x97è\x90¥é\x94\x80ç\xad\x96ç\x95¥"ã\x80\x82\nèµ\x84æ\x96\x99æ\x9d¥æº\x90\nå¼\x80å±\x95å\x8f\x97ä¼\x97ç\xa0\x94ç©¶ä¸\x8eå\x88\x86æ\x9e\x90\nå\x88©ç\x94¨ LinkedIn ç\x9a\x84å\x88\x86æ\x9e\x90å·¥å\x85·æ·±å\x85¥äº\x86è§£ä½\xa0ç\x9a\x84å\x8f\x97ä¼\x97ã\x80\x82å\x88\x86æ\x9e\x90å\x85³æ³¨è\x80\x85ç\x9a\x84äººå\x8f£ç»\x9fè®¡æ\x95°æ\x8d®ï¼\x8cè·\x9fè¸ªå\x8f\x82ä¸\x8eåº¦æ\x8c\x87æ\xa0\x87ï¼\x8cå¹¶è§\x82å¯\x9fè¡¨ç\x8e°è\x89¯å¥½ç\x9a\x84å\x86\x85å®¹ç±»å\x9e\x8bã\x80\x82è¿\x99ç§\x8dä»¥æ\x95°æ\x8d®ä¸ºå¯¼å\x90\x91ç\x9a\x84æ\x96¹æ³\x95å\x8f¯å¸®å\x8a©æ\x82¨é\x80\x90æ\xad¥å®\x8cå\x96\x84å\x86\x85å®¹ç\xad\x96ç\x95¥ã\x80\x82\nå¦\x82æ\x9e\x9cä½\xa0å\x8f\x91ç\x8e°è\x87ªå·±å\x9c¨ LinkedIn ä¸\x8aå\x8f\x91å¸\x83ç\x9a\x84å\x8c\x85å\x90«è¡\x8cä¸\x9aè§\x81è§£å\x92\x8cå®\x9eç\x94¨æ\x8a\x80å·§ç\x9a\x84å¸\x96å\xad\x90æ\x94¶å\x88°ç\x9a\x84ç\x82¹èµ\x9eå\x92\x8cè¯\x84è®ºæ\x98\x8eæ\x98¾å¤\x9aäº\x8eå\x85¶ä»\x96å¸\x96å\xad\x90ï¼\x8cé\x82£ä¹\x88ä½\xa0å°±å\x8f¯ä»¥å¾\x97å\x87ºç»\x93è®ºï¼\x9aä½\xa0ç\x9a\x84å\x8f\x97ä¼\x97é\x9d\x9eå¸¸é\x87\x8dè§\x86å\x8f¯æ\x93\x8dä½\x9cç\x9a\x84å»ºè®®ã\x80\x82ç\x84¶å\x90\x8eï¼\x8cä½\xa0å°±å\x8f¯ä»¥ä¸\x93æ³¨äº\x8eå\x88\x9bå»ºæ\x9b´å¤\x9aæ\xad¤ç±»å\x86\x85å®¹ã\x80\x82\næ\xa0¹æ\x8d®å\x8f\x97ä¼\x97ç\x9a\x84é\x9c\x80æ±\x82å\x92\x8cå\x85´è¶£å ...
#  {'title': '分享內容| LinkedIn 說明',
#   'source': 'https://www.linkedin.com/help/linkedin/topic/a148004?lang=zh-TW',
#   'content': "相關主題：「分享內容」\n60 篇文章\n所有會員和管理員（LinkedIn 頁面超級管理員或內容管理員）都可發表有關自身專業及興趣的文章。文章顯示於個人檔案「動態」區塊下方。該內容會透過動態消息，有時則是透過通知，分享給您的聯絡人與關注者。文章可以在 LinkedIn、Facebook 或 Twitter 上分享。如要撰寫文章：備註：相關任務首頁上方附近有一個分享方框，請按一下方框中的撰寫文章。如果您是 LinkedIn 頁面的超級管理員或內容管理員…\n在撰寫 LinkedIn 文章時，您可以在文章的本文中使用圖片、影片和 Instagram 圖片與推文等其他多媒體檔案（目前無法插入表格）。備註：封面圖片已停止支援 GIF 格式。封面圖片支援的檔案類型為 JPEG、JPG、PNG 和 WEBP。\n封面圖片的最佳大小為 1920（寬）x 1080（高）像素。\xa0系統會將封面圖片裁切成 16:9 的比例。\n我們支援 YouTube、SlideShare、TED、Getty…\nLinkedIn 提供絕佳平台，讓您與自己的人脈網及更廣大的 LinkedIn 社群分享專業知識、經歷以及趣聞。本文羅列了您要在 LinkedIn 開始形塑個人品牌所需要的所有資源。以下是一些您在 LinkedIn 打造專業及個人品牌時可能會遇到的常見問題。相關任務深入瞭解在 LinkedIn 上發文，就是將您的聲音帶入全世界最大的專業社群網站。分享知識、意見和職涯經歷，可以讓您結識更多會員、培養社群並開創機會。平均而言…\n您可以查看內容（包括短篇貼文、圖片、影片、活動、投票和文章）的貼文分析，以深入瞭解它們對您的 LinkedIn 受眾有何影響。深入瞭解若要查看貼文分析：若要查看貼文分析：只有您本人才能查看您的貼文分析。您自己的觀看次數也會計入您的內容分析。我們不針對您僅與聯絡人或僅在 LinkedIn 社團分享的內容提供熱門活動訪客背景資料。活動訪客背景、熱門文章活動訪客背景、影片觀看訪客、熱門影片觀看活動訪客背景都是以不重複會員為基礎（例如…\n重要事項：您的會員資格以及對我們其他服務的使用都受到 LinkedIn 用戶協議與專業社群政策的規範。會員不得有不實或不專業之行為，包括張貼不適當、不正確或有異議之內容。您可以使用 LinkedIn 首頁上方的分享方框來發表和分享 LinkedIn 上的內容。從 LinkedIn 桌面版介面的主要分享方塊使用撰寫貼文或用 AI 產生草稿來查看其他分享選項。\xa0除此之外，您還能：注意：當會員在他們自己的貼文上留言時…\n您現在可以查看您的評論獲得了多少次展示，以深入瞭解LinkedIn社區中的影響。\n每次有人查看您的評論時，系統都會統計一次評論展示次數。此計數是非唯一的，如果同一成員查看評論兩次，則計為 2 次評論展示。您自己的觀看次數也會計入展示次數。備註：深入瞭解只有您可以查看評論的展示次數。展示次數顯示為評論的一部分，例如在LinkedIn源或LinkedIn群組中。\n評論展示次數不會顯示在任何功能板中…\n您可以在個人檔案頁面的動態區塊中，瀏覽自己或其他 LinkedIn 會員的動態消息、文章和個人檔案更新。若您在會員的個人檔案動態區塊中看不到任何動態，可能是因為會員將設定改為隱藏，或是沒有任何最新動態。若您長達 360 天未在 LinkedIn 上有任何動態，您的個人檔案就會把動態區塊隱藏起來。若要瀏覽您在 LinkedIn 上的最新動態，其步驟如下：備註：深入瞭解您可控制活動是否要在您人脈的動態消息中顯示…\n您可以在個人檔案獲得 LinkedIn 話題人物或社群話題人物計畫其中一種「話題人物」標章。您可以顯示或隱藏個人檔案上顯示的話題人物標章。深入瞭解在個人檔案上顯示或隱藏話題人物標章的步驟如下：在個人檔案上顯示或隱藏話題人物標章的步驟如下：LinkedIn 話題人物協作文章協作文章常見問題解答按一下LinkedIn 首頁上方的我圖示。按一下查看檔案。按一下專頁簡介區段中的編輯圖示。向下捲動至編輯專業簡介彈出視窗中的話題人物標章區塊…\n您可以在出版平台上查看您發表的文章。深入瞭解如何查看您的文章：如何從個人檔案瀏覽文章：如何查看您的文章：在 LinkedIn 發表文章按兩下 LinkedIn 主頁頂部的Write article （撰寫文章）。如果您是 LinkedIn 頁面的超級管理員或內容管理員，您將看到發表方式的選項，請選擇要從哪個帳戶發表內容，然後按一下下一步。這會將您導向發表工具。單擊發佈工具右上角附近的Manage下拉功能表，然後選…\n一旦您開始寫作，您的文章就會自動儲存為草稿。您可以隨時存取已儲存的草稿，以進行編輯、發表或刪除。您可以先與其他會員分享文章草稿，以在文章於 LinkedIn 分享之前，取得有關內容的意見反映。草稿預覽是公開的，可以透過複製當前網址來分享。如果您想以相同的格式發表文章，您還可以複製草稿以快速建立現有頁面的副本。相關任務若要管理已儲存的文章草稿：若要分享或複製您目前正在撰寫的文章草稿：若要分享或複製以前儲存的草稿：在 LinkedIn…\n所有 LinkedIn 會員都可以存取創作者分析，當中包括：深入瞭解綜合貼文分析- 呈現您的內容（包括短篇貼文、圖片、影片、活動、投票及文章）在一段時間內的表現；以及受眾分析- 針對您的關注人數增長趨勢及關注者的組成背景提供實用資訊。查看創作者分析的步驟如下：查看綜合貼文分析的步驟如下：注意：您在頂部這兩個下拉選單中所做的選擇，會套用到整個動態分頁。\n查看受眾分析的步驟如下：查看創作者分析的步驟如下：查看綜合貼文分析的步驟如下…\n您可以使用 LinkedIn 首頁、社團或 LinkedIn 頁面上方的分享方框與人脈分享照片。照片規定如下：多照片貼文的條件為：注意：您可擇一分享 URL 連結或圖片貼文，但不可同時使用這兩種方式分享。若為 URL 連結，我們會使用所分享的網站來建立預覽圖片。深入瞭解若要分享照片：若要分享照片：上傳檔案大小上限為 5 MB。照片尺寸最小要有 552（寬）x 276（高）像素，但我們建議使用 1080（寬）像素…\n您可以使用 LinkedIn 首頁、社團或 LinkedIn 頁面上方的分享方框與人脈分享影片。請查看下方的常見問題解答，深入瞭解在 LinkedIn 分享影片的資訊。深入瞭解您的 1 度聯絡人會自動關注您的貼文和文章。其他不在您人脈網內的人士也都可關注您。您可控制只讓 1 度聯絡人關注您，請由「設定與隱私」頁面調整。您也可以選擇將關注設為主要操作，會員查看您的帳戶時將看到此操作。建議您分享高畫質影片，藉此反映會員如何使用…\n任何會員都可以經由「分析和工具」這個統一路徑來存取相關工具和資源。透過分析和工具，您可以：衡量您的成效。這包括創作者分析（例如綜合貼文分析和受眾分析）以及個人檔案分析（例如「誰來造訪」和搜尋曝光次數）。獲得下一則貼文的靈感。探索您可以使用的創作工具。存取「分析和工具」的步驟如下：深入瞭解按一下 LinkedIn 首頁上方的\ufeff\ufeff我圖示。按一下查看檔案。向下捲動至分析區塊，然後按一下顯示所有分析資料。在分析和工具頁面中，您可以…\n作為電子報作者，您可以對您熱衷的專業主題定期撰寫文章。會員可以訂閱您的電子報，以在您發表新內容時收到動態消息。最吸引人的電子報通常會專門針對一個獨特主題持續發表內容，讓訂閱者引頸期待下一篇文章。所有人都可以探索、閱讀和分享您的 LinkedIn 電子報。LinkedIn會員也可以訂閱電子報。您可以以個人或 LinkedIn 頁面名義來建立電子報。相關任務深入瞭解若要在 LinkedIn 建立電子報：若要在電子報中發表新文章…\n電子報是定期發表在 LinkedIn 上的文章集，通常與特定主題相關。您可以以自己或 LinkedIn 頁面建立電子報。成員每位 LinkedIn 會員都有在 LinkedIn 建立電子報的權限。頁面頁面若要建立電子報，則須滿足下列條件：相關任務深入瞭解受眾群\n關注者和/或聯絡人超過 150 人的頁面，始有資格接受 LinkedIn 電子報存取權的評估。最近分享了原創內容（任何類型）\n我們要找的是具備 LinkedIn…\n所有 LinkedIn 會員都可以建立關於自身專業知識和興趣的電子報。請依照下列指示建立您的電子報。若要建立電子報：您可以利用 LinkedIn 上的電子報，對您熱衷的專業主題定期發表言論。LinkedIn 會員可以訂閱您的電子報，獲得您所發佈新文章的通知，而您可藉此建立和培養長期互動的受眾。在 LinkedIn 開始建立電子報，意味著您從發佈瞬間起即開始吸引受眾。LinkedIn 讓您在建立電子報時…\n以下的最佳典範可幫助您創建引人入勝的電子報並更接觸廣泛受眾。相關工作深入瞭解選擇能清楚說明主題且對象能理解的電子報名稱。上傳電子報標誌以增加響應度（建議使用 300x300 像素）。為電子報中的每篇文章上傳封面照片（建議使用 1920（寬）x 1080（高）像素）。盡量避免剪貼畫或其他通用庫存圖片。有臉部與人物的圖片較能引起對象的共鳴。為各電子報刊號選擇清楚的標題，以協助對象瞭解文章內容。自訂您的 SEO（搜尋引擎最佳化…\n標註聯絡人或其他會員可以鼓勵他們與您的貼文和回應互動。標註的聯絡人或其他會員會收到有關貼文或回應的通知。貼文或回應與聯絡人或其他會員的個人檔案相關聯。若要查看，可以按一下聯絡人或其他會員的姓名以瀏覽至其個人檔案。注 ...
#  {'title': '6 步驟打造專業LinkedIn 個人主頁，讓HR 主動聯繫你！',
#   'source': 'https://jason-career.com/linkedin/?srsltid=AfmBOoqMnoy0yIM4j0Jp8vg8-FrMQkq8F3iRZc7msKX6ru6jIVjsKbjC',
#   'content': '最後更新時間： 2025 年 01 月 18 日\n「具專業感的 LinkedIn 主頁竟然讓我收到 HR 主動發的面試邀約？！」\n擁有一個專業的 Profile 會提供人們一個額外了解你的機會，不只在求職和 Networking 過程中幫到你，也能在申請海外 MBA 的過程中增加錄取機會，甚至能收到 HR 的主動聯繫！\n這篇文章想分享 Networking 和申請哥大 MBA 時，LinkedIn 是如何幫助到我的！我自己在申請 MBA 或其他碩士項目時，部分學校有提供欄位讓申請人填寫 LinkedIn 領英網址。\n不管是主動在簡歷附上 LinkedIn URL，或是公司 HR、大學招生官在搜尋個人的 LinkedIn，正確且專業的使用 LinkedIn 會提供一個額外向他人展示個人品牌的機會。\n由於 LinkedIn 是偏向專業的社交媒體平台，所以在 LinkedIn 上建立一個專業的個人品牌，展示自身經歷、價值觀和興趣是至關重要的！\n內容目錄\nToggle\n事前準備\n關閉檔案更新通知\n在開始對 LinkedIn 個人資料進行修改之前，請確保你的 Network 不被打擾。\n請點擊「我」\n→\n設置和隱私\n→\n公開度\n→\n將檔案更新分享到人脈網【關閉】 設置個人專屬的 URL\n設置個人專屬的 URL\nLinkedIn 提供修改主頁 URL 的機會，這展示了對細節的關注，是一個區別於其他 LinkedIn 資料和候選人的標誌。若沒有修改的話，預設會是一串字母跟數字組成的亂碼。\n修改方式：個人主頁\n→\n右上角的方框內「編輯公開檔案和網址」\n→\n編輯自訂網址，將 URL 改為盡可能接近你的名字（羅馬拼音或英文名＋姓氏）。\n開始動工，翻修個人主頁 LinkedIn Profile\n撰寫吸引人的標題與個人摘要\n為什麼重要？標題與摘要是 HR 和其他用戶最先看到的內容，它們會直接影響他們是否有興趣繼續瀏覽下去你的 Profile。\n如何做？\n標題\n：除了職位名稱，加入你的專長與價值，例如：「數據分析師｜精通 Python、SQL｜專注於商業洞察」。\n摘要\n：用 2-3 段簡單明瞭的語言，概述你的職業背景、成就和未來目標。可以用故事化的方式呈現，讓人讀起來更有吸引力。\n範例摘要\n：\n我是一名具備 5 年經驗的數據分析師，擅長運用數據解決商業問題，幫助企業提升營收。我精通 Python 和 SQL，並在過去一年中完成了 3 項提升效率的專案，為公司節省 20% 的營運成本。目前，我希望透過數據驅動的洞察，助力更多企業成長。\n專業的個人頭像照片\nLinkedIn\n是一個專業的平台，個人資料必須有一張專業的頭貼，而不是集體照或生活照；個人建議是不要使用證件照（例如：身分證或護照大頭貼），會顯得有些突兀。根據網路上不可靠資料，有附帶照片的檔案被查看機率是沒有照片的數十倍。下面是我整理有關 LinkedIn 照片的一些 ”Do’s” 和 “Don’t”。\n最推薦的樣式是：一個人(only YOU) + 微笑，清楚、近期、背景單純。\n更進階的 tips 是可以嘗試符合產業⾵格，與你平常⼯作模樣相近的打扮。\n⭕ Do’s\n❌ Don’t\n近距離拍攝\n正裝照\n近期照片\n聘請專業攝影師（非必須）\n自拍\n團體照\n過時的照片\n其他的人/動物/動畫/虛擬頭像\n奇怪的背景\n背景圖片/封面\n選擇一個最能代表你的形象，比較常見的圖片可以是演講照片、志工服務、社團活動等等。也可⽤\nCanva\n設計自己的單色背景圖⽚，展現你的特質和專業領域。\n簡單來說，第一印象很關鍵！專業的頭像可以讓人覺得你值得信賴，而背景照片則是展示個人品牌的絕佳機會：\n頭像\n：選用清晰、自然且帶有微笑的照片，背景簡單乾淨，建議穿著符合職業形象的衣服。\n背景照片\n：選擇與你的行業或專業相關的圖片，例如公司活動、技術插畫，或自訂一張帶有你的個人標語的設計。\n注意\n：避免使用過度修圖或自拍照，這可能給人不專業的印象。\n關於（自我介紹）\n寫一篇令人過目不忘的自我介紹，嘗試突出你的專業、職業經驗、榮譽和領導能力。寫下你職業生涯中最相關的成就，避免使用艱澀難懂的行話 (Jargon)。把重點集中在前幾行，寫作方式可以參考 Elevator pitch，以第⼀⼈稱⾃我介紹：特質、熱忱、價值觀、近期⽬標、個人背景如何成就了現在的你。\n注意：不要混淆關於 About 和工作經歷 Experience，About 是總結、Experience 部分應該寫得更詳盡。\n我出版了三本電子書！分別是：\nSOP、CV、英文面試\n，每本都\n超高 CP 值、乾貨滿滿、銷售破百本\n，持續更新增補內容，陪伴大家走過留學＆求職！\n當你看到這邊，恭喜你獲得讀者專屬優惠碼！\n輸入優惠碼：BLOG100，\n每本電子書都折 $100\n，三本一起購買就可以折 $300！\n👉🏻\n點擊這裡\n一次搞懂申請需要的資源、撇步和知識吧！用傳統代辦 3% 不到的價格，獲得 300+% 價值\n工作經歷摘要\n這個區塊並非是讓人直接將簡歷複製上來，也不是 Job Description，而應該是量化地描述成就和工作的總結。此外，雖然只需要包括工作中最關鍵的方面，但不⽤像履歷那樣只有幾個 Bullet Point。可以考慮用「說故事」的方式，或是擬一個小段落，甚至可以上傳媒體、放上作品、網⾴等。\n教育背景\n列出你的畢業學校、系所、排名、GPA（建議如果大於 3.5 可以放上），也可以放上修過的課程等等。甚至，你也可以在上面描述你做的研究（例如，畢業論文、Research Project），以及你在大學期間參與過的社團活動。\n其他區塊\n【資格認證】列出與你的⽬標領域⾼度相關的項⽬即可，太多⼜雜反⽽失去焦點。\n【志願服務】將社區服務經驗寫上去可以讓人認識你專業方面以外的貢獻與付出。\n【精選 Featured】領英的 Featured 一欄提供了展示自己的空間，你可以在這裡放上你取得的工作成就和成果，或是置頂一些你之前發布過的文章。如果 Profile 全都是文字的話會顯得單調，放上一些精選可以補充一些媒體，讓你的形象更立體。\n成為領英 LinkedIn 大師，進階 Tips 秒變專業\n下面還有整理一些更進階的經營 Tips，讓大家成為領英大師，熟稔操作並增加曝光。\n客製化邀請\n訊息\n在你持續建立 Connection 時，可以使用更加個性化的好友邀請訊息，提及您與他們的共同興趣、參加的共同活動或學校或共同朋友等等。通常發送默認消息的好友通過率不高，並且其他人還需要點進你的頁面後回想他是否認識你。\n打招呼＆自我介紹＆說明目的，先揭露你自己、別人才會更願意揭露他自己！\n保持更新\n在畢業、找到新工作、完成專案、被學校錄取等各種時機，都可以發 post 跟大家分享好消息，並且分享自己的心得跟表達感謝。工作經歷等檔案也記得定期更新。LinkedIn 的 post 提供了另一種方式來提升您的影響力，並且讓他人了解你感興趣的領域，通過發布有影響力的內容來突出您的專業知識和興趣，並且積累更多相似興趣、想法的人脈。\n分享專業內容、心得感想、職場體悟，建立個人品牌\n主動分享高價值的內容，不僅能展現你的專業能力，還能提高你的主頁曝光率。\n分享文章\n：針對行業趨勢、案例分析或職場技能分享你的見解。\n撰寫文章\n：發布你的專業洞察，例如「如何用數據驅動業務增長」。\n參與討論\n：在別人的文章或貼文下發表有深度的評論，增加你的能見度。\n注意\n：保持內容專業且相關，不要過於頻繁地發布私人內容。\n頭銜\n可以用頭銜來突出你目前的職位和公司（例如：CB 公司的營運長）、突出您的專業知識或獎項，或展示技能（例如：分析師、講師、顧問）。\n位置和行業\n這兩個簡單的設置將幫助更多的人找到你，並幫助你找到更多相關的潛在 Connection。\n添加新區塊\nLinkedIn 允許添加多個部分，您可以添加志願服務、語言能力、榮譽和獎項、專利、學術期刊發布等部分。\n一致性\n如果整個領英 Profile 的內容高度一致且有深度，會更加有利於他人認識你。在語言使用上也需要注意，領英編輯時可以同時編輯中文和英文檔案，在編輯英文檔案時須注意公司名稱等欄位是否也變更成英文。\n在用領英做 Connection 時，歡迎參考這篇文章 👉🏻 教你如何\n問對問題脫穎而出，展現主動性！這些秘訣助你在留學和職場大放異彩！\n針對以上訣竅，該如何寫出自己專屬的 Profile 呢？\n學習行業前輩\n各個行業都有資深人士，可以查看並學習他們的 LinkedIn 個人頁面寫法，但是注意不要抄襲。個人建議可以多多查看英文母語使用者的 Profile，他們在用詞的架構跟精確度上都會比較好。\n用詞精確\n盡量避免過度使用太 General 的關鍵詞，應該適時加入精準的關鍵詞（職稱、產品、程式語言技能等），讓公司 HR 在搜尋時可以更清楚的了解你過往的經歷與能力。\n避免廣告\n發文時盡量不要大篇幅描述產品或者公司業務，在西方視角中，這類型的廣告用個人頁面發出並不恰當。可以嘗試具體化自己的行業經驗和專業技能，以及自己曾經涉及到的項目經驗，以提高個人專業度，甚至去分享自己的所學和感想。\n結語\n好的 LinkedIn 帶你上天堂，順利通過履歷篩選後，可以參考這篇文章進一步的了解\n面試時該如何向面試官提問\n！社會新鮮人如果缺乏工作經 ...

# %% [markdown]
# # 同學的練習
# - 延續剛剛挑選的主題，接續執行，確認正確無誤
# - 你可以使用 https://markdownlivepreview.com/ 來查看生成的結果
# - 給同學 5 分鐘的時間練習
