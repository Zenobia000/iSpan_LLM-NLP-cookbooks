# %% [markdown]
# ## Whisper API implement to Podcast for 語音轉文字

# %%
# Import necessary libraries
## 設定 OpenAI API Key 變數
from dotenv import load_dotenv
import os

# Load the environment variables from .env file
load_dotenv()

# Access the API key
openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
import requests
import json
from pprint import pp

# %%
def get_completion(messages, model="gpt-3.5-turbo", temperature=0, max_tokens=4000):
  payload = { "model": model, "temperature": temperature, "messages": messages, "max_tokens": max_tokens }
  headers = { "Authorization": f'Bearer {openai_api_key}', "Content-Type": "application/json" }
  response = requests.post('https://api.openai.com/v1/chat/completions', headers = headers, data = json.dumps(payload) )
  obj = json.loads(response.text)
  if response.status_code == 200 :
    return obj["choices"][0]["message"]["content"]
  else :
    return obj["error"]

# %%
# !pip install feedparser -q

# %% [markdown]
# ## 解析 podcast 音訊檔案

# %%
import feedparser
# 數位時代 https://open.firstory.me/user/bnext
podcast_feed_url = "https://open.firstory.me/rss/user/ckkqnneka7mxc0866j53j5ljw"
podcast_feed = feedparser.parse(podcast_feed_url)
print ("The number of podcast entries is ", len(podcast_feed.entries))
# Out:
# The number of podcast entries is  594

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
podcast_feed["entries"][0]["title_detail"]
# Out:
# {'type': 'text/plain',
#  'language': None,
#  'base': 'https://feed.firstory.me/rss/user/ckkqnneka7mxc0866j53j5ljw',
#  'value': '記者茶水間118.史上最盛大的Computex！黃仁勳、蘇姿丰說了什麼AI關鍵字？'}

# %%
print(podcast_feed.entries[0])
# Out:
# {'title': '記者茶水間118.史上最盛大的Computex！黃仁勳、蘇姿丰說了什麼AI關鍵字？', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://feed.firstory.me/rss/user/ckkqnneka7mxc0866j53j5ljw', 'value': '記者茶水間118.史上最盛大的Computex！黃仁勳、蘇姿丰說了什麼AI關鍵字？'}, 'summary': '<p>2024年的Computex剛剛落幕，由於AI PC 是熱門話題，而台灣身處在半導體供應鏈的關鍵位置，吸引各大科技巨頭都齊聚一塊。今年，他們各自帶來哪些亮點？將如何引領這波風潮？ <br /> <br /> <br />本集重點： <br /> <br />1.史上規模最大！2024 Computex夯什麼？ <br />2.輝達黃仁勳開第一槍！台大校園場揭兩大AI亮點 <br />3.超微、英特爾、聯發科齊聚，AI PC迎接戰國時代！ <br /> <br />📸更多Computex直擊》<a href="https://www.bnext.com.tw/topic/view/805" target="_blank">https://www.bnext.com.tw/topic/view/805</a> <br /> <br />---------------- <br />🗞️每天晚上8點，AI主播魏時黛為您讀新聞🗞️ <br /> <br />訂閱數位時代YouTube頻道，掌握科技大事》 <br /><a href="https://www.youtube.com/@official6771/videos" target="_blank">https://www.youtube.com/@official6771/videos</a> <br />---------------- <br /> <br />🤩有合作需求請洽：podcast@bnext.com.tw <br /></p> <br /> <br />Powered by <a href="https://firstory.me">Firstory Hosting</a>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://feed.firstory.me/rss/user/ckkqnneka7mxc0866j53j5ljw', 'value': '<p>2024年的Computex剛剛落幕，由於AI PC 是熱門話題，而台灣身處在半導體供應鏈的關鍵位置，吸引各大科技巨頭都齊聚一塊。今年，他們各自帶來哪些亮點？將如何引領這波風潮？ <br /> <br /> <br />本集重點： <br /> <br />1.史上規模最大！2024 Computex夯什麼？ <br />2.輝達黃仁勳開第一槍！台大校園場揭兩大AI亮點 <br />3.超微、英特爾、聯發科齊聚，AI PC迎接戰國時代！ <br /> <br />📸更多Computex直擊》<a href="https://www.bnext.com.tw/topic/view/805" target="_blank">https://www.bnext.com.tw/topic/view/805</a> <br /> <br />---------------- <br />🗞️每天晚上8點，AI主播魏時黛為您讀新聞🗞️ <br /> <br />訂閱數位時代YouTube頻道，掌握科技大事》 <br /><a href="https://www.youtube.com/@official6771/videos" target="_blank">https://www.youtube.com/@official6771/videos</a> <br />---------------- <br /> <br />🤩有合作需求請洽：podcast@bnext.com.tw <br /></p> <br /> <br />Powered by <a href="https://firstory.me">Firstory Hosting</a>'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://open.firstory.me/story/clx8udn3a002f01wcfc0i880r'}, {'length': '25003476', 'type': 'audio/mpeg', 'href': 'https://chrt.fm/track/AD8A17/m.cdn.firstory.me/track/ckkqnneka7mxc0866j53j5ljw/clx8udn3a002f01wcfc0i880r/https%3A%2F%2Fd3mww1g1pfq2pt.cloudfront.net%2FRecord%2Fckkqnneka7mxc0866j53j5ljw%2Fclx8udn3a002g01wc9b5qfgho.mp3?v=1718016045177', 'rel': 'enclosure'}], 'link': 'https://open.firstory.me/story/clx8udn3a002f01wcfc0i880r', 'id': 'clx8udn3a002f01wcfc0i880r', 'guidislink': False, 'authors': [{'name': '數位時代 Business Next'}], 'author': '數位時代 Business Next', 'author_detail': {'name': '數位時代 Business Next'}, 'published': 'Mon, 10 Jun 2024 22:31:00 GMT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=10, tm_hour=22, tm_min=31, tm_sec=0, tm_wday=0, tm_yday=162, tm_isdst=0), 'itunes_duration': '1550', 'image': {'href': 'https://image.firstory-cdn.me/Image/ckkqnneka7mxc0866j53j5ljw/4F9us-3l_K_KKfyMSXUBA.jpg'}, 'itunes_title': '記者茶水間118.史上最盛大的Computex！黃仁勳、蘇姿丰說了什麼AI關鍵字？', 'googleplay_description': '<p>2024年的Computex剛剛落幕，由於AI PC 是熱門話題，而台灣身處在半導體供應鏈的關鍵位置，吸引各大科技巨頭都齊聚一塊。今年，他們各自帶來哪些亮點？將如何引領這波風潮？ <br /> <br /> <br />本集重點： <br /> <br />1.史上規模最大！2024 Computex夯什麼？ <br />2.輝達黃仁勳開第一槍！台大校園場揭兩大AI亮點 <br />3.超微、英特爾、聯發科齊聚，AI PC迎接戰國時代！ <br /> <br />📸更多Computex直擊》<a href="https://www.bnext.com.tw/topic/view/805" target="_blank">https://www.bnext.com.tw/topic/view/805</a> <br /> <br />---------------- <br />🗞️每天晚上8點，AI主播魏時黛為您讀新聞🗞️ <br /> <br />訂閱數位時代YouTube頻道，掌握科技大事》 <br /><a href="https://www.youtube.com/@official6771/videos" target="_blank">https://www.youtube.com/@official6771/videos</a> <br />---------------- <br /> <br />🤩有合作需求請洽：podcast@bnext.com.tw <br /></p> <br /> <br/>Powered by <a href="https://firstory.me">Firstory Hosting</a>', 'content': [{'type': 'text/html', 'language': None, 'base': 'https://feed.firstory.me/rss/user/ckkqnneka7mxc0866j53j5ljw', 'value': '<p>2024年的Computex剛剛落幕，由於AI PC 是熱門話題，而台灣身處在半導體供應鏈的關鍵位置，吸引各大科技巨頭都齊聚一塊。今年，他們各自帶來哪些亮點？將如何引領這波風潮？ <br /> <br /> <br />本集重點： <br /> <br />1.史上規模最大！2024 Computex夯什麼？ <br />2. ...

# %%
podcast_feed["entries"][0]["links"]
# Out:
# [{'rel': 'alternate',
#   'type': 'text/html',
#   'href': 'https://open.firstory.me/story/clx8udn3a002f01wcfc0i880r'},
#  {'length': '25003476',
#   'type': 'audio/mpeg',
#   'href': 'https://chrt.fm/track/AD8A17/m.cdn.firstory.me/track/ckkqnneka7mxc0866j53j5ljw/clx8udn3a002f01wcfc0i880r/https%3A%2F%2Fd3mww1g1pfq2pt.cloudfront.net%2FRecord%2Fckkqnneka7mxc0866j53j5ljw%2Fclx8udn3a002g01wc9b5qfgho.mp3?v=1718016045177',
#   'rel': 'enclosure'}]

# %%
# 挑個檔案最小的那筆
episode_length = 30003476
episode_title = ''
for item in podcast_feed.entries[0:10]:
  for link in item.links:
    if (link['type'] == 'audio/mpeg'):
      if int(link.length) < episode_length:
        episode_url = link.href
        episode_length = int(link.length)
        episode_title = item.title
        print(episode_title, episode_length)
          


 # -O = output 成特定檔案名
# Out:
# 記者茶水間118.史上最盛大的Computex！黃仁勳、蘇姿丰說了什麼AI關鍵字？ 25003476
# 記者茶水間117.台灣又有新航空！沅星航空創辦人專訪幕後：有錢就是任性嗎？ 18629433

# %%
episode_url
# Out:
# 'https://chrt.fm/track/AD8A17/m.cdn.firstory.me/track/ckkqnneka7mxc0866j53j5ljw/clwz3ivz729fr01uk1wh06zms/https%3A%2F%2Fd3mww1g1pfq2pt.cloudfront.net%2FRecord%2Fckkqnneka7mxc0866j53j5ljw%2Fclwz3ivz729fs01uk9mb7f40e.mp3?v=1717426738353'

# %%
import requests

def download_audio(url, save_path):
    response = requests.get(url)
    with open(save_path, 'wb') as file:
        file.write(response.content)
    print(f"Audio downloaded successfully and saved to {save_path}")


episode_url = episode_url  # 替換為實際的音訊URL
save_path = "./data/podcast_episode.mp3"
download_audio(episode_url, save_path)


# 你也可以使用 linux 指令下載
# !wget -O 'podcast_episode.mp3' {episode_url}
# Out:
# Audio downloaded successfully and saved to ./data/podcast_episode.mp3

# %% [markdown]
# ## Whisper API
#
# https://platform.openai.com/docs/api-reference/audio
#
# * 上傳的檔案大小限制是 25 MB (如果超過，可以換別的 podcast 看看)
# * 格式支援 mp3, mp4, mpeg, mpga, m4a, wav, webm
#
# ![image.png](attachment:image.png)

# %%
data = { "model": "whisper-1", "prompt": "Chinese Mandarin Taiwanese including punctuation" } # whisper 也可以有 prompt 指示
f = open('./data/podcast_episode.mp3', 'rb')
files = [("file", ("podcast_episode.mp3", f, "application/octet-stream"))]

headers = { "Authorization": f'Bearer {openai_api_key}' } # 不需要加 "Content-Type": "multipart/form-data" 我猜 request libray 幫你加了
response = requests.post('https://api.openai.com/v1/audio/transcriptions', 
                         headers = headers, 
                         data = data, 
                         files = files )

# 需要數分鐘來跑
podcast_transcript = response.text
pp(podcast_transcript)
# Out:
# ('{\n'
#  '  "text": "台灣又多一家航空公司了 但跟一般瞄準出國旅遊的公司不一樣 原興航空把客群鎖定在私人包機 究竟他要怎麼經營呢? 在台灣有市場嗎? '
#  '今天我們就一起來認識一下這家新公司 歡迎回來本週的記者茶水間 那我們首先歡迎數位時代的記者 芷源 哈囉 我是芷源 好 '
#  '那在節目開始之前我們要先跟大家工商一下 就是數位時代六月號的雜誌已經出刊囉 這次的主題是引領台灣破浪的創業家們 那我們在封面故事裡面訪問了四位創業家 '
#  '之後也會推出相關的微電影還有一系列的活動 那歡迎大家先追蹤數位時代的臉書 IG 或者是官方LINE帳號 都可以獲得第一手資訊喔 那如果你是品牌的乾爹乾媽 '
#  '想要將你的產品分享給更多數位時代的優質聽眾 也歡迎把相關的資訊寄到我們資訊欄中的email喔 嗯 沒錯 好 那工商時間結束 '
#  '開頭呢已經簡單的介紹了一下今天的主題 就是之前討論度很高的新成立的原興航空 那我覺得大家應該都對這一間公司很好奇 因為就欸 成立了一個新的航空公司 '
#  '可是看起來他的服務的市場跟我們大家一般的想像 就是那種出國玩啊這種好像不太一樣 那子緣可以先簡單幫我們介紹一下這家公司 嗯 因為像剛剛講的 '
#  '就是他們公司其實要瞄準的就是私人包機服務 那我先講一下我們普遍現在有的私人包機模式 就是我們想像說欸有錢人可能就買一架飛機 那不管是怎麼樣有錢的人 '
#  '他的飛機就是要掛在一家航空公司底下 就是所謂的托機代管 擁有一架私人飛機的成本其實比想像中還要高 就是你買一台飛機 即便是二手飛機就是飛了可能八年十年了 '
#  '那大概也至少需要兩千萬美元 就是換算大概是六億 對六億台幣 但是這個只是買 買完之後你的託管費用 託管就是包含你可能維修啊 或是放在那邊就是保養什麼的 '
#  '就是也要買車位啊 對對對你一架飛機光是停在人家的停機坪上 你都不要飛 那一年的維修費就要百萬幾甲 可能大概是一百二十萬美元左右 平均啦大概初戀的算 '
#  '那就是新台幣大概三千多萬 所以托機代管才是這些私人包機公司 他們真正要賺的錢 就是每年的那個維修的這些錢 所以像這一間就是說 '
#  '遠新航空他們瞄準的也是這個業務嗎 就是其中一部分啦 就是他瞄準的是這個托機代管這一件事情嗎 對他們其實要做的是托機代管 但會比較不一樣就是說 '
#  '欸以前有那他們為什麼要做 就以前的市場是說 台灣可能算是一個相對比較封閉的市場 我們其實聽過台灣有錢人可能就是 真的是金字塔頂端一趴的那些有錢人 '
#  '中信金啊 其實那些人我們都知道是誰 對大概可以猜得到就是有錢人 感覺人數也不多對不對 大概八九十個 我覺得是可以數得出來 那他們一人最多擁有三架好不好 '
#  '那其實也差不多三十而已其實也不多吧 對就是說欸他們有飛機 但是他們可能也不太會計較說 喔那些什麼託管費用 那個真的不是他們需要在乎的錢 '
#  '但是還有一群人可能是金字塔再往下挪一點點的 這些人的話他們可能是前十%好了 那一撮有錢人 他可能就比較不願意花這個錢了 因為我買飛機 '
#  '但是我一年可能就飛大概一百個小時 或是再多一點點 但多數時間你還是停在那邊 就是在那邊燒錢這樣子 那我不如就直接去租飛機嘛 對他來說是不划算 '
#  '對我買飛機實在是不太划算 那我不如就去租飛機 可是又回到一個問題就是 那台灣又很難租到私人飛機 因為本身在做這種飛機然後做租賃服務的 依現在來看的話 '
#  '台灣可能就只有兩架飛機是有單座這樣 就是這兩架就是屬於航空公司本身在做這件事情 喔所以說假設我是這一群就是 有錢可是卻沒有私人飛機的人 然後我想要租的話 '
#  '目前的選項是全台灣只有兩架飛機嗎 是這個意思 對就是我可能 喔那真的很少 對我不太捨得能花錢去買這個飛機 那我想要享受呢 可是我比較沒有這個需求 '
#  '對可是我可能想要偶爾享受一下私人包機 我又租不太到 所以就變成說這個也是今天訪談這樣聽下來 可能原型航空創辦人他本身也算是 可能那幾趴的有錢人 '
#  '對他可能也遇到這樣的 發現這樣的市場痛點 就是他本身他自己去學開飛機的 然後他想要買一台飛機 然後買一台飛機的時候又遇到這些狀況 '
#  '然後說不如開一間航空公司 聽起來是蠻有錢人的 有錢人任性嗎 但是這個大概就是他可能成立的這個初衷 那他想要服務的對象大概就是 '
#  '你可能願意花成本可是不願意承擔 原本我們想設定的那個那麼高額成本 但是你又希望能夠享受私人飛機服務的這群有錢人 那實際上他是要怎麼就是去進行呢 '
#  '前半段的商業模式大概跟 傳統的那些私人包機服務大概類似 就是我一樣讓一部分的有錢人來買飛機 那由原型航空這邊來負責維護跟管理 我一樣收託管費 '
#  '但是在飛機沒有使用 他們是設定說飛機一年大概就是飛600個小時 那這些買飛機的人飛機擁有者 我大概就是用100個小時 那剩下500個小時呢 '
#  '等於說他把剩下這500個小時拿來賣嗎 是這樣嗎 對 就是 拿來租啦 租 有點像共享 然後租給其他的 共享飛機 共享飛機平台 所以他們一直在強調共享平台 '
#  '其實我一開始對共享平台 我有點不太能理解到底要怎麼運作 但我今天聽完他大概意思就是說 我開放租賃給其他有錢人 那他們自己啦 因為現在還沒有實際運作 '
#  '但他們現在算下來是覺得說 這500個小時的租賃費 如果算下來會比託管費再高一點點 應該不只一點點 那個錢我現在已經有點金錢價值觀混亂了 那應該就是多一些 '
#  '然後這樣子回來的話 你還可以再多賺一點 就是你本身飛機持有者 因為他們多賺那個利潤 他們是跟飛機持有者一起去分潤 會分的 大概他的立場是這樣子 '
#  '然後這樣的終極目標就是說 那這樣飛機擁有者你可以降低你的維護成本 你還可以賺取額外的費用 那整個私人包機的市場 其實你多了就是 '
#  '你就是抬高那個飛機數量把市場做大 那他的理想啦 這個我不太能去評論是因為 我不太知道他真實營運上能不能符合他的期待 因為實際上他們還沒開始營運嘛 對 '
#  '所以他理想上是 降低飛機持有者的成本 然後擴大市場讓更多人去享受他的私人包機服務 大概是這樣 就他希望更多有錢人來買飛機跟來租飛機 大概是這樣嗎 '
#  '我聽下來目前應該更希望有更多人 可以去使用那剩下的五百小時 因為我說實在 我真的還是覺得台灣能去 有意去買飛機的人 我必須平衡一下報導 '
#  '就是我自己還是覺得有點 我保留這個態度 不會覺得到那麼多這樣子 對 我覺得反而是那個 飛機剩下五百小時拿來租賃這件事情 看起來比較像是他們主打 '
#  '或是我覺得會比較多人去使用的服務嗎 相對啦 相對比較多 會更去詢問的一個方案吧 不管是為了旅遊目的也好 或是商務 就是有一些可能要到日本熊本去開一些 '
#  '產業的 或是往東南亞這些 你可能會大老闆啦 省時間嘛 時間就是金錢 對他們來講 那可能就會需要這樣的私人包機服務 會不會有一種就是 譬如說你今天是富翔 '
#  '你的女兒要辦派對 Oh my god 包機然後去一個 譬如說什麼日本石垣島 然後辦一個生日派對什麼這種 四十分鐘就可以到欸 這種就是一次性的事情啊 '
#  '就是你這一年或是可能近五年 譬如說他是慶祝三十歲好了 然後下一次大慶祝可能是三十五歲 那這五年內他就不會用到 不太可能沒有這個機會 '
#  '他就可能需要這種一次性 對 有沒有富翔想要 有沒有可能 我們不要幫他打廣告 他好像是真的 我覺得有機會啦 就是留市場 我想像是這樣 對好 '
#  '那我們剛剛有講到一個就是 就是他的其中一個商業模式嘛 那我自己覺得這個還蠻 蠻創新的還蠻酷 因為這個 說實在這真的就是 貧窮現實我們想像是這樣嗎 '
#  '就是我們沒有接觸過這個世界 就是比較 不知道欸原來還有這樣子的商業模式 那另外一種我覺得 我們可能稍微比較可以想像 就是跟我剛剛講的有點類似 就是 '
#  '他是不是也有做一些類似旅遊的部分 就是我今天 就是為了想要 慶祝某一件事情 然後我可能存了錢 然後想要來一個奢華豪華的旅行 他是不是也有做這樣子的服務 '
#  '好 奢華旅遊也是我 其實也是生活不太會碰到的 我也是去問了 有一些有去測訪一些旅行社 然後說喔原來旅行社有分喔 就是 我們大眾旅遊的旅行社 '
#  '就是我們大眾旅遊 頂多就是高端 那還有分成一個是奢華旅遊 所以有些人可能會去奢華旅行社這邊 去問一下說 欸有沒有私人包機服務 那這樣子其實就可以對接到 '
#  '原型航空或是其他類似的私人包機服務 喔 對 我覺得這個好像 聽起來像是一個比較 也還蠻有商機的市場 因為 就是可能有錢人他追求的就是 私人 就是安靜 '
#  '只有我自己人 然後快 然後可以到一些可能 不是那種大眾旅遊地 就譬如說滑雪 滑雪勝地可能會去一些 大家比較常聽的 那他可能要去一些人比較少的 '
#  '然後旅遊體驗會比較好的地方 有錢人就追求一個 安靜 而且他會想要追求不一樣的 對 跟別人不一樣 對 這也是問來的 因為我也不知道 哈哈 我們不是有錢人 '
#  '對 大概訪了一下 大概 具體是這樣 對 所以這個部分應該也是他們一個 還蠻重要的市場這樣子 那其實我們之前就是 原先航空成立的消息出來之後 '
#  '我們又整理一個報導嘛 那也有稍微分析了一下他的 商業模式 那剛剛子綿有幫我們就是 再更解釋得更清楚 可是我覺得 蠻多讀者 或是像我自己看完這個文章之後 '
#  '的也會有一個 疑問的地方 就是這個市場真的夠大嗎 就像我們剛剛前面講的其實 真正的有錢人就是 在台灣啦 就是 因為台灣人口比較少嘛 有錢人就更少 '
#  '所以真正可以affordable 這個服務的人 可能真的很少 那就算他一次單價很高 但是我覺得應該也比不了 比如說 像就是以 也是很新成立的航空公司 '
#  '就新宇 就是這種大眾客機的規模 跟就是旅客的數量 相較起來應該是差蠻多的 那他這樣的商業模式 真的有辦法維持下去嗎 或者是 我覺得大家會很好奇說 '
#  '光靠這些人真的有辦法 就是撐起一個航空公司嗎 我先講說 他們評估的潛在市場規模 確實客源在哪裡會是 我們這樣聽下來的話 會覺得是他們的挑戰 '
#  '就他們下一個挑戰就是 我到底我的客人 能夠一直在買單的 或是能夠維持穩定獲利的 那個基礎在哪裡 那如果以整個比較 商務飛機報告來去講的話 就是 '
#  '他們是評論說 假設你一個國家的GDP 達到一兆美元 你就可以擁有 250架商務機的一個勢力 那如果以台灣的狀況來講的話 台灣大概GDP2022年 '
#  '是21兆泰幣 那台灣就大概可以擁有 180架商務包機的勢力 那我目前市場上 大概有18到19架 包含有錢人的那幾架私人飛機 所以其實他覺得說 欸 '
#  '還有10倍的成長空間 喔 所以他用這樣子的數字來看 這是這家公司去評論 他們自己的市場情形 那如果以更客觀的立場來講的話 確實他們要做大這個市場 '
#  '就是兩步嘛 一個就是要跟一頁合作了 一個就是我們剛剛講的旅行社 你想像如果你要旅遊的話 第一步應該還是找旅行社 對 比較難直接說 喔 就是私人包機 '
#  '就如果像這種 你可能是要去一些特別一點的地方 或是想要那種很 很私人的行程 行程還有什麼的 對 很酷那種什麼 飛去看極光那種 對 這種比較特別的行程的話 '
#  '先找到旅行社 然後他可能再跟你說 欸 那你私人包機要不要 這是一個路徑 所以我覺得他們跟一頁合作 那第二步的話我是覺得說 喔 他們有講到 '
#  '就是這個市場一定不可能只局限在台灣 喔 就是我一定不可能只服務台灣的這群有錢人 嗯 因為基數還是有限 那海外周遭幾個鄰近地區 應該是他要關注的市場 '
#  '那他們有說他們想要做的是 私人包機的維修中心 喔 有點像是A 還有另外一個 對 以前的飛機可能就是飛到一個點 然後做維修 然後再起飛 那個時間可能就是 '
#  '其實不會像想像中那麼長 嗯 那以前這個維修中心的 有點類似轉運的一個地方 大概是集中在香港 喔 對 那因為香港最近幾年給 有點地緣政治的關係 '
#  '所以這個業務量轉到新加坡 嗯 那他們是覺得說 原型航空覺得說 這個業務量應該要留在台灣 因為台灣 對 台灣其實地理位置蠻好的 對對對 '
#  '然後到亞洲附近幾個國家的 平均航程大概是175分鐘 大概是 3小時 喔 差不多 對對對 那他覺得說台灣 有點欠缺利用這個優勢啦 喔 '
#  '他們想要把這個業務量做起來 但這個都還是未知數 因為還在 還在起步 就是現在這個比較像是他們的想像這樣子 嗯 就是除了做旅遊 也應該要做其他的 '
#  '利用私人包機這個為基礎來去做其他業務 嗯 算是他們要拓展的幾個面向 這也是我一開始去訪之前 我沒有 我有看過別家的報導 但是我是說如果只聽到私人包機 '
#  '我沒有辦法想像到說 欸 他想要做的業務量那麼廣 對 其實他涉及涵蓋的範圍就是還蠻廣的 還蠻多東西可以做的這樣 尤其是剛講到香港這個 '
#  '因為就是他們現在香港的那個維修的量能 可能轉到新加坡嘛 但實際上香港跟新加坡的地理位置還是差蠻遠的 大概也是要飛4個小時左右才會到 '
#  '所以我覺得台灣就是瞄準香港 就是留室的這些市場其實還不錯 是一個還不錯的選項 因為就很近 相對比較近這樣子 嗯 但確實 我們地理位置就是很有優勢這樣 '
#  '確實還是要有錢先做一間航空公司 不然 對啊 他們除了旅遊跟剛剛講的維運 其實我有多問一點 就是可能未來也有機會做寵物啊 或是醫療 '
#  '不過我覺得這是後面的事啦 哦 就是醫療包機什麼 這可能要到 這也是要跟很多醫業去做合作 那這可能到 保守估計應該三年吧 因為他們其實現在還沒有開始營業 '
#  '嗯嗯 就是航空公司要成立之前 都需要經過民航局這邊的審查許可 大概需要五階段 那他們現在是四階段 哦 他們也有說就是大概到後期 '
#  '就是辦公室也會移到松山機場內部 嗯 就是這還在審查期間 那還在審查中 那可快可慢 就是說最快是六月底可以開張 哦 但這個時間也不好說 嗯 '
#  '好我們之後也可以期待一下 那最後我覺得 大家應該也會很好奇說 這一家公司原型航空的創辦人 那他叫做盧浩志 那我覺得大家又很好奇他的背景是什麼 今天是 '
#  '今天有訪問到他對不對 對一開始出來的時候其實大家是 問號 嗯 有點問號 然後大家也很困惑 欸這是誰 怎麼會有一個有錢人 前面是不是才一個有錢人出來 '
#  '經營航空公司 哈哈哈哈 然後怎麼又 對啊所以對他的背景 而且查的時候google確實資料量蠻少的 只知道他是台商 嗯 那今天確認大概就是 '
#  '今天做的公司就是櫻華置 是一家做連接器的公司 那主要的業務都是集中在中國那邊 哦 那說富二代也對 但其實他就是他跟他父親 就我們訪談了解 '
#  '大概就是1997年那時候就已經在 中國深圳那邊就是 打拼事業吧 所以我會定義嚴格來講應該是半個富二代啦 因為他也是參與了 一開始的事業 '
#  '所以以後打拼就對了 對對對也不能是 就是對啊 好 這家公司應該算是他的再創業之作嗎 或是我覺得是 也算是第一次創業啦 就是他自己的公司 嗯那 '
#  '我是真的覺得有錢人的邏輯是真的蠻 直觀的 呃他去學飛 就在疫情期間 欸他有分享他說 那個 虎航的董事長 有跟大家在同一個那個 同一個學校 '
#  '就是他們認識這樣子 我覺得蠻好玩的 然後虎航的董事長現在 有在他們那邊當教官 喔真的喔 好酷好酷 對反正就是他就說 欸疫情期間留在台灣 啊就去學飛 '
#  '學飛之後就想要有一台自己的飛機 然後買的時候開始思考 欸划算嗎 欸不划算的話租不太到 所以就乾脆來開一間航空公司 所以就是他等於他自己親身經歷了這個 '
#  '我們剛剛前面講那種 有錢人的困擾之後 然後覺得說 啊那不然我開一間公司 來解決這件事情好了 我覺得好像有點簡單暴力 但我是覺得 '
#  '嗯其實講直接好像就是差不多這個意思 但蠻好玩的 我是真的覺得這個服務聽起來 至少我訪談沒有遇過這樣的 啊反正就有錢嘛 張國威也是有這樣講 '
#  '喔可以直接點名嗎 對不起 因為有人問他說什麼 大家都說你都是靠你爸爸 他也不避諱啊 對張國威就說對啊 我就覺得欸確實啊 其實這樣蠻好的 蠻直接的 '
#  '也蠻好的啊 反正就是也是他們也是 創業然後做自己想做的事情 我覺得也蠻酷 而且他這個商業模式 我自己覺得還蠻值得期待的 因為這是一個大家比較少見的 '
#  '嗯應該沒什麼競爭對手吧 誰要跟誰要去競爭 對啊可能就只有國外的 國外的公司吧 台灣可能不多 就是國內現有的那幾家 嗯航空公司 '
#  '嗯好那這個原型航空之後的發展呢 或是他們之後開幕的一些策略啊 或者是有更多不同的數字 初衛史在這邊呢都會繼續追蹤報導 那希望大家也可以鎖定我們的網站 '
#  '那今天呢非常感謝幾位的分享 如果你喜歡這一集的內容 別忘了在Apple Podcast給我們五星好評 或者是留言告訴我們你們的想法 那我們就下週再見囉 '
#  '掰掰 掰掰"\n'
#  '}')

# %%
podcast_transcript
# Out:
# '{\n  "text": "台灣又多一家航空公司了 但跟一般瞄準出國旅遊的公司不一樣 原興航空把客群鎖定在私人包機 究竟他要怎麼經營呢? 在台灣有市場嗎? 今天我們就一起來認識一下這家新公司 歡迎回來本週的記者茶水間 那我們首先歡迎數位時代的記者 芷源 哈囉 我是芷源 好 那在節目開始之前我們要先跟大家工商一下 就是數位時代六月號的雜誌已經出刊囉 這次的主題是引領台灣破浪的創業家們 那我們在封面故事裡面訪問了四位創業家 之後也會推出相關的微電影還有一系列的活動 那歡迎大家先追蹤數位時代的臉書 IG 或者是官方LINE帳號 都可以獲得第一手資訊喔 那如果你是品牌的乾爹乾媽 想要將你的產品分享給更多數位時代的優質聽眾 也歡迎把相關的資訊寄到我們資訊欄中的email喔 嗯 沒錯 好 那工商時間結束 開頭呢已經簡單的介紹了一下今天的主題 就是之前討論度很高的新成立的原興航空 那我覺得大家應該都對這一間公司很好奇 因為就欸 成立了一個新的航空公司 可是看起來他的服務的市場跟我們大家一般的想像 就是那種出國玩啊這種好像不太一樣 那子緣可以先簡單幫我們介紹一下這家公司 嗯 因為像剛剛講的 就是他們公司其實要瞄準的就是私人包機服務 那我先講一下我們普遍現在有的私人包機模式 就是我們想像說欸有錢人可能就買一架飛機 那不管是怎麼樣有錢的人 他的飛機就是要掛在一家航空公司底下 就是所謂的托機代管 擁有一架私人飛機的成本其實比想像中還要高 就是你買一台飛機 即便是二手飛機就是飛了可能八年十年了 那大概也至少需要兩千萬美元 就是換算大概是六億 對六億台幣 但是這個只是買 買完之後你的託管費用 託管就是包含你可能維修啊 或是放在那邊就是保養什麼的 就是也要買車位啊 對對對你一架飛機光是停在人家的停機坪上 你都不要飛 那一年的維修費就要百萬幾甲 可能大概是一百二十萬美元左右 平均啦大概初戀的算 那就是新台幣大概三千多萬 所以托機代管才是這些私人包機公司 他們真正要賺的錢 就是每年的那個維修的這些錢 所以像這一間就是說 遠新航空他們瞄準的也是這個業務嗎 就是其中一部分啦 就是他瞄準的是這個托機代管這一件事情嗎 對他們其實要做的是托機代管 但會比較不一樣就是說 欸以前有那他們為什麼要做 就以前的市場是說 台灣可能算是一個相對比較封閉的市場 我們其實聽過台灣有錢人可能就是 真的是金字塔頂端一趴的那些有錢人 中信金啊 其實那些人我們都知道是誰 對大概可以猜得到就是有錢人 感覺人數也不多對不對 大概八九十個 我覺得是可以數得出來 那他們一人最多擁有三架好不好 那其實也差不多三十而已其實也不多吧 對就是說欸他們有飛機 但是他們可能也不太會計較說 喔那些什麼託管費用 那個真的不是他們需要在乎的錢 但是還有一群人可能是金字塔再往下挪一點點的 這些人的話他們可能是前十%好了 那一撮有錢人 他可能就比較不願意花這個錢了 因為我買飛機 但是我一年可能就飛大概一百個小時 或是再多一點點 但多數時間你還是停在那邊 就是在那邊燒錢這樣子 那我不如就直接去租飛機嘛 對他來說是不划算 對我買飛機實在是不太划算 那我不如就去租飛機 可是又回到一個問題就是 那台灣又很難租到私人飛機 因為本身在做這種飛機然後做租賃服務的 依現在來看的話 台灣可能就只有兩架飛機是有單座這樣 就是這兩架就是屬於航空公司本身在做這件事情 喔所以說假設我是這一群就是 有錢可是卻沒有私人飛機的人 然後我想要租的話 目前的選項是全台灣只有兩架飛機嗎 是這個意思 對就是我可能 喔那真的很少 對我不太捨得能花錢去買這個飛機 那我想要享受呢 可是我比較沒有這個需求 對可是我可能想要偶爾享受一下私人包機 我又租不太到 所以就變成說這個也是今天訪談這樣聽下來 可能原型航空創辦人他本身也算是 可能那幾趴的有錢人 對他可能也遇到這樣的 發現這樣的市場痛點 就是他本身他自己去學開飛機的 然後他想要買一台飛機 然後買一台飛機的時候又遇到這些狀況 然後說不如開一間航空公司 聽起來是蠻有錢人的 有錢人任性嗎 但是這個大概就是他可能成立的這個初衷 那他想要服務的對象大概就是 你可能願意花成本可是不願意承擔 原本我們想設定的那個那麼高額成本 但是你又希望能夠享受私人飛機服務的這群有錢人 那實際上他是要怎麼就是去進行呢 前半段的商業模式大概跟 傳統的那些私人包機服務大概類似 就是我一樣讓一部分的有錢人來買飛機 那由原型航空這邊來負責維護跟管理 我一樣收託管費 但是在飛機沒有使用 他們是設定說飛機一年大概就是飛600個小時 那這些買飛機的人飛機擁有者 我大概就是用100個小時 那剩下500個小時呢 等於說他把剩下這500個小時拿來賣嗎 是這樣嗎 對 就是 拿來租啦 租 有點像共享 然後租給其他的 共享飛機 共享飛機平台 所以他們一直在強調共享平台 其實我一開始對共享平台 我有點不太能理解到底要怎麼運作 但我今天聽完他大概意思就是說 我開放租賃給其他有錢人 那他們自己啦 因為現在還沒有實際運作 但他們現在算下來是覺得說 這500個小時的租賃費 如果算下來會比託管費再高一點點 應該不只一點點 那個錢我現在已經有點金錢價值觀混亂了 那應該就是多一些 然後這樣子回來的話 你還可以再多賺一點 就是你本身飛機持有者 因為他們多賺那個利潤 他們是跟飛機持有者一起去分潤 會分的 大概他的立場是這樣子 然後這樣的終極目標就是說 那這樣飛機擁有者你可以降低你的維護成本 你還可以賺取額外的費用 那整個私人包機的市場 其實你多了就是 你就是抬高那個飛機數量把市場做大 那他的理想啦 這個我不太能去評論是因為 我不太知道他真實營運上能不能符合他的期待 因為實際上他們還沒開始營運嘛 對 所以他理想上是 降低飛機持有者的成本 然後擴大市場讓更多人去享受他的私人包機服務 大概是這樣 就他希望更多有錢人來買飛機跟來租飛機 大概是這樣嗎 我聽下來目前應該更希望有更多人 可以去使用那剩下的五百小時 因為我說實在 我真的還是覺得台灣能去 有意去買飛機的人 我必須平衡一下報導 就是我自己還是覺得有點 我保留這個態度 不會覺得到那麼多這樣子 對 我覺得反而是那個 飛機剩下五百小時拿來租賃這件事情 看起來比較像是他們主打 或是我覺得會比較多人去使用的服務嗎 相對啦 相對比較多 會更去詢問的一個方案吧 不管是為了旅遊目的也好 或是商務 就是有一些可能要到日本熊本去開一些 產業的 或是往東南亞這些 你可能會大老闆啦 省時間嘛 時間就是金錢 對他們來講 那可能就會需要這樣的私人包機服務 會不會有一種就是 譬如說你今天是富翔 你的女兒要辦派對 Oh my god 包機然後去一個 譬如說什麼日本石垣島 然後辦一個生日派對什麼這種 四十分鐘就可以到欸 這種就是一次性的事情啊 就是你這一年或是可能近五年 譬如說他是慶祝三十歲好了 然後下一次大慶祝可能是三十五歲 那這五年內他就不會用到 不太可能沒有這個機會 他就可能需要這種一次性 對 有沒有富翔想要 有沒有可能 我們不要幫他打廣告 他好像是真的 我覺得有機會啦 就是留市場 我想像是這樣 對好 那我們剛剛有講到一個就是 就是他的其中一個商業模式嘛 那我自己覺得這個還蠻 蠻創新的還蠻酷 因為這個 說實在這真的就是 貧窮現實我們想像是這樣嗎 就是我們沒有接觸過這個世界 就是比較 不知道欸原來還有這樣子的商業模式 那另外一種我覺得 我們可能稍微比較可以想像 就是跟我剛剛講的有點類似 就是 他是不是也有做一些類似旅遊的部分 就是我今天 就是為了想要 慶祝某一件事情 然後我可能存了錢 然後想要來一個奢華豪華的旅行 他是不是也有做這樣子的服務 好 奢華旅遊也是我 其實也是生活不太會碰到的 我也是去問了 有一些有去測訪一些旅行社 然後說喔原來旅行社有分喔 就是 我們大眾旅遊的旅行社 就是我們大眾旅遊 頂多就是高端 那還有分成一個是奢華旅遊 所以有些人可能會去奢華旅行社這邊 去問一下說 欸有沒有私人包機服務 那這樣子其實就可以對接到 原型航空或是其他類似的私人包機服務 喔 對 我覺得這個好像 聽起來像是一個比較 也還蠻有商機的市場 因為 就是可能有錢人他追求的就是 私人 就是安靜 只有我自己人 然後快 然後可以到一些可能 不是那種大眾旅遊地 就譬如說滑雪 滑雪勝地可能會去一些 大家比較常聽的 那他可能要去一些人比較少的 然後旅遊體驗會比較好的地方 有錢人就追求一個 安靜 而且他會想要追求不一樣的 對 跟別人不一樣 對 這也是問來的 因為我也不知道 哈哈 我們不是有錢人 對 大概訪了一下 大概 具體是這樣 對 所以這個部分應該也是他們一個 還蠻重要的市場這樣子 那其實我們之前就是 原先航空成立的消息出來之後 我們又整理一個報導嘛 那也有稍微分析了一下他的 商業模式 那剛剛子綿有幫我們就是 再更解釋得更清楚 可是我覺得 蠻多讀者 或是像我自己看完這個文章之後 的也會有一個 疑問的地方 就是這個市場真的夠大嗎 就像我們剛剛前面講的其實 真正的有錢人就是 在台灣啦 就是 因為台灣人口比較少嘛 有錢人就更少 所以真正可以affordable 這個服務的人 可能真的很少 那就算他一次單價很高 但是我覺得應該也比不了 比如說 像就是以 也是很新成立的航空公司 就新宇 就是這種大眾客機的規模 跟就是旅客的數量 相較起來應該是差蠻多的 那他這樣的商業模式 真的有辦法維持下去嗎 或者是 我覺得大家會很好奇說 光靠這些人真的有辦法 就是撐起一個航空公司嗎 我先講說 他們評估的潛在市場規模 確實客源在哪裡會是 我們這樣聽下來的話 會覺得是他們的挑戰 就他們下一個挑戰就是 我到底我的客人 能夠一直在買單的 或是能夠維持穩定獲 ...

# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")
num_tokens = len(encoding.encode(podcast_transcript))
print(num_tokens)
# Out:
# 9096

# %% [markdown]
# ## 長文本摘要
#
# ### 方法一: zero shot

# %%
messages = [
    {
        "role": "system",
        "content": "(zh-tw) 你是一個擅長語言理解和摘要的高度熟練 AI。我希望你能閱讀以下文字並將其摘要成一個簡潔的段落。請盡量保留最重要的要點，提供一個連貫且易讀的摘要，使人能夠在不需要閱讀全文的情況下理解討論的主要內容。請避免不必要的細節或偏題的部分。"
    },
    {
        "role": "user",
        "content": podcast_transcript
    }
]

abstract_summary = get_completion(messages)
pp(abstract_summary)
# Out:
# '原興航空是台灣一家新興航空公司，專注於私人包機服務，提供托機代管業務。在台灣市場，有錢人擁有私人飛機，但維護成本高，原興航空的商業模式是讓飛機擁有者分享飛行時間，以租賃方式賺取額外收入。公司計畫擴展至旅遊、奢華旅遊等領域，並考慮成立私人包機維修中心。創辦人盧浩志是台商，曾在中國打拼，現回台創業。公司目前在審查階段，預計六月底開張，並計畫與旅行社合作拓展市場。整體而言，原興航空的商業模式創新，面臨挑戰但也有潛力，值得關注。'

# %% [markdown]
# ### 方法二: zero shot 條列整理 點線大綱
#
# ### prompt 框架設計 - Executive Summary
#
# Introduction（引言）：<br>
# - 簡短介紹話題，說明背景和重要性。
#
# Key Points（關鍵點）：<br>
# - 列出時事評論的主要觀點，每個觀點用一兩句話概述。
# - 重點突出，易於快速閱讀。
#
# Implications（影響）：<br>
# - 分析該時事對業務、行業或市場的潛在影響。
# - 強調對公司戰略或決策的相關性。
#
# Recommendations（建議）：<br>
# - 根據評論內容，提出具體建議或行動步驟。
# - 簡明扼要，直接指出可行方案。
#
# Conclusion（結論）：<br>
# - 總結主要觀點和建議。
# - 簡潔有力，讓經理人能快速理解摘要的重點。

# %%
summarization_framwork = """

(zh-tw) 你是一個專精於將信息提煉成關鍵要點的高度熟練 AI。
根據以下文字，請識別並列出討論或提出的主要要點。這些應該是最重要的觀點、發現或主題，對於討論的本質至關重要。
你的目標是提供一個列表，讓人可以快速了解討論的內容。請確保你的回答符合Executive Summary框架，並且涵蓋了所有面向。

$$$ prompt 框架設計 - Executive Summary

Introduction（引言）：<br>
- 簡短介紹話題，說明背景和重要性。

Key Points（關鍵點）：<br>
- 列出時事評論的主要觀點，每個觀點用一兩句話概述。
- 重點突出，易於快速閱讀。

Implications（影響）：<br>
- 分析該時事對業務、行業或市場的潛在影響。
- 強調對公司戰略或決策的相關性。

Recommendations（建議）：<br>
- 根據評論內容，提出具體建議或行動步驟。
- 簡明扼要，直接指出可行方案。

Conclusion（結論）：<br>
- 總結主要觀點和建議。
- 簡潔有力，讓經理人能快速理解摘要的重點。

"""


messages = [
    {
    "role": "system",
    "content": summarization_framwork
    },
    {
        "role": "user",
        "content": podcast_transcript
    }
]

key_points = get_completion(messages, model = "gpt-4-turbo")
print(key_points)
# Out:
# ### Introduction
# 原興航空是一家新成立的台灣航空公司，專注於提供私人包機服務。此公司的商業模式與傳統面向大眾的航空服務不同，主要針對高端市場，提供更個性化和專屬的飛行體驗。
#
# ### Key Points
# 1. **市場定位與服務特色**：
#    - 原興航空主要提供私人包機和托機代管服務，針對的是需要高度隱私和靈活性的客戶群。
#    - 公司計劃利用共享經濟模式，讓飛機擁有者可以出租未使用的飛行時數，創造額外收益。
#
# 2. **市場潛力與挑戰**：
#    - 台灣的私人飛機市場相對封閉，但有潛在的成長空間。目前市場上私人飛機數量遠低於潛在需求。
#    - 原興航空面臨的挑戰包括擴大客源、與旅行社合作推廣私人飛行服務，以及可能的國際擴展。
#
# 3. **創辦人背景與動機**：
#    - 創辦人盧浩志是一位台商，擁有連接器製造業的背景。他因個人需求和市場缺口，決定創立原興航空。
#
# ### Implications
# - **對高端旅遊市場的影響**：原興航空的服務可能會改變台灣及周邊地區的高端旅遊市場，提供更多私人化的旅行選擇。
# - **對航空業的影響**：引入私人包機共享模式可能會為航空業帶來新的商業模式和收益來源。
#
# ### Recommendations
# 1. **市場教育與宣傳**：加強對潛在客戶的市場教育，明確傳達私人包機的優勢和可行性。
# 2. **建立合作夥伴關係**：與旅行社和企業建立合作，推廣私人飛機租賃服務。
# 3. **探索國際市場**：考慮擴展至東南亞等鄰近地區，利用台灣的地理優勢。
#
# ### Conclusion
# 原興航空的創立提供了一個新的高端旅遊選擇，其私人包機服務和共享經濟模式可能會對台灣及國際航空市場產生重要影響。公司需要有效地解決市場教育和客源擴展的挑戰，以實現其業務目標和增長潛力。
